# %% [markdown]
# # User Story B
# **Privacy Enhancing Data Generation and Evaluation**
#
# This demo will show how to generate and evaluate privacy-enhanced data using `PETsARD`.
#
# In this demonstration, you, as the user, already possess a data file locally, and `PETsARD` will assist you in loading that file and then generating a privacy-enhanced version of it.
#
# 本示範將展示如何使用 `PETsARD` 生成與評測隱私強化資料。
#
# 在這個示範中，您作為使用者，在本機上已經擁有一份資料檔案，而 `PETsARD` 將幫助您讀取該檔案、生成經隱私強化後的版本、最終評測。

# %% [markdown]
# ---
#
# ## Environment

# %%
import os
import pprint
import sys

import yaml


# Setting up the path to the PETsARD package
path_petsard = os.path.dirname(os.getcwd())
print(path_petsard)
sys.path.append(path_petsard)
# setting for pretty priny YAML
pp = pprint.PrettyPrinter(depth=3, sort_dicts=False)


from PETsARD import Executor
# Out:
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD

# %% [markdown]
# ---
#
# ## User Story B-1
# **Default Evaluating**
#
# Following User Story A, if users enable the "evaluate" step ,  the evaluation module will create a report covering default privacy risk and utility metrics.
#
# 根據用戶故事 A，如果使用者啟用了 "evaluate" 步驟，評估模組會產生涵蓋預設的隱私風險與效用指標的報告。

# %%
config_file = '../yaml/User Story B-1.yaml'

with open(config_file, 'r') as yaml_file:
    yaml_raw: dict = yaml.safe_load(yaml_file)
pp.pprint(yaml_raw)
# Out:
# {'Loader': {'adult': {'filepath': 'benchmark/adult-income.csv',
#                       'na_values': {...}}},
#  'Preprocessor': {'demo': {'method': 'default'}},
#  'Synthesizer': {'demo': {'method': 'default'}},
#  'Postprocessor': {'demo': {'method': 'default'}},
#  'Evaluator': {'demo': {'method': 'default'}},
#  'Reporter': {'save_data': {'method': 'save_data',
#                             'output': 'User Story B-1',
#                             'source': 'Postprocessor'},
#               'save_report_global': {'method': 'save_report',
#                                      'output': 'User Story B-1',
#                                      'eval': 'demo',
#                                      'granularity': 'global'}}}

# %%
exec = Executor(config=config_file)
exec.run()
# Out:
# Now is Loader with adult...
# Now is Preprocessor with demo...
# [I 20241108 10:30:38] MediatorMissing is created.
# [I 20241108 10:30:38] MediatorOutlier is created.
# [I 20241108 10:30:38] MediatorEncoder is created.
# [I 20241108 10:30:38] missing fitting done.
# [I 20241108 10:30:38] <PETsARD.processor.mediator.MediatorMissing object at 0x323c7ea10> fitting done.
# [I 20241108 10:30:38] outlier fitting done.
# [I 20241108 10:30:38] <PETsARD.processor.mediator.MediatorOutlier object at 0x3255047f0> fitting done.
# [I 20241108 10:30:38] encoder fitting done.
# [I 20241108 10:30:38] <PETsARD.processor.mediator.MediatorEncoder object at 0x325504820> fitting done.
# [I 20241108 10:30:38] scaler fitting done.
# [I 20241108 10:30:38] missing transformation done.
# [I 20241108 10:30:38] <PETsARD.processor.mediator.MediatorMissing object at 0x323c7ea10> transformation done.
# [I 20241108 10:30:38] outlier transformation done.
# [I 20241108 10:30:38] <PETsARD.processor.mediator.MediatorOutlier object at 0x3255047f0> transformation done.
# [I 20241108 10:30:39] encoder transformation done.
# [I 20241108 10:30:39] <PETsARD.processor.mediator.MediatorEncoder object at 0x325504820> transformation done.
# [I 20241108 10:30:39] scaler transformation done.
# Now is Synthesizer with demo...
# [I 20241108 10:30:39] {'EVENT': 'Instance', 'TIMESTAMP': datetime.datetime(2024, 11, 8, 10, 30, 39, 74494), 'SYNTHESIZER CLASS NAME': 'GaussianCopulaSynthesizer', 'SYNTHESIZER ID': 'GaussianCopulaSynthesizer_1.17.1_426eaa16f120441093dd06129c8247d5'}
# Synthesizer (SDV): Fitting GaussianCopula.
# [I 20241108 10:30:39] {'EVENT': 'Fit', 'TIMESTAMP': datetime.datetime(2024, 11, 8, 10, 30, 39, 74702), 'SYNTHESIZER CLASS NAME': 'GaussianCopulaSynthesizer', 'SYNTHESIZER ID': 'GaussianCopulaSynthesizer_1.17.1_426eaa16f120441093dd06129c8247d5', 'TOTAL NUMBER OF TABLES': 1, 'TOTAL NUMBER OF ROWS': 26933, 'TOTAL NUMBER OF COLUMNS': 15}
# [I 20241108 10:30:39] Fitting table  metadata
# [I 20241108 10:30:39] Fitting formatters for table
# [I 20241108 10:30:39] No rounding scheme detected for column 'age'. Data will not be rounded.
# [I 20241108 10:30:39] No rounding scheme detected for column 'workclass'. Data will not be rounded.
# [I 20241108 10:30:39] No rounding scheme detected for column 'fnlwgt'. Data will not be rounded.
# [I 20241108 10:30:39] No rounding scheme detected for column 'education'. Data will not be rounded.
# [I 20241108 10:30:39] No rounding scheme detected for column 'educational-num'. Data will not be rounded.
# [I 20241108 10:30:39] No rounding scheme detected for column 'marital-status'. Data will not be rounded.
# [I 20241108 10:30:39] No rounding scheme detected for column 'occupation'. Data will not be rounded.
# [I 20241108 10:30:39] No rounding scheme detected for column 'relationship'. Data will not be rounded.
# [I 20241108 10:30:39] No rounding scheme detected for column 'race'. Data will not be rounded.
# [I 20241108 10:30:39] No rounding scheme detected for column 'gender'. Data will not be rounded.
# [I 20241108 10:30:39] No rounding scheme detected for column 'capital-gain'. Data will not be rounded.
# [I 20241108 10:30:39] No rounding scheme detected for column 'capital-loss'. Data will not be rounded.
# [I 20241108 10:30:39] No rounding scheme detected for column 'hours-per-week'. Data will not be rounded.
# [I 20241108 10:30:39] No rounding scheme detected for column 'native-country'. Data will not be rounded.
# [I 20241108 10:30:39] No rounding scheme detected for column 'income'. Data will not be rounded.
# [I 20241108 10:30:39] Fitting constraints for table
# [I 20241108 10:30:39] Setting the configuration for the ``HyperTransformer`` for table
# [I 20241108 10:30:39] Fitting HyperTransformer for table
# [I 20241108 10:30:39] No rounding scheme detected for column 'age'. Data will not be rounded.
# [I 20241108 10:30:39] No rounding scheme detected for column 'workclass'. Data will not be rounded.
# [I 20241108 10:30:39] No rounding scheme detected for column 'fnlwgt'. Data will not be rounded.
# [I 20241108 10:30:39] No rounding scheme detected for column 'education'. Data will not be rounded.
# [I 20241108 10:30:39] No rounding scheme detected for column 'educational-num'. Data will not be rounded.
# [I 20241108 10:30:39] No rounding scheme detected for column 'marital-status'. Data will not be rounded.
# [I 20241108 10:30:39] No rounding scheme detected for column 'occupation'. Data will not be rounded.
# [I 20241108 10:30:39] No rounding scheme detected for column 'relationship'. Data will not be rounded.
# [I 20241108 10:30:39] No rounding scheme detected for column 'race'. Data will not be rounded.
# [I 20241108 10:30:39] No rounding scheme detected for column 'gender'. Data will not be rounded.
# [I 20241108 10:30:39] No rounding scheme detected for column 'capital-gain'. Data will not be rounded.
# [I 20241108 10:30:39] No rounding scheme detected for column 'capital-loss'. Data will not be rounded.
# [I 20241108 10:30:39] No rounding scheme detected for column 'hours-per-week'. Data will not be rounded.
# [I 20241108 10:30:39] No rounding scheme detected for column 'native-country'. Data will not be rounded.
# [I 20241108 10:30:39] No rounding scheme detected for column 'income'. Data will not be rounded.
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdv/single_table/base.py:120: FutureWarning: The 'SingleTableMetadata' is deprecated. Please use the new 'Metadata' class for synthesizers.
#   warnings.warn(DEPRECATION_MSG, FutureWarning)
# [I 20241108 10:30:39] {'EVENT': 'Fit processed data', 'TIMESTAMP': datetime.datetime(2024, 11, 8, 10, 30, 39, 287299), 'SYNTHESIZER CLASS NAME': 'GaussianCopulaSynthesizer', 'SYNTHESIZER ID': 'GaussianCopulaSynthesizer_1.17.1_426eaa16f120441093dd06129c8247d5', 'TOTAL NUMBER OF TABLES': 1, 'TOTAL NUMBER OF ROWS': 26933, 'TOTAL NUMBER OF COLUMNS': 15}
# [I 20241108 10:30:39] Fitting GaussianMultivariate(distribution="{'age': <class 'copulas.univariate.beta.BetaUnivariate'>, 'workclass': <class 'copulas.univariate.beta.BetaUnivariate'>, 'fnlwgt': <class 'copulas.univariate.beta.BetaUnivariate'>, 'education': <class 'copulas.univariate.beta.BetaUnivariate'>, 'educational-num': <class 'copulas.univariate.beta.BetaUnivariate'>, 'marital-status': <class 'copulas.univariate.beta.BetaUnivariate'>, 'occupation': <class 'copulas.univariate.beta.BetaUnivariate'>, 'relationship': <class 'copulas.univariate.beta.BetaUnivariate'>, 'race': <class 'copulas.univariate.beta.BetaUnivariate'>, 'gender': <class 'copulas.univariate.beta.BetaUnivariate'>, 'capital-gain': <class 'copulas.univariate.beta.BetaUnivariate'>, 'capital-loss': <class 'copulas.univariate.beta.BetaUnivariate'>, 'hours-per-week': <class 'copulas.univariate.beta.BetaUnivariate'>, 'native-country': <class 'copulas.univariate.beta.BetaUnivariate'>, 'income': <class 'copulas.univariate.beta.BetaUnivariate'>}")
# Synthesizer (SDV): Fitting GaussianCopula spent 1.7691 sec.
# [I 20241108 10:30:41] {'EVENT': 'Sample', 'TIMESTAMP': datetime.datetime(2024, 11, 8, 10, 30, 40, 843865), 'SYNTHESIZER CLASS NAME': 'GaussianCopulaSynthesizer', 'SYNTHESIZER ID': 'GaussianCopulaSynthesizer_1.17.1_426eaa16f120441093dd06129c8247d5', 'TOTAL NUMBER OF TABLES': 1, 'TOTAL NUMBER OF ROWS': 48842, 'TOTAL NUMBER OF COLUMNS': 15}
# Synthesizer (SDV): Sampling GaussianCopula # 48842 rows (same as Loader data) in 0.6009 sec.
# Now is Postprocessor with demo...
# [I 20241108 10:30:41] MediatorEncoder is created.
# [I 20241108 10:30:41] scaler inverse transformation done.
# [I 20241108 10:30:41] <PETsARD.processor.mediator.MediatorEncoder object at 0x325504820> transformation done.
# [I 20241108 10:30:41] encoder inverse transformation done.
# [I 20241108 10:30:41] missing inverse transformation done.
# [I 20241108 10:30:41] age changes data dtype from float64 to int8 for metadata alignment.
# [I 20241108 10:30:41] workclass changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241108 10:30:41] fnlwgt changes data dtype from float64 to int32 for metadata alignment.
# [I 20241108 10:30:41] education changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241108 10:30:41] educational-num changes data dtype from float64 to int8 for metadata alignment.
# [I 20241108 10:30:41] marital-status changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241108 10:30:41] occupation changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241108 10:30:41] relationship changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241108 10:30:41] race changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241108 10:30:41] gender changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241108 10:30:41] capital-gain changes data dtype from float64 to int32 for metadata alignment.
# [I 20241108 10:30:41] capital-loss changes data dtype from float64 to int16 for metadata alignment.
# [I 20241108 10:30:41] hours-per-week changes data dtype from float64 to int8 for metadata alignment.
# [I 20241108 10:30:41] native-country changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241108 10:30:41] income changes data dtype from category[object] to category[object] for metadata alignment.
# Now is Evaluator with demo...
# [I 20241108 10:30:41] workclass changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241108 10:30:41] education changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241108 10:30:41] marital-status changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241108 10:30:41] occupation changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241108 10:30:41] relationship changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241108 10:30:41] race changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241108 10:30:41] gender changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241108 10:30:41] capital-gain changes data dtype from int32 to int32 for metadata alignment.
# [I 20241108 10:30:41] capital-loss changes data dtype from int16 to int16 for metadata alignment.
# [I 20241108 10:30:41] native-country changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241108 10:30:41] income changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241108 10:30:41] Detected metadata:
# [I 20241108 10:30:41] {
#     "METADATA_SPEC_VERSION": "SINGLE_TABLE_V1",
#     "columns": {
#         "age": {
#             "sdtype": "numerical"
#         },
#         "workclass": {
#             "sdtype": "categorical"
#         },
#         "fnlwgt": {
#             "sdtype": "numerical"
#         },
#         "education": {
#             "sdtype": "categorical"
#         },
#         "educational-num": {
#             "sdtype": "numerical"
#         },
#         "marital-status": {
#             "sdtype": "categorical"
#         },
#         "occupation": {
#             "sdtype": "categorical"
#         },
#         "relationship": {
#             "sdtype": "categorical"
#         },
#         "race": {
#             "sdtype": "categorical"
#         },
#         "gender": {
#             "sdtype": "categorical"
#         },
#         "capital-gain": {
#             "sdtype": "numerical"
#         },
#         "capital-loss": {
#             "sdtype": "numerical"
#         },
#         "hours-per-week": {
#             "sdtype": "numerical"
#         },
#         "native-country": {
#             "sdtype": "categorical"
#         },
#         "income": {
#             "sdtype": "categorical"
#         }
#     }
# }
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 15/15 [00:00<00:00, 95.73it/s]|
# Column Shapes Score: 94.49%
#
# (2/2) Evaluating Column Pair Trends: |█████▏    | 55/105 [00:00<00:00, 271.32it/s]|
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# ...
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# Now is Reporter with save_report_global...
# Now is User Story B-1[Report]_demo_[global] save to csv...

# %%
pp.pprint(exec.get_result())
# Out:
# {'Loader[adult]_Preprocessor[demo]_Synthesizer[demo]_Postprocessor[demo]_Evaluator[demo]_Reporter[save_data]': {'Loader[adult]_Preprocessor[demo]_Synthesizer[demo]_Postprocessor[demo]':        age         workclass  fnlwgt     education  educational-num  \
# 0       57           Private  228611  Some-college               15
# 1       37         Local-gov  186314       HS-grad               10
# 2       37         State-gov  225306       HS-grad                7
# 3       38           Private  186673       HS-grad               10
# 4       42           Private   76036          10th               12
# ...    ...               ...     ...           ...              ...
# 48837   28           Private   52763       HS-grad                8
# 48838   33           Private  149830       HS-grad               11
# 48839   47           Private  206575          10th                9
# 48840   49  Self-emp-not-inc   48361       HS-grad               13
# 48841   22           Private   83557       HS-grad               10
#
#               marital-status       occupation   relationship  \
# 0              Never-married            Sales        Husband
# 1              Never-married  Protective-serv      Own-child
# 2              Never-married  Exec-managerial      Unmarried
# 3         Married-civ-spouse     Adm-clerical        Husband
# 4         Married-civ-spouse  Exec-managerial      Unmarried
# ...                      ...              ...            ...
# 48837          Never-married  Exec-managerial  Not-in-family
# 48838  Married-spouse-absent  Protective-serv           Wife
# 48839          Never-married    Other-service  Not-in-family
# 48840     Married-civ-spouse    Other-service        Husband
# 48841     Married-civ-spouse  Exec-managerial        Husband
#
#                      race  gender  capital-gain  capital-loss  hours-per-week  \
# 0                   White    Male             0             0              42
# 1                   White    Male             0             0              41
# 2                   White  Female             0             0              41
# 3                   White    Male             0             0              40
# 4      Asian-Pac-Islander  Female             0             0              41
# ...                   ...     ...           ...           ...             ...
# 48837               White    Male             0             0              44
# 48838               White    Male             0             0              52
# 48839               White    Male             0             0              41
# 48840               White    Male             0             0              44
# 48841               White    Male             0             0              44
#
#       native-country income
# 0      United-States  <=50K
# 1      United-States  <=50K
# 2      United-States  <=50K
# 3      United-States  <=50K
# 4      United-States  <=50K
# ...              ...    ...
# 48837  United-States  <=50K
# 48838  United-States  <=50K
# 48839  United-States  <=50K
# 48840  United-States  <=50K
# 48841  United-States  <=50K
#
# [48842 rows x 15 columns]},
#  'Loader[adult]_Preprocessor[demo]_Synthesizer[demo]_Postprocessor[demo]_Evaluator[demo]_Reporter[save_report_global]': {'demo_[global]':                                            full_expt_name Loader Preprocessor  \
# result  Loader[adult]_Preprocessor[demo]_Synthesizer[d...  adult         demo
#
#        Synthesizer Postprocessor      Evaluator  demo_Score  \
# result        demo          demo  demo_[global]    0.774643
#
#         demo_Column Shapes  demo_Column Pair Trends
# result            0.944943                 0.604344  }}

# %% [markdown]
# ---
#
# ## User Story B-2
# **Customized Evaluating**
#
# Following User Story B-1, if specific types of metrics are set or a customized evaluation script is provided, the module will create a customized evaluation report.
#
# 根據用戶故事 B-1，如果指定特定的指標、或是提供用戶自定義的評估腳本，模組會產生客製化的評估報告。

# %%
config_file = '../yaml/User Story B-2.yaml'

with open(config_file, 'r') as yaml_file:
    yaml_raw: dict = yaml.safe_load(yaml_file)
pp.pprint(yaml_raw)
# Out:
# {'Loader': {'adult': {'filepath': 'benchmark/adult-income.csv',
#                       'na_values': {...}}},
#  'Preprocessor': {'demo': {'method': 'default'}},
#  'Synthesizer': {'demo': {'method': 'default'}},
#  'Postprocessor': {'demo': {'method': 'default'}},
#  'Evaluator': {'custom': {'method': 'custom_method', 'custom_method': {...}}},
#  'Reporter': {'save_report_global': {'method': 'save_report',
#                                      'output': 'User Story B-2',
#                                      'eval': 'custom',
#                                      'granularity': 'global'},
#               'save_report_columnwise': {'method': 'save_report',
#                                          'output': 'User Story B-2',
#                                          'eval': 'custom',
#                                          'granularity': 'columnwise'},
#               'save_report_pairwise': {'method': 'save_report',
#                                        'output': 'User Story B-2',
#                                        'eval': 'custom',
#                                        'granularity': 'pairwise'}}}

# %%
exec = Executor(config=config_file)
exec.run()
# Out:
# Now is Loader with adult...
# Now is Preprocessor with demo...
# [I 20241108 10:30:42] MediatorMissing is created.
# [I 20241108 10:30:42] MediatorOutlier is created.
# [I 20241108 10:30:42] MediatorEncoder is created.
# [I 20241108 10:30:42] missing fitting done.
# [I 20241108 10:30:42] <PETsARD.processor.mediator.MediatorMissing object at 0x32553f8b0> fitting done.
# [I 20241108 10:30:42] outlier fitting done.
# [I 20241108 10:30:42] <PETsARD.processor.mediator.MediatorOutlier object at 0x32553ee60> fitting done.
# [I 20241108 10:30:42] encoder fitting done.
# [I 20241108 10:30:42] <PETsARD.processor.mediator.MediatorEncoder object at 0x32553ef50> fitting done.
# [I 20241108 10:30:42] scaler fitting done.
# [I 20241108 10:30:42] missing transformation done.
# [I 20241108 10:30:42] <PETsARD.processor.mediator.MediatorMissing object at 0x32553f8b0> transformation done.
# [I 20241108 10:30:42] outlier transformation done.
# [I 20241108 10:30:42] <PETsARD.processor.mediator.MediatorOutlier object at 0x32553ee60> transformation done.
# [I 20241108 10:30:42] encoder transformation done.
# [I 20241108 10:30:42] <PETsARD.processor.mediator.MediatorEncoder object at 0x32553ef50> transformation done.
# [I 20241108 10:30:42] scaler transformation done.
# Now is Synthesizer with demo...
# [I 20241108 10:30:42] {'EVENT': 'Instance', 'TIMESTAMP': datetime.datetime(2024, 11, 8, 10, 30, 42, 596090), 'SYNTHESIZER CLASS NAME': 'GaussianCopulaSynthesizer', 'SYNTHESIZER ID': 'GaussianCopulaSynthesizer_1.17.1_6e56dd12425b4f42983c7b24dd8e2b99'}
# Synthesizer (SDV): Fitting GaussianCopula.
# [I 20241108 10:30:42] {'EVENT': 'Fit', 'TIMESTAMP': datetime.datetime(2024, 11, 8, 10, 30, 42, 596305), 'SYNTHESIZER CLASS NAME': 'GaussianCopulaSynthesizer', 'SYNTHESIZER ID': 'GaussianCopulaSynthesizer_1.17.1_6e56dd12425b4f42983c7b24dd8e2b99', 'TOTAL NUMBER OF TABLES': 1, 'TOTAL NUMBER OF ROWS': 26933, 'TOTAL NUMBER OF COLUMNS': 15}
# [I 20241108 10:30:42] Fitting table  metadata
# [I 20241108 10:30:42] Fitting formatters for table
# [I 20241108 10:30:42] No rounding scheme detected for column 'age'. Data will not be rounded.
# [I 20241108 10:30:42] No rounding scheme detected for column 'workclass'. Data will not be rounded.
# [I 20241108 10:30:42] No rounding scheme detected for column 'fnlwgt'. Data will not be rounded.
# [I 20241108 10:30:42] No rounding scheme detected for column 'education'. Data will not be rounded.
# [I 20241108 10:30:42] No rounding scheme detected for column 'educational-num'. Data will not be rounded.
# [I 20241108 10:30:42] No rounding scheme detected for column 'marital-status'. Data will not be rounded.
# [I 20241108 10:30:42] No rounding scheme detected for column 'occupation'. Data will not be rounded.
# [I 20241108 10:30:42] No rounding scheme detected for column 'relationship'. Data will not be rounded.
# [I 20241108 10:30:42] No rounding scheme detected for column 'race'. Data will not be rounded.
# [I 20241108 10:30:42] No rounding scheme detected for column 'gender'. Data will not be rounded.
# [I 20241108 10:30:42] No rounding scheme detected for column 'capital-gain'. Data will not be rounded.
# [I 20241108 10:30:42] No rounding scheme detected for column 'capital-loss'. Data will not be rounded.
# [I 20241108 10:30:42] No rounding scheme detected for column 'hours-per-week'. Data will not be rounded.
# [I 20241108 10:30:42] No rounding scheme detected for column 'native-country'. Data will not be rounded.
# [I 20241108 10:30:42] No rounding scheme detected for column 'income'. Data will not be rounded.
# [I 20241108 10:30:42] Fitting constraints for table
# [I 20241108 10:30:42] Setting the configuration for the ``HyperTransformer`` for table
# [I 20241108 10:30:42] Fitting HyperTransformer for table
# [I 20241108 10:30:42] No rounding scheme detected for column 'age'. Data will not be rounded.
# [I 20241108 10:30:42] No rounding scheme detected for column 'workclass'. Data will not be rounded.
# [I 20241108 10:30:42] No rounding scheme detected for column 'fnlwgt'. Data will not be rounded.
# [I 20241108 10:30:42] No rounding scheme detected for column 'education'. Data will not be rounded.
# [I 20241108 10:30:42] No rounding scheme detected for column 'educational-num'. Data will not be rounded.
# [I 20241108 10:30:42] No rounding scheme detected for column 'marital-status'. Data will not be rounded.
# [I 20241108 10:30:42] No rounding scheme detected for column 'occupation'. Data will not be rounded.
# [I 20241108 10:30:42] No rounding scheme detected for column 'relationship'. Data will not be rounded.
# [I 20241108 10:30:42] No rounding scheme detected for column 'race'. Data will not be rounded.
# [I 20241108 10:30:42] No rounding scheme detected for column 'gender'. Data will not be rounded.
# [I 20241108 10:30:42] No rounding scheme detected for column 'capital-gain'. Data will not be rounded.
# [I 20241108 10:30:42] No rounding scheme detected for column 'capital-loss'. Data will not be rounded.
# [I 20241108 10:30:42] No rounding scheme detected for column 'hours-per-week'. Data will not be rounded.
# [I 20241108 10:30:42] No rounding scheme detected for column 'native-country'. Data will not be rounded.
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdv/single_table/base.py:120: FutureWarning: The 'SingleTableMetadata' is deprecated. Please use the new 'Metadata' class for synthesizers.
#   warnings.warn(DEPRECATION_MSG, FutureWarning)
# [I 20241108 10:30:42] No rounding scheme detected for column 'income'. Data will not be rounded.
# [I 20241108 10:30:42] {'EVENT': 'Fit processed data', 'TIMESTAMP': datetime.datetime(2024, 11, 8, 10, 30, 42, 825036), 'SYNTHESIZER CLASS NAME': 'GaussianCopulaSynthesizer', 'SYNTHESIZER ID': 'GaussianCopulaSynthesizer_1.17.1_6e56dd12425b4f42983c7b24dd8e2b99', 'TOTAL NUMBER OF TABLES': 1, 'TOTAL NUMBER OF ROWS': 26933, 'TOTAL NUMBER OF COLUMNS': 15}
# [I 20241108 10:30:42] Fitting GaussianMultivariate(distribution="{'age': <class 'copulas.univariate.beta.BetaUnivariate'>, 'workclass': <class 'copulas.univariate.beta.BetaUnivariate'>, 'fnlwgt': <class 'copulas.univariate.beta.BetaUnivariate'>, 'education': <class 'copulas.univariate.beta.BetaUnivariate'>, 'educational-num': <class 'copulas.univariate.beta.BetaUnivariate'>, 'marital-status': <class 'copulas.univariate.beta.BetaUnivariate'>, 'occupation': <class 'copulas.univariate.beta.BetaUnivariate'>, 'relationship': <class 'copulas.univariate.beta.BetaUnivariate'>, 'race': <class 'copulas.univariate.beta.BetaUnivariate'>, 'gender': <class 'copulas.univariate.beta.BetaUnivariate'>, 'capital-gain': <class 'copulas.univariate.beta.BetaUnivariate'>, 'capital-loss': <class 'copulas.univariate.beta.BetaUnivariate'>, 'hours-per-week': <class 'copulas.univariate.beta.BetaUnivariate'>, 'native-country': <class 'copulas.univariate.beta.BetaUnivariate'>, 'income': <class 'copulas.univariate.beta.BetaUnivariate'>}")
# Synthesizer (SDV): Fitting GaussianCopula spent 1.7799 sec.
# [I 20241108 10:30:44] {'EVENT': 'Sample', 'TIMESTAMP': datetime.datetime(2024, 11, 8, 10, 30, 44, 376302), 'SYNTHESIZER CLASS NAME': 'GaussianCopulaSynthesizer', 'SYNTHESIZER ID': 'GaussianCopulaSynthesizer_1.17.1_6e56dd12425b4f42983c7b24dd8e2b99', 'TOTAL NUMBER OF TABLES': 1, 'TOTAL NUMBER OF ROWS': 48842, 'TOTAL NUMBER OF COLUMNS': 15}
# Synthesizer (SDV): Sampling GaussianCopula # 48842 rows (same as Loader data) in 0.5883 sec.
# Now is Postprocessor with demo...
# [I 20241108 10:30:44] MediatorEncoder is created.
# [I 20241108 10:30:44] scaler inverse transformation done.
# [I 20241108 10:30:44] <PETsARD.processor.mediator.MediatorEncoder object at 0x32553ef50> transformation done.
# [I 20241108 10:30:44] encoder inverse transformation done.
# [I 20241108 10:30:44] missing inverse transformation done.
# [I 20241108 10:30:44] age changes data dtype from float64 to int8 for metadata alignment.
# [I 20241108 10:30:44] workclass changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241108 10:30:44] fnlwgt changes data dtype from float64 to int32 for metadata alignment.
# [I 20241108 10:30:44] education changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241108 10:30:44] educational-num changes data dtype from float64 to int8 for metadata alignment.
# [I 20241108 10:30:44] marital-status changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241108 10:30:44] occupation changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241108 10:30:44] relationship changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241108 10:30:44] race changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241108 10:30:44] gender changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241108 10:30:44] capital-gain changes data dtype from float64 to int32 for metadata alignment.
# [I 20241108 10:30:44] capital-loss changes data dtype from float64 to int16 for metadata alignment.
# [I 20241108 10:30:44] hours-per-week changes data dtype from float64 to int8 for metadata alignment.
# [I 20241108 10:30:44] native-country changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241108 10:30:44] income changes data dtype from category[object] to category[object] for metadata alignment.
# Now is Evaluator with custom...
# [I 20241108 10:30:45] workclass changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241108 10:30:45] education changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241108 10:30:45] marital-status changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241108 10:30:45] occupation changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241108 10:30:45] relationship changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241108 10:30:45] race changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241108 10:30:45] gender changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241108 10:30:45] capital-gain changes data dtype from int32 to int32 for metadata alignment.
# [I 20241108 10:30:45] capital-loss changes data dtype from int16 to int16 for metadata alignment.
# [I 20241108 10:30:45] native-country changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241108 10:30:45] income changes data dtype from category[object] to category[object] for metadata alignment.
# Now is Reporter with save_report_global...
# Now is User Story B-2[Report]_custom_[global] save to csv...
# Now is Reporter with save_report_columnwise...
# Now is User Story B-2[Report]_custom_[columnwise] save to csv...
# Now is Reporter with save_report_pairwise...
# Now is User Story B-2[Report]_custom_[pairwise] save to csv...

# %%
pp.pprint(exec.get_result())
# Out:
# {'Loader[adult]_Preprocessor[demo]_Synthesizer[demo]_Postprocessor[demo]_Evaluator[custom]_Reporter[save_report_global]': {'custom_[global]':                                            full_expt_name Loader Preprocessor  \
# result  Loader[adult]_Preprocessor[demo]_Synthesizer[d...  adult         demo
#
#        Synthesizer Postprocessor        Evaluator  custom_score
# result        demo          demo  custom_[global]           100  },
#  'Loader[adult]_Preprocessor[demo]_Synthesizer[demo]_Postprocessor[demo]_Evaluator[custom]_Reporter[save_report_columnwise]': {'custom_[columnwise]':                                        full_expt_name Loader Preprocessor  \
# 0   Loader[adult]_Preprocessor[demo]_Synthesizer[d...  adult         demo
# 1   Loader[adult]_Preprocessor[demo]_Synthesizer[d...  adult         demo
# 2   Loader[adult]_Preprocessor[demo]_Synthesizer[d...  adult         demo
# 3   Loader[adult]_Preprocessor[demo]_Synthesizer[d...  adult         demo
# 4   Loader[adult]_Preprocessor[demo]_Synthesizer[d...  adult         demo
# 5   Loader[adult]_Preprocessor[demo]_Synthesizer[d...  adult         demo
# 6   Loader[adult]_Preprocessor[demo]_Synthesizer[d...  adult         demo
# 7   Loader[adult]_Preprocessor[demo]_Synthesizer[d...  adult         demo
# 8   Loader[adult]_Preprocessor[demo]_Synthesizer[d...  adult         demo
# 9   Loader[adult]_Preprocessor[demo]_Synthesizer[d...  adult         demo
# 10  Loader[adult]_Preprocessor[demo]_Synthesizer[d...  adult         demo
# 11  Loader[adult]_Preprocessor[demo]_Synthesizer[d...  adult         demo
# 12  Loader[adult]_Preprocessor[demo]_Synthesizer[d...  adult         demo
# 13  Loader[adult]_Preprocessor[demo]_Synthesizer[d...  adult         demo
# 14  Loader[adult]_Preprocessor[demo]_Synthesizer[d...  adult         demo
#
#    Synthesizer Postprocessor            Evaluator           column  \
# 0         demo          demo  custom_[columnwise]              age
# 1         demo          demo  custom_[columnwise]        workclass
# 2         demo          demo  custom_[columnwise]           fnlwgt
# 3         demo          demo  custom_[columnwise]        education
# 4         demo          demo  custom_[columnwise]  educational-num
# 5         demo          demo  custom_[columnwise]   marital-status
# 6         demo          demo  custom_[columnwise]       occupation
# 7         demo          demo  custom_[columnwise]     relationship
# 8         demo          demo  custom_[columnwise]             race
# 9         demo          demo  custom_[columnwise]           gender
# 10        demo          demo  custom_[columnwise]     capital-gain
# 11        demo          demo  custom_[columnwise]     capital-loss
# 12        demo          demo  custom_[columnwise]   hours-per-week
# 13        demo          demo  custom_[columnwise]   native-country
# 14        demo          demo  custom_[columnwise]           income
#
#     custom_score
# 0            100
# 1            100
# 2            100
# 3            100
# 4            100
# 5            100
# 6            100
# 7            100
# 8            100
# 9            100
# 10           100
# 11           100
# 12           100
# 13           100
# 14           100  },
#  'Loader[adult]_Preprocessor[demo]_Synthesizer[demo]_Postprocessor[demo]_Evaluator[custom]_Reporter[save_report_pairwise]': {'custom_[pairwise]':                                         full_expt_name Loader Preprocessor  \
# 0    Loader[adult]_Preprocessor[demo]_Synthesizer[d...  adult         demo
# 1    Loader[adult]_Preprocessor[demo]_Synthesizer[d...  adult         demo
# 2    Loader[adult]_Preprocessor[demo]_Synthesizer[d...  adult         demo
# 3    Loader[adult]_Preprocessor[demo]_Synthesizer[d...  adult         demo
# 4    Loader[adult]_Preprocessor[demo]_Synthesizer[d...  adult         demo
# ..                                                 ...    ...          ...
# 115  Loader[adult]_Preprocessor[demo]_Synthesizer[d...  adult         demo
# 116  Loader[adult]_Preprocessor[demo]_Synthesizer[d...  adult         demo
# 117  Loader[adult]_Preprocessor[demo]_Synthesizer[d...  adult         demo
# 118  Loader[adult]_Preprocessor[demo]_Synthesizer[d...  adult         demo
# 119  Loader[adult]_Preprocessor[demo]_Synthesizer[d...  adult         demo
#
#     Synthesizer Postprocessor          Evaluator    column1         column2  \
# 0          demo          demo  custom_[pairwise]        age             age
# 1          demo          demo  custom_[pairwise]  workclass             age
# 2          demo          demo  custom_[pairwise]  workclass       workclass
# 3          demo          demo  custom_[pairwise]     fnlwgt             age
# 4          demo          demo  custom_[pairwise]     fnlwgt       workclass
# ..          ...           ...                ...        ...             ...
# 115        demo          demo  custom_[pairwise]     income    capital-gain
# 116        demo          demo  custom_[pairwise]     income    capital-loss
# 117        demo          demo  custom_[pairwise]     income  hours-per-week
# 118        demo          demo  custom_[pairwise]     income  native-country
# 119        demo          demo  custom_[pairwise]     income          income
#
#      custom_score
# 0             100
# 1             100
# 2             100
# 3             100
# 4             100
# ..            ...
# 115           100
# 116           100
# 117           100
# 118           100
# 119           100
#
# [120 rows x 9 columns]}}
