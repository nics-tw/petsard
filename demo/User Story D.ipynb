# %% [markdown]
# ## User Story D
# **Research on Benchmark datasets**
#
#
# This demo will show how to use `PETsARD`'s benchmark datasets to evaluate synthetic algorithms.
#
# In this demonstration, as an advanced user with a basic understanding of different differential privacy/synthetic data technologies and their corresponding evaluation metrics, you aim to assess the differences between technologies and other academic and practical issues.
#
# PETsARD provides a complete platform that, by integrating commonly used benchmark datasets in academics, competitions, or practical applications, allows for easy setup of different benchmark datasets, execution on various synthetic algorithms, and execution of different evaluation combinations. This enables you to easily obtain comprehensive data support, focusing on your academic or development work.
#
# 本示範將展示如何使用 `PETsARD` 的基準資料集來評估合成演算法。
#
# 在這個示範中，您作為進階的使用者，對於不同的差分隱私/合成資料技術、以及對應的評測指標有初步理解，希望評估技術彼此之間的差異等學術與實務議題。
#
# 而 `PETsARD` 將提供你完整的平台，藉由預先整合好的，在學術、比賽或實務上常用的基準資料集， `PETsARD` 能輕鬆設定不同基準資料集、執行在不同合成演算法上、並執行不同評測的實驗組合，讓您能輕鬆獲得綜合性資料的支持，專注在您的學術或開發工作上。

# %% [markdown]
# ---
#
# ## Environment

# %%
import os
import pprint
import sys

import yaml


# Setting up the path to the PETsARD package
path_petsard = os.path.dirname(os.getcwd())
sys.path.append(path_petsard)
# setting for pretty priny YAML
pp = pprint.PrettyPrinter(depth=3, sort_dicts=False)


from petsard import Executor

# %% [markdown]
# ---
#
# ## User Story D-1
# **Synthesizing on default data**
#
# With a specified data generation algorithm, a default benchmark dataset collection will serve as inputs, and the pipeline will generate the corresponding privacy enhanced datasets as output, using the selected algorithm.
#
# 指定資料生成演算法後，預設的經典資料集會用作輸入，並且該流程將使用該演算法輸出對應的隱私強化資料集。

# %%
config_file = '../yaml/User Story D-1.yaml'

with open(config_file, 'r') as yaml_file:
    yaml_raw: dict = yaml.safe_load(yaml_file)
pp.pprint(yaml_raw)
# Out:
# {'Loader': {'demo': {'method': 'default'}},
#  'Preprocessor': {'demo': {'method': 'default'}},
#  'Synthesizer': {'sdv-gaussian': {'method': 'sdv-single_table-gaussiancopula'}},
#  'Postprocessor': {'demo': {'method': 'default'}},
#  'Reporter': {'save_data': {'method': 'save_data',
#                             'output': 'User Story D-1',
#                             'source': 'Postprocessor'}}}

# %%
exec = Executor(config=config_file)
exec.run()
# Out:
# Now is Loader with demo...
# Loader - Benchmarker : Success download the benchmark dataset from https://petsard-benchmark.s3.amazonaws.com/adult-income.csv.
# Now is Preprocessor with demo...
# [I 20241225 10:24:54] MediatorMissing is created.
# [I 20241225 10:24:54] MediatorOutlier is created.
# [I 20241225 10:24:54] MediatorEncoder is created.
# [I 20241225 10:24:54] missing fitting done.
# [I 20241225 10:24:54] <petsard.processor.mediator.MediatorMissing object at 0x329019240> fitting done.
# [I 20241225 10:24:54] outlier fitting done.
# [I 20241225 10:24:54] <petsard.processor.mediator.MediatorOutlier object at 0x32901aec0> fitting done.
# [I 20241225 10:24:54] encoder fitting done.
# [I 20241225 10:24:54] <petsard.processor.mediator.MediatorEncoder object at 0x32901b040> fitting done.
# [I 20241225 10:24:54] scaler fitting done.
# [I 20241225 10:24:54] missing transformation done.
# [I 20241225 10:24:54] <petsard.processor.mediator.MediatorMissing object at 0x329019240> transformation done.
# [I 20241225 10:24:54] outlier transformation done.
# [I 20241225 10:24:54] <petsard.processor.mediator.MediatorOutlier object at 0x32901aec0> transformation done.
# [I 20241225 10:24:54] encoder transformation done.
# [I 20241225 10:24:54] <petsard.processor.mediator.MediatorEncoder object at 0x32901b040> transformation done.
# [I 20241225 10:24:54] scaler transformation done.
# Now is Synthesizer with sdv-gaussian...
# [I 20241225 10:24:54] {'EVENT': 'Instance', 'TIMESTAMP': datetime.datetime(2024, 12, 25, 10, 24, 54, 523643), 'SYNTHESIZER CLASS NAME': 'GaussianCopulaSynthesizer', 'SYNTHESIZER ID': 'GaussianCopulaSynthesizer_1.17.1_0d369ad5a1bc43688b86d826fcab42b2'}
# Synthesizer (SDV): Fitting GaussianCopula.
# [I 20241225 10:24:54] {'EVENT': 'Fit', 'TIMESTAMP': datetime.datetime(2024, 12, 25, 10, 24, 54, 523909), 'SYNTHESIZER CLASS NAME': 'GaussianCopulaSynthesizer', 'SYNTHESIZER ID': 'GaussianCopulaSynthesizer_1.17.1_0d369ad5a1bc43688b86d826fcab42b2', 'TOTAL NUMBER OF TABLES': 1, 'TOTAL NUMBER OF ROWS': 28558, 'TOTAL NUMBER OF COLUMNS': 15}
# [I 20241225 10:24:54] Fitting table  metadata
# [I 20241225 10:24:54] Fitting formatters for table
# [I 20241225 10:24:54] No rounding scheme detected for column 'age'. Data will not be rounded.
# [I 20241225 10:24:54] No rounding scheme detected for column 'workclass'. Data will not be rounded.
# [I 20241225 10:24:54] No rounding scheme detected for column 'fnlwgt'. Data will not be rounded.
# [I 20241225 10:24:54] No rounding scheme detected for column 'education'. Data will not be rounded.
# [I 20241225 10:24:54] No rounding scheme detected for column 'educational-num'. Data will not be rounded.
# [I 20241225 10:24:54] No rounding scheme detected for column 'marital-status'. Data will not be rounded.
# [I 20241225 10:24:54] No rounding scheme detected for column 'occupation'. Data will not be rounded.
# [I 20241225 10:24:54] No rounding scheme detected for column 'relationship'. Data will not be rounded.
# [I 20241225 10:24:54] No rounding scheme detected for column 'race'. Data will not be rounded.
# [I 20241225 10:24:54] No rounding scheme detected for column 'gender'. Data will not be rounded.
# [I 20241225 10:24:54] No rounding scheme detected for column 'capital-gain'. Data will not be rounded.
# [I 20241225 10:24:54] No rounding scheme detected for column 'capital-loss'. Data will not be rounded.
# [I 20241225 10:24:54] No rounding scheme detected for column 'hours-per-week'. Data will not be rounded.
# [I 20241225 10:24:54] No rounding scheme detected for column 'native-country'. Data will not be rounded.
# [I 20241225 10:24:54] No rounding scheme detected for column 'income'. Data will not be rounded.
# [I 20241225 10:24:54] Fitting constraints for table
# [I 20241225 10:24:54] Setting the configuration for the ``HyperTransformer`` for table
# [I 20241225 10:24:54] Fitting HyperTransformer for table
# [I 20241225 10:24:54] No rounding scheme detected for column 'age'. Data will not be rounded.
# [I 20241225 10:24:54] No rounding scheme detected for column 'workclass'. Data will not be rounded.
# [I 20241225 10:24:54] No rounding scheme detected for column 'fnlwgt'. Data will not be rounded.
# [I 20241225 10:24:54] No rounding scheme detected for column 'education'. Data will not be rounded.
# [I 20241225 10:24:54] No rounding scheme detected for column 'educational-num'. Data will not be rounded.
# [I 20241225 10:24:54] No rounding scheme detected for column 'marital-status'. Data will not be rounded.
# [I 20241225 10:24:54] No rounding scheme detected for column 'occupation'. Data will not be rounded.
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdv/single_table/base.py:120: FutureWarning: The 'SingleTableMetadata' is deprecated. Please use the new 'Metadata' class for synthesizers.
#   warnings.warn(DEPRECATION_MSG, FutureWarning)
# [I 20241225 10:24:54] No rounding scheme detected for column 'relationship'. Data will not be rounded.
# [I 20241225 10:24:54] No rounding scheme detected for column 'race'. Data will not be rounded.
# [I 20241225 10:24:54] No rounding scheme detected for column 'gender'. Data will not be rounded.
# [I 20241225 10:24:54] No rounding scheme detected for column 'capital-gain'. Data will not be rounded.
# [I 20241225 10:24:54] No rounding scheme detected for column 'capital-loss'. Data will not be rounded.
# [I 20241225 10:24:54] No rounding scheme detected for column 'hours-per-week'. Data will not be rounded.
# [I 20241225 10:24:54] No rounding scheme detected for column 'native-country'. Data will not be rounded.
# [I 20241225 10:24:54] No rounding scheme detected for column 'income'. Data will not be rounded.
# [I 20241225 10:24:54] {'EVENT': 'Fit processed data', 'TIMESTAMP': datetime.datetime(2024, 12, 25, 10, 24, 54, 780050), 'SYNTHESIZER CLASS NAME': 'GaussianCopulaSynthesizer', 'SYNTHESIZER ID': 'GaussianCopulaSynthesizer_1.17.1_0d369ad5a1bc43688b86d826fcab42b2', 'TOTAL NUMBER OF TABLES': 1, 'TOTAL NUMBER OF ROWS': 28558, 'TOTAL NUMBER OF COLUMNS': 15}
# [I 20241225 10:24:54] Fitting GaussianMultivariate(distribution="{'age': <class 'copulas.univariate.beta.BetaUnivariate'>, 'workclass': <class 'copulas.univariate.beta.BetaUnivariate'>, 'fnlwgt': <class 'copulas.univariate.beta.BetaUnivariate'>, 'education': <class 'copulas.univariate.beta.BetaUnivariate'>, 'educational-num': <class 'copulas.univariate.beta.BetaUnivariate'>, 'marital-status': <class 'copulas.univariate.beta.BetaUnivariate'>, 'occupation': <class 'copulas.univariate.beta.BetaUnivariate'>, 'relationship': <class 'copulas.univariate.beta.BetaUnivariate'>, 'race': <class 'copulas.univariate.beta.BetaUnivariate'>, 'gender': <class 'copulas.univariate.beta.BetaUnivariate'>, 'capital-gain': <class 'copulas.univariate.beta.BetaUnivariate'>, 'capital-loss': <class 'copulas.univariate.beta.BetaUnivariate'>, 'hours-per-week': <class 'copulas.univariate.beta.BetaUnivariate'>, 'native-country': <class 'copulas.univariate.beta.BetaUnivariate'>, 'income': <class 'copulas.univariate.beta.BetaUnivariate'>}")
# Synthesizer (SDV): Fitting GaussianCopula spent 2.1712 sec.
# [I 20241225 10:24:57] {'EVENT': 'Sample', 'TIMESTAMP': datetime.datetime(2024, 12, 25, 10, 24, 56, 695146), 'SYNTHESIZER CLASS NAME': 'GaussianCopulaSynthesizer', 'SYNTHESIZER ID': 'GaussianCopulaSynthesizer_1.17.1_0d369ad5a1bc43688b86d826fcab42b2', 'TOTAL NUMBER OF TABLES': 1, 'TOTAL NUMBER OF ROWS': 48842, 'TOTAL NUMBER OF COLUMNS': 15}
# Synthesizer (SDV): Sampling GaussianCopula # 48842 rows (same as Loader data) in 0.6016 sec.
# Now is Postprocessor with demo...
# [I 20241225 10:24:57] MediatorEncoder is created.
# [I 20241225 10:24:57] scaler inverse transformation done.
# [I 20241225 10:24:57] <petsard.processor.mediator.MediatorEncoder object at 0x32901b040> transformation done.
# [I 20241225 10:24:57] encoder inverse transformation done.
# [I 20241225 10:24:57] missing inverse transformation done.
# [I 20241225 10:24:57] age changes data dtype from float64 to int8 for metadata alignment.
# [I 20241225 10:24:57] workclass changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241225 10:24:57] fnlwgt changes data dtype from float64 to int32 for metadata alignment.
# [I 20241225 10:24:57] education changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241225 10:24:57] educational-num changes data dtype from float64 to int8 for metadata alignment.
# [I 20241225 10:24:57] marital-status changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241225 10:24:57] occupation changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241225 10:24:57] relationship changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241225 10:24:57] race changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241225 10:24:57] gender changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241225 10:24:57] capital-gain changes data dtype from float64 to int32 for metadata alignment.
# [I 20241225 10:24:57] capital-loss changes data dtype from float64 to int16 for metadata alignment.
# [I 20241225 10:24:57] hours-per-week changes data dtype from float64 to int8 for metadata alignment.
# [I 20241225 10:24:57] native-country changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241225 10:24:57] income changes data dtype from category[object] to category[object] for metadata alignment.
# Now is Reporter with save_data...
# Now is User Story D-1_Loader[demo]_Preprocessor[demo]_Synthesizer[sdv-gaussian]_Postprocessor[demo] save to csv...

# %%
pp.pprint(exec.get_result())
# Out:
# {'Loader[demo]_Preprocessor[demo]_Synthesizer[sdv-gaussian]_Postprocessor[demo]_Reporter[save_data]': {'Loader[demo]_Preprocessor[demo]_Synthesizer[sdv-gaussian]_Postprocessor[demo]':        age         workclass  fnlwgt     education  educational-num  \
# 0       36           Private   63960    Assoc-acdm               10
# 1       21  Self-emp-not-inc   85886       HS-grad                9
# 2       44           Private   51705       HS-grad               11
# 3       41           Private  192972     Bachelors                8
# 4       51      Self-emp-inc  258854     Bachelors               12
# ...    ...               ...     ...           ...              ...
# 48837   41           Private  292629       HS-grad               10
# 48838   19       Federal-gov  190607  Some-college                9
# 48839   21           Private  223081     Bachelors               10
# 48840   51       Federal-gov  159476  Some-college                9
# 48841   47           Private  355768  Some-college                9
#
#               marital-status         occupation    relationship   race  \
# 0         Married-civ-spouse     Prof-specialty   Not-in-family  White
# 1         Married-civ-spouse       Craft-repair   Not-in-family  Black
# 2                  Separated                  ?   Not-in-family  White
# 3         Married-civ-spouse      Other-service   Not-in-family  White
# 4              Never-married       Adm-clerical   Not-in-family  White
# ...                      ...                ...             ...    ...
# 48837          Never-married  Machine-op-inspct   Not-in-family  White
# 48838  Married-spouse-absent  Machine-op-inspct  Other-relative  White
# 48839     Married-civ-spouse  Handlers-cleaners   Not-in-family  White
# 48840     Married-civ-spouse       Craft-repair         Husband  White
# 48841     Married-civ-spouse       Adm-clerical         Husband  White
#
#        gender  capital-gain  capital-loss  hours-per-week native-country  \
# 0        Male             0             0              47  United-States
# 1        Male             0             0              42  United-States
# 2        Male             0             0              43  United-States
# 3        Male             0             0              41  United-States
# 4      Female             0             0              37  United-States
# ...       ...           ...           ...             ...            ...
# 48837    Male             0             0              39  United-States
# 48838    Male             0             0              51  United-States
# 48839    Male             0             0              34  United-States
# 48840    Male             0             0              46  United-States
# 48841    Male             0             0              43  United-States
#
#       income
# 0       >50K
# 1      <=50K
# 2      <=50K
# 3      <=50K
# 4      <=50K
# ...      ...
# 48837  <=50K
# 48838  <=50K
# 48839   >50K
# 48840  <=50K
# 48841  <=50K
#
# [48842 rows x 15 columns]}}

# %% [markdown]
# ---
#
# ## User Story D-2
# **Synthesizing on multiple data**
#
# Following User Story D-1, the user can specify a list of datasets instead.
#
# 根據用戶故事 D-1，使用者可以改為指定一個資料集列表。

# %%
config_file = '../yaml/User Story D-2.yaml'

with open(config_file, 'r') as yaml_file:
    yaml_raw: dict = yaml.safe_load(yaml_file)
pp.pprint(yaml_raw)
# Out:
# {'Loader': {'default': {'method': 'default'},
#             'adult': {'filepath': 'benchmark://adult', 'na_values': {...}}},
#  'Preprocessor': {'demo': {'method': 'default'}},
#  'Synthesizer': {'sdv-gaussian': {'method': 'sdv-single_table-gaussiancopula'}},
#  'Postprocessor': {'demo': {'method': 'default'}},
#  'Reporter': {'save_data': {'method': 'save_data',
#                             'output': 'User Story D-2',
#                             'source': 'Postprocessor'}}}

# %%
exec = Executor(config=config_file)
exec.run()
# Out:
# Now is Loader with default...
# Loader - Benchmarker: file benchmark/adult-income.csv already exist and match SHA-256.
#                       petsard will ignore download and use local data directly.
# Now is Preprocessor with demo...
# [I 20241225 10:24:57] MediatorMissing is created.
# [I 20241225 10:24:57] MediatorOutlier is created.
# [I 20241225 10:24:57] MediatorEncoder is created.
# [I 20241225 10:24:57] missing fitting done.
# [I 20241225 10:24:57] <petsard.processor.mediator.MediatorMissing object at 0x32901bd30> fitting done.
# [I 20241225 10:24:57] outlier fitting done.
# [I 20241225 10:24:57] <petsard.processor.mediator.MediatorOutlier object at 0x328fb3970> fitting done.
# [I 20241225 10:24:57] encoder fitting done.
# [I 20241225 10:24:57] <petsard.processor.mediator.MediatorEncoder object at 0x328fb3a90> fitting done.
# [I 20241225 10:24:57] scaler fitting done.
# [I 20241225 10:24:57] missing transformation done.
# [I 20241225 10:24:57] <petsard.processor.mediator.MediatorMissing object at 0x32901bd30> transformation done.
# [I 20241225 10:24:57] outlier transformation done.
# [I 20241225 10:24:57] <petsard.processor.mediator.MediatorOutlier object at 0x328fb3970> transformation done.
# [I 20241225 10:24:57] encoder transformation done.
# [I 20241225 10:24:57] <petsard.processor.mediator.MediatorEncoder object at 0x328fb3a90> transformation done.
# [I 20241225 10:24:57] scaler transformation done.
# Now is Synthesizer with sdv-gaussian...
# [I 20241225 10:24:57] {'EVENT': 'Instance', 'TIMESTAMP': datetime.datetime(2024, 12, 25, 10, 24, 57, 992836), 'SYNTHESIZER CLASS NAME': 'GaussianCopulaSynthesizer', 'SYNTHESIZER ID': 'GaussianCopulaSynthesizer_1.17.1_c13fd19348134433a349489eeaad0283'}
# Synthesizer (SDV): Fitting GaussianCopula.
# [I 20241225 10:24:57] {'EVENT': 'Fit', 'TIMESTAMP': datetime.datetime(2024, 12, 25, 10, 24, 57, 993112), 'SYNTHESIZER CLASS NAME': 'GaussianCopulaSynthesizer', 'SYNTHESIZER ID': 'GaussianCopulaSynthesizer_1.17.1_c13fd19348134433a349489eeaad0283', 'TOTAL NUMBER OF TABLES': 1, 'TOTAL NUMBER OF ROWS': 28558, 'TOTAL NUMBER OF COLUMNS': 15}
# [I 20241225 10:24:58] Fitting table  metadata
# [I 20241225 10:24:58] Fitting formatters for table
# [I 20241225 10:24:58] No rounding scheme detected for column 'age'. Data will not be rounded.
# [I 20241225 10:24:58] No rounding scheme detected for column 'workclass'. Data will not be rounded.
# [I 20241225 10:24:58] No rounding scheme detected for column 'fnlwgt'. Data will not be rounded.
# [I 20241225 10:24:58] No rounding scheme detected for column 'education'. Data will not be rounded.
# [I 20241225 10:24:58] No rounding scheme detected for column 'educational-num'. Data will not be rounded.
# [I 20241225 10:24:58] No rounding scheme detected for column 'marital-status'. Data will not be rounded.
# [I 20241225 10:24:58] No rounding scheme detected for column 'occupation'. Data will not be rounded.
# [I 20241225 10:24:58] No rounding scheme detected for column 'relationship'. Data will not be rounded.
# [I 20241225 10:24:58] No rounding scheme detected for column 'race'. Data will not be rounded.
# [I 20241225 10:24:58] No rounding scheme detected for column 'gender'. Data will not be rounded.
# [I 20241225 10:24:58] No rounding scheme detected for column 'capital-gain'. Data will not be rounded.
# [I 20241225 10:24:58] No rounding scheme detected for column 'capital-loss'. Data will not be rounded.
# [I 20241225 10:24:58] No rounding scheme detected for column 'hours-per-week'. Data will not be rounded.
# [I 20241225 10:24:58] No rounding scheme detected for column 'native-country'. Data will not be rounded.
# [I 20241225 10:24:58] No rounding scheme detected for column 'income'. Data will not be rounded.
# [I 20241225 10:24:58] Fitting constraints for table
# [I 20241225 10:24:58] Setting the configuration for the ``HyperTransformer`` for table
# [I 20241225 10:24:58] Fitting HyperTransformer for table
# [I 20241225 10:24:58] No rounding scheme detected for column 'age'. Data will not be rounded.
# [I 20241225 10:24:58] No rounding scheme detected for column 'workclass'. Data will not be rounded.
# [I 20241225 10:24:58] No rounding scheme detected for column 'fnlwgt'. Data will not be rounded.
# [I 20241225 10:24:58] No rounding scheme detected for column 'education'. Data will not be rounded.
# [I 20241225 10:24:58] No rounding scheme detected for column 'educational-num'. Data will not be rounded.
# [I 20241225 10:24:58] No rounding scheme detected for column 'marital-status'. Data will not be rounded.
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdv/single_table/base.py:120: FutureWarning: The 'SingleTableMetadata' is deprecated. Please use the new 'Metadata' class for synthesizers.
#   warnings.warn(DEPRECATION_MSG, FutureWarning)
# [I 20241225 10:24:58] No rounding scheme detected for column 'occupation'. Data will not be rounded.
# [I 20241225 10:24:58] No rounding scheme detected for column 'relationship'. Data will not be rounded.
# [I 20241225 10:24:58] No rounding scheme detected for column 'race'. Data will not be rounded.
# [I 20241225 10:24:58] No rounding scheme detected for column 'gender'. Data will not be rounded.
# [I 20241225 10:24:58] No rounding scheme detected for column 'capital-gain'. Data will not be rounded.
# [I 20241225 10:24:58] No rounding scheme detected for column 'capital-loss'. Data will not be rounded.
# [I 20241225 10:24:58] No rounding scheme detected for column 'hours-per-week'. Data will not be rounded.
# [I 20241225 10:24:58] No rounding scheme detected for column 'native-country'. Data will not be rounded.
# [I 20241225 10:24:58] No rounding scheme detected for column 'income'. Data will not be rounded.
# [I 20241225 10:24:58] {'EVENT': 'Fit processed data', 'TIMESTAMP': datetime.datetime(2024, 12, 25, 10, 24, 58, 251952), 'SYNTHESIZER CLASS NAME': 'GaussianCopulaSynthesizer', 'SYNTHESIZER ID': 'GaussianCopulaSynthesizer_1.17.1_c13fd19348134433a349489eeaad0283', 'TOTAL NUMBER OF TABLES': 1, 'TOTAL NUMBER OF ROWS': 28558, 'TOTAL NUMBER OF COLUMNS': 15}
# [I 20241225 10:24:58] Fitting GaussianMultivariate(distribution="{'age': <class 'copulas.univariate.beta.BetaUnivariate'>, 'workclass': <class 'copulas.univariate.beta.BetaUnivariate'>, 'fnlwgt': <class 'copulas.univariate.beta.BetaUnivariate'>, 'education': <class 'copulas.univariate.beta.BetaUnivariate'>, 'educational-num': <class 'copulas.univariate.beta.BetaUnivariate'>, 'marital-status': <class 'copulas.univariate.beta.BetaUnivariate'>, 'occupation': <class 'copulas.univariate.beta.BetaUnivariate'>, 'relationship': <class 'copulas.univariate.beta.BetaUnivariate'>, 'race': <class 'copulas.univariate.beta.BetaUnivariate'>, 'gender': <class 'copulas.univariate.beta.BetaUnivariate'>, 'capital-gain': <class 'copulas.univariate.beta.BetaUnivariate'>, 'capital-loss': <class 'copulas.univariate.beta.BetaUnivariate'>, 'hours-per-week': <class 'copulas.univariate.beta.BetaUnivariate'>, 'native-country': <class 'copulas.univariate.beta.BetaUnivariate'>, 'income': <class 'copulas.univariate.beta.BetaUnivariate'>}")
# Synthesizer (SDV): Fitting GaussianCopula spent 2.2881 sec.
# [I 20241225 10:25:00] {'EVENT': 'Sample', 'TIMESTAMP': datetime.datetime(2024, 12, 25, 10, 25, 0, 281264), 'SYNTHESIZER CLASS NAME': 'GaussianCopulaSynthesizer', 'SYNTHESIZER ID': 'GaussianCopulaSynthesizer_1.17.1_c13fd19348134433a349489eeaad0283', 'TOTAL NUMBER OF TABLES': 1, 'TOTAL NUMBER OF ROWS': 48842, 'TOTAL NUMBER OF COLUMNS': 15}
# Synthesizer (SDV): Sampling GaussianCopula # 48842 rows (same as Loader data) in 0.5667 sec.
# Now is Postprocessor with demo...
# [I 20241225 10:25:00] MediatorEncoder is created.
# [I 20241225 10:25:00] scaler inverse transformation done.
# [I 20241225 10:25:00] <petsard.processor.mediator.MediatorEncoder object at 0x328fb3a90> transformation done.
# [I 20241225 10:25:00] encoder inverse transformation done.
# [I 20241225 10:25:00] missing inverse transformation done.
# [I 20241225 10:25:00] age changes data dtype from float64 to int8 for metadata alignment.
# [I 20241225 10:25:00] workclass changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241225 10:25:00] fnlwgt changes data dtype from float64 to int32 for metadata alignment.
# [I 20241225 10:25:00] education changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241225 10:25:00] educational-num changes data dtype from float64 to int8 for metadata alignment.
# [I 20241225 10:25:00] marital-status changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241225 10:25:00] occupation changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241225 10:25:00] relationship changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241225 10:25:00] race changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241225 10:25:00] gender changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241225 10:25:00] capital-gain changes data dtype from float64 to int32 for metadata alignment.
# [I 20241225 10:25:00] capital-loss changes data dtype from float64 to int16 for metadata alignment.
# [I 20241225 10:25:00] hours-per-week changes data dtype from float64 to int8 for metadata alignment.
# [I 20241225 10:25:00] native-country changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241225 10:25:00] income changes data dtype from category[object] to category[object] for metadata alignment.
# Now is Reporter with save_data...
# Now is User Story D-2_Loader[default]_Preprocessor[demo]_Synthesizer[sdv-gaussian]_Postprocessor[demo] save to csv...
# Now is Loader with adult...
# Loader - Benchmarker : Success download the benchmark dataset from https://petsard-benchmark.s3.amazonaws.com/adult_uci.csv.
# Now is Preprocessor with demo...
# [I 20241225 10:25:02] MediatorMissing is created.
# [I 20241225 10:25:02] MediatorOutlier is created.
# [I 20241225 10:25:02] MediatorEncoder is created.
# [I 20241225 10:25:02] missing fitting done.
# [I 20241225 10:25:02] <petsard.processor.mediator.MediatorMissing object at 0x32ac29330> fitting done.
# [I 20241225 10:25:02] outlier fitting done.
# [I 20241225 10:25:02] <petsard.processor.mediator.MediatorOutlier object at 0x32ab09d50> fitting done.
# [I 20241225 10:25:02] encoder fitting done.
# [I 20241225 10:25:02] <petsard.processor.mediator.MediatorEncoder object at 0x32ab09cf0> fitting done.
# [I 20241225 10:25:02] scaler fitting done.
# [I 20241225 10:25:02] missing transformation done.
# [I 20241225 10:25:02] <petsard.processor.mediator.MediatorMissing object at 0x32ac29330> transformation done.
# [I 20241225 10:25:02] outlier transformation done.
# [I 20241225 10:25:02] <petsard.processor.mediator.MediatorOutlier object at 0x32ab09d50> transformation done.
# [I 20241225 10:25:02] encoder transformation done.
# [I 20241225 10:25:02] <petsard.processor.mediator.MediatorEncoder object at 0x32ab09cf0> transformation done.
# [I 20241225 10:25:02] scaler transformation done.
# Now is Synthesizer with sdv-gaussian...
# [I 20241225 10:25:02] {'EVENT': 'Instance', 'TIMESTAMP': datetime.datetime(2024, 12, 25, 10, 25, 2, 426185), 'SYNTHESIZER CLASS NAME': 'GaussianCopulaSynthesizer', 'SYNTHESIZER ID': 'GaussianCopulaSynthesizer_1.17.1_7e933de8f72d4291881dfbb7dc822c5f'}
# Synthesizer (SDV): Fitting GaussianCopula.
# [I 20241225 10:25:02] {'EVENT': 'Fit', 'TIMESTAMP': datetime.datetime(2024, 12, 25, 10, 25, 2, 426433), 'SYNTHESIZER CLASS NAME': 'GaussianCopulaSynthesizer', 'SYNTHESIZER ID': 'GaussianCopulaSynthesizer_1.17.1_7e933de8f72d4291881dfbb7dc822c5f', 'TOTAL NUMBER OF TABLES': 1, 'TOTAL NUMBER OF ROWS': 18997, 'TOTAL NUMBER OF COLUMNS': 15}
# [I 20241225 10:25:02] Fitting table  metadata
# [I 20241225 10:25:02] Fitting formatters for table
# [I 20241225 10:25:02] No rounding scheme detected for column 'age'. Data will not be rounded.
# [I 20241225 10:25:02] No rounding scheme detected for column 'workclass'. Data will not be rounded.
# [I 20241225 10:25:02] No rounding scheme detected for column 'fnlwgt'. Data will not be rounded.
# [I 20241225 10:25:02] No rounding scheme detected for column 'education'. Data will not be rounded.
# [I 20241225 10:25:02] No rounding scheme detected for column 'education-num'. Data will not be rounded.
# [I 20241225 10:25:02] No rounding scheme detected for column 'marital-status'. Data will not be rounded.
# [I 20241225 10:25:02] No rounding scheme detected for column 'occupation'. Data will not be rounded.
# [I 20241225 10:25:02] No rounding scheme detected for column 'relationship'. Data will not be rounded.
# [I 20241225 10:25:02] No rounding scheme detected for column 'race'. Data will not be rounded.
# [I 20241225 10:25:02] No rounding scheme detected for column 'sex'. Data will not be rounded.
# [I 20241225 10:25:02] No rounding scheme detected for column 'capital-gain'. Data will not be rounded.
# [I 20241225 10:25:02] No rounding scheme detected for column 'capital-loss'. Data will not be rounded.
# [I 20241225 10:25:02] No rounding scheme detected for column 'hours-per-week'. Data will not be rounded.
# [I 20241225 10:25:02] No rounding scheme detected for column 'native-country'. Data will not be rounded.
# [I 20241225 10:25:02] No rounding scheme detected for column 'income'. Data will not be rounded.
# [I 20241225 10:25:02] Fitting constraints for table
# [I 20241225 10:25:02] Setting the configuration for the ``HyperTransformer`` for table
# [I 20241225 10:25:02] Fitting HyperTransformer for table
# [I 20241225 10:25:02] No rounding scheme detected for column 'age'. Data will not be rounded.
# [I 20241225 10:25:02] No rounding scheme detected for column 'workclass'. Data will not be rounded.
# [I 20241225 10:25:02] No rounding scheme detected for column 'fnlwgt'. Data will not be rounded.
# [I 20241225 10:25:02] No rounding scheme detected for column 'education'. Data will not be rounded.
# [I 20241225 10:25:02] No rounding scheme detected for column 'education-num'. Data will not be rounded.
# [I 20241225 10:25:02] No rounding scheme detected for column 'marital-status'. Data will not be rounded.
# [I 20241225 10:25:02] No rounding scheme detected for column 'occupation'. Data will not be rounded.
# [I 20241225 10:25:02] No rounding scheme detected for column 'relationship'. Data will not be rounded.
# [I 20241225 10:25:02] No rounding scheme detected for column 'race'. Data will not be rounded.
# [I 20241225 10:25:02] No rounding scheme detected for column 'sex'. Data will not be rounded.
# [I 20241225 10:25:02] No rounding scheme detected for column 'capital-gain'. Data will not be rounded.
# [I 20241225 10:25:02] No rounding scheme detected for column 'capital-loss'. Data will not be rounded.
# [I 20241225 10:25:02] No rounding scheme detected for column 'hours-per-week'. Data will not be rounded.
# [I 20241225 10:25:02] No rounding scheme detected for column 'native-country'. Data will not be rounded.
# [I 20241225 10:25:02] No rounding scheme detected for column 'income'. Data will not be rounded.
# [I 20241225 10:25:02] {'EVENT': 'Fit processed data', 'TIMESTAMP': datetime.datetime(2024, 12, 25, 10, 25, 2, 619527), 'SYNTHESIZER CLASS NAME': 'GaussianCopulaSynthesizer', 'SYNTHESIZER ID': 'GaussianCopulaSynthesizer_1.17.1_7e933de8f72d4291881dfbb7dc822c5f', 'TOTAL NUMBER OF TABLES': 1, 'TOTAL NUMBER OF ROWS': 18997, 'TOTAL NUMBER OF COLUMNS': 15}
# [I 20241225 10:25:02] Fitting GaussianMultivariate(distribution="{'age': <class 'copulas.univariate.beta.BetaUnivariate'>, 'workclass': <class 'copulas.univariate.beta.BetaUnivariate'>, 'fnlwgt': <class 'copulas.univariate.beta.BetaUnivariate'>, 'education': <class 'copulas.univariate.beta.BetaUnivariate'>, 'education-num': <class 'copulas.univariate.beta.BetaUnivariate'>, 'marital-status': <class 'copulas.univariate.beta.BetaUnivariate'>, 'occupation': <class 'copulas.univariate.beta.BetaUnivariate'>, 'relationship': <class 'copulas.univariate.beta.BetaUnivariate'>, 'race': <class 'copulas.univariate.beta.BetaUnivariate'>, 'sex': <class 'copulas.univariate.beta.BetaUnivariate'>, 'capital-gain': <class 'copulas.univariate.beta.BetaUnivariate'>, 'capital-loss': <class 'copulas.univariate.beta.BetaUnivariate'>, 'hours-per-week': <class 'copulas.univariate.beta.BetaUnivariate'>, 'native-country': <class 'copulas.univariate.beta.BetaUnivariate'>, 'income': <class 'copulas.univariate.beta.BetaUnivariate'>}")
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdv/single_table/base.py:120: FutureWarning: The 'SingleTableMetadata' is deprecated. Please use the new 'Metadata' class for synthesizers.
#   warnings.warn(DEPRECATION_MSG, FutureWarning)
# Synthesizer (SDV): Fitting GaussianCopula spent 1.4851 sec.
# [I 20241225 10:25:04] {'EVENT': 'Sample', 'TIMESTAMP': datetime.datetime(2024, 12, 25, 10, 25, 3, 911577), 'SYNTHESIZER CLASS NAME': 'GaussianCopulaSynthesizer', 'SYNTHESIZER ID': 'GaussianCopulaSynthesizer_1.17.1_7e933de8f72d4291881dfbb7dc822c5f', 'TOTAL NUMBER OF TABLES': 1, 'TOTAL NUMBER OF ROWS': 32561, 'TOTAL NUMBER OF COLUMNS': 15}
# Synthesizer (SDV): Sampling GaussianCopula # 32561 rows (same as Loader data) in 0.4257 sec.
# Now is Postprocessor with demo...
# [I 20241225 10:25:04] MediatorEncoder is created.
# [I 20241225 10:25:04] scaler inverse transformation done.
# [I 20241225 10:25:04] <petsard.processor.mediator.MediatorEncoder object at 0x32ab09cf0> transformation done.
# [I 20241225 10:25:04] encoder inverse transformation done.
# [I 20241225 10:25:04] missing inverse transformation done.
# [I 20241225 10:25:04] age changes data dtype from float64 to int8 for metadata alignment.
# [I 20241225 10:25:04] workclass changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241225 10:25:04] fnlwgt changes data dtype from float64 to int32 for metadata alignment.
# [I 20241225 10:25:04] education changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241225 10:25:04] education-num changes data dtype from float64 to int8 for metadata alignment.
# [I 20241225 10:25:04] marital-status changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241225 10:25:04] occupation changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241225 10:25:04] relationship changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241225 10:25:04] race changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241225 10:25:04] sex changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241225 10:25:04] capital-gain changes data dtype from float64 to int32 for metadata alignment.
# [I 20241225 10:25:04] capital-loss changes data dtype from float64 to int16 for metadata alignment.
# [I 20241225 10:25:04] hours-per-week changes data dtype from float64 to int8 for metadata alignment.
# [I 20241225 10:25:04] native-country changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241225 10:25:04] income changes data dtype from category[object] to category[object] for metadata alignment.
# Now is Reporter with save_data...
# Now is User Story D-2_Loader[adult]_Preprocessor[demo]_Synthesizer[sdv-gaussian]_Postprocessor[demo] save to csv...

# %%
pp.pprint(exec.get_result())
# Out:
# {'Loader[default]_Preprocessor[demo]_Synthesizer[sdv-gaussian]_Postprocessor[demo]_Reporter[save_data]': {'Loader[default]_Preprocessor[demo]_Synthesizer[sdv-gaussian]_Postprocessor[demo]':        age         workclass  fnlwgt     education  educational-num  \
# 0       53           Private  289692     Bachelors               15
# 1       32           Private  229890       HS-grad               11
# 2       35  Self-emp-not-inc  274308       HS-grad                7
# 3       35           Private  218093  Some-college               10
# 4       50         Local-gov   30968          11th               12
# ...    ...               ...     ...           ...              ...
# 48837   25           Private  110113       HS-grad                8
# 48838   48           Private  127665       HS-grad               11
# 48839   46           Private  132146     Assoc-voc                9
# 48840   41           Private  118226       HS-grad               13
# 48841   27           Private   79861       HS-grad               10
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married      Other-service      Husband  White    Male
# 1      Married-civ-spouse       Tech-support    Own-child  White    Male
# 2           Never-married       Craft-repair    Unmarried  Black  Female
# 3      Married-civ-spouse      Other-service      Husband  White    Male
# 4      Married-civ-spouse    Exec-managerial    Unmarried  White  Female
# ...                   ...                ...          ...    ...     ...
# 48837       Never-married    Exec-managerial      Husband  White    Male
# 48838             Widowed       Adm-clerical    Unmarried  White    Male
# 48839       Never-married  Handlers-cleaners    Own-child  White    Male
# 48840  Married-civ-spouse       Adm-clerical      Husband  Black    Male
# 48841  Married-civ-spouse       Craft-repair      Husband  White    Male
#
#        capital-gain  capital-loss  hours-per-week native-country income
# 0                 0             0              40  United-States  <=50K
# 1                 0             0              38              ?   >50K
# 2                 0             0              34  United-States  <=50K
# 3                 0             0              44  United-States  <=50K
# 4                 0             0              39  United-States  <=50K
# ...             ...           ...             ...            ...    ...
# 48837             0             0              45  United-States  <=50K
# 48838             0             0              33           Cuba   >50K
# 48839             0             0              49  United-States  <=50K
# 48840             0             0              41         Mexico  <=50K
# 48841             0             0              43  United-States  <=50K
#
# [48842 rows x 15 columns]},
#  'Loader[adult]_Preprocessor[demo]_Synthesizer[sdv-gaussian]_Postprocessor[demo]_Reporter[save_data]': {'Loader[adult]_Preprocessor[demo]_Synthesizer[sdv-gaussian]_Postprocessor[demo]':        age          workclass  fnlwgt   education  education-num  \
# 0       35          State-gov  167350        10th              9
# 1       22                  ?  183064     HS-grad              9
# 2       27            Private  293915     HS-grad             12
# 3       46            Private  158805   Bachelors              7
# 4       30            Private  186733   Assoc-voc             14
# ...    ...                ...     ...         ...            ...
# 32556   54   Self-emp-not-inc   95160   Bachelors             13
# 32557   34            Private  197144     HS-grad              9
# 32558   54            Private   69424     HS-grad              8
# 32559   28            Private  128666     HS-grad              8
# 32560   24            Private  153032     HS-grad              9
#
#             marital-status          occupation    relationship  \
# 0       Married-civ-spouse        Craft-repair         Husband
# 1       Married-civ-spouse     Exec-managerial       Own-child
# 2                 Divorced       Other-service       Own-child
# 3       Married-civ-spouse       Other-service         Husband
# 4       Married-civ-spouse        Craft-repair       Unmarried
# ...                    ...                 ...             ...
# 32556   Married-civ-spouse               Sales   Not-in-family
# 32557   Married-civ-spouse        Adm-clerical         Husband
# 32558            Separated       Other-service   Not-in-family
# 32559        Never-married   Machine-op-inspct       Own-child
# 32560        Never-married        Adm-clerical       Own-child
#
#                       race      sex  capital-gain  capital-loss  \
# 0                    White     Male             0             0
# 1                    White     Male             0             0
# 2                    White     Male             0             0
# 3                    White     Male             0             0
# 4                    White   Female             0             0
# ...                    ...      ...           ...           ...
# 32556                White     Male             0             0
# 32557   Asian-Pac-Islander     Male             0             0
# 32558                White     Male             0             0
# 32559                White     Male             0             0
# 32560                White   Female             0             0
#
#        hours-per-week  native-country  income
# 0                  42   United-States    >50K
# 1                  39   United-States   <=50K
# 2                  41   United-States   <=50K
# 3                  41   United-States   <=50K
# 4                  46   United-States   <=50K
# ...               ...             ...     ...
# 32556              43   United-States    >50K
# 32557              40   United-States   <=50K
# 32558              36   United-States   <=50K
# 32559              36   United-States   <=50K
# 32560              42   United-States   <=50K
#
# [32561 rows x 15 columns]}}

# %% [markdown]
# ---
#
# ## User Story D-3
# **Synthesizing and Evaluating on default data**
#
# Following User Story D-1, if users enable the evaluation step,  the evaluation module will create a report covering default privacy risk and utility metrics for all datasets.
#
# 根據用戶故事 D-1，如果使用者啟用評估步驟，評估模組將會產生一份涵蓋所有資料集的隱私風險與效用指標報告。

# %%
config_file = '../yaml/User Story D-3.yaml'

with open(config_file, 'r') as yaml_file:
    yaml_raw: dict = yaml.safe_load(yaml_file)
pp.pprint(yaml_raw)
# Out:
# {'Loader': {'demo': {'method': 'default'}},
#  'Preprocessor': {'demo': {'method': 'default'}},
#  'Synthesizer': {'sdv-gaussian': {'method': 'sdv-single_table-gaussiancopula'}},
#  'Postprocessor': {'demo': {'method': 'default'}},
#  'Evaluator': {'demo': {'method': 'default'}},
#  'Reporter': {'save_data': {'method': 'save_data',
#                             'output': 'User Story D-3',
#                             'source': 'Postprocessor'},
#               'save_report_global': {'method': 'save_report',
#                                      'output': 'User Story D-3',
#                                      'eval': 'demo',
#                                      'granularity': 'global'}}}

# %%
exec = Executor(config=config_file)
exec.run()
# Out:
# Now is Loader with demo...
# Loader - Benchmarker: file benchmark/adult-income.csv already exist and match SHA-256.
#                       petsard will ignore download and use local data directly.
# Now is Preprocessor with demo...
# [I 20241225 10:25:04] MediatorMissing is created.
# [I 20241225 10:25:04] MediatorOutlier is created.
# [I 20241225 10:25:04] MediatorEncoder is created.
# [I 20241225 10:25:04] missing fitting done.
# [I 20241225 10:25:04] <petsard.processor.mediator.MediatorMissing object at 0x32ac2b7f0> fitting done.
# [I 20241225 10:25:04] outlier fitting done.
# [I 20241225 10:25:04] <petsard.processor.mediator.MediatorOutlier object at 0x32ab5ae30> fitting done.
# [I 20241225 10:25:04] encoder fitting done.
# [I 20241225 10:25:04] <petsard.processor.mediator.MediatorEncoder object at 0x32ab5aef0> fitting done.
# [I 20241225 10:25:04] scaler fitting done.
# [I 20241225 10:25:04] missing transformation done.
# [I 20241225 10:25:04] <petsard.processor.mediator.MediatorMissing object at 0x32ac2b7f0> transformation done.
# [I 20241225 10:25:04] outlier transformation done.
# [I 20241225 10:25:04] <petsard.processor.mediator.MediatorOutlier object at 0x32ab5ae30> transformation done.
# [I 20241225 10:25:04] encoder transformation done.
# [I 20241225 10:25:04] <petsard.processor.mediator.MediatorEncoder object at 0x32ab5aef0> transformation done.
# [I 20241225 10:25:04] scaler transformation done.
# Now is Synthesizer with sdv-gaussian...
# [I 20241225 10:25:04] {'EVENT': 'Instance', 'TIMESTAMP': datetime.datetime(2024, 12, 25, 10, 25, 4, 917890), 'SYNTHESIZER CLASS NAME': 'GaussianCopulaSynthesizer', 'SYNTHESIZER ID': 'GaussianCopulaSynthesizer_1.17.1_581d32e16c084c86995e8bbb5b4deb6e'}
# Synthesizer (SDV): Fitting GaussianCopula.
# [I 20241225 10:25:04] {'EVENT': 'Fit', 'TIMESTAMP': datetime.datetime(2024, 12, 25, 10, 25, 4, 918121), 'SYNTHESIZER CLASS NAME': 'GaussianCopulaSynthesizer', 'SYNTHESIZER ID': 'GaussianCopulaSynthesizer_1.17.1_581d32e16c084c86995e8bbb5b4deb6e', 'TOTAL NUMBER OF TABLES': 1, 'TOTAL NUMBER OF ROWS': 28558, 'TOTAL NUMBER OF COLUMNS': 15}
# [I 20241225 10:25:05] Fitting table  metadata
# [I 20241225 10:25:05] Fitting formatters for table
# [I 20241225 10:25:05] No rounding scheme detected for column 'age'. Data will not be rounded.
# [I 20241225 10:25:05] No rounding scheme detected for column 'workclass'. Data will not be rounded.
# [I 20241225 10:25:05] No rounding scheme detected for column 'fnlwgt'. Data will not be rounded.
# [I 20241225 10:25:05] No rounding scheme detected for column 'education'. Data will not be rounded.
# [I 20241225 10:25:05] No rounding scheme detected for column 'educational-num'. Data will not be rounded.
# [I 20241225 10:25:05] No rounding scheme detected for column 'marital-status'. Data will not be rounded.
# [I 20241225 10:25:05] No rounding scheme detected for column 'occupation'. Data will not be rounded.
# [I 20241225 10:25:05] No rounding scheme detected for column 'relationship'. Data will not be rounded.
# [I 20241225 10:25:05] No rounding scheme detected for column 'race'. Data will not be rounded.
# [I 20241225 10:25:05] No rounding scheme detected for column 'gender'. Data will not be rounded.
# [I 20241225 10:25:05] No rounding scheme detected for column 'capital-gain'. Data will not be rounded.
# [I 20241225 10:25:05] No rounding scheme detected for column 'capital-loss'. Data will not be rounded.
# [I 20241225 10:25:05] No rounding scheme detected for column 'hours-per-week'. Data will not be rounded.
# [I 20241225 10:25:05] No rounding scheme detected for column 'native-country'. Data will not be rounded.
# [I 20241225 10:25:05] No rounding scheme detected for column 'income'. Data will not be rounded.
# [I 20241225 10:25:05] Fitting constraints for table
# [I 20241225 10:25:05] Setting the configuration for the ``HyperTransformer`` for table
# [I 20241225 10:25:05] Fitting HyperTransformer for table
# [I 20241225 10:25:05] No rounding scheme detected for column 'age'. Data will not be rounded.
# [I 20241225 10:25:05] No rounding scheme detected for column 'workclass'. Data will not be rounded.
# [I 20241225 10:25:05] No rounding scheme detected for column 'fnlwgt'. Data will not be rounded.
# [I 20241225 10:25:05] No rounding scheme detected for column 'education'. Data will not be rounded.
# [I 20241225 10:25:05] No rounding scheme detected for column 'educational-num'. Data will not be rounded.
# [I 20241225 10:25:05] No rounding scheme detected for column 'marital-status'. Data will not be rounded.
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdv/single_table/base.py:120: FutureWarning: The 'SingleTableMetadata' is deprecated. Please use the new 'Metadata' class for synthesizers.
#   warnings.warn(DEPRECATION_MSG, FutureWarning)
# [I 20241225 10:25:05] No rounding scheme detected for column 'occupation'. Data will not be rounded.
# [I 20241225 10:25:05] No rounding scheme detected for column 'relationship'. Data will not be rounded.
# [I 20241225 10:25:05] No rounding scheme detected for column 'race'. Data will not be rounded.
# [I 20241225 10:25:05] No rounding scheme detected for column 'gender'. Data will not be rounded.
# [I 20241225 10:25:05] No rounding scheme detected for column 'capital-gain'. Data will not be rounded.
# [I 20241225 10:25:05] No rounding scheme detected for column 'capital-loss'. Data will not be rounded.
# [I 20241225 10:25:05] No rounding scheme detected for column 'hours-per-week'. Data will not be rounded.
# [I 20241225 10:25:05] No rounding scheme detected for column 'native-country'. Data will not be rounded.
# [I 20241225 10:25:05] No rounding scheme detected for column 'income'. Data will not be rounded.
# [I 20241225 10:25:05] {'EVENT': 'Fit processed data', 'TIMESTAMP': datetime.datetime(2024, 12, 25, 10, 25, 5, 183682), 'SYNTHESIZER CLASS NAME': 'GaussianCopulaSynthesizer', 'SYNTHESIZER ID': 'GaussianCopulaSynthesizer_1.17.1_581d32e16c084c86995e8bbb5b4deb6e', 'TOTAL NUMBER OF TABLES': 1, 'TOTAL NUMBER OF ROWS': 28558, 'TOTAL NUMBER OF COLUMNS': 15}
# [I 20241225 10:25:05] Fitting GaussianMultivariate(distribution="{'age': <class 'copulas.univariate.beta.BetaUnivariate'>, 'workclass': <class 'copulas.univariate.beta.BetaUnivariate'>, 'fnlwgt': <class 'copulas.univariate.beta.BetaUnivariate'>, 'education': <class 'copulas.univariate.beta.BetaUnivariate'>, 'educational-num': <class 'copulas.univariate.beta.BetaUnivariate'>, 'marital-status': <class 'copulas.univariate.beta.BetaUnivariate'>, 'occupation': <class 'copulas.univariate.beta.BetaUnivariate'>, 'relationship': <class 'copulas.univariate.beta.BetaUnivariate'>, 'race': <class 'copulas.univariate.beta.BetaUnivariate'>, 'gender': <class 'copulas.univariate.beta.BetaUnivariate'>, 'capital-gain': <class 'copulas.univariate.beta.BetaUnivariate'>, 'capital-loss': <class 'copulas.univariate.beta.BetaUnivariate'>, 'hours-per-week': <class 'copulas.univariate.beta.BetaUnivariate'>, 'native-country': <class 'copulas.univariate.beta.BetaUnivariate'>, 'income': <class 'copulas.univariate.beta.BetaUnivariate'>}")
# Synthesizer (SDV): Fitting GaussianCopula spent 2.4956 sec.
# [I 20241225 10:25:07] {'EVENT': 'Sample', 'TIMESTAMP': datetime.datetime(2024, 12, 25, 10, 25, 7, 413741), 'SYNTHESIZER CLASS NAME': 'GaussianCopulaSynthesizer', 'SYNTHESIZER ID': 'GaussianCopulaSynthesizer_1.17.1_581d32e16c084c86995e8bbb5b4deb6e', 'TOTAL NUMBER OF TABLES': 1, 'TOTAL NUMBER OF ROWS': 48842, 'TOTAL NUMBER OF COLUMNS': 15}
# Synthesizer (SDV): Sampling GaussianCopula # 48842 rows (same as Loader data) in 0.5652 sec.
# Now is Postprocessor with demo...
# [I 20241225 10:25:07] MediatorEncoder is created.
# [I 20241225 10:25:07] scaler inverse transformation done.
# [I 20241225 10:25:07] <petsard.processor.mediator.MediatorEncoder object at 0x32ab5aef0> transformation done.
# [I 20241225 10:25:07] encoder inverse transformation done.
# [I 20241225 10:25:07] missing inverse transformation done.
# [I 20241225 10:25:07] age changes data dtype from float64 to int8 for metadata alignment.
# [I 20241225 10:25:07] workclass changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241225 10:25:07] fnlwgt changes data dtype from float64 to int32 for metadata alignment.
# [I 20241225 10:25:07] education changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241225 10:25:07] educational-num changes data dtype from float64 to int8 for metadata alignment.
# [I 20241225 10:25:08] marital-status changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241225 10:25:08] occupation changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241225 10:25:08] relationship changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241225 10:25:08] race changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241225 10:25:08] gender changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241225 10:25:08] capital-gain changes data dtype from float64 to int32 for metadata alignment.
# [I 20241225 10:25:08] capital-loss changes data dtype from float64 to int16 for metadata alignment.
# [I 20241225 10:25:08] hours-per-week changes data dtype from float64 to int8 for metadata alignment.
# [I 20241225 10:25:08] native-country changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241225 10:25:08] income changes data dtype from category[object] to category[object] for metadata alignment.
# Now is Evaluator with demo...
# [I 20241225 10:25:08] workclass changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241225 10:25:08] education changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241225 10:25:08] marital-status changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241225 10:25:08] occupation changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241225 10:25:08] relationship changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241225 10:25:08] race changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241225 10:25:08] gender changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241225 10:25:08] capital-gain changes data dtype from int32 to int32 for metadata alignment.
# [I 20241225 10:25:08] capital-loss changes data dtype from int16 to int16 for metadata alignment.
# [I 20241225 10:25:08] native-country changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241225 10:25:08] income changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241225 10:25:08] Detected metadata:
# [I 20241225 10:25:08] {
#     "columns": {
#         "age": {
#             "sdtype": "numerical"
#         },
#         "workclass": {
#             "sdtype": "categorical"
#         },
#         "fnlwgt": {
#             "sdtype": "numerical"
#         },
#         "education": {
#             "sdtype": "categorical"
#         },
#         "educational-num": {
#             "sdtype": "numerical"
#         },
#         "marital-status": {
#             "sdtype": "categorical"
#         },
#         "occupation": {
#             "sdtype": "categorical"
#         },
#         "relationship": {
#             "sdtype": "categorical"
#         },
#         "race": {
#             "sdtype": "categorical"
#         },
#         "gender": {
#             "sdtype": "categorical"
#         },
#         "capital-gain": {
#             "sdtype": "numerical"
#         },
#         "capital-loss": {
#             "sdtype": "numerical"
#         },
#         "hours-per-week": {
#             "sdtype": "numerical"
#         },
#         "native-country": {
#             "sdtype": "categorical"
#         },
#         "income": {
#             "sdtype": "categorical"
#         }
#     },
#     "METADATA_SPEC_VERSION": "SINGLE_TABLE_V1"
# }
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 15/15 [00:00<00:00, 85.95it/s]|
# Column Shapes Score: 95.41%
#
# (2/2) Evaluating Column Pair Trends: |████▋     | 49/105 [00:00<00:00, 242.99it/s]|
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# ...
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# Overall Score (Average): 78.04%
#
# Now is Reporter with save_data...
# Now is User Story D-3_Loader[demo]_Preprocessor[demo]_Synthesizer[sdv-gaussian]_Postprocessor[demo] save to csv...
# Now is Reporter with save_report_global...
# Now is User Story D-3[Report]_demo_[global] save to csv...

# %%
pp.pprint(exec.get_result())
# Out:
# {'Loader[demo]_Preprocessor[demo]_Synthesizer[sdv-gaussian]_Postprocessor[demo]_Evaluator[demo]_Reporter[save_data]': {'Loader[demo]_Preprocessor[demo]_Synthesizer[sdv-gaussian]_Postprocessor[demo]':        age         workclass  fnlwgt     education  educational-num  \
# 0       38      Self-emp-inc  180795     Bachelors               10
# 1       47           Private  220719  Some-college                7
# 2       44         State-gov  201048     Bachelors               11
# 3       31           Private  177691       HS-grad                8
# 4       42           Private   75222       Masters               13
# ...    ...               ...     ...           ...              ...
# 48837   39           Private   55673  Some-college               10
# 48838   20  Self-emp-not-inc   41130    Assoc-acdm                8
# 48839   21           Private  195825       HS-grad               11
# 48840   54         Local-gov   43509     Assoc-voc                9
# 48841   39           Private   91609     Bachelors                9
#
#            marital-status         occupation   relationship   race  gender  \
# 0      Married-civ-spouse     Prof-specialty  Not-in-family  White    Male
# 1           Never-married       Craft-repair        Husband  Black    Male
# 2                Divorced       Tech-support      Own-child  White    Male
# 3      Married-civ-spouse      Other-service  Not-in-family  White    Male
# 4           Never-married       Craft-repair  Not-in-family  Black  Female
# ...                   ...                ...            ...    ...     ...
# 48837       Never-married  Handlers-cleaners      Own-child  White    Male
# 48838            Divorced       Craft-repair      Own-child  Black    Male
# 48839       Never-married       Craft-repair  Not-in-family  White    Male
# 48840  Married-civ-spouse       Adm-clerical        Husband  White    Male
# 48841  Married-civ-spouse                  ?        Husband  White    Male
#
#        capital-gain  capital-loss  hours-per-week native-country income
# 0                 0             0              45  United-States   >50K
# 1                 0             0              42  United-States  <=50K
# 2                 0             0              34  United-States  <=50K
# 3                 0             0              44  United-States  <=50K
# 4                 0             0              38      Guatemala  <=50K
# ...             ...           ...             ...            ...    ...
# 48837             0             0              43  United-States  <=50K
# 48838             0             0              33  United-States  <=50K
# 48839             0             0              49              ?  <=50K
# 48840             0             0              44  United-States  <=50K
# 48841             0             0              41  United-States  <=50K
#
# [48842 rows x 15 columns]},
#  'Loader[demo]_Preprocessor[demo]_Synthesizer[sdv-gaussian]_Postprocessor[demo]_Evaluator[demo]_Reporter[save_report_global]': {'demo_[global]':                                            full_expt_name Loader Preprocessor  \
# result  Loader[demo]_Preprocessor[demo]_Synthesizer[sd...   demo         demo
#
#          Synthesizer Postprocessor      Evaluator  demo_Score  \
# result  sdv-gaussian          demo  demo_[global]    0.780393
#
#         demo_Column Shapes  demo_Column Pair Trends
# result            0.954078                 0.606708  }}
