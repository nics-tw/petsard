# %% [markdown]
# ## User Story D
# **Research on Benchmark datasets**
#
#
# This demo will show how to use `PETsARD`'s benchmark datasets to evaluate synthetic algorithms.
#
# In this demonstration, as an advanced user with a basic understanding of different differential privacy/synthetic data technologies and their corresponding evaluation metrics, you aim to assess the differences between technologies and other academic and practical issues.
#
# PETsARD provides a complete platform that, by integrating commonly used benchmark datasets in academics, competitions, or practical applications, allows for easy setup of different benchmark datasets, execution on various synthetic algorithms, and execution of different evaluation combinations. This enables you to easily obtain comprehensive data support, focusing on your academic or development work.
#
# 本示範將展示如何使用 `PETsARD` 的基準資料集來評估合成演算法。
#
# 在這個示範中，您作為進階的使用者，對於不同的差分隱私/合成資料技術、以及對應的評測指標有初步理解，希望評估技術彼此之間的差異等學術與實務議題。
#
# 而 `PETsARD` 將提供你完整的平台，藉由預先整合好的，在學術、比賽或實務上常用的基準資料集， `PETsARD` 能輕鬆設定不同基準資料集、執行在不同合成演算法上、並執行不同評測的實驗組合，讓您能輕鬆獲得綜合性資料的支持，專注在您的學術或開發工作上。

# %% [markdown]
# ---
#
# ## Environment

# %%
import os
import pprint
import sys

import yaml


# Setting up the path to the PETsARD package
path_petsard = os.path.dirname(os.getcwd())
print(path_petsard)
sys.path.append(path_petsard)
# setting for pretty priny YAML
pp = pprint.PrettyPrinter(depth=3, sort_dicts=False)


from PETsARD import Executor
# Out:
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD

# %% [markdown]
# ---
#
# ## User Story D-1
# **Synthesizing on default data**
#
# With a specified data generation algorithm, a default benchmark dataset collection will serve as inputs, and the pipeline will generate the corresponding privacy enhanced datasets as output, using the selected algorithm.
#
# 指定資料生成演算法後，預設的經典資料集會用作輸入，並且該流程將使用該演算法輸出對應的隱私強化資料集。

# %%
config_file = '../yaml/User Story D-1.yaml'

with open(config_file, 'r') as yaml_file:
    yaml_raw: dict = yaml.safe_load(yaml_file)
pp.pprint(yaml_raw)
# Out:
# {'Loader': {'demo': {'method': 'default'}},
#  'Preprocessor': {'demo': {'method': 'default'}},
#  'Synthesizer': {'sdv-gaussian': {'method': 'sdv-single_table-gaussiancopula'}},
#  'Postprocessor': {'demo': {'method': 'default'}},
#  'Reporter': {'save_data': {'method': 'save_data',
#                             'output': 'User Story D-1',
#                             'source': 'Postprocessor'}}}

# %%
exec = Executor(config=config_file)
exec.run()
# Out:
# Now is Loader with demo...
# Loader - Benchmarker: file benchmark/adult-income.csv already exist and match SHA-256.
#                       PETsARD will ignore download and use local data directly.
# Now is Preprocessor with demo...
# [I 20241108 10:53:28] MediatorMissing is created.
# [I 20241108 10:53:28] MediatorOutlier is created.
# [I 20241108 10:53:28] MediatorEncoder is created.
# [I 20241108 10:53:28] missing fitting done.
# [I 20241108 10:53:28] <PETsARD.processor.mediator.MediatorMissing object at 0x323bbf2e0> fitting done.
# [I 20241108 10:53:28] outlier fitting done.
# [I 20241108 10:53:28] <PETsARD.processor.mediator.MediatorOutlier object at 0x32564e3e0> fitting done.
# [I 20241108 10:53:28] encoder fitting done.
# [I 20241108 10:53:28] <PETsARD.processor.mediator.MediatorEncoder object at 0x32564f880> fitting done.
# [I 20241108 10:53:28] scaler fitting done.
# [I 20241108 10:53:28] missing transformation done.
# [I 20241108 10:53:28] <PETsARD.processor.mediator.MediatorMissing object at 0x323bbf2e0> transformation done.
# [I 20241108 10:53:28] outlier transformation done.
# [I 20241108 10:53:28] <PETsARD.processor.mediator.MediatorOutlier object at 0x32564e3e0> transformation done.
# [I 20241108 10:53:28] encoder transformation done.
# [I 20241108 10:53:28] <PETsARD.processor.mediator.MediatorEncoder object at 0x32564f880> transformation done.
# [I 20241108 10:53:28] scaler transformation done.
# Now is Synthesizer with sdv-gaussian...
# [I 20241108 10:53:28] {'EVENT': 'Instance', 'TIMESTAMP': datetime.datetime(2024, 11, 8, 10, 53, 28, 411058), 'SYNTHESIZER CLASS NAME': 'GaussianCopulaSynthesizer', 'SYNTHESIZER ID': 'GaussianCopulaSynthesizer_1.17.1_a8d06bb3cad9445694fa47c7e3e54e80'}
# Synthesizer (SDV): Fitting GaussianCopula.
# [I 20241108 10:53:28] {'EVENT': 'Fit', 'TIMESTAMP': datetime.datetime(2024, 11, 8, 10, 53, 28, 411269), 'SYNTHESIZER CLASS NAME': 'GaussianCopulaSynthesizer', 'SYNTHESIZER ID': 'GaussianCopulaSynthesizer_1.17.1_a8d06bb3cad9445694fa47c7e3e54e80', 'TOTAL NUMBER OF TABLES': 1, 'TOTAL NUMBER OF ROWS': 28558, 'TOTAL NUMBER OF COLUMNS': 15}
# [I 20241108 10:53:28] Fitting table  metadata
# [I 20241108 10:53:28] Fitting formatters for table
# [I 20241108 10:53:28] No rounding scheme detected for column 'age'. Data will not be rounded.
# [I 20241108 10:53:28] No rounding scheme detected for column 'workclass'. Data will not be rounded.
# [I 20241108 10:53:28] No rounding scheme detected for column 'fnlwgt'. Data will not be rounded.
# [I 20241108 10:53:28] No rounding scheme detected for column 'education'. Data will not be rounded.
# [I 20241108 10:53:28] No rounding scheme detected for column 'educational-num'. Data will not be rounded.
# [I 20241108 10:53:28] No rounding scheme detected for column 'marital-status'. Data will not be rounded.
# [I 20241108 10:53:28] No rounding scheme detected for column 'occupation'. Data will not be rounded.
# [I 20241108 10:53:28] No rounding scheme detected for column 'relationship'. Data will not be rounded.
# [I 20241108 10:53:28] No rounding scheme detected for column 'race'. Data will not be rounded.
# [I 20241108 10:53:28] No rounding scheme detected for column 'gender'. Data will not be rounded.
# [I 20241108 10:53:28] No rounding scheme detected for column 'capital-gain'. Data will not be rounded.
# [I 20241108 10:53:28] No rounding scheme detected for column 'capital-loss'. Data will not be rounded.
# [I 20241108 10:53:28] No rounding scheme detected for column 'hours-per-week'. Data will not be rounded.
# [I 20241108 10:53:28] No rounding scheme detected for column 'native-country'. Data will not be rounded.
# [I 20241108 10:53:28] No rounding scheme detected for column 'income'. Data will not be rounded.
# [I 20241108 10:53:28] Fitting constraints for table
# [I 20241108 10:53:28] Setting the configuration for the ``HyperTransformer`` for table
# [I 20241108 10:53:28] Fitting HyperTransformer for table
# [I 20241108 10:53:28] No rounding scheme detected for column 'age'. Data will not be rounded.
# [I 20241108 10:53:28] No rounding scheme detected for column 'workclass'. Data will not be rounded.
# [I 20241108 10:53:28] No rounding scheme detected for column 'fnlwgt'. Data will not be rounded.
# [I 20241108 10:53:28] No rounding scheme detected for column 'education'. Data will not be rounded.
# [I 20241108 10:53:28] No rounding scheme detected for column 'educational-num'. Data will not be rounded.
# [I 20241108 10:53:28] No rounding scheme detected for column 'marital-status'. Data will not be rounded.
# [I 20241108 10:53:28] No rounding scheme detected for column 'occupation'. Data will not be rounded.
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdv/single_table/base.py:120: FutureWarning: The 'SingleTableMetadata' is deprecated. Please use the new 'Metadata' class for synthesizers.
#   warnings.warn(DEPRECATION_MSG, FutureWarning)
# [I 20241108 10:53:28] No rounding scheme detected for column 'relationship'. Data will not be rounded.
# [I 20241108 10:53:28] No rounding scheme detected for column 'race'. Data will not be rounded.
# [I 20241108 10:53:28] No rounding scheme detected for column 'gender'. Data will not be rounded.
# [I 20241108 10:53:28] No rounding scheme detected for column 'capital-gain'. Data will not be rounded.
# [I 20241108 10:53:28] No rounding scheme detected for column 'capital-loss'. Data will not be rounded.
# [I 20241108 10:53:28] No rounding scheme detected for column 'hours-per-week'. Data will not be rounded.
# [I 20241108 10:53:28] No rounding scheme detected for column 'native-country'. Data will not be rounded.
# [I 20241108 10:53:28] No rounding scheme detected for column 'income'. Data will not be rounded.
# [I 20241108 10:53:28] {'EVENT': 'Fit processed data', 'TIMESTAMP': datetime.datetime(2024, 11, 8, 10, 53, 28, 663617), 'SYNTHESIZER CLASS NAME': 'GaussianCopulaSynthesizer', 'SYNTHESIZER ID': 'GaussianCopulaSynthesizer_1.17.1_a8d06bb3cad9445694fa47c7e3e54e80', 'TOTAL NUMBER OF TABLES': 1, 'TOTAL NUMBER OF ROWS': 28558, 'TOTAL NUMBER OF COLUMNS': 15}
# [I 20241108 10:53:28] Fitting GaussianMultivariate(distribution="{'age': <class 'copulas.univariate.beta.BetaUnivariate'>, 'workclass': <class 'copulas.univariate.beta.BetaUnivariate'>, 'fnlwgt': <class 'copulas.univariate.beta.BetaUnivariate'>, 'education': <class 'copulas.univariate.beta.BetaUnivariate'>, 'educational-num': <class 'copulas.univariate.beta.BetaUnivariate'>, 'marital-status': <class 'copulas.univariate.beta.BetaUnivariate'>, 'occupation': <class 'copulas.univariate.beta.BetaUnivariate'>, 'relationship': <class 'copulas.univariate.beta.BetaUnivariate'>, 'race': <class 'copulas.univariate.beta.BetaUnivariate'>, 'gender': <class 'copulas.univariate.beta.BetaUnivariate'>, 'capital-gain': <class 'copulas.univariate.beta.BetaUnivariate'>, 'capital-loss': <class 'copulas.univariate.beta.BetaUnivariate'>, 'hours-per-week': <class 'copulas.univariate.beta.BetaUnivariate'>, 'native-country': <class 'copulas.univariate.beta.BetaUnivariate'>, 'income': <class 'copulas.univariate.beta.BetaUnivariate'>}")
# Synthesizer (SDV): Fitting GaussianCopula spent 2.5312 sec.
# [I 20241108 10:53:31] {'EVENT': 'Sample', 'TIMESTAMP': datetime.datetime(2024, 11, 8, 10, 53, 30, 942528), 'SYNTHESIZER CLASS NAME': 'GaussianCopulaSynthesizer', 'SYNTHESIZER ID': 'GaussianCopulaSynthesizer_1.17.1_a8d06bb3cad9445694fa47c7e3e54e80', 'TOTAL NUMBER OF TABLES': 1, 'TOTAL NUMBER OF ROWS': 48842, 'TOTAL NUMBER OF COLUMNS': 15}
# Synthesizer (SDV): Sampling GaussianCopula # 48842 rows (same as Loader data) in 0.597 sec.
# Now is Postprocessor with demo...
# [I 20241108 10:53:31] MediatorEncoder is created.
# [I 20241108 10:53:31] scaler inverse transformation done.
# [I 20241108 10:53:31] <PETsARD.processor.mediator.MediatorEncoder object at 0x32564f880> transformation done.
# [I 20241108 10:53:31] encoder inverse transformation done.
# [I 20241108 10:53:31] missing inverse transformation done.
# [I 20241108 10:53:31] age changes data dtype from float64 to int8 for metadata alignment.
# [I 20241108 10:53:31] workclass changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241108 10:53:31] fnlwgt changes data dtype from float64 to int32 for metadata alignment.
# [I 20241108 10:53:31] education changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241108 10:53:31] educational-num changes data dtype from float64 to int8 for metadata alignment.
# [I 20241108 10:53:31] marital-status changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241108 10:53:31] occupation changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241108 10:53:31] relationship changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241108 10:53:31] race changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241108 10:53:31] gender changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241108 10:53:31] capital-gain changes data dtype from float64 to int32 for metadata alignment.
# [I 20241108 10:53:31] capital-loss changes data dtype from float64 to int16 for metadata alignment.
# [I 20241108 10:53:31] hours-per-week changes data dtype from float64 to int8 for metadata alignment.
# [I 20241108 10:53:31] native-country changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241108 10:53:31] income changes data dtype from category[object] to category[object] for metadata alignment.
# Now is Reporter with save_data...
# Now is User Story D-1_Loader[demo]_Preprocessor[demo]_Synthesizer[sdv-gaussian]_Postprocessor[demo] save to csv...

# %%
pp.pprint(exec.get_result())
# Out:
# {'Loader[demo]_Preprocessor[demo]_Synthesizer[sdv-gaussian]_Postprocessor[demo]_Reporter[save_data]': {'Loader[demo]_Preprocessor[demo]_Synthesizer[sdv-gaussian]_Postprocessor[demo]':        age  workclass  fnlwgt     education  educational-num  \
# 0       36          ?  178572  Some-college               16
# 1       37    Private  234756       HS-grad               11
# 2       28    Private  239395    Assoc-acdm                7
# 3       40    Private  158074       HS-grad               10
# 4       28    Private  153816     Assoc-voc               13
# ...    ...        ...     ...           ...              ...
# 48837   39    Private   50983  Some-college                7
# 48838   19    Private   38358     Bachelors               12
# 48839   25  Local-gov  127916       HS-grad               10
# 48840   43    Private   74163     Bachelors               13
# 48841   51    Private   99458       Masters                9
#
#            marital-status         occupation   relationship   race  gender  \
# 0      Married-civ-spouse              Sales        Husband  White    Male
# 1           Never-married    Exec-managerial  Not-in-family  White    Male
# 2           Never-married       Adm-clerical      Unmarried  White    Male
# 3           Never-married    Farming-fishing        Husband  White    Male
# 4           Never-married     Prof-specialty           Wife  White    Male
# ...                   ...                ...            ...    ...     ...
# 48837       Never-married      Other-service        Husband  White    Male
# 48838  Married-civ-spouse              Sales  Not-in-family  Black  Female
# 48839  Married-civ-spouse              Sales      Own-child  White    Male
# 48840       Never-married       Adm-clerical        Husband  White    Male
# 48841  Married-civ-spouse  Machine-op-inspct        Husband  White    Male
#
#        capital-gain  capital-loss  hours-per-week native-country income
# 0                 0             0              42  United-States  <=50K
# 1                 0             0              43  United-States  <=50K
# 2                 0             0              37  United-States  <=50K
# 3                 0             0              40  United-States  <=50K
# 4                 0             0              41  United-States  <=50K
# ...             ...           ...             ...            ...    ...
# 48837             0             0              44  United-States  <=50K
# 48838             0             0              34  United-States  <=50K
# 48839             0             0              46          Haiti  <=50K
# 48840             0             0              45  United-States  <=50K
# 48841             0             0              41  United-States  <=50K
#
# [48842 rows x 15 columns]}}

# %% [markdown]
# ---
#
# ## User Story D-2
# **Synthesizing on multiple data**
#
# Following User Story D-1, the user can specify a list of datasets instead.
#
# 根據用戶故事 D-1，使用者可以改為指定一個資料集列表。

# %%
config_file = '../yaml/User Story D-2.yaml'

with open(config_file, 'r') as yaml_file:
    yaml_raw: dict = yaml.safe_load(yaml_file)
pp.pprint(yaml_raw)
# Out:
# {'Loader': {'default': {'method': 'default'},
#             'adult': {'filepath': 'benchmark://adult', 'na_values': {...}}},
#  'Preprocessor': {'demo': {'method': 'default'}},
#  'Synthesizer': {'sdv-gaussian': {'method': 'sdv-single_table-gaussiancopula'}},
#  'Postprocessor': {'demo': {'method': 'default'}},
#  'Reporter': {'save_data': {'method': 'save_data',
#                             'output': 'User Story D-2',
#                             'source': 'Postprocessor'}}}

# %%
exec = Executor(config=config_file)
exec.run()
# Out:
# Now is Loader with default...
# Loader - Benchmarker: file benchmark/adult-income.csv already exist and match SHA-256.
#                       PETsARD will ignore download and use local data directly.
# Now is Preprocessor with demo...
# [I 20241108 10:53:31] MediatorMissing is created.
# [I 20241108 10:53:31] MediatorOutlier is created.
# [I 20241108 10:53:31] MediatorEncoder is created.
# [I 20241108 10:53:31] missing fitting done.
# [I 20241108 10:53:31] <PETsARD.processor.mediator.MediatorMissing object at 0x325553a00> fitting done.
# [I 20241108 10:53:31] outlier fitting done.
# [I 20241108 10:53:31] <PETsARD.processor.mediator.MediatorOutlier object at 0x3256a5360> fitting done.
# [I 20241108 10:53:31] encoder fitting done.
# [I 20241108 10:53:31] <PETsARD.processor.mediator.MediatorEncoder object at 0x3256a7760> fitting done.
# [I 20241108 10:53:31] scaler fitting done.
# [I 20241108 10:53:31] missing transformation done.
# [I 20241108 10:53:31] <PETsARD.processor.mediator.MediatorMissing object at 0x325553a00> transformation done.
# [I 20241108 10:53:31] outlier transformation done.
# [I 20241108 10:53:31] <PETsARD.processor.mediator.MediatorOutlier object at 0x3256a5360> transformation done.
# [I 20241108 10:53:32] encoder transformation done.
# [I 20241108 10:53:32] <PETsARD.processor.mediator.MediatorEncoder object at 0x3256a7760> transformation done.
# [I 20241108 10:53:32] scaler transformation done.
# Now is Synthesizer with sdv-gaussian...
# [I 20241108 10:53:32] {'EVENT': 'Instance', 'TIMESTAMP': datetime.datetime(2024, 11, 8, 10, 53, 32, 138308), 'SYNTHESIZER CLASS NAME': 'GaussianCopulaSynthesizer', 'SYNTHESIZER ID': 'GaussianCopulaSynthesizer_1.17.1_d3175d5161e9425da3f126b53068e931'}
# Synthesizer (SDV): Fitting GaussianCopula.
# [I 20241108 10:53:32] {'EVENT': 'Fit', 'TIMESTAMP': datetime.datetime(2024, 11, 8, 10, 53, 32, 138505), 'SYNTHESIZER CLASS NAME': 'GaussianCopulaSynthesizer', 'SYNTHESIZER ID': 'GaussianCopulaSynthesizer_1.17.1_d3175d5161e9425da3f126b53068e931', 'TOTAL NUMBER OF TABLES': 1, 'TOTAL NUMBER OF ROWS': 28558, 'TOTAL NUMBER OF COLUMNS': 15}
# [I 20241108 10:53:32] Fitting table  metadata
# [I 20241108 10:53:32] Fitting formatters for table
# [I 20241108 10:53:32] No rounding scheme detected for column 'age'. Data will not be rounded.
# [I 20241108 10:53:32] No rounding scheme detected for column 'workclass'. Data will not be rounded.
# [I 20241108 10:53:32] No rounding scheme detected for column 'fnlwgt'. Data will not be rounded.
# [I 20241108 10:53:32] No rounding scheme detected for column 'education'. Data will not be rounded.
# [I 20241108 10:53:32] No rounding scheme detected for column 'educational-num'. Data will not be rounded.
# [I 20241108 10:53:32] No rounding scheme detected for column 'marital-status'. Data will not be rounded.
# [I 20241108 10:53:32] No rounding scheme detected for column 'occupation'. Data will not be rounded.
# [I 20241108 10:53:32] No rounding scheme detected for column 'relationship'. Data will not be rounded.
# [I 20241108 10:53:32] No rounding scheme detected for column 'race'. Data will not be rounded.
# [I 20241108 10:53:32] No rounding scheme detected for column 'gender'. Data will not be rounded.
# [I 20241108 10:53:32] No rounding scheme detected for column 'capital-gain'. Data will not be rounded.
# [I 20241108 10:53:32] No rounding scheme detected for column 'capital-loss'. Data will not be rounded.
# [I 20241108 10:53:32] No rounding scheme detected for column 'hours-per-week'. Data will not be rounded.
# [I 20241108 10:53:32] No rounding scheme detected for column 'native-country'. Data will not be rounded.
# [I 20241108 10:53:32] No rounding scheme detected for column 'income'. Data will not be rounded.
# [I 20241108 10:53:32] Fitting constraints for table
# [I 20241108 10:53:32] Setting the configuration for the ``HyperTransformer`` for table
# [I 20241108 10:53:32] Fitting HyperTransformer for table
# [I 20241108 10:53:32] No rounding scheme detected for column 'age'. Data will not be rounded.
# [I 20241108 10:53:32] No rounding scheme detected for column 'workclass'. Data will not be rounded.
# [I 20241108 10:53:32] No rounding scheme detected for column 'fnlwgt'. Data will not be rounded.
# [I 20241108 10:53:32] No rounding scheme detected for column 'education'. Data will not be rounded.
# [I 20241108 10:53:32] No rounding scheme detected for column 'educational-num'. Data will not be rounded.
# [I 20241108 10:53:32] No rounding scheme detected for column 'marital-status'. Data will not be rounded.
# [I 20241108 10:53:32] No rounding scheme detected for column 'occupation'. Data will not be rounded.
# [I 20241108 10:53:32] No rounding scheme detected for column 'relationship'. Data will not be rounded.
# [I 20241108 10:53:32] No rounding scheme detected for column 'race'. Data will not be rounded.
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdv/single_table/base.py:120: FutureWarning: The 'SingleTableMetadata' is deprecated. Please use the new 'Metadata' class for synthesizers.
#   warnings.warn(DEPRECATION_MSG, FutureWarning)
# [I 20241108 10:53:32] No rounding scheme detected for column 'gender'. Data will not be rounded.
# [I 20241108 10:53:32] No rounding scheme detected for column 'capital-gain'. Data will not be rounded.
# [I 20241108 10:53:32] No rounding scheme detected for column 'capital-loss'. Data will not be rounded.
# [I 20241108 10:53:32] No rounding scheme detected for column 'hours-per-week'. Data will not be rounded.
# [I 20241108 10:53:32] No rounding scheme detected for column 'native-country'. Data will not be rounded.
# [I 20241108 10:53:32] No rounding scheme detected for column 'income'. Data will not be rounded.
# [I 20241108 10:53:32] {'EVENT': 'Fit processed data', 'TIMESTAMP': datetime.datetime(2024, 11, 8, 10, 53, 32, 386597), 'SYNTHESIZER CLASS NAME': 'GaussianCopulaSynthesizer', 'SYNTHESIZER ID': 'GaussianCopulaSynthesizer_1.17.1_d3175d5161e9425da3f126b53068e931', 'TOTAL NUMBER OF TABLES': 1, 'TOTAL NUMBER OF ROWS': 28558, 'TOTAL NUMBER OF COLUMNS': 15}
# [I 20241108 10:53:32] Fitting GaussianMultivariate(distribution="{'age': <class 'copulas.univariate.beta.BetaUnivariate'>, 'workclass': <class 'copulas.univariate.beta.BetaUnivariate'>, 'fnlwgt': <class 'copulas.univariate.beta.BetaUnivariate'>, 'education': <class 'copulas.univariate.beta.BetaUnivariate'>, 'educational-num': <class 'copulas.univariate.beta.BetaUnivariate'>, 'marital-status': <class 'copulas.univariate.beta.BetaUnivariate'>, 'occupation': <class 'copulas.univariate.beta.BetaUnivariate'>, 'relationship': <class 'copulas.univariate.beta.BetaUnivariate'>, 'race': <class 'copulas.univariate.beta.BetaUnivariate'>, 'gender': <class 'copulas.univariate.beta.BetaUnivariate'>, 'capital-gain': <class 'copulas.univariate.beta.BetaUnivariate'>, 'capital-loss': <class 'copulas.univariate.beta.BetaUnivariate'>, 'hours-per-week': <class 'copulas.univariate.beta.BetaUnivariate'>, 'native-country': <class 'copulas.univariate.beta.BetaUnivariate'>, 'income': <class 'copulas.univariate.beta.BetaUnivariate'>}")
# Synthesizer (SDV): Fitting GaussianCopula spent 2.4869 sec.
# [I 20241108 10:53:35] {'EVENT': 'Sample', 'TIMESTAMP': datetime.datetime(2024, 11, 8, 10, 53, 34, 625423), 'SYNTHESIZER CLASS NAME': 'GaussianCopulaSynthesizer', 'SYNTHESIZER ID': 'GaussianCopulaSynthesizer_1.17.1_d3175d5161e9425da3f126b53068e931', 'TOTAL NUMBER OF TABLES': 1, 'TOTAL NUMBER OF ROWS': 48842, 'TOTAL NUMBER OF COLUMNS': 15}
# Synthesizer (SDV): Sampling GaussianCopula # 48842 rows (same as Loader data) in 0.5017 sec.
# Now is Postprocessor with demo...
# [I 20241108 10:53:35] MediatorEncoder is created.
# [I 20241108 10:53:35] scaler inverse transformation done.
# [I 20241108 10:53:35] <PETsARD.processor.mediator.MediatorEncoder object at 0x3256a7760> transformation done.
# [I 20241108 10:53:35] encoder inverse transformation done.
# [I 20241108 10:53:35] missing inverse transformation done.
# [I 20241108 10:53:35] age changes data dtype from float64 to int8 for metadata alignment.
# [I 20241108 10:53:35] workclass changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241108 10:53:35] fnlwgt changes data dtype from float64 to int32 for metadata alignment.
# [I 20241108 10:53:35] education changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241108 10:53:35] educational-num changes data dtype from float64 to int8 for metadata alignment.
# [I 20241108 10:53:35] marital-status changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241108 10:53:35] occupation changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241108 10:53:35] relationship changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241108 10:53:35] race changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241108 10:53:35] gender changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241108 10:53:35] capital-gain changes data dtype from float64 to int32 for metadata alignment.
# [I 20241108 10:53:35] capital-loss changes data dtype from float64 to int16 for metadata alignment.
# [I 20241108 10:53:35] hours-per-week changes data dtype from float64 to int8 for metadata alignment.
# [I 20241108 10:53:35] native-country changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241108 10:53:35] income changes data dtype from category[object] to category[object] for metadata alignment.
# Now is Reporter with save_data...
# Now is User Story D-2_Loader[default]_Preprocessor[demo]_Synthesizer[sdv-gaussian]_Postprocessor[demo] save to csv...
# Now is Loader with adult...
# Loader - Benchmarker: file benchmark/adult_uci.csv already exist and match SHA-256.
#                       PETsARD will ignore download and use local data directly.
# Now is Preprocessor with demo...
# [I 20241108 10:53:35] MediatorMissing is created.
# [I 20241108 10:53:35] MediatorOutlier is created.
# [I 20241108 10:53:35] MediatorEncoder is created.
# [I 20241108 10:53:35] missing fitting done.
# [I 20241108 10:53:35] <PETsARD.processor.mediator.MediatorMissing object at 0x323bbd120> fitting done.
# [I 20241108 10:53:35] outlier fitting done.
# [I 20241108 10:53:35] <PETsARD.processor.mediator.MediatorOutlier object at 0x3256a48e0> fitting done.
# [I 20241108 10:53:35] encoder fitting done.
# [I 20241108 10:53:35] <PETsARD.processor.mediator.MediatorEncoder object at 0x3256a6fb0> fitting done.
# [I 20241108 10:53:35] scaler fitting done.
# [I 20241108 10:53:35] missing transformation done.
# [I 20241108 10:53:35] <PETsARD.processor.mediator.MediatorMissing object at 0x323bbd120> transformation done.
# [I 20241108 10:53:35] outlier transformation done.
# [I 20241108 10:53:35] <PETsARD.processor.mediator.MediatorOutlier object at 0x3256a48e0> transformation done.
# [I 20241108 10:53:35] encoder transformation done.
# [I 20241108 10:53:35] <PETsARD.processor.mediator.MediatorEncoder object at 0x3256a6fb0> transformation done.
# [I 20241108 10:53:35] scaler transformation done.
# Now is Synthesizer with sdv-gaussian...
# [I 20241108 10:53:35] {'EVENT': 'Instance', 'TIMESTAMP': datetime.datetime(2024, 11, 8, 10, 53, 35, 529987), 'SYNTHESIZER CLASS NAME': 'GaussianCopulaSynthesizer', 'SYNTHESIZER ID': 'GaussianCopulaSynthesizer_1.17.1_32e927e3dc154256897a1d698d0539aa'}
# Synthesizer (SDV): Fitting GaussianCopula.
# [I 20241108 10:53:35] {'EVENT': 'Fit', 'TIMESTAMP': datetime.datetime(2024, 11, 8, 10, 53, 35, 530188), 'SYNTHESIZER CLASS NAME': 'GaussianCopulaSynthesizer', 'SYNTHESIZER ID': 'GaussianCopulaSynthesizer_1.17.1_32e927e3dc154256897a1d698d0539aa', 'TOTAL NUMBER OF TABLES': 1, 'TOTAL NUMBER OF ROWS': 18997, 'TOTAL NUMBER OF COLUMNS': 15}
# [I 20241108 10:53:35] Fitting table  metadata
# [I 20241108 10:53:35] Fitting formatters for table
# [I 20241108 10:53:35] No rounding scheme detected for column 'age'. Data will not be rounded.
# [I 20241108 10:53:35] No rounding scheme detected for column 'workclass'. Data will not be rounded.
# [I 20241108 10:53:35] No rounding scheme detected for column 'fnlwgt'. Data will not be rounded.
# [I 20241108 10:53:35] No rounding scheme detected for column 'education'. Data will not be rounded.
# [I 20241108 10:53:35] No rounding scheme detected for column 'education-num'. Data will not be rounded.
# [I 20241108 10:53:35] No rounding scheme detected for column 'marital-status'. Data will not be rounded.
# [I 20241108 10:53:35] No rounding scheme detected for column 'occupation'. Data will not be rounded.
# [I 20241108 10:53:35] No rounding scheme detected for column 'relationship'. Data will not be rounded.
# [I 20241108 10:53:35] No rounding scheme detected for column 'race'. Data will not be rounded.
# [I 20241108 10:53:35] No rounding scheme detected for column 'sex'. Data will not be rounded.
# [I 20241108 10:53:35] No rounding scheme detected for column 'capital-gain'. Data will not be rounded.
# [I 20241108 10:53:35] No rounding scheme detected for column 'capital-loss'. Data will not be rounded.
# [I 20241108 10:53:35] No rounding scheme detected for column 'hours-per-week'. Data will not be rounded.
# [I 20241108 10:53:35] No rounding scheme detected for column 'native-country'. Data will not be rounded.
# [I 20241108 10:53:35] No rounding scheme detected for column 'income'. Data will not be rounded.
# [I 20241108 10:53:35] Fitting constraints for table
# [I 20241108 10:53:35] Setting the configuration for the ``HyperTransformer`` for table
# [I 20241108 10:53:35] Fitting HyperTransformer for table
# [I 20241108 10:53:35] No rounding scheme detected for column 'age'. Data will not be rounded.
# [I 20241108 10:53:35] No rounding scheme detected for column 'workclass'. Data will not be rounded.
# [I 20241108 10:53:35] No rounding scheme detected for column 'fnlwgt'. Data will not be rounded.
# [I 20241108 10:53:35] No rounding scheme detected for column 'education'. Data will not be rounded.
# [I 20241108 10:53:35] No rounding scheme detected for column 'education-num'. Data will not be rounded.
# [I 20241108 10:53:35] No rounding scheme detected for column 'marital-status'. Data will not be rounded.
# [I 20241108 10:53:35] No rounding scheme detected for column 'occupation'. Data will not be rounded.
# [I 20241108 10:53:35] No rounding scheme detected for column 'relationship'. Data will not be rounded.
# [I 20241108 10:53:35] No rounding scheme detected for column 'race'. Data will not be rounded.
# [I 20241108 10:53:35] No rounding scheme detected for column 'sex'. Data will not be rounded.
# [I 20241108 10:53:35] No rounding scheme detected for column 'capital-gain'. Data will not be rounded.
# [I 20241108 10:53:35] No rounding scheme detected for column 'capital-loss'. Data will not be rounded.
# [I 20241108 10:53:35] No rounding scheme detected for column 'hours-per-week'. Data will not be rounded.
# [I 20241108 10:53:35] No rounding scheme detected for column 'native-country'. Data will not be rounded.
# [I 20241108 10:53:35] No rounding scheme detected for column 'income'. Data will not be rounded.
# [I 20241108 10:53:35] {'EVENT': 'Fit processed data', 'TIMESTAMP': datetime.datetime(2024, 11, 8, 10, 53, 35, 708377), 'SYNTHESIZER CLASS NAME': 'GaussianCopulaSynthesizer', 'SYNTHESIZER ID': 'GaussianCopulaSynthesizer_1.17.1_32e927e3dc154256897a1d698d0539aa', 'TOTAL NUMBER OF TABLES': 1, 'TOTAL NUMBER OF ROWS': 18997, 'TOTAL NUMBER OF COLUMNS': 15}
# [I 20241108 10:53:35] Fitting GaussianMultivariate(distribution="{'age': <class 'copulas.univariate.beta.BetaUnivariate'>, 'workclass': <class 'copulas.univariate.beta.BetaUnivariate'>, 'fnlwgt': <class 'copulas.univariate.beta.BetaUnivariate'>, 'education': <class 'copulas.univariate.beta.BetaUnivariate'>, 'education-num': <class 'copulas.univariate.beta.BetaUnivariate'>, 'marital-status': <class 'copulas.univariate.beta.BetaUnivariate'>, 'occupation': <class 'copulas.univariate.beta.BetaUnivariate'>, 'relationship': <class 'copulas.univariate.beta.BetaUnivariate'>, 'race': <class 'copulas.univariate.beta.BetaUnivariate'>, 'sex': <class 'copulas.univariate.beta.BetaUnivariate'>, 'capital-gain': <class 'copulas.univariate.beta.BetaUnivariate'>, 'capital-loss': <class 'copulas.univariate.beta.BetaUnivariate'>, 'hours-per-week': <class 'copulas.univariate.beta.BetaUnivariate'>, 'native-country': <class 'copulas.univariate.beta.BetaUnivariate'>, 'income': <class 'copulas.univariate.beta.BetaUnivariate'>}")
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdv/single_table/base.py:120: FutureWarning: The 'SingleTableMetadata' is deprecated. Please use the new 'Metadata' class for synthesizers.
#   warnings.warn(DEPRECATION_MSG, FutureWarning)
# Synthesizer (SDV): Fitting GaussianCopula spent 1.5715 sec.
# [I 20241108 10:53:37] {'EVENT': 'Sample', 'TIMESTAMP': datetime.datetime(2024, 11, 8, 10, 53, 37, 101767), 'SYNTHESIZER CLASS NAME': 'GaussianCopulaSynthesizer', 'SYNTHESIZER ID': 'GaussianCopulaSynthesizer_1.17.1_32e927e3dc154256897a1d698d0539aa', 'TOTAL NUMBER OF TABLES': 1, 'TOTAL NUMBER OF ROWS': 32561, 'TOTAL NUMBER OF COLUMNS': 15}
# Synthesizer (SDV): Sampling GaussianCopula # 32561 rows (same as Loader data) in 0.3903 sec.
# Now is Postprocessor with demo...
# [I 20241108 10:53:37] MediatorEncoder is created.
# [I 20241108 10:53:37] scaler inverse transformation done.
# [I 20241108 10:53:37] <PETsARD.processor.mediator.MediatorEncoder object at 0x3256a6fb0> transformation done.
# [I 20241108 10:53:37] encoder inverse transformation done.
# [I 20241108 10:53:37] missing inverse transformation done.
# [I 20241108 10:53:37] age changes data dtype from float64 to int8 for metadata alignment.
# [I 20241108 10:53:37] workclass changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241108 10:53:37] fnlwgt changes data dtype from float64 to int32 for metadata alignment.
# [I 20241108 10:53:37] education changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241108 10:53:37] education-num changes data dtype from float64 to int8 for metadata alignment.
# [I 20241108 10:53:37] marital-status changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241108 10:53:37] occupation changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241108 10:53:37] relationship changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241108 10:53:37] race changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241108 10:53:37] sex changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241108 10:53:37] capital-gain changes data dtype from float64 to int32 for metadata alignment.
# [I 20241108 10:53:37] capital-loss changes data dtype from float64 to int16 for metadata alignment.
# [I 20241108 10:53:37] hours-per-week changes data dtype from float64 to int8 for metadata alignment.
# [I 20241108 10:53:37] native-country changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241108 10:53:37] income changes data dtype from category[object] to category[object] for metadata alignment.
# Now is Reporter with save_data...
# Now is User Story D-2_Loader[adult]_Preprocessor[demo]_Synthesizer[sdv-gaussian]_Postprocessor[demo] save to csv...

# %%
pp.pprint(exec.get_result())
# Out:
# {'Loader[default]_Preprocessor[demo]_Synthesizer[sdv-gaussian]_Postprocessor[demo]_Reporter[save_data]': {'Loader[default]_Preprocessor[demo]_Synthesizer[sdv-gaussian]_Postprocessor[demo]':        age         workclass  fnlwgt     education  educational-num  \
# 0       45           Private   84837  Some-college               16
# 1       21           Private   77454       HS-grad               11
# 2       33  Self-emp-not-inc   40725     Bachelors                7
# 3       45           Private  200900  Some-college               10
# 4       53      Self-emp-inc  249495     Bachelors               11
# ...    ...               ...     ...           ...              ...
# 48837   34  Self-emp-not-inc  262869  Some-college                8
# 48838   20       Federal-gov  243501       HS-grad               12
# 48839   28           Private  284252  Some-college               10
# 48840   49         State-gov  139576       HS-grad               12
# 48841   38           Private  321368     Bachelors                9
#
#            marital-status         occupation   relationship   race  gender  \
# 0      Married-civ-spouse       Adm-clerical        Husband  White    Male
# 1      Married-civ-spouse      Other-service  Not-in-family  White    Male
# 2                Divorced      Other-service      Unmarried  White  Female
# 3      Married-civ-spouse  Machine-op-inspct        Husband  White    Male
# 4                 Widowed       Craft-repair  Not-in-family  White  Female
# ...                   ...                ...            ...    ...     ...
# 48837  Married-civ-spouse                  ?      Own-child  White    Male
# 48838       Never-married    Farming-fishing      Own-child  White  Female
# 48839  Married-civ-spouse     Prof-specialty        Husband  White    Male
# 48840       Never-married                  ?        Husband  White    Male
# 48841  Married-civ-spouse  Handlers-cleaners  Not-in-family  White    Male
#
#        capital-gain  capital-loss  hours-per-week native-country income
# 0                 0             0              46  United-States  <=50K
# 1                 0             0              40  United-States  <=50K
# 2                 0             0              45  United-States  <=50K
# 3                 0             0              40  United-States  <=50K
# 4                 0             0              37  United-States   >50K
# ...             ...           ...             ...            ...    ...
# 48837             0             0              39  United-States  <=50K
# 48838             0             0              52  United-States  <=50K
# 48839             0             0              36  United-States  <=50K
# 48840             0             0              41  United-States   >50K
# 48841             0             0              42  United-States   >50K
#
# [48842 rows x 15 columns]},
#  'Loader[adult]_Preprocessor[demo]_Synthesizer[sdv-gaussian]_Postprocessor[demo]_Reporter[save_data]': {'Loader[adult]_Preprocessor[demo]_Synthesizer[sdv-gaussian]_Postprocessor[demo]':        age   workclass  fnlwgt      education  education-num  \
# 0       50     Private   85936   Some-college             15
# 1       58     Private  142772      Bachelors              9
# 2       35     Private  105572        HS-grad              7
# 3       30     Private  137073        HS-grad             10
# 4       25     Private  327108           10th             13
# ...    ...         ...     ...            ...            ...
# 32556   55     Private   41607      Bachelors             11
# 32557   20     Private  368199   Some-college              9
# 32558   37   State-gov   99520        HS-grad              8
# 32559   31     Private  221281        HS-grad              8
# 32560   34     Private  154765        HS-grad              8
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married       Other-service         Husband   White
# 1            Never-married   Handlers-cleaners   Not-in-family   White
# 2            Never-married      Prof-specialty       Unmarried   White
# 3       Married-civ-spouse       Other-service         Husband   White
# 4            Never-married      Prof-specialty            Wife   White
# ...                    ...                 ...             ...     ...
# 32556   Married-civ-spouse     Exec-managerial   Not-in-family   White
# 32557   Married-civ-spouse     Exec-managerial         Husband   White
# 32558   Married-civ-spouse   Handlers-cleaners         Husband   White
# 32559   Married-civ-spouse   Machine-op-inspct   Not-in-family   White
# 32560             Divorced        Adm-clerical       Unmarried   White
#
#            sex  capital-gain  capital-loss  hours-per-week  native-country  \
# 0         Male             0             0              42   United-States
# 1         Male             0             0              41   United-States
# 2       Female             0             0              45   United-States
# 3         Male             0             0              39   United-States
# 4         Male             0             0              42   United-States
# ...        ...           ...           ...             ...             ...
# 32556     Male             0             0              43   United-States
# 32557     Male             0             0              37   United-States
# 32558   Female             0             0              38   United-States
# 32559   Female             0             0              36   United-States
# 32560     Male             0             0              40   United-States
#
#        income
# 0        >50K
# 1       <=50K
# 2       <=50K
# 3       <=50K
# 4       <=50K
# ...       ...
# 32556    >50K
# 32557   <=50K
# 32558   <=50K
# 32559   <=50K
# 32560   <=50K
#
# [32561 rows x 15 columns]}}

# %% [markdown]
# ---
#
# ## User Story D-3
# **Synthesizing and Evaluating on default data**
#
# Following User Story D-1, if users enable the evaluation step,  the evaluation module will create a report covering default privacy risk and utility metrics for all datasets.
#
# 根據用戶故事 D-1，如果使用者啟用評估步驟，評估模組將會產生一份涵蓋所有資料集的隱私風險與效用指標報告。

# %%
config_file = '../yaml/User Story D-3.yaml'

with open(config_file, 'r') as yaml_file:
    yaml_raw: dict = yaml.safe_load(yaml_file)
pp.pprint(yaml_raw)
# Out:
# {'Loader': {'demo': {'method': 'default'}},
#  'Preprocessor': {'demo': {'method': 'default'}},
#  'Synthesizer': {'sdv-gaussian': {'method': 'sdv-single_table-gaussiancopula'}},
#  'Postprocessor': {'demo': {'method': 'default'}},
#  'Evaluator': {'demo': {'method': 'default'}},
#  'Reporter': {'save_data': {'method': 'save_data',
#                             'output': 'User Story D-3',
#                             'source': 'Postprocessor'},
#               'save_report_global': {'method': 'save_report',
#                                      'output': 'User Story D-3',
#                                      'eval': 'demo',
#                                      'granularity': 'global'}}}

# %%
exec = Executor(config=config_file)
exec.run()
# Out:
# Now is Loader with demo...
# Loader - Benchmarker: file benchmark/adult-income.csv already exist and match SHA-256.
#                       PETsARD will ignore download and use local data directly.
# Now is Preprocessor with demo...
# [I 20241108 10:53:37] MediatorMissing is created.
# [I 20241108 10:53:37] MediatorOutlier is created.
# [I 20241108 10:53:37] MediatorEncoder is created.
# [I 20241108 10:53:37] missing fitting done.
# [I 20241108 10:53:37] <PETsARD.processor.mediator.MediatorMissing object at 0x3256a78b0> fitting done.
# [I 20241108 10:53:37] outlier fitting done.
# [I 20241108 10:53:37] <PETsARD.processor.mediator.MediatorOutlier object at 0x3255ca110> fitting done.
# [I 20241108 10:53:37] encoder fitting done.
# [I 20241108 10:53:37] <PETsARD.processor.mediator.MediatorEncoder object at 0x3255c9840> fitting done.
# [I 20241108 10:53:37] scaler fitting done.
# [I 20241108 10:53:37] missing transformation done.
# [I 20241108 10:53:37] <PETsARD.processor.mediator.MediatorMissing object at 0x3256a78b0> transformation done.
# [I 20241108 10:53:37] outlier transformation done.
# [I 20241108 10:53:37] <PETsARD.processor.mediator.MediatorOutlier object at 0x3255ca110> transformation done.
# [I 20241108 10:53:38] encoder transformation done.
# [I 20241108 10:53:38] <PETsARD.processor.mediator.MediatorEncoder object at 0x3255c9840> transformation done.
# [I 20241108 10:53:38] scaler transformation done.
# Now is Synthesizer with sdv-gaussian...
# [I 20241108 10:53:38] {'EVENT': 'Instance', 'TIMESTAMP': datetime.datetime(2024, 11, 8, 10, 53, 38, 47672), 'SYNTHESIZER CLASS NAME': 'GaussianCopulaSynthesizer', 'SYNTHESIZER ID': 'GaussianCopulaSynthesizer_1.17.1_e3ad61c08ef54498915d53300fc9d68c'}
# Synthesizer (SDV): Fitting GaussianCopula.
# [I 20241108 10:53:38] {'EVENT': 'Fit', 'TIMESTAMP': datetime.datetime(2024, 11, 8, 10, 53, 38, 47877), 'SYNTHESIZER CLASS NAME': 'GaussianCopulaSynthesizer', 'SYNTHESIZER ID': 'GaussianCopulaSynthesizer_1.17.1_e3ad61c08ef54498915d53300fc9d68c', 'TOTAL NUMBER OF TABLES': 1, 'TOTAL NUMBER OF ROWS': 28558, 'TOTAL NUMBER OF COLUMNS': 15}
# [I 20241108 10:53:38] Fitting table  metadata
# [I 20241108 10:53:38] Fitting formatters for table
# [I 20241108 10:53:38] No rounding scheme detected for column 'age'. Data will not be rounded.
# [I 20241108 10:53:38] No rounding scheme detected for column 'workclass'. Data will not be rounded.
# [I 20241108 10:53:38] No rounding scheme detected for column 'fnlwgt'. Data will not be rounded.
# [I 20241108 10:53:38] No rounding scheme detected for column 'education'. Data will not be rounded.
# [I 20241108 10:53:38] No rounding scheme detected for column 'educational-num'. Data will not be rounded.
# [I 20241108 10:53:38] No rounding scheme detected for column 'marital-status'. Data will not be rounded.
# [I 20241108 10:53:38] No rounding scheme detected for column 'occupation'. Data will not be rounded.
# [I 20241108 10:53:38] No rounding scheme detected for column 'relationship'. Data will not be rounded.
# [I 20241108 10:53:38] No rounding scheme detected for column 'race'. Data will not be rounded.
# [I 20241108 10:53:38] No rounding scheme detected for column 'gender'. Data will not be rounded.
# [I 20241108 10:53:38] No rounding scheme detected for column 'capital-gain'. Data will not be rounded.
# [I 20241108 10:53:38] No rounding scheme detected for column 'capital-loss'. Data will not be rounded.
# [I 20241108 10:53:38] No rounding scheme detected for column 'hours-per-week'. Data will not be rounded.
# [I 20241108 10:53:38] No rounding scheme detected for column 'native-country'. Data will not be rounded.
# [I 20241108 10:53:38] No rounding scheme detected for column 'income'. Data will not be rounded.
# [I 20241108 10:53:38] Fitting constraints for table
# [I 20241108 10:53:38] Setting the configuration for the ``HyperTransformer`` for table
# [I 20241108 10:53:38] Fitting HyperTransformer for table
# [I 20241108 10:53:38] No rounding scheme detected for column 'age'. Data will not be rounded.
# [I 20241108 10:53:38] No rounding scheme detected for column 'workclass'. Data will not be rounded.
# [I 20241108 10:53:38] No rounding scheme detected for column 'fnlwgt'. Data will not be rounded.
# [I 20241108 10:53:38] No rounding scheme detected for column 'education'. Data will not be rounded.
# [I 20241108 10:53:38] No rounding scheme detected for column 'educational-num'. Data will not be rounded.
# [I 20241108 10:53:38] No rounding scheme detected for column 'marital-status'. Data will not be rounded.
# [I 20241108 10:53:38] No rounding scheme detected for column 'occupation'. Data will not be rounded.
# [I 20241108 10:53:38] No rounding scheme detected for column 'relationship'. Data will not be rounded.
# [I 20241108 10:53:38] No rounding scheme detected for column 'race'. Data will not be rounded.
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdv/single_table/base.py:120: FutureWarning: The 'SingleTableMetadata' is deprecated. Please use the new 'Metadata' class for synthesizers.
#   warnings.warn(DEPRECATION_MSG, FutureWarning)
# [I 20241108 10:53:38] No rounding scheme detected for column 'gender'. Data will not be rounded.
# [I 20241108 10:53:38] No rounding scheme detected for column 'capital-gain'. Data will not be rounded.
# [I 20241108 10:53:38] No rounding scheme detected for column 'capital-loss'. Data will not be rounded.
# [I 20241108 10:53:38] No rounding scheme detected for column 'hours-per-week'. Data will not be rounded.
# [I 20241108 10:53:38] No rounding scheme detected for column 'native-country'. Data will not be rounded.
# [I 20241108 10:53:38] No rounding scheme detected for column 'income'. Data will not be rounded.
# [I 20241108 10:53:38] {'EVENT': 'Fit processed data', 'TIMESTAMP': datetime.datetime(2024, 11, 8, 10, 53, 38, 294565), 'SYNTHESIZER CLASS NAME': 'GaussianCopulaSynthesizer', 'SYNTHESIZER ID': 'GaussianCopulaSynthesizer_1.17.1_e3ad61c08ef54498915d53300fc9d68c', 'TOTAL NUMBER OF TABLES': 1, 'TOTAL NUMBER OF ROWS': 28558, 'TOTAL NUMBER OF COLUMNS': 15}
# [I 20241108 10:53:38] Fitting GaussianMultivariate(distribution="{'age': <class 'copulas.univariate.beta.BetaUnivariate'>, 'workclass': <class 'copulas.univariate.beta.BetaUnivariate'>, 'fnlwgt': <class 'copulas.univariate.beta.BetaUnivariate'>, 'education': <class 'copulas.univariate.beta.BetaUnivariate'>, 'educational-num': <class 'copulas.univariate.beta.BetaUnivariate'>, 'marital-status': <class 'copulas.univariate.beta.BetaUnivariate'>, 'occupation': <class 'copulas.univariate.beta.BetaUnivariate'>, 'relationship': <class 'copulas.univariate.beta.BetaUnivariate'>, 'race': <class 'copulas.univariate.beta.BetaUnivariate'>, 'gender': <class 'copulas.univariate.beta.BetaUnivariate'>, 'capital-gain': <class 'copulas.univariate.beta.BetaUnivariate'>, 'capital-loss': <class 'copulas.univariate.beta.BetaUnivariate'>, 'hours-per-week': <class 'copulas.univariate.beta.BetaUnivariate'>, 'native-country': <class 'copulas.univariate.beta.BetaUnivariate'>, 'income': <class 'copulas.univariate.beta.BetaUnivariate'>}")
# Synthesizer (SDV): Fitting GaussianCopula spent 2.3851 sec.
# [I 20241108 10:53:40] {'EVENT': 'Sample', 'TIMESTAMP': datetime.datetime(2024, 11, 8, 10, 53, 40, 433077), 'SYNTHESIZER CLASS NAME': 'GaussianCopulaSynthesizer', 'SYNTHESIZER ID': 'GaussianCopulaSynthesizer_1.17.1_e3ad61c08ef54498915d53300fc9d68c', 'TOTAL NUMBER OF TABLES': 1, 'TOTAL NUMBER OF ROWS': 48842, 'TOTAL NUMBER OF COLUMNS': 15}
# Synthesizer (SDV): Sampling GaussianCopula # 48842 rows (same as Loader data) in 0.5174 sec.
# Now is Postprocessor with demo...
# [I 20241108 10:53:40] MediatorEncoder is created.
# [I 20241108 10:53:40] scaler inverse transformation done.
# [I 20241108 10:53:40] <PETsARD.processor.mediator.MediatorEncoder object at 0x3255c9840> transformation done.
# [I 20241108 10:53:40] encoder inverse transformation done.
# [I 20241108 10:53:40] missing inverse transformation done.
# [I 20241108 10:53:40] age changes data dtype from float64 to int8 for metadata alignment.
# [I 20241108 10:53:40] workclass changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241108 10:53:40] fnlwgt changes data dtype from float64 to int32 for metadata alignment.
# [I 20241108 10:53:40] education changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241108 10:53:40] educational-num changes data dtype from float64 to int8 for metadata alignment.
# [I 20241108 10:53:40] marital-status changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241108 10:53:40] occupation changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241108 10:53:40] relationship changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241108 10:53:40] race changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241108 10:53:40] gender changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241108 10:53:40] capital-gain changes data dtype from float64 to int32 for metadata alignment.
# [I 20241108 10:53:40] capital-loss changes data dtype from float64 to int16 for metadata alignment.
# [I 20241108 10:53:40] hours-per-week changes data dtype from float64 to int8 for metadata alignment.
# [I 20241108 10:53:40] native-country changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241108 10:53:40] income changes data dtype from category[object] to category[object] for metadata alignment.
# Now is Evaluator with demo...
# [I 20241108 10:53:40] workclass changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241108 10:53:40] education changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241108 10:53:40] marital-status changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241108 10:53:40] occupation changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241108 10:53:40] relationship changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241108 10:53:40] race changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241108 10:53:40] gender changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241108 10:53:40] capital-gain changes data dtype from int32 to int32 for metadata alignment.
# [I 20241108 10:53:40] capital-loss changes data dtype from int16 to int16 for metadata alignment.
# [I 20241108 10:53:40] native-country changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241108 10:53:40] income changes data dtype from category[object] to category[object] for metadata alignment.
# [I 20241108 10:53:41] Detected metadata:
# [I 20241108 10:53:41] {
#     "METADATA_SPEC_VERSION": "SINGLE_TABLE_V1",
#     "columns": {
#         "age": {
#             "sdtype": "numerical"
#         },
#         "workclass": {
#             "sdtype": "categorical"
#         },
#         "fnlwgt": {
#             "sdtype": "numerical"
#         },
#         "education": {
#             "sdtype": "categorical"
#         },
#         "educational-num": {
#             "sdtype": "numerical"
#         },
#         "marital-status": {
#             "sdtype": "categorical"
#         },
#         "occupation": {
#             "sdtype": "categorical"
#         },
#         "relationship": {
#             "sdtype": "categorical"
#         },
#         "race": {
#             "sdtype": "categorical"
#         },
#         "gender": {
#             "sdtype": "categorical"
#         },
#         "capital-gain": {
#             "sdtype": "numerical"
#         },
#         "capital-loss": {
#             "sdtype": "numerical"
#         },
#         "hours-per-week": {
#             "sdtype": "numerical"
#         },
#         "native-country": {
#             "sdtype": "categorical"
#         },
#         "income": {
#             "sdtype": "categorical"
#         }
#     }
# }
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 15/15 [00:00<00:00, 95.48it/s]|
# Column Shapes Score: 95.39%
#
# (2/2) Evaluating Column Pair Trends: |█████▌    | 58/105 [00:00<00:00, 291.72it/s]|
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# ...
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/PETsARD/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# Now is Reporter with save_report_global...
# Now is User Story D-3[Report]_demo_[global] save to csv...

# %%
pp.pprint(exec.get_result())
# Out:
# {'Loader[demo]_Preprocessor[demo]_Synthesizer[sdv-gaussian]_Postprocessor[demo]_Evaluator[demo]_Reporter[save_data]': {'Loader[demo]_Preprocessor[demo]_Synthesizer[sdv-gaussian]_Postprocessor[demo]':        age         workclass  fnlwgt     education  educational-num  \
# 0       45         Local-gov  220745     Bachelors                9
# 1       31         Local-gov  181721       HS-grad                8
# 2       51           Private  210846       HS-grad               11
# 3       35           Private  196491  Some-college                8
# 4       45  Self-emp-not-inc   45410       Masters               13
# ...    ...               ...     ...           ...              ...
# 48837   36           Private   69793  Some-college               10
# 48838   43           Private  117850       HS-grad                8
# 48839   26           Private  214151       HS-grad               11
# 48840   50           Private   40547     Bachelors                9
# 48841   37           Private   99791    Assoc-acdm                9
#
#            marital-status         occupation   relationship   race  gender  \
# 0      Married-civ-spouse     Prof-specialty        Husband  White  Female
# 1      Married-civ-spouse  Machine-op-inspct      Own-child  White  Female
# 2                Divorced    Farming-fishing      Own-child  White  Female
# 3           Never-married       Adm-clerical        Husband  White    Male
# 4                Divorced       Craft-repair      Unmarried  Black    Male
# ...                   ...                ...            ...    ...     ...
# 48837       Never-married   Transport-moving        Husband  White    Male
# 48838  Married-civ-spouse       Craft-repair  Not-in-family  White  Female
# 48839  Married-civ-spouse       Craft-repair  Not-in-family  Black    Male
# 48840  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 48841  Married-civ-spouse  Handlers-cleaners        Husband  White    Male
#
#        capital-gain  capital-loss  hours-per-week native-country income
# 0                 0             0              44  United-States   >50K
# 1                 0             0              41  United-States   >50K
# 2                 0             0              34  United-States  <=50K
# 3                 0             0              45  United-States  <=50K
# 4                 0             0              37  United-States  <=50K
# ...             ...           ...             ...            ...    ...
# 48837             0             0              43  United-States  <=50K
# 48838             0             0              33    Philippines  <=50K
# 48839             0             0              48  United-States  <=50K
# 48840             0             0              42  United-States   >50K
# 48841             0             0              43  United-States  <=50K
#
# [48842 rows x 15 columns]},
#  'Loader[demo]_Preprocessor[demo]_Synthesizer[sdv-gaussian]_Postprocessor[demo]_Evaluator[demo]_Reporter[save_report_global]': {'demo_[global]':                                            full_expt_name Loader Preprocessor  \
# result  Loader[demo]_Preprocessor[demo]_Synthesizer[sd...   demo         demo
#
#          Synthesizer Postprocessor      Evaluator  demo_Score  \
# result  sdv-gaussian          demo  demo_[global]    0.780217
#
#         demo_Column Shapes  demo_Column Pair Trends
# result             0.95391                 0.606525  }}
