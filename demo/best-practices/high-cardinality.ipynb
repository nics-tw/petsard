# %% [markdown]
# # Environment setting
# 環境設定

# %%
import os
import requests
import sys
from pathlib import Path
from pprint import pprint
from typing import Optional

import pandas as pd


# determine branch, default is main
branch: str = '746-docs-split-high-cardinality-and-multi-table' # 'main'

# determine subfolder, default is None (petsard/demo/)
subfolder: Optional[str]  = 'best-practices'


# Check if running in Google Colab, if so, download the utils.py file from GitHub
is_colab: bool = 'COLAB_GPU' in os.environ
if is_colab:
    utils_url = f"https://raw.githubusercontent.com/nics-tw/petsard/{branch}/demo/utils.py"
    response = requests.get(utils_url)

    if response.status_code == 200:
        with open('utils.py', 'w') as f:
            f.write(response.text)

        Path('__init__.py').touch()
    else:
        raise RuntimeError(f"Failed to download utils.py. Status code: {response.status_code}")


# If not colab, and also contains subfolderl, add the correct path of util.py
else:
    if subfolder:
        sys.path.append(os.path.dirname(os.getcwd()))

# %%
import importlib

# Import the utils module
from utils import (
    get_yaml_path,
    setup_environment,
)


# Setup the environment
setup_environment(
    is_colab,
    branch,
    benchmark_data=[
        'best-practices_categorical_high-cardinality',
    ],
    subfolder='best-practices',
)

# Setup utils in best-practices
best_practices_utils = importlib.import_module("best-practices.best_practices_utils")
# Out:
# Looking in links: /var/folders/lb/lwjvbr314wj7bt1k63plw4bw0000gn/T/tmp4uw9j6v6
# Requirement already satisfied: setuptools in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.11/site-packages (78.1.0)
# Requirement already satisfied: pip in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.11/site-packages (25.0.1)
# Obtaining file:///Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career%20%E5%B7%A5%E4%BD%9C/20231016_NICS%20%E8%B3%87%E5%AE%89%E9%99%A2/3_%E5%B7%A5%E8%97%9D%EF%BC%9APETsARD/petsard
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Checking if build backend supports build_editable: started
#   Checking if build backend supports build_editable: finished with status 'done'
#   Getting requirements to build editable: started
#   Getting requirements to build editable: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing editable metadata (pyproject.toml): started
#   Preparing editable metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: anonymeter<2,>=1.0.0 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.11/site-packages (from petsard==1.2.2) (1.0.0)
# Requirement already satisfied: boto3>=1.37.36 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.11/site-packages (from petsard==1.2.2) (1.37.36)
# Requirement already satisfied: faker>=37.1.0 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.11/site-packages (from petsard==1.2.2) (37.1.0)
# Requirement already satisfied: filelock>=3.18.0 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.11/site-packages (from petsard==1.2.2) (3.18.0)
# Requirement already satisfied: fsspec>=2025.3.2 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.11/site-packages (from petsard==1.2.2) (2025.3.2)
# Requirement already satisfied: jinja2>=3.1.6 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.11/site-packages (from petsard==1.2.2) (3.1.6)
# Requirement already satisfied: narwhals>=1.34.1 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.11/site-packages (from petsard==1.2.2) (1.35.0)
# Requirement already satisfied: numba>=0.61.2 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.11/site-packages (from petsard==1.2.2) (0.61.2)
# Requirement already satisfied: platformdirs>=4.3.7 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.11/site-packages (from petsard==1.2.2) (4.3.7)
# Requirement already satisfied: plotly>=6.0.1 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.11/site-packages (from petsard==1.2.2) (6.0.1)
# Requirement already satisfied: python-dateutil>=2.9.0.post0 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.11/site-packages (from petsard==1.2.2) (2.9.0.post0)
# Requirement already satisfied: pytz>=2025.2 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.11/site-packages (from petsard==1.2.2) (2025.2)
# Requirement already satisfied: pyyaml>=6.0.2 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.11/site-packages (from petsard==1.2.2) (6.0.2)
# Requirement already satisfied: requests>=2.32.3 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.11/site-packages (from petsard==1.2.2) (2.32.3)
# Requirement already satisfied: s3transfer>=0.11.4 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.11/site-packages (from petsard==1.2.2) (0.11.5)
# Requirement already satisfied: scipy>=1.15.2 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.11/site-packages (from petsard==1.2.2) (1.15.2)
# Requirement already satisfied: sdmetrics<1,>=0.18.0 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.11/site-packages (from petsard==1.2.2) (0.18.0)
# Requirement already satisfied: sdv<2,>=1.17.4 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.11/site-packages (from petsard==1.2.2) (1.17.4)
# Requirement already satisfied: threadpoolctl>=3.6.0 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.11/site-packages (from petsard==1.2.2) (3.6.0)
# Requirement already satisfied: torch>=2.6.0 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.11/site-packages (from petsard==1.2.2) (2.6.0)
# Requirement already satisfied: typing-extensions>=4.13.2 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.11/site-packages (from petsard==1.2.2) (4.13.2)
# Requirement already satisfied: tzdata>=2025.2 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.11/site-packages (from petsard==1.2.2) (2025.2)
# Requirement already satisfied: urllib3>=2.4.0 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.11/site-packages (from petsard==1.2.2) (2.4.0)
# Requirement already satisfied: scikit-learn~=1.2 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.11/site-packages (from anonymeter<2,>=1.0.0->petsard==1.2.2) (1.6.1)
# Requirement already satisfied: numpy<1.27,>=1.22 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.11/site-packages (from anonymeter<2,>=1.0.0->petsard==1.2.2) (1.26.4)
# Requirement already satisfied: pandas>=1.4 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.11/site-packages (from anonymeter<2,>=1.0.0->petsard==1.2.2) (2.2.3)
# Requirement already satisfied: joblib~=1.2 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.11/site-packages (from anonymeter<2,>=1.0.0->petsard==1.2.2) (1.4.2)
# Requirement already satisfied: botocore<1.38.0,>=1.37.36 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.11/site-packages (from boto3>=1.37.36->petsard==1.2.2) (1.37.36)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.11/site-packages (from boto3>=1.37.36->petsard==1.2.2) (1.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.11/site-packages (from jinja2>=3.1.6->petsard==1.2.2) (3.0.2)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.11/site-packages (from numba>=0.61.2->petsard==1.2.2) (0.44.0)
# Requirement already satisfied: packaging in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.11/site-packages (from plotly>=6.0.1->petsard==1.2.2) (24.2)
# Requirement already satisfied: six>=1.5 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.11/site-packages (from python-dateutil>=2.9.0.post0->petsard==1.2.2) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.11/site-packages (from requests>=2.32.3->petsard==1.2.2) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.11/site-packages (from requests>=2.32.3->petsard==1.2.2) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.11/site-packages (from requests>=2.32.3->petsard==1.2.2) (2025.1.31)
# Requirement already satisfied: copulas>=0.11.0 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.11/site-packages (from sdmetrics<1,>=0.18.0->petsard==1.2.2) (0.12.1)
# Requirement already satisfied: tqdm>=4.29 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.11/site-packages (from sdmetrics<1,>=0.18.0->petsard==1.2.2) (4.67.1)
# Requirement already satisfied: cloudpickle>=2.1.0 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.11/site-packages (from sdv<2,>=1.17.4->petsard==1.2.2) (3.1.1)
# Requirement already satisfied: graphviz>=0.13.2 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.11/site-packages (from sdv<2,>=1.17.4->petsard==1.2.2) (0.20.3)
# Requirement already satisfied: ctgan>=0.10.2 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.11/site-packages (from sdv<2,>=1.17.4->petsard==1.2.2) (0.10.2)
# Requirement already satisfied: deepecho>=0.6.1 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.11/site-packages (from sdv<2,>=1.17.4->petsard==1.2.2) (0.6.1)
# Requirement already satisfied: rdt>=1.13.2 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.11/site-packages (from sdv<2,>=1.17.4->petsard==1.2.2) (1.13.2)
# Requirement already satisfied: networkx in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.11/site-packages (from torch>=2.6.0->petsard==1.2.2) (3.4.2)
# Requirement already satisfied: sympy==1.13.1 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.11/site-packages (from torch>=2.6.0->petsard==1.2.2) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.11/site-packages (from sympy==1.13.1->torch>=2.6.0->petsard==1.2.2) (1.3.0)
# Building wheels for collected packages: petsard
#   Building editable for petsard (pyproject.toml): started
#   Building editable for petsard (pyproject.toml): finished with status 'done'
#   Created wheel for petsard: filename=petsard-1.2.2-py3-none-any.whl size=4119 sha256=5da044f0cf6cbd99cb2711e084428e3e5a477ec301ee5852aa12aa9d63432dc5
#   Stored in directory: /private/var/folders/lb/lwjvbr314wj7bt1k63plw4bw0000gn/T/pip-ephem-wheel-cache-1g3wu1du/wheels/39/44/7f/a24ab63fb7ae83f1e28bdbf3047cd0b764c5a5878eada627c3
# Successfully built petsard
# Installing collected packages: petsard
#   Attempting uninstall: petsard
#     Found existing installation: petsard 1.2.2
#     Uninstalling petsard-1.2.2:
#       Successfully uninstalled petsard-1.2.2
# Successfully installed petsard-1.2.2
# Installation complete!
# Successful loading benchmark data: best-practices_categorical_high-cardinality

# %%
# Import PETsARD
from petsard import Executor

# %% [markdown]
# # Best practices: Categorical variables - Uniform encoding
# 最佳實踐：高基數變項 - 約束條件

# %%
students = pd.read_csv('benchmark/best-practices_categorical_high-cardinality.csv')


students_columns = {}
for column in students.columns:
    students_columns[column] = {}
    students_columns[column]['cardinality'] = students[column].nunique()
    students_columns[column]['dtype'] = str(students[column].dtype)

print("columns: ")
pprint(students_columns)
# Out:
# columns:
# {'admission_type': {'cardinality': 11, 'dtype': 'object'},
#  'admission_type_code': {'cardinality': 11, 'dtype': 'object'},
#  'birth_day': {'cardinality': 31, 'dtype': 'int64'},
#  'birth_month': {'cardinality': 12, 'dtype': 'int64'},
#  'birth_year': {'cardinality': 7, 'dtype': 'int64'},
#  'college': {'cardinality': 4, 'dtype': 'object'},
#  'college_code': {'cardinality': 6, 'dtype': 'object'},
#  'department_code': {'cardinality': 24, 'dtype': 'int64'},
#  'department_name': {'cardinality': 20, 'dtype': 'object'},
#  'disabled_code': {'cardinality': 2, 'dtype': 'int64'},
#  'disabled_type': {'cardinality': 2, 'dtype': 'object'},
#  'identity': {'cardinality': 14, 'dtype': 'object'},
#  'identity_code': {'cardinality': 14, 'dtype': 'int64'},
#  'nationality': {'cardinality': 63, 'dtype': 'object'},
#  'nationality_code': {'cardinality': 62, 'dtype': 'object'},
#  'sex': {'cardinality': 2, 'dtype': 'object'},
#  'university': {'cardinality': 2, 'dtype': 'object'},
#  'university_code': {'cardinality': 2, 'dtype': 'int64'},
#  'zodiac': {'cardinality': 12, 'dtype': 'object'}}

# %%
students.head(5).T
# Out:
#                                  0         1        2       3        4
# birth_year                    2005      2003     2002    2002     2000
# birth_month                      4         1       11      12       10
# birth_day                        9        16        7      24        7
# zodiac                         牡羊座       摩羯座      天蠍座     摩羯座      天秤座
# university_code                  2         1        1       1        1
# university                  國立政治大學    國立臺灣大學   國立臺灣大學  國立臺灣大學   國立臺灣大學
# college_code                   700      2000     1000    9000     1000
# college                        理學院       理學院      文學院  電機資訊學院      文學院
# department_code                702      2080     1070    9020     1040
# department_name               心理學系  地理環境資源學系   日本語文學系  資訊工程學系      哲學系
# admission_type_code             01        46       51      46       51
# admission_type       學士班 (指考分發/聯考)      繁星推薦  學士班申請入學    繁星推薦  學士班申請入學
# disabled_code                    0         0        0       0        0
# disabled_type                無身心障礙     無身心障礙    無身心障礙   無身心障礙    無身心障礙
# nationality_code               NaN       NaN      NaN     NaN      NaN
# nationality                   中華民國      中華民國     中華民國    中華民國     中華民國
# identity_code                    1         1        1       1        1
# identity                       一般生       一般生      一般生     一般生      一般生
# sex                              女         女        男       男        女

# %% [markdown]
# # YAML Configuration of Categorical variables for PETsARD
# PETsARD 的類別變項 YAML 設定

# %%
yaml_file_case: str = 'categorical.yaml'

yaml_path_case: str = get_yaml_path(
    is_colab=is_colab,
    yaml_file=yaml_file_case,
    branch=branch,
    subfolder='best-practices',
)
# Out:
# Configuration content:
# ---
# Loader:
#   data:
#     filepath: 'benchmark/best-practices_categorical_high-cardinality.csv'
#     column_types:
#       category:
#         - university_code
#         - college_code
#         - department_code
# Preprocessor:
#   encoding_uniform:
#     sequence:
#       - 'encoder'
#     encoder:
#       birth_year: 'encoding_uniform'
#       birth_month: 'encoding_uniform'
#       birth_day: 'encoding_uniform'
#       zodiac: 'encoding_uniform'
#       university_code: 'encoding_uniform'
#       university: 'encoding_uniform'
#       college_code: 'encoding_uniform'
#       college: 'encoding_uniform'
#       deparment_code: 'encoding_uniform'
#       department_name: 'encoding_uniform'
#       admission_type_code: 'encoding_uniform'
#       admission_type: 'encoding_uniform'
#       disabled_code: 'encoding_uniform'
#       disabled_type: 'encoding_uniform'
#       nationality_code: 'encoding_uniform'
#       nationality: 'encoding_uniform'
#       identity_code: 'encoding_uniform'
#       identity: 'encoding_uniform'
#       sex: 'encoding_uniform'
# Synthesizer:
#   demo:
#     method: 'default'
# Postprocessor:
#   demo:
#     method: 'default'
# Reporter:
#   output:
#     method: 'save_data'
#     source: 'Postprocessor'
# ...

# %% [markdown]
# ### Execution and Result
# 執行與結果

# %%
# Initialize and run executor
exec_case = Executor(config=yaml_path_case)
exec_case.run()
# Out:
# Now is petsard_Loader[data]_Preprocessor[encoding_uniform]_Synthesizer[demo]_Postprocessor[demo] save to csv...

# %%
output = exec_case.get_result()[
    'Loader[data]_Preprocessor[encoding_uniform]_Synthesizer[demo]_Postprocessor[demo]_Reporter[output]'
]['Loader[data]_Preprocessor[encoding_uniform]_Synthesizer[demo]_Postprocessor[demo]'].copy()

output.head(5).T
# Out:
#                              0        1        2        3       4
# birth_year                2003     2001     2005     2003    2003
# birth_month                  4       12        3        5       4
# birth_day                   10        7       23       29      19
# zodiac                     摩羯座      天蠍座      處女座      摩羯座     牡羊座
# university_code            002      002      002      002     002
# university              國立臺灣大學   國立政治大學   國立政治大學   國立臺灣大學  國立政治大學
# college_code              2000     1000     2000     2000    1000
# college                    文學院      文學院      文學院      理學院    資訊學院
# department_code            103     2020      702     1030    9010
# department_name           戲劇學系     戲劇學系    資訊科學系     物理學系    歷史學系
# admission_type_code         51       51       51       51      46
# admission_type            繁星推薦  學士班申請入學  學士班申請入學  學士班申請入學    繁星推薦
# disabled_code                1        1        1        1       1
# disabled_type            有身心障礙    有身心障礙    有身心障礙    有身心障礙   有身心障礙
# nationality_code           NaN      NaN      NaN      NaN     NaN
# nationality               中華民國     中華民國     中華民國     中華民國    中華民國
# identity_code               24       17        3        9       4
# identity             原住民 (泰雅族)      一般生      一般生      一般生     一般生
# sex                          男        男        男        男       女

# %% [markdown]
# # Invalid on Constraints
# 約束條件違反

# %% [markdown]
# ## Birthday and Zodiac Sign: Field Constraints (`field_constraints`)
# 生日與星座：欄位約束 (`field_constraints`)

# %%
best_practices_utils.check_invalid(output, ['birthday'])
# Out:
# # 154 invalid birthday dates found
#
#    index                                          reason  year  month  day
# 0    240  該年2月沒有29日 Day 29 does not exist in 2 that year  2003      2   29
# 1    446  該年9月沒有31日 Day 31 does not exist in 9 that year  2005      9   31
# 2    481  該年9月沒有31日 Day 31 does not exist in 9 that year  2003      9   31
# 3    510  該年2月沒有29日 Day 29 does not exist in 2 that year  2003      2   29
# 4    573  該年2月沒有29日 Day 29 does not exist in 2 that year  2005      2   29
#
# Counts by reason:
# reason
# 該年11月沒有31日 Day 31 does not exist in 11 that year    17
# 該年2月沒有29日 Day 29 does not exist in 2 that year      27
# 該年2月沒有30日 Day 30 does not exist in 2 that year      33
# 該年2月沒有31日 Day 31 does not exist in 2 that year      21
# 該年4月沒有31日 Day 31 does not exist in 4 that year      22
# 該年6月沒有31日 Day 31 does not exist in 6 that year      18
# 該年9月沒有31日 Day 31 does not exist in 9 that year      16
# Name: index, dtype: int64
#
# Total invalid records: 154
# Unique invalid records: 154

# %%
best_practices_utils.check_invalid(output, ['zodiac'])
# Out:
# # 9156 invalid zodiac signs found
#
#    index                      reason  month  day zodiac expected_zodiac
# 0      0  星座與出生日期不匹配 Zodiac mismatch      4   10    摩羯座             牡羊座
# 1      1  星座與出生日期不匹配 Zodiac mismatch     12    7    天蠍座             射手座
# 2      2  星座與出生日期不匹配 Zodiac mismatch      3   23    處女座             牡羊座
# 3      3  星座與出生日期不匹配 Zodiac mismatch      5   29    摩羯座             雙子座
# 4      5  星座與出生日期不匹配 Zodiac mismatch      3    9    射手座             雙魚座
#
# Counts by reason:
# reason
# 星座與出生日期不匹配 Zodiac mismatch    9156
# Name: index, dtype: int64
#
# Total invalid records: 9156
# Unique invalid records: 9156

# %% [markdown]
# ## University, College, and Department: Field Combination Constraints (`field_combinations`)
# 大學、學院、與系所：欄位組合約束 (`field_combinations`)

# %%
best_practices_utils.check_invalid(output, ['university'])
# Out:
# # 3163 invalid universities found
#
#    index university_code university  \
# 0      0             002     國立臺灣大學
# 1      3             002     國立臺灣大學
# 2      5             002     國立臺灣大學
# 3      6             002     國立臺灣大學
# 4     11             002     國立臺灣大學
#
#                                               reason
# 0  大學代碼與名稱不符，大學代碼應對應 國立政治大學 (University code and ...
# 1  大學代碼與名稱不符，大學代碼應對應 國立政治大學 (University code and ...
# 2  大學代碼與名稱不符，大學代碼應對應 國立政治大學 (University code and ...
# 3  大學代碼與名稱不符，大學代碼應對應 國立政治大學 (University code and ...
# 4  大學代碼與名稱不符，大學代碼應對應 國立政治大學 (University code and ...
#
# Counts by reason:
# reason
# 大學代碼與名稱不符，大學代碼應對應 國立政治大學 (University code and name mismatch)    3163
# Name: index, dtype: int64
#
# Total invalid records: 3163
# Unique invalid records: 3163

# %%
best_practices_utils.check_invalid(output, ['college'])
# Out:
# # 8213 invalid university-college relationships found
#
#    index university_code college_code  \
# 0      0             002         2000
# 1      1             002         1000
# 2      2             002         2000
# 3      3             002         2000
# 4      4             002         1000
#
#                                               reason
# 0  學院 2000 不屬於大學 002 (College does not belong to ...
# 1  學院 1000 不屬於大學 002 (College does not belong to ...
# 2  學院 2000 不屬於大學 002 (College does not belong to ...
# 3  學院 2000 不屬於大學 002 (College does not belong to ...
# 4  學院 1000 不屬於大學 002 (College does not belong to ...
#
# Counts by reason:
# reason
# 學院 100 不屬於大學 001 (College does not belong to university)       90
# 學院 1000 不屬於大學 002 (College does not belong to university)     670
# 學院 2000 不屬於大學 002 (College does not belong to university)    7041
# 學院 9000 不屬於大學 002 (College does not belong to university)     396
# 學院 ZA0 不屬於大學 001 (College does not belong to university)       16
# Name: index, dtype: int64
#
# # 6396 invalid colleges found
#
#    index college_code college  \
# 0      0         2000     文學院
# 1      2         2000     文學院
# 2      4         1000    資訊學院
# 3      5         1000    資訊學院
# 4      6         2000     文學院
#
#                                               reason
# 0  學院代碼與名稱不符，學院代碼應對應 理學院 (College code and name m...
# 1  學院代碼與名稱不符，學院代碼應對應 理學院 (College code and name m...
# 2  學院代碼與名稱不符，學院代碼應對應 文學院 (College code and name m...
# 3  學院代碼與名稱不符，學院代碼應對應 文學院 (College code and name m...
# 4  學院代碼與名稱不符，學院代碼應對應 理學院 (College code and name m...
#
# Counts by reason:
# reason
# 學院代碼與名稱不符，學院代碼應對應 文學院 (College code and name mismatch)       1762
# 學院代碼與名稱不符，學院代碼應對應 理學院 (College code and name mismatch)       4231
# 學院代碼與名稱不符，學院代碼應對應 資訊學院 (College code and name mismatch)       118
# 學院代碼與名稱不符，學院代碼應對應 電機資訊學院 (College code and name mismatch)     285
# Name: index, dtype: int64
#
# Total invalid records: 14609
# Unique invalid records: 9532

# %%
best_practices_utils.check_invalid(output, ['department'])
# Out:
# # 8314 invalid college-department relationships found
#
#    index college_code department_code  \
# 0      0         2000             103
# 1      1         1000            2020
# 2      2         2000             702
# 3      3         2000            1030
# 4      4         1000            9010
#
#                                               reason
# 0  系所 103 不屬於該學院 (Department does not belong to c...
# 1  系所 2020 不屬於該學院 (Department does not belong to ...
# 2  系所 702 不屬於該學院 (Department does not belong to c...
# 3  系所 1030 不屬於該學院 (Department does not belong to ...
# 4  系所 9010 不屬於該學院 (Department does not belong to ...
#
# Counts by reason:
# reason
# 系所 101 不屬於該學院 (Department does not belong to college)      360
# 系所 1010 不屬於該學院 (Department does not belong to college)     165
# 系所 102 不屬於該學院 (Department does not belong to college)      374
# 系所 1020 不屬於該學院 (Department does not belong to college)     188
# 系所 103 不屬於該學院 (Department does not belong to college)      355
# 系所 1030 不屬於該學院 (Department does not belong to college)     197
# 系所 104 不屬於該學院 (Department does not belong to college)      353
# 系所 1040 不屬於該學院 (Department does not belong to college)     184
# 系所 1050 不屬於該學院 (Department does not belong to college)     175
# 系所 1060 不屬於該學院 (Department does not belong to college)     231
# 系所 1070 不屬於該學院 (Department does not belong to college)     193
# 系所 1090 不屬於該學院 (Department does not belong to college)     202
# 系所 2010 不屬於該學院 (Department does not belong to college)      45
# 系所 2020 不屬於該學院 (Department does not belong to college)      66
# 系所 2030 不屬於該學院 (Department does not belong to college)      56
# 系所 2040 不屬於該學院 (Department does not belong to college)      54
# 系所 2070 不屬於該學院 (Department does not belong to college)      80
# 系所 2080 不屬於該學院 (Department does not belong to college)      70
# 系所 2090 不屬於該學院 (Department does not belong to college)      55
# 系所 701 不屬於該學院 (Department does not belong to college)      816
# 系所 702 不屬於該學院 (Department does not belong to college)      889
# 系所 703 不屬於該學院 (Department does not belong to college)     1610
# 系所 9010 不屬於該學院 (Department does not belong to college)     843
# 系所 9020 不屬於該學院 (Department does not belong to college)     753
# Name: index, dtype: int64
#
# # 9136 invalid departments found
#
#    index department_code department_name  \
# 0      0             103            戲劇學系
# 1      1            2020            戲劇學系
# 2      2             702           資訊科學系
# 3      3            1030            物理學系
# 4      4            9010            歷史學系
#
#                                               reason
# 0  系所代碼與名稱不符，系所代碼應對應 歷史學系 (Department code and na...
# 1  系所代碼與名稱不符，系所代碼應對應 物理學系 (Department code and na...
# 2  系所代碼與名稱不符，系所代碼應對應 心理學系 (Department code and na...
# 3  系所代碼與名稱不符，系所代碼應對應 歷史學系 (Department code and na...
# 4  系所代碼與名稱不符，系所代碼應對應 電機工程學系 (Department code and ...
#
# Counts by reason:
# reason
# 系所代碼與名稱不符，系所代碼應對應 中國文學系 (Department code and name mismatch)        539
# 系所代碼與名稱不符，系所代碼應對應 人類學系 (Department code and name mismatch)         173
# 系所代碼與名稱不符，系所代碼應對應 化學系 (Department code and name mismatch)          233
# 系所代碼與名稱不符，系所代碼應對應 哲學系 (Department code and name mismatch)          581
# 系所代碼與名稱不符，系所代碼應對應 圖書資訊學系 (Department code and name mismatch)       234
# 系所代碼與名稱不符，系所代碼應對應 地理環境資源學系 (Department code and name mismatch)     284
# 系所代碼與名稱不符，系所代碼應對應 地質科學系 (Department code and name mismatch)        231
# 系所代碼與名稱不符，系所代碼應對應 外國語文學系 (Department code and name mismatch)       194
# 系所代碼與名稱不符，系所代碼應對應 大氣科學系 (Department code and name mismatch)        214
# 系所代碼與名稱不符，系所代碼應對應 心理學系 (Department code and name mismatch)        1076
# 系所代碼與名稱不符，系所代碼應對應 應用數學系 (Department code and name mismatch)        740
# 系所代碼與名稱不符，系所代碼應對應 戲劇學系 (Department code and name mismatch)         199
# 系所代碼與名稱不符，系所代碼應對應 教育學系 (Department code and name mismatch)         407
# 系所代碼與名稱不符，系所代碼應對應 數學系 (Department code and name mismatch)          193
# 系所代碼與名稱不符，系所代碼應對應 日本語文學系 (Department code and name mismatch)       204
# 系所代碼與名稱不符，系所代碼應對應 歷史學系 (Department code and name mismatch)         551
# 系所代碼與名稱不符，系所代碼應對應 物理學系 (Department code and name mismatch)         220
# 系所代碼與名稱不符，系所代碼應對應 資訊工程學系 (Department code and name mismatch)       739
# 系所代碼與名稱不符，系所代碼應對應 資訊科學系 (Department code and name mismatch)       1323
# 系所代碼與名稱不符，系所代碼應對應 電機工程學系 (Department code and name mismatch)       801
# Name: index, dtype: int64
#
# Total invalid records: 17450
# Unique invalid records: 9913

# %% [markdown]
# ## Nationality and Nationality Code: Missing Value Group Constraints (`nan_group`)
# 國籍與國籍代碼：遺失值群組約束 (`nan_group`)

# %%
best_practices_utils.check_invalid(output, ['nationality'])
# Out:
# # 1332 invalid nationalities found
#
#    index nationality_code nationality  \
# 0      7              403        中華民國
# 1     12              503        中華民國
# 2     22              113        中華民國
# 3     23              113        中華民國
# 4     35              113        中華民國
#
#                                               reason
# 0  中華民國國籍不應有國籍代碼 (ROC nationality should not have...
# 1  中華民國國籍不應有國籍代碼 (ROC nationality should not have...
# 2  中華民國國籍不應有國籍代碼 (ROC nationality should not have...
# 3  中華民國國籍不應有國籍代碼 (ROC nationality should not have...
# 4  中華民國國籍不應有國籍代碼 (ROC nationality should not have...
#
# Counts by reason:
# reason
# 中華民國國籍不應有國籍代碼 (ROC nationality should not have nationality code)    1332
# Name: index, dtype: int64
#
# Total invalid records: 1332
# Unique invalid records: 1332

# %% [markdown]
# # YAML Configuration for PETsARD
# PETsARD 的 YAML 設定

# %%
yaml_file_case: str = 'high-cardinality.yaml'

yaml_path_case: str = get_yaml_path(
    is_colab=is_colab,
    yaml_file=yaml_file_case,
    branch=branch,
    subfolder='best-practices',
)
# Out:
# Configuration content:
# ---
# Loader:
#   data:
#     filepath: 'benchmark/best-practices_categorical_high-cardinality.csv'
#     column_types:
#       category:
#         - university_code
#         - college_code
#         - department_code
# Preprocessor:
#   encoding_uniform:
#     sequence:
#       - 'encoder'
#     encoder:
#       birth_year: 'encoding_uniform'
#       birth_month: 'encoding_uniform'
#       birth_day: 'encoding_uniform'
#       zodiac: 'encoding_uniform'
#       university_code: 'encoding_uniform'
#       university: 'encoding_uniform'
#       college_code: 'encoding_uniform'
#       college: 'encoding_uniform'
#       deparment_code: 'encoding_uniform'
#       department_name: 'encoding_uniform'
#       admission_type_code: 'encoding_uniform'
#       admission_type: 'encoding_uniform'
#       disabled_code: 'encoding_uniform'
#       disabled_type: 'encoding_uniform'
#       nationality_code: 'encoding_uniform'
#       nationality: 'encoding_uniform'
#       identity_code: 'encoding_uniform'
#       identity: 'encoding_uniform'
#       sex: 'encoding_uniform'
# Synthesizer:
#   demo:
#     method: 'default'
# Postprocessor:
#   demo:
#     method: 'default'
# Constrainer:
#   demo:
#     max_trials: 500
#     field_constraints:
#       # 出生年限制 Birth year restriction
#       - (birth_year >= 1990) & (birth_year <= 2020)
#       # 出生日限制 Birth day minimum restriction
#       - birth_day >= 1
#       # 出生月日限制：包含 1990-2020 的閏年列表
#       # Birth month and day restrictions, including list of leap years between 1990-2020
#       - |
#         (((birth_month == 1) | (birth_month ==  3) | (birth_month ==  5) | (birth_month == 7) |
#           (birth_month == 8) | (birth_month == 10) | (birth_month == 12)
#          ) & (birth_day <= 31)
#         ) |
#         (((birth_month == 4) | (birth_month == 6) | (birth_month == 9) | (birth_month == 11)
#          ) & (birth_day <= 30)
#         ) |
#         ((birth_month == 2) & (
#           (((birth_year == 1992) | (birth_year == 1996) | (birth_year == 2000) |
#             (birth_year == 2004) | (birth_year == 2008) | (birth_year == 2012) |
#             (birth_year == 2016) | (birth_year == 2020)
#            ) & (birth_day <= 29) |
#           (birth_day <= 28)
#           )
#          )
#         )
#       # 星座與出生日期的對應關係 Zodiac Sign and Birth Date Correspondence
#       - |
#         ((zodiac == '摩羯座') &
#         (((birth_month == 12) & (birth_day >= 22)) |
#         ((birth_month == 1) & (birth_day <= 19)))) |
#
#         ((zodiac == '水瓶座') &
#         (((birth_month == 1) & (birth_day >= 20)) |
#         ((birth_month == 2) & (birth_day <= 18)))) |
#
#         ((zodiac == '雙魚座') &
#         (((birth_month == 2) & (birth_day >= 19)) |
#         ((birth_month == 3) & (birth_day <= 20)))) |
#
#         ((zodiac == '牡羊座') &
#         (((birth_month == 3) & (birth_day >= 21)) |
#         ((birth_month == 4) & (birth_day <= 19)))) |
#
#         ((zodiac == '金牛座') &
#         (((birth_month == 4) & (birth_day >= 20)) |
#         ((birth_month == 5) & (birth_day <= 20)))) |
#
#         ((zodiac == '雙子座') &
#         (((birth_month == 5) & (birth_day >= 21)) |
#         ((birth_month == 6) & (birth_day <= 21)))) |
#
#         ((zodiac == '巨蟹座') &
#         (((birth_month == 6) & (birth_day >= 22)) |
#         ((birth_month == 7) & (birth_day <= 22)))) |
#
#         ((zodiac == '獅子座') &
#         (((birth_month == 7) & (birth_day >= 23)) |
#         ((birth_month == 8) & (birth_day <= 22)))) |
#
#         ((zodiac == '處女座') &
#         (((birth_month == 8) & (birth_day >= 23)) |
#         ((birth_month == 9) & (birth_day <= 22)))) |
#
#         ((zodiac == '天秤座') &
#         (((birth_month == 9) & (birth_day >= 23)) |
#         ((birth_month == 10) & (birth_day <= 23)))) |
#
#         ((zodiac == '天蠍座') &
#         (((birth_month == 10) & (birth_day >= 24)) |
#         ((birth_month == 11) & (birth_day <= 22)))) |
#
#         ((zodiac == '射手座') &
#         (((birth_month == 11) & (birth_day >= 23)) |
#         ((birth_month == 12) & (birth_day <= 21))))
#     field_combinations:
#       # 大學代碼與大學名稱的對應關係 University code and university name mapping
#       -
#         - {'university_code': 'university'}
#         - {
#             '001': ['國立臺灣大學'],
#             '002': ['國立政治大學'],
#           }
#       # 學院代碼與學院名稱的對應關係 College code and college name mapping
#       -
#         - {'college_code': 'college'}
#         - {
#             # 臺大 NTU
#             '1000': ['文學院'],
#             '2000': ['理學院'],
#             '9000': ['電機資訊學院'],
#             # 政大 NCCU
#             '100': ['文學院'],
#             '700': ['理學院'],
#             'ZA0': ['資訊學院']
#           }
#       # 大學代碼與學院代碼的對應關係 University code and college code mapping
#       -
#         - {'university_code': 'college_code'}
#         - {
#             '001': ['1000', '2000', '9000'],
#             '002': ['100', '700', 'ZA0']
#           }
#       # 系所代碼與系所名稱的對應關係 Department code and department name mapping
#       -
#         - {'department_code': 'department_name'}
#         - {
#             # 臺大 NTU
#             '1010': ['中國文學系'],
#             '1020': ['外國語文學系'],
#             '1030': ['歷史學系'],
#             '1040': ['哲學系'],
#             '1050': ['人類學系'],
#             '1060': ['圖書資訊學系'],
#             '1070': ['日本語文學系'],
#             '1090': ['戲劇學系'],
#             '2010': ['數學系'],
#             '2020': ['物理學系'],
#             '2030': ['化學系'],
#             '2040': ['地質科學系'],
#             '2070': ['心理學系'],
#             '2080': ['地理環境資源學系'],
#             '2090': ['大氣科學系'],
#             '9010': ['電機工程學系'],
#             '9020': ['資訊工程學系'],
#             # 政大 NCCU
#             '101': ['中國文學系'],
#             '102': ['教育學系'],
#             '103': ['歷史學系'],
#             '104': ['哲學系'],
#             '701': ['應用數學系'],
#             '702': ['心理學系'],
#             '703': ['資訊科學系']
#           }
#       # 學院代碼與系所代碼的對應關係 College code and department code mapping
#       -
#         - {'college_code': 'department_code'}
#         - {
#             # 臺大 NTU
#             '1000': ['1010', '1020', '1030', '1040', '1050', '1060', '1070', '1090'],
#             '2000': ['2010', '2020', '2030', '2040', '2070', '2080', '2090'],
#             '9000': ['9010', '9020'],
#             # 政大 NCCU
#             '100': ['101', '102', '103', '104'],
#             '700': ['701', '702'],
#             'ZA0': ['703']
#           }
#     nan_groups:
#       nationality_code:
#         nan_if_condition:
#           nationality:
#             - '中華民國' # ROC (Taiwan)
# Reporter:
#   output:
#     method: 'save_data'
#     source: 'Constrainer'
# ...

# %% [markdown]
# ### Execution and Result
# 執行與結果

# %%
# Initialize and run executor
exec_case = Executor(config=yaml_path_case)
exec_case.run()
# Out:
# Trial 10: Got 20 rows, need 9980 more
# Trial 20: Got 31 rows, need 9969 more
# Trial 30: Got 43 rows, need 9957 more
# Trial 40: Got 49 rows, need 9951 more
# Trial 50: Got 59 rows, need 9941 more
# Trial 60: Got 64 rows, need 9936 more
# Trial 70: Got 73 rows, need 9927 more
# Trial 80: Got 83 rows, need 9917 more
# Trial 90: Got 88 rows, need 9912 more
# Trial 100: Got 97 rows, need 9903 more
# Trial 110: Got 107 rows, need 9893 more
# Trial 120: Got 117 rows, need 9883 more
# Trial 130: Got 126 rows, need 9874 more
# Trial 140: Got 134 rows, need 9866 more
# Trial 150: Got 144 rows, need 9856 more
# Trial 160: Got 152 rows, need 9848 more
# Trial 170: Got 161 rows, need 9839 more
# Trial 180: Got 166 rows, need 9834 more
# Trial 190: Got 174 rows, need 9826 more
# Trial 200: Got 186 rows, need 9814 more
# Trial 210: Got 199 rows, need 9801 more
# Trial 220: Got 213 rows, need 9787 more
# Trial 230: Got 225 rows, need 9775 more
# Trial 240: Got 235 rows, need 9765 more
# Trial 250: Got 242 rows, need 9758 more
# Trial 260: Got 257 rows, need 9743 more
# Trial 270: Got 270 rows, need 9730 more
# Trial 280: Got 283 rows, need 9717 more
# Trial 290: Got 288 rows, need 9712 more
# Trial 300: Got 302 rows, need 9698 more
# Trial 310: Got 314 rows, need 9686 more
# Trial 320: Got 327 rows, need 9673 more
# Trial 330: Got 338 rows, need 9662 more
# Trial 340: Got 352 rows, need 9648 more
# Trial 350: Got 358 rows, need 9642 more
# Trial 360: Got 369 rows, need 9631 more
# Trial 370: Got 379 rows, need 9621 more
# Trial 380: Got 390 rows, need 9610 more
# Trial 390: Got 404 rows, need 9596 more
# Trial 400: Got 416 rows, need 9584 more
# Trial 410: Got 426 rows, need 9574 more
# Trial 420: Got 435 rows, need 9565 more
# Trial 430: Got 448 rows, need 9552 more
# Trial 440: Got 458 rows, need 9542 more
# Trial 450: Got 473 rows, need 9527 more
# Trial 460: Got 485 rows, need 9515 more
# Trial 470: Got 495 rows, need 9505 more
# Trial 480: Got 503 rows, need 9497 more
# Trial 490: Got 517 rows, need 9483 more
# Now is petsard_Loader[data]_Preprocessor[encoding_uniform]_Synthesizer[demo]_Postprocessor[demo]_Constrainer[demo] save to csv...
# /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/petsard/constrainer/constrainer.py:132: UserWarning: Maximum trials (500) reached but only got 525 rows
#   warnings.warn(

# %%
output_w_const = exec_case.get_result()[
    'Loader[data]_Preprocessor[encoding_uniform]_Synthesizer[demo]_Postprocessor[demo]_Constrainer[demo]_Reporter[output]'
]['Loader[data]_Preprocessor[encoding_uniform]_Synthesizer[demo]_Postprocessor[demo]_Constrainer[demo]'].copy()

output_w_const.head(5).T
# Out:
#                              0          1       2          3        4
# birth_year                2001       2002    2003       2004     2003
# birth_month                  8          4       5          4        9
# birth_day                    6          7      24          7        8
# zodiac                     獅子座        牡羊座     雙子座        牡羊座      處女座
# university_code            002        002     002        002      002
# university              國立政治大學     國立政治大學  國立政治大學     國立政治大學   國立政治大學
# college_code               ZA0        ZA0     ZA0        ZA0      ZA0
# college                   資訊學院       資訊學院    資訊學院       資訊學院     資訊學院
# department_code            703        703     703        703      703
# department_name          資訊科學系      資訊科學系   資訊科學系      資訊科學系    資訊科學系
# admission_type_code         51         51      51         51       51
# admission_type         學士班申請入學       繁星推薦    繁星推薦    學士班申請入學  學士班申請入學
# disabled_code                1          1       1          1        1
# disabled_type            有身心障礙      有身心障礙   有身心障礙      有身心障礙    有身心障礙
# nationality_code           NaN        NaN     NaN        113      NaN
# nationality               中華民國       中華民國    中華民國   馬紹爾群島共和國     中華民國
# identity_code               23          7       7         27        4
# identity             原住民 (泰雅族)  原住民 (泰雅族)     一般生  原住民 (泰雅族)      一般生
# sex                          女          女       男          男        男

# %% [markdown]
# # Invalid on Constraints: After setting Constraints
# 約束條件違反：在設定約束條件之後

# %%
best_practices_utils.check_invalid(output_w_const)
# Out:
# # No invalid departments found
#
# # No invalid birthday dates found
#
# # No invalid zodiac signs found
#
# # No invalid university-college relationships found
#
# # No invalid nationalities found
#
# # No invalid universities found
#
# # 704 invalid college-department relationships found
#
#    index college_code department_code  \
# 0      1          ZA0             701
# 1      2         2000            1010
# 2      5         2000            1010
# 3      8         2000             104
# 4     12         1000            2040
#
#                                               reason
# 0  系所 701 不屬於該學院 (Department does not belong to c...
# 1  系所 1010 不屬於該學院 (Department does not belong to ...
# 2  系所 1010 不屬於該學院 (Department does not belong to ...
# 3  系所 104 不屬於該學院 (Department does not belong to c...
# 4  系所 2040 不屬於該學院 (Department does not belong to ...
#
# Counts by reason:
# reason
# 系所 101 不屬於該學院 (Department does not belong to college)      27
# 系所 1010 不屬於該學院 (Department does not belong to college)    173
# 系所 102 不屬於該學院 (Department does not belong to college)      25
# 系所 1020 不屬於該學院 (Department does not belong to college)     13
# 系所 103 不屬於該學院 (Department does not belong to college)      28
# 系所 1030 不屬於該學院 (Department does not belong to college)     66
# 系所 104 不屬於該學院 (Department does not belong to college)      14
# 系所 1040 不屬於該學院 (Department does not belong to college)     20
# 系所 1050 不屬於該學院 (Department does not belong to college)     47
# 系所 1060 不屬於該學院 (Department does not belong to college)     10
# 系所 1070 不屬於該學院 (Department does not belong to college)      5
# 系所 1090 不屬於該學院 (Department does not belong to college)     17
# 系所 2010 不屬於該學院 (Department does not belong to college)      2
# 系所 2020 不屬於該學院 (Department does not belong to college)      4
# 系所 2030 不屬於該學院 (Department does not belong to college)      8
# 系所 2040 不屬於該學院 (Department does not belong to college)      8
# 系所 2080 不屬於該學院 (Department does not belong to college)      1
# 系所 2090 不屬於該學院 (Department does not belong to college)      1
# 系所 701 不屬於該學院 (Department does not belong to college)      61
# 系所 702 不屬於該學院 (Department does not belong to college)      13
# 系所 9010 不屬於該學院 (Department does not belong to college)    135
# 系所 9020 不屬於該學院 (Department does not belong to college)     26
# Name: index, dtype: int64
#
# # No invalid colleges found
#
# Total invalid records: 704
# Unique invalid records: 704
