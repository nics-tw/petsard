# %% [markdown]
# # Environment setting
# 環境設定

# %%
import os
import requests
import sys
from pathlib import Path
from pprint import pprint
from typing import Optional

import pandas as pd


# determine branch, default is main
branch: str = 'main'

# determine subfolder, default is None (petsard/demo/)
subfolder: Optional[str]  = 'best-practices'


# Check if running in Google Colab, if so, download the utils.py file from GitHub
is_colab: bool = 'COLAB_GPU' in os.environ
if is_colab:
    utils_url = f"https://raw.githubusercontent.com/nics-tw/petsard/{branch}/demo/utils.py"
    response = requests.get(utils_url)

    if response.status_code == 200:
        with open('utils.py', 'w') as f:
            f.write(response.text)

        Path('__init__.py').touch()
    else:
        raise RuntimeError(f"Failed to download utils.py. Status code: {response.status_code}")


# If not colab, and also contains subfolderl, add the correct path of util.py
else:
    if subfolder:
        sys.path.append(os.path.dirname(os.getcwd()))

# %%
# Import the utils module
from utils import (
    get_yaml_path,
    setup_environment,
)

# Setup the environment
setup_environment(
    is_colab,
    branch,
    benchmark_data=[
        'best-practices_multi-table',
    ],
    subfolder='best-practices',
)
# Out:
# Looking in links: /var/folders/lb/lwjvbr314wj7bt1k63plw4bw0000gn/T/tmpseg68rsa
# Requirement already satisfied: setuptools in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.10/site-packages (65.5.0)
# Requirement already satisfied: pip in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.10/site-packages (23.0.1)
# Obtaining file:///Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career%20%E5%B7%A5%E4%BD%9C/20231016_NICS%20%E8%B3%87%E5%AE%89%E9%99%A2/3_%E5%B7%A5%E8%97%9D%EF%BC%9APETsARD/petsard
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Checking if build backend supports build_editable: started
#   Checking if build backend supports build_editable: finished with status 'done'
#   Getting requirements to build editable: started
#   Getting requirements to build editable: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing editable metadata (pyproject.toml): started
#   Preparing editable metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: python-dateutil>=2.9.0.post0 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.10/site-packages (from petsard==1.2.2) (2.9.0.post0)
# Requirement already satisfied: pytz>=2025.2 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.10/site-packages (from petsard==1.2.2) (2025.2)
# Requirement already satisfied: urllib3>=2.4.0 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.10/site-packages (from petsard==1.2.2) (2.4.0)
# Requirement already satisfied: requests>=2.32.3 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.10/site-packages (from petsard==1.2.2) (2.32.3)
# Requirement already satisfied: filelock>=3.18.0 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.10/site-packages (from petsard==1.2.2) (3.18.0)
# Requirement already satisfied: narwhals>=1.34.1 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.10/site-packages (from petsard==1.2.2) (1.35.0)
# Requirement already satisfied: pyyaml>=6.0.2 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.10/site-packages (from petsard==1.2.2) (6.0.2)
# Requirement already satisfied: scipy>=1.15.2 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.10/site-packages (from petsard==1.2.2) (1.15.2)
# Requirement already satisfied: sdmetrics<1,>=0.18.0 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.10/site-packages (from petsard==1.2.2) (0.18.0)
# Requirement already satisfied: fsspec>=2025.3.2 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.10/site-packages (from petsard==1.2.2) (2025.3.2)
# Requirement already satisfied: torch>=2.6.0 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.10/site-packages (from petsard==1.2.2) (2.6.0)
# Requirement already satisfied: jinja2>=3.1.6 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.10/site-packages (from petsard==1.2.2) (3.1.6)
# Requirement already satisfied: numba>=0.61.2 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.10/site-packages (from petsard==1.2.2) (0.61.2)
# Requirement already satisfied: plotly>=6.0.1 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.10/site-packages (from petsard==1.2.2) (6.0.1)
# Requirement already satisfied: boto3>=1.37.36 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.10/site-packages (from petsard==1.2.2) (1.37.36)
# Requirement already satisfied: tzdata>=2025.2 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.10/site-packages (from petsard==1.2.2) (2025.2)
# Requirement already satisfied: anonymeter<2,>=1.0.0 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.10/site-packages (from petsard==1.2.2) (1.0.0)
# Requirement already satisfied: sdv<2,>=1.17.4 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.10/site-packages (from petsard==1.2.2) (1.17.4)
# Requirement already satisfied: s3transfer>=0.11.4 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.10/site-packages (from petsard==1.2.2) (0.11.5)
# Requirement already satisfied: typing-extensions>=4.13.2 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.10/site-packages (from petsard==1.2.2) (4.13.2)
# Requirement already satisfied: platformdirs>=4.3.7 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.10/site-packages (from petsard==1.2.2) (4.3.7)
# Requirement already satisfied: faker>=37.1.0 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.10/site-packages (from petsard==1.2.2) (37.1.0)
# Requirement already satisfied: threadpoolctl>=3.6.0 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.10/site-packages (from petsard==1.2.2) (3.6.0)
# Requirement already satisfied: joblib~=1.2 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.10/site-packages (from anonymeter<2,>=1.0.0->petsard==1.2.2) (1.4.2)
# Requirement already satisfied: numpy<1.27,>=1.22 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.10/site-packages (from anonymeter<2,>=1.0.0->petsard==1.2.2) (1.26.4)
# Requirement already satisfied: pandas>=1.4 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.10/site-packages (from anonymeter<2,>=1.0.0->petsard==1.2.2) (2.2.3)
# Requirement already satisfied: scikit-learn~=1.2 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.10/site-packages (from anonymeter<2,>=1.0.0->petsard==1.2.2) (1.6.1)
# Requirement already satisfied: botocore<1.38.0,>=1.37.36 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.10/site-packages (from boto3>=1.37.36->petsard==1.2.2) (1.37.36)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.10/site-packages (from boto3>=1.37.36->petsard==1.2.2) (1.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.10/site-packages (from jinja2>=3.1.6->petsard==1.2.2) (3.0.2)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.10/site-packages (from numba>=0.61.2->petsard==1.2.2) (0.44.0)
# Requirement already satisfied: packaging in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.10/site-packages (from plotly>=6.0.1->petsard==1.2.2) (24.2)
# Requirement already satisfied: six>=1.5 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.10/site-packages (from python-dateutil>=2.9.0.post0->petsard==1.2.2) (1.17.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.10/site-packages (from requests>=2.32.3->petsard==1.2.2) (2025.1.31)
# Requirement already satisfied: idna<4,>=2.5 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.10/site-packages (from requests>=2.32.3->petsard==1.2.2) (3.10)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.10/site-packages (from requests>=2.32.3->petsard==1.2.2) (3.4.1)
# Requirement already satisfied: copulas>=0.11.0 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.10/site-packages (from sdmetrics<1,>=0.18.0->petsard==1.2.2) (0.12.1)
# Requirement already satisfied: tqdm>=4.29 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.10/site-packages (from sdmetrics<1,>=0.18.0->petsard==1.2.2) (4.67.1)
# Requirement already satisfied: ctgan>=0.10.2 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.10/site-packages (from sdv<2,>=1.17.4->petsard==1.2.2) (0.10.2)
# Requirement already satisfied: rdt>=1.13.2 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.10/site-packages (from sdv<2,>=1.17.4->petsard==1.2.2) (1.13.2)
# Requirement already satisfied: deepecho>=0.6.1 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.10/site-packages (from sdv<2,>=1.17.4->petsard==1.2.2) (0.6.1)
# Requirement already satisfied: cloudpickle>=2.1.0 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.10/site-packages (from sdv<2,>=1.17.4->petsard==1.2.2) (3.1.1)
# Requirement already satisfied: graphviz>=0.13.2 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.10/site-packages (from sdv<2,>=1.17.4->petsard==1.2.2) (0.20.3)
# Requirement already satisfied: networkx in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.10/site-packages (from torch>=2.6.0->petsard==1.2.2) (3.4.2)
# Requirement already satisfied: sympy==1.13.1 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.10/site-packages (from torch>=2.6.0->petsard==1.2.2) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.10/site-packages (from sympy==1.13.1->torch>=2.6.0->petsard==1.2.2) (1.3.0)
# Building wheels for collected packages: petsard
#   Building editable for petsard (pyproject.toml): started
#   Building editable for petsard (pyproject.toml): finished with status 'done'
#   Created wheel for petsard: filename=petsard-1.2.2-py3-none-any.whl size=4119 sha256=5da044f0cf6cbd99cb2711e084428e3e5a477ec301ee5852aa12aa9d63432dc5
#   Stored in directory: /private/var/folders/lb/lwjvbr314wj7bt1k63plw4bw0000gn/T/pip-ephem-wheel-cache-0i_27avc/wheels/07/5b/18/befdab3d4be5c5f73cd596784284c302e032b3bb3ff749cb57
# Successfully built petsard
# Installing collected packages: petsard
#   Attempting uninstall: petsard
#     Found existing installation: petsard 1.2.2
#     Uninstalling petsard-1.2.2:
#       Successfully uninstalled petsard-1.2.2
# Successfully installed petsard-1.2.2
# Installation complete!
# Successful loading benchmark data: best-practices_multi-table

# %%
# Import PETsARD
from petsard import Executor

# %% [markdown]
# # Best practices: Multi-Timestamp data - Time Anchoring
# 最佳實踐：多時間點資料 - 時間定錨

# %%
multitable = pd.read_csv('benchmark/best-practices_multi-table.csv')

print("Multi-table columns: ")
pprint(multitable.columns.tolist())
# Out:
# Multi-table columns:
# ['company_id',
#  'industry',
#  'sub_industry',
#  'city',
#  'district',
#  'established_date',
#  'capital',
#  'first_apply_application_id',
#  'first_apply_loan_type',
#  'first_apply_apply_date',
#  'first_apply_approval_date',
#  'first_apply_status',
#  'first_apply_amount_requested',
#  'first_apply_amount_approved',
#  'latest_apply_application_id',
#  'latest_apply_loan_type',
#  'latest_apply_apply_date',
#  'latest_apply_approval_date',
#  'latest_apply_status',
#  'latest_apply_amount_requested',
#  'latest_apply_amount_approved',
#  'latest_track_application_id',
#  'latest_track_profit_ratio_avg_profit_ratio',
#  'latest_track_profit_ratio_min_profit_ratio',
#  'latest_track_profit_ratio_profit_ratio_std',
#  'latest_track_profit_ratio_negative_profit_count',
#  'latest_track_tracking_date_tracking_months',
#  'latest_track_tracking_date_last_tracking_date',
#  'latest_track_revenue_avg_revenue',
#  'latest_track_revenue_revenue_growth',
#  'latest_track_risk_level_last_risk',
#  'latest_track_risk_level_second_last_risk']

# %%
multitable.head(5).T
# Out:
#                                                                0  \
# company_id                                               C000001
# industry                                                    營建工程
# sub_industry                                                環保工程
# city                                                         新北市
# district                                                     板橋區
# established_date                                      2019-11-03
# capital                                                 19899000
# first_apply_application_id                             A00000001
# first_apply_loan_type                                       廠房擴充
# first_apply_apply_date                                2022-01-21
# first_apply_approval_date                             2022-03-19
# first_apply_status                                      approved
# first_apply_amount_requested                          12848000.0
# first_apply_amount_approved                           12432000.0
# latest_apply_application_id                            A00000003
# latest_apply_loan_type                                      創新研發
# latest_apply_apply_date                               2025-01-05
# latest_apply_approval_date                            2025-01-30
# latest_apply_status                                     approved
# latest_apply_amount_requested                         11683000.0
# latest_apply_amount_approved                          10703000.0
# latest_track_application_id                            A00000002
# latest_track_profit_ratio_avg_profit_ratio             -0.002636
# latest_track_profit_ratio_min_profit_ratio              -0.08058
# latest_track_profit_ratio_profit_ratio_std              0.074297
# latest_track_profit_ratio_negative_profit_count              6.0
# latest_track_tracking_date_tracking_months                  30.0
# latest_track_tracking_date_last_tracking_date         2027-07-31
# latest_track_revenue_avg_revenue                 19263501.818182
# latest_track_revenue_revenue_growth                     1.284445
# latest_track_risk_level_last_risk                         normal
# latest_track_risk_level_second_last_risk                 warning
#
#                                                             1  \
# company_id                                            C000002
# industry                                                 營建工程
# sub_industry                                             建築工程
# city                                                      臺北市
# district                                                  內湖區
# established_date                                   2017-01-02
# capital                                              17359000
# first_apply_application_id                          A00000006
# first_apply_loan_type                                    數位轉型
# first_apply_apply_date                             2020-03-17
# first_apply_approval_date                                 NaN
# first_apply_status                                  withdrawn
# first_apply_amount_requested                       15281000.0
# first_apply_amount_approved                               NaN
# latest_apply_application_id                         A00000005
# latest_apply_loan_type                                   廠房擴充
# latest_apply_apply_date                            2026-02-14
# latest_apply_approval_date                                NaN
# latest_apply_status                                  rejected
# latest_apply_amount_requested                       1433000.0
# latest_apply_amount_approved                              NaN
# latest_track_application_id                         A00000007
# latest_track_profit_ratio_avg_profit_ratio           0.002074
# latest_track_profit_ratio_min_profit_ratio          -0.091077
# latest_track_profit_ratio_profit_ratio_std           0.093598
# latest_track_profit_ratio_negative_profit_count           4.0
# latest_track_tracking_date_tracking_months               21.0
# latest_track_tracking_date_last_tracking_date      2024-09-26
# latest_track_revenue_avg_revenue                 23880199.375
# latest_track_revenue_revenue_growth                  0.090593
# latest_track_risk_level_last_risk                   attention
# latest_track_risk_level_second_last_risk               normal
#
#                                                                2           3  \
# company_id                                               C000003     C000004
# industry                                                     製造業        營建工程
# sub_industry                                                金屬加工        環保工程
# city                                                         臺北市         桃園市
# district                                                     內湖區         中壢區
# established_date                                      2012-05-29  2010-09-24
# capital                                                  5452000    20497000
# first_apply_application_id                             A00000008         NaN
# first_apply_loan_type                                       廠房擴充         NaN
# first_apply_apply_date                                2016-05-08         NaN
# first_apply_approval_date                             2016-06-29         NaN
# first_apply_status                                      approved         NaN
# first_apply_amount_requested                           4514000.0         NaN
# first_apply_amount_approved                            3402000.0         NaN
# latest_apply_application_id                            A00000009         NaN
# latest_apply_loan_type                                      數位轉型         NaN
# latest_apply_apply_date                               2018-04-28         NaN
# latest_apply_approval_date                                   NaN         NaN
# latest_apply_status                                     rejected         NaN
# latest_apply_amount_requested                          2353000.0         NaN
# latest_apply_amount_approved                                 NaN         NaN
# latest_track_application_id                            A00000008         NaN
# latest_track_profit_ratio_avg_profit_ratio              0.038045         NaN
# latest_track_profit_ratio_min_profit_ratio             -0.033057         NaN
# latest_track_profit_ratio_profit_ratio_std              0.053279         NaN
# latest_track_profit_ratio_negative_profit_count              3.0         NaN
# latest_track_tracking_date_tracking_months                  30.0         NaN
# latest_track_tracking_date_last_tracking_date         2018-12-16         NaN
# latest_track_revenue_avg_revenue                 23902145.272727         NaN
# latest_track_revenue_revenue_growth                    -0.516376         NaN
# latest_track_risk_level_last_risk                      high_risk         NaN
# latest_track_risk_level_second_last_risk                  normal         NaN
#
#                                                            4
# company_id                                           C000005
# industry                                                批發零售
# sub_industry                                              零售
# city                                                     臺北市
# district                                                 內湖區
# established_date                                  2010-07-24
# capital                                             17379000
# first_apply_application_id                         A00000014
# first_apply_loan_type                                   疫後紓困
# first_apply_apply_date                            2014-01-04
# first_apply_approval_date                                NaN
# first_apply_status                                  rejected
# first_apply_amount_requested                      11881000.0
# first_apply_amount_approved                              NaN
# latest_apply_application_id                        A00000012
# latest_apply_loan_type                                  廠房擴充
# latest_apply_apply_date                           2019-12-04
# latest_apply_approval_date                               NaN
# latest_apply_status                                withdrawn
# latest_apply_amount_requested                     17333000.0
# latest_apply_amount_approved                             NaN
# latest_track_application_id                        A00000013
# latest_track_profit_ratio_avg_profit_ratio          0.160562
# latest_track_profit_ratio_min_profit_ratio          0.101412
# latest_track_profit_ratio_profit_ratio_std           0.04299
# latest_track_profit_ratio_negative_profit_count          0.0
# latest_track_tracking_date_tracking_months               9.0
# latest_track_tracking_date_last_tracking_date     2020-06-26
# latest_track_revenue_avg_revenue                 22360711.25
# latest_track_revenue_revenue_growth                -0.773645
# latest_track_risk_level_last_risk                     normal
# latest_track_risk_level_second_last_risk              normal

# %% [markdown]
# # YAML Configuration for PETsARD
# PETsARD 的 YAML 設定

# %%
yaml_file_case: str = 'multi-timestamp.yaml'

yaml_path_case: str = get_yaml_path(
    is_colab=is_colab,
    yaml_file=yaml_file_case,
    branch=branch,
    subfolder='best-practices',
)
# Out:
# Configuration content:
# ---
# Loader:
#   data:
#     filepath: 'benchmark/best-practices_multi-table.csv'
# Preprocessor:
#   time-anchoring:
#     method: 'default'
#     config:
#       scaler:
#         'established_date':
#           # 以公司成立日為錨點，計算與申請、核准、追蹤等重要時間點的天數差異
#           # Using company establishment date as anchor to calculate day differences
#           #  with application, approval and tracking dates
#           method: 'scaler_timeanchor'
#           reference:
#             - 'apply_date'
#             - 'approval_date'
#             - 'tracking_date_last_tracking_date'
#           unit: 'D' # D 代表以天為單位 D represents measurement in days
# Synthesizer:
#   demo:
#     method: 'default'
# Postprocessor:
#   demo:
#     method: 'default'
# Reporter:
#   output:
#     method: 'save_data'
#     source: 'Postprocessor'
# ...

# %% [markdown]
# ### Execution and Result
# 執行與結果

# %%
# Initialize and run executor
exec_case = Executor(config=yaml_path_case)
exec_case.run()
# Out:
# Now is petsard_Loader[data]_Preprocessor[time-anchoring]_Synthesizer[demo]_Postprocessor[demo] save to csv...

# %%
exec_case.get_result()[
    'Loader[data]_Preprocessor[time-anchoring]_Synthesizer[demo]_Postprocessor[demo]_Reporter[output]'
]['Loader[data]_Preprocessor[time-anchoring]_Synthesizer[demo]_Postprocessor[demo]'].head(5).T
# Out:
#                                                                    0  \
# company_id                                                   C000596
# industry                                                        營建工程
# sub_industry                                                    環保工程
# city                                                             新北市
# district                                                         信義區
# established_date                                 2011-11-25 12:00:58
# capital                                                     11206464
# first_apply_application_id                                 A00001495
# first_apply_loan_type                                           廠房擴充
# first_apply_apply_date                           2014-11-15 10:33:36
# first_apply_approval_date                        2014-12-22 20:07:28
# first_apply_status                                          approved
# first_apply_amount_requested                              16719374.0
# first_apply_amount_approved                               10954020.0
# latest_apply_application_id                                A00001519
# latest_apply_loan_type                                          創新研發
# latest_apply_apply_date                          2018-06-28 12:52:16
# latest_apply_approval_date                       2018-07-13 21:05:04
# latest_apply_status                                         approved
# latest_apply_amount_requested                              9626225.0
# latest_apply_amount_approved                              11476945.0
# latest_track_application_id                                A00002214
# latest_track_profit_ratio_avg_profit_ratio                   0.06433
# latest_track_profit_ratio_min_profit_ratio                 -0.066085
# latest_track_profit_ratio_profit_ratio_std                  0.017894
# latest_track_profit_ratio_negative_profit_count             3.948321
# latest_track_tracking_date_tracking_months                 25.153469
# latest_track_tracking_date_last_tracking_date    2020-06-16 00:32:00
# latest_track_revenue_avg_revenue                          29353386.0
# latest_track_revenue_revenue_growth                         2.834212
# latest_track_risk_level_last_risk                          attention
# latest_track_risk_level_second_last_risk                   attention
#
#                                                                    1  \
# company_id                                                   C000464
# industry                                                         服務業
# sub_industry                                                      零售
# city                                                             新北市
# district                                                         龜山區
# established_date                                 2012-05-29 00:13:50
# capital                                                     42696110
# first_apply_application_id                                 A00001191
# first_apply_loan_type                                           廠房擴充
# first_apply_apply_date                           2014-11-18 15:30:08
# first_apply_approval_date                        2014-11-16 22:41:04
# first_apply_status                                          approved
# first_apply_amount_requested                              13280524.0
# first_apply_amount_approved                               12517498.0
# latest_apply_application_id                                A00001178
# latest_apply_loan_type                                          疫後紓困
# latest_apply_apply_date                          2019-09-13 21:54:08
# latest_apply_approval_date                       2019-10-26 05:39:12
# latest_apply_status                                         approved
# latest_apply_amount_requested                             18474530.0
# latest_apply_amount_approved                              15420018.0
# latest_track_application_id                                A00000758
# latest_track_profit_ratio_avg_profit_ratio                  0.118445
# latest_track_profit_ratio_min_profit_ratio                 -0.047265
# latest_track_profit_ratio_profit_ratio_std                  0.017894
# latest_track_profit_ratio_negative_profit_count             1.905332
# latest_track_tracking_date_tracking_months                 30.951511
# latest_track_tracking_date_last_tracking_date    2021-08-23 14:30:24
# latest_track_revenue_avg_revenue                          24937154.0
# latest_track_revenue_revenue_growth                        -0.288691
# latest_track_risk_level_last_risk                             normal
# latest_track_risk_level_second_last_risk                      severe
#
#                                                                    2  \
# company_id                                                   C000100
# industry                                                        批發零售
# sub_industry                                                    金屬加工
# city                                                             臺北市
# district                                                         桃園區
# established_date                                 2018-07-09 08:19:21
# capital                                                     22801786
# first_apply_application_id                                 A00000023
# first_apply_loan_type                                           疫後紓困
# first_apply_apply_date                           2022-11-28 09:48:48
# first_apply_approval_date                        2023-01-19 09:06:08
# first_apply_status                                          approved
# first_apply_amount_requested                              10686745.0
# first_apply_amount_approved                                4691046.5
# latest_apply_application_id                                A00000025
# latest_apply_loan_type                                          數位轉型
# latest_apply_apply_date                          2026-05-02 18:27:12
# latest_apply_approval_date                       2026-05-19 16:55:28
# latest_apply_status                                         approved
# latest_apply_amount_requested                             12703342.0
# latest_apply_amount_approved                               8123465.0
# latest_track_application_id                                A00000200
# latest_track_profit_ratio_avg_profit_ratio                  0.002425
# latest_track_profit_ratio_min_profit_ratio                 -0.072596
# latest_track_profit_ratio_profit_ratio_std                  0.017894
# latest_track_profit_ratio_negative_profit_count             3.381263
# latest_track_tracking_date_tracking_months                 13.769205
# latest_track_tracking_date_last_tracking_date    2027-11-10 02:59:12
# latest_track_revenue_avg_revenue                          27850160.0
# latest_track_revenue_revenue_growth                         3.333127
# latest_track_risk_level_last_risk                             severe
# latest_track_risk_level_second_last_risk                   high_risk
#
#                                                                    3  \
# company_id                                                   C000409
# industry                                                         服務業
# sub_industry                                                      食品
# city                                                             臺北市
# district                                                         中壢區
# established_date                                 2012-01-30 11:39:36
# capital                                                      4205642
# first_apply_application_id                                 A00000032
# first_apply_loan_type                                         購置機器設備
# first_apply_apply_date                           2020-08-28 11:35:28
# first_apply_approval_date                        2020-08-13 18:35:44
# first_apply_status                                          approved
# first_apply_amount_requested                              2520625.75
# first_apply_amount_approved                              924410.5625
# latest_apply_application_id                                A00000031
# latest_apply_loan_type                                          疫後紓困
# latest_apply_apply_date                          2022-12-05 03:01:20
# latest_apply_approval_date                       2023-01-30 15:53:36
# latest_apply_status                                         approved
# latest_apply_amount_requested                             10453826.0
# latest_apply_amount_approved                               5707276.0
# latest_track_application_id                                A00000216
# latest_track_profit_ratio_avg_profit_ratio                  0.024522
# latest_track_profit_ratio_min_profit_ratio                 -0.066452
# latest_track_profit_ratio_profit_ratio_std                  0.017894
# latest_track_profit_ratio_negative_profit_count             3.616034
# latest_track_tracking_date_tracking_months                  9.670528
# latest_track_tracking_date_last_tracking_date    2023-09-25 19:44:00
# latest_track_revenue_avg_revenue                          33744556.0
# latest_track_revenue_revenue_growth                         4.590058
# latest_track_risk_level_last_risk                            warning
# latest_track_risk_level_second_last_risk                      normal
#
#                                                                    4
# company_id                                                   C000672
# industry                                                        批發零售
# sub_industry                                                    塑膠製品
# city                                                             臺北市
# district                                                         新莊區
# established_date                                 2012-10-16 08:43:57
# capital                                                     19495330
# first_apply_application_id                                       nan
# first_apply_loan_type                                            nan
# first_apply_apply_date                           2016-03-14 06:15:28
# first_apply_approval_date                        2016-04-26 20:30:56
# first_apply_status                                          approved
# first_apply_amount_requested                              10730284.0
# first_apply_amount_approved                                5645237.0
# latest_apply_application_id                                A00001658
# latest_apply_loan_type                                        購置機器設備
# latest_apply_apply_date                          2018-08-16 10:46:24
# latest_apply_approval_date                                       NaT
# latest_apply_status                                         approved
# latest_apply_amount_requested                             19047060.0
# latest_apply_amount_approved                                     NaN
# latest_track_application_id                                      nan
# latest_track_profit_ratio_avg_profit_ratio                  0.038854
# latest_track_profit_ratio_min_profit_ratio                 -0.091642
# latest_track_profit_ratio_profit_ratio_std                  0.017894
# latest_track_profit_ratio_negative_profit_count              1.84424
# latest_track_tracking_date_tracking_months                       NaN
# latest_track_tracking_date_last_tracking_date    2020-01-05 20:03:12
# latest_track_revenue_avg_revenue                          33359212.0
# latest_track_revenue_revenue_growth                              NaN
# latest_track_risk_level_last_risk                             normal
# latest_track_risk_level_second_last_risk                         nan
