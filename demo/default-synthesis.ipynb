# %% [markdown]
# # Environment setting
# 環境設定

# %%
import os
import requests
from pathlib import Path


# determine branch, default is main
branch = "main"

# Check if running in Google Colab
is_colab = "COLAB_GPU" in os.environ

if is_colab:
    # Download the utils.py file from GitHub
    utils_url = (
        f"https://raw.githubusercontent.com/nics-tw/petsard/{branch}/demo/utils.py"
    )
    response = requests.get(utils_url)

    if response.status_code == 200:
        # Save the utils.py file
        with open("utils.py", "w") as f:
            f.write(response.text)

        # Create an empty __init__.py
        Path("__init__.py").touch()
    else:
        raise RuntimeError(
            f"Failed to download utils.py. Status code: {response.status_code}"
        )

# %%
# Now import and run the setup
from utils import (
    get_yaml_path,
    setup_environment,
)


setup_environment(
    is_colab,
    branch,
    benchmark_data=[
        "adult-income",
    ],
)

# %%
from petsard import Executor

# %% [markdown]
# # YAML Configuration for PETsARD
# PETsARD 的 YAML 設定

# %% [markdown]
# ## Default Synthesis
# 預設合成

# %%
yaml_file_case: str = "default-synthesis.yaml"

yaml_path_case: str = get_yaml_path(
    is_colab=is_colab,
    yaml_file=yaml_file_case,
    branch=branch,
)
# Out:
# Configuration content:
# ---
# Loader:
#   data:
#     filepath: 'benchmark/adult-income.csv'
# Preprocessor:
#   demo:
#     method: 'default'
# Synthesizer:
#   demo:
#     method: 'default' # sdv-single_table-gaussiancopula
# Postprocessor:
#   demo:
#     method: 'default'
# Reporter:
#   output:
#     method: 'save_data'
#     source: 'Postprocessor'
# ...

# %% [markdown]
# ### Execution and Result
# 執行與結果

# %%
# Initialize and run executor
exec_case = Executor(config=yaml_path_case)
exec_case.run()
# Out:
# Now is petsard_Loader[data]_Preprocessor[demo]_Synthesizer[demo]_Postprocessor[demo] save to csv...

# %%
exec_case.get_result()[
    "Loader[data]_Preprocessor[demo]_Synthesizer[demo]_Postprocessor[demo]_Reporter[output]"
]["Loader[data]_Preprocessor[demo]_Synthesizer[demo]_Postprocessor[demo]"]
# Out:
#              age     workclass         fnlwgt     education  educational-num  \
# 0      45.512893     Local-gov  105689.955677       HS-grad        12.105632
# 1      30.499560       Private  142167.749168     Bachelors         9.944627
# 2      30.666088  Self-emp-inc   70682.239701  Some-college        11.984635
# 3      35.605122       Private  217418.314592       Masters         8.728909
# 4      31.010978       Private   85353.960525  Some-college        11.887584
# ...          ...           ...            ...           ...              ...
# 28553  45.744612       Private  204517.687124       HS-grad        10.556457
# 28554  40.147268       Private  215714.871541       HS-grad         8.935876
# 28555  37.076593       Private  300336.570022     Bachelors        11.688682
# 28556  20.479046       Private  283649.417044     Bachelors        12.262469
# 28557  33.254965       Private  117875.907551     Assoc-voc        11.186968
#
#            marital-status        occupation   relationship  \
# 0           Never-married  Transport-moving        Husband
# 1      Married-civ-spouse   Protective-serv        Husband
# 2           Never-married   Exec-managerial      Unmarried
# 3           Never-married                 ?  Not-in-family
# 4           Never-married     Other-service        Husband
# ...                   ...               ...            ...
# 28553  Married-civ-spouse  Transport-moving        Husband
# 28554            Divorced   Exec-managerial        Husband
# 28555            Divorced    Prof-specialty      Unmarried
# 28556             Widowed      Craft-repair      Own-child
# 28557  Married-civ-spouse   Exec-managerial        Husband
#
#                      race  gender  capital-gain  capital-loss  hours-per-week  \
# 0                   White  Female           0.0           0.0       38.749747
# 1                   Black    Male           0.0           0.0       35.750809
# 2                   White  Female           0.0           0.0       35.629287
# 3                   White    Male           0.0           0.0       36.473108
# 4                   White  Female           0.0           0.0       51.820506
# ...                   ...     ...           ...           ...             ...
# 28553               White    Male           0.0           0.0       50.428579
# 28554               White    Male           0.0           0.0       47.407423
# 28555  Asian-Pac-Islander    Male           0.0           0.0       51.664408
# 28556               White  Female           0.0           0.0       34.931739
# 28557               White    Male           0.0           0.0       45.865096
#
#       native-country income
# 0      United-States  <=50K
# 1      United-States   >50K
# 2      United-States  <=50K
# 3             Canada  <=50K
# 4      United-States  <=50K
# ...              ...    ...
# 28553  United-States  <=50K
# 28554  United-States  <=50K
# 28555  United-States  <=50K
# 28556  United-States  <=50K
# 28557  United-States  <=50K
#
# [28558 rows x 15 columns]
