# %% [markdown]
# # Environment setting / 環境設定
# Default Synthesis / 預設合成

# %%
import os
import sys
from pathlib import Path

# 自動載入 utils / Auto-load utils
if "COLAB_GPU" in os.environ:
    url = "https://raw.githubusercontent.com/nics-tw/petsard/main/demo/utils.py"
    exec(open(url).read())
else:
    # 靜默搜尋 utils.py / Silent search for utils.py
    current = Path.cwd()
    for _ in range(5):
        if (current / "utils.py").exists():
            sys.path.insert(0, str(current))
            break
        current = current.parent

    # 匯入 utils 模組 / Import utils module
    from utils import quick_setup

# 快速設定 / Quick setup
is_colab, branch, yaml_path = quick_setup(
    yaml_file="default-synthesis.yaml",
    benchmark_data=["adult-income"],
    branch="main",  # 可選，預設為 "main"
)

from petsard import Executor
# Out:
# 🚀 PETsARD v1.5.1
# 📅 2025-07-31 12:15:37 UTC+8
# 📁 Subfolder: tutorial
# 📄 YAML path: petsard/demo/tutorial/default-synthesis.yaml
# ⚙️ Configuration content:
# ---
# Loader:
#   data:
#     filepath: 'benchmark/adult-income.csv'
# Preprocessor:
#   demo:
#     method: 'default'
# Synthesizer:
#   demo:
#     method: 'default' # sdv-single_table-gaussiancopula
# Postprocessor:
#   demo:
#     method: 'default'
# Reporter:
#   output:
#     method: 'save_data'
#     source: 'Synthesizer'
# ...

# %% [markdown]
# # Execution and Result / 執行與結果

# %%
exec_case = Executor(config=yaml_path)
exec_case.run()
# Out:
# Now is petsard_Loader[data]_Preprocessor[demo]_Synthesizer[demo] save to csv...

# %%
exec_case.get_result()[
    "Loader[data]_Preprocessor[demo]_Synthesizer[demo]_Postprocessor[demo]_Reporter[output]"
]["Loader[data]_Preprocessor[demo]_Synthesizer[demo]"]
# Out:
#             age  workclass    fnlwgt  education  educational-num  \
# 0      0.501032   0.059234 -0.795189   0.194796         0.788638
# 1     -0.594005   0.046071 -0.449763   0.148219        -0.051912
# 2     -0.581861   0.567381 -1.126690   0.421630         0.741574
# 3     -0.221617   0.813418  0.262816   0.629012        -0.524779
# 4     -0.556704   0.103736 -0.987758   0.353144         0.703824
# ...         ...        ...       ...        ...              ...
# 28553  0.517931   0.246797  0.140655   0.681239         0.186067
# 28554  0.109677   0.078080  0.246684   0.956475        -0.444277
# 28555 -0.114293   0.495569  1.048006   0.237319         0.626459
# 28556 -1.324875   0.737206  0.889986   0.285872         0.849641
# 28557 -0.393030   0.448976 -0.679796   0.863625         0.431312
#
#        marital-status  occupation  relationship      race    gender  \
# 0            0.629865    0.785610      0.384897  0.244968  0.913642
# 1            0.145817    0.113718      0.233780  0.888037  0.231349
# 2            0.054994    0.723776      0.077794  0.266242  0.976405
# 3            0.383744    0.906657      0.564476  0.542368  0.606708
# 4            0.124340    0.178456      0.359694  0.414121  0.051116
# ...               ...         ...           ...       ...       ...
# 28553        0.856765    0.110798      0.653378  0.560473  0.364818
# 28554        0.031843    0.510090      0.122781  0.522233  0.555150
# 28555        0.062945    0.289332      0.970315  0.468648  0.777344
# 28556        0.412720    0.550136      0.289544  0.712524  0.760655
# 28557        0.798539    0.819150      0.217531  0.548520  0.797878
#
#        capital-gain  capital-loss  hours-per-week  native-country    income
# 0         -0.144804     -0.217127       -0.134987        0.565861  0.195325
# 1         -0.144804     -0.217127       -0.377003        0.064805  0.941897
# 2         -0.144804     -0.217127       -0.386809        0.457210  0.643473
# 3         -0.144804     -0.217127       -0.318713        0.950928  0.829251
# 4         -0.144804     -0.217127        0.919848        0.191044  0.315061
# ...             ...           ...             ...             ...       ...
# 28553     -0.144804     -0.217127        0.807517        0.979285  0.584939
# 28554     -0.144804     -0.217127        0.563702        0.955705  0.119676
# 28555     -0.144804     -0.217127        0.907250        0.101455  0.338737
# 28556     -0.144804     -0.217127       -0.443105        0.853846  0.782989
# 28557     -0.144804     -0.217127        0.439233        0.939173  0.732653
#
# [28558 rows x 15 columns]
