# %% [markdown]
# # Environment setting / 環境設定
# Specify Data Schema / 指定資料表架構

# %%
import os
import sys
from pathlib import Path

# 自動載入 utils / Auto-load utils
if "COLAB_GPU" in os.environ:
    url = "https://raw.githubusercontent.com/nics-tw/petsard/main/demo/utils.py"
    exec(open(url).read())
else:
    # 靜默搜尋 utils.py / Silent search for utils.py
    current = Path.cwd()
    for _ in range(5):
        if (current / "utils.py").exists():
            sys.path.insert(0, str(current))
            break
        current = current.parent

    # 匯入 utils 模組 / Import utils module
    from utils import quick_setup

# 快速設定 / Quick setup
is_colab, branch, yaml_path = quick_setup(
    yaml_file="specify-schema.yaml",
    benchmark_data=[
        "adult-income",
    ],
    branch="main",  # 可選，預設為 "main"
)

from petsard import Executor
# Out:
# 🚀 PETsARD v1.5.1
# 📅 2025-08-03 02:24:31 UTC+8
# 📁 Subfolder: tutorial/use-cases
# 📄 YAML path: petsard/demo/tutorial/use-cases/specify-schema.yaml
# ⚙️ Configuration content:
# ---
# Loader:
#   data:
#     filepath: 'benchmark/adult-income.csv'
#   data-w-schema:
#     filepath: 'benchmark/adult-income.csv'
#     schema:
#       # 全域參數
#       compute_stats: true
#       optimize_dtypes: true
#       nullable_int: true
#
#       # 欄位參數
#       fields:
#         # 數值型欄位
#         age:
#           type: 'int'
#         fnlwgt:
#           type: 'int'
#         # 字串型欄位
#         gender:
#           type: 'str'
#           category_method: 'force'
#         # 含自訂缺失值的欄位
#         native-country:
#           type: 'str'
#           na_values: '?'
#         workclass:
#           type: 'str'
#           na_values: '?'
#         occupation:
#           type: 'str'
#           na_values: '?'
# Describer:
#   summary:
#     method: 'default'
# Reporter:
#   save_report_columnwise:
#     method: 'save_report'
#     granularity: 'columnwise'
# ...

# %% [markdown]
# # Execution and Result / 執行與結果

# %%
exec_case = Executor(config=yaml_path)
exec_case.run()
# Out:
# Now is petsard[Report]_[columnwise] save to csv...
# Now is petsard[Report]_[columnwise] save to csv...

# %%
exec_case.get_result()[
    "Loader[data]_Describer[summary]_Reporter[save_report_columnwise]"
]["[columnwise]"]
# Out:
#                         full_expt_name Loader     Describer           column  \
# 0   Loader[data]_Describer[columnwise]   data  [columnwise]              age
# 1   Loader[data]_Describer[columnwise]   data  [columnwise]           fnlwgt
# 2   Loader[data]_Describer[columnwise]   data  [columnwise]  educational-num
# 3   Loader[data]_Describer[columnwise]   data  [columnwise]     capital-gain
# 4   Loader[data]_Describer[columnwise]   data  [columnwise]     capital-loss
# 5   Loader[data]_Describer[columnwise]   data  [columnwise]   hours-per-week
# 6   Loader[data]_Describer[columnwise]   data  [columnwise]        workclass
# 7   Loader[data]_Describer[columnwise]   data  [columnwise]        education
# 8   Loader[data]_Describer[columnwise]   data  [columnwise]   marital-status
# 9   Loader[data]_Describer[columnwise]   data  [columnwise]       occupation
# 10  Loader[data]_Describer[columnwise]   data  [columnwise]     relationship
# 11  Loader[data]_Describer[columnwise]   data  [columnwise]             race
# 12  Loader[data]_Describer[columnwise]   data  [columnwise]           gender
# 13  Loader[data]_Describer[columnwise]   data  [columnwise]   native-country
# 14  Loader[data]_Describer[columnwise]   data  [columnwise]           income
#
#     summary_mean  summary_median  summary_std  summary_min  summary_max  \
# 0          38.64            37.0        13.71         17.0         90.0
# 1      189664.13        178144.5    105604.03      12285.0    1490400.0
# 2          10.08            10.0         2.57          1.0         16.0
# 3        1079.07             0.0      7452.02          0.0      99999.0
# 4          87.50             0.0       403.00          0.0       4356.0
# 5          40.42            40.0        12.39          1.0         99.0
# 6            NaN             NaN          NaN          NaN          NaN
# 7            NaN             NaN          NaN          NaN          NaN
# 8            NaN             NaN          NaN          NaN          NaN
# 9            NaN             NaN          NaN          NaN          NaN
# 10           NaN             NaN          NaN          NaN          NaN
# 11           NaN             NaN          NaN          NaN          NaN
# 12           NaN             NaN          NaN          NaN          NaN
# 13           NaN             NaN          NaN          NaN          NaN
# 14           NaN             NaN          NaN          NaN          NaN
#
#     summary_kurtosis  summary_skew  summary_q1  summary_q3  summary_na_count  \
# 0              -0.18          0.56        28.0        48.0               0.0
# 1               6.06          1.44    117550.5    237642.0               0.0
# 2               0.63         -0.32         9.0        12.0               0.0
# 3             152.69         11.89         0.0         0.0               0.0
# 4              20.01          4.57         0.0         0.0               0.0
# 5               2.95          0.24        40.0        45.0               0.0
# 6                NaN           NaN         NaN         NaN               0.0
# 7                NaN           NaN         NaN         NaN               0.0
# 8                NaN           NaN         NaN         NaN               0.0
# 9                NaN           NaN         NaN         NaN               0.0
# 10               NaN           NaN         NaN         NaN               0.0
# 11               NaN           NaN         NaN         NaN               0.0
# 12               NaN           NaN         NaN         NaN               0.0
# 13               NaN           NaN         NaN         NaN               0.0
# 14               NaN           NaN         NaN         NaN               0.0
#
#    summary_nunique
# 0             <NA>
# 1             <NA>
# 2             <NA>
# 3             <NA>
# 4             <NA>
# 5             <NA>
# 6                9
# 7               16
# 8                7
# 9               15
# 10               6
# 11               5
# 12               2
# 13              42
# 14               2

# %%
exec_case.get_result()[
    "Loader[data-w-schema]_Describer[summary]_Reporter[save_report_columnwise]"
]["[columnwise]"]
# Out:
#                                  full_expt_name         Loader     Describer  \
# 0   Loader[data-w-schema]_Describer[columnwise]  data-w-schema  [columnwise]
# 1   Loader[data-w-schema]_Describer[columnwise]  data-w-schema  [columnwise]
# 2   Loader[data-w-schema]_Describer[columnwise]  data-w-schema  [columnwise]
# 3   Loader[data-w-schema]_Describer[columnwise]  data-w-schema  [columnwise]
# 4   Loader[data-w-schema]_Describer[columnwise]  data-w-schema  [columnwise]
# 5   Loader[data-w-schema]_Describer[columnwise]  data-w-schema  [columnwise]
# 6   Loader[data-w-schema]_Describer[columnwise]  data-w-schema  [columnwise]
# 7   Loader[data-w-schema]_Describer[columnwise]  data-w-schema  [columnwise]
# 8   Loader[data-w-schema]_Describer[columnwise]  data-w-schema  [columnwise]
# 9   Loader[data-w-schema]_Describer[columnwise]  data-w-schema  [columnwise]
# 10  Loader[data-w-schema]_Describer[columnwise]  data-w-schema  [columnwise]
# 11  Loader[data-w-schema]_Describer[columnwise]  data-w-schema  [columnwise]
# 12  Loader[data-w-schema]_Describer[columnwise]  data-w-schema  [columnwise]
# 13  Loader[data-w-schema]_Describer[columnwise]  data-w-schema  [columnwise]
# 14  Loader[data-w-schema]_Describer[columnwise]  data-w-schema  [columnwise]
# 15           Loader[data]_Describer[columnwise]           data  [columnwise]
# 16           Loader[data]_Describer[columnwise]           data  [columnwise]
# 17           Loader[data]_Describer[columnwise]           data  [columnwise]
# 18           Loader[data]_Describer[columnwise]           data  [columnwise]
# 19           Loader[data]_Describer[columnwise]           data  [columnwise]
# 20           Loader[data]_Describer[columnwise]           data  [columnwise]
# 21           Loader[data]_Describer[columnwise]           data  [columnwise]
# 22           Loader[data]_Describer[columnwise]           data  [columnwise]
# 23           Loader[data]_Describer[columnwise]           data  [columnwise]
# 24           Loader[data]_Describer[columnwise]           data  [columnwise]
# 25           Loader[data]_Describer[columnwise]           data  [columnwise]
# 26           Loader[data]_Describer[columnwise]           data  [columnwise]
# 27           Loader[data]_Describer[columnwise]           data  [columnwise]
# 28           Loader[data]_Describer[columnwise]           data  [columnwise]
# 29           Loader[data]_Describer[columnwise]           data  [columnwise]
#
#              column  summary_mean  summary_median  summary_std  summary_min  \
# 0               age         38.64            37.0        13.71         17.0
# 1      capital-gain       1079.07             0.0      7452.02          0.0
# 2      capital-loss         87.50             0.0       403.00          0.0
# 3         education           NaN             NaN          NaN          NaN
# 4   educational-num         10.08            10.0         2.57          1.0
# 5            fnlwgt     189664.13        178144.5    105604.03      12285.0
# 6            gender           NaN             NaN          NaN          NaN
# 7    hours-per-week         40.42            40.0        12.39          1.0
# 8            income           NaN             NaN          NaN          NaN
# 9    marital-status           NaN             NaN          NaN          NaN
# 10   native-country           NaN             NaN          NaN          NaN
# 11       occupation           NaN             NaN          NaN          NaN
# 12             race           NaN             NaN          NaN          NaN
# 13     relationship           NaN             NaN          NaN          NaN
# 14        workclass           NaN             NaN          NaN          NaN
# 15              age         38.64            37.0        13.71         17.0
# 16     capital-gain       1079.07             0.0      7452.02          0.0
# 17     capital-loss         87.50             0.0       403.00          0.0
# 18        education           NaN             NaN          NaN          NaN
# 19  educational-num         10.08            10.0         2.57          1.0
# 20           fnlwgt     189664.13        178144.5    105604.03      12285.0
# 21           gender           NaN             NaN          NaN          NaN
# 22   hours-per-week         40.42            40.0        12.39          1.0
# 23           income           NaN             NaN          NaN          NaN
# 24   marital-status           NaN             NaN          NaN          NaN
# 25   native-country           NaN             NaN          NaN          NaN
# 26       occupation           NaN             NaN          NaN          NaN
# 27             race           NaN             NaN          NaN          NaN
# 28     relationship           NaN             NaN          NaN          NaN
# 29        workclass           NaN             NaN          NaN          NaN
#
#     summary_max  summary_kurtosis  summary_skew  summary_q1  summary_q3  \
# 0          90.0             -0.18          0.56        28.0        48.0
# 1       99999.0            152.69         11.89         0.0         0.0
# 2        4356.0             20.01          4.57         0.0         0.0
# 3           NaN               NaN           NaN         NaN         NaN
# 4          16.0              0.63         -0.32         9.0        12.0
# 5     1490400.0              6.06          1.44    117550.5    237642.0
# 6           NaN               NaN           NaN         NaN         NaN
# 7          99.0              2.95          0.24        40.0        45.0
# 8           NaN               NaN           NaN         NaN         NaN
# 9           NaN               NaN           NaN         NaN         NaN
# 10          NaN               NaN           NaN         NaN         NaN
# 11          NaN               NaN           NaN         NaN         NaN
# 12          NaN               NaN           NaN         NaN         NaN
# 13          NaN               NaN           NaN         NaN         NaN
# 14          NaN               NaN           NaN         NaN         NaN
# 15         90.0             -0.18          0.56        28.0        48.0
# 16      99999.0            152.69         11.89         0.0         0.0
# 17       4356.0             20.01          4.57         0.0         0.0
# 18          NaN               NaN           NaN         NaN         NaN
# 19         16.0              0.63         -0.32         9.0        12.0
# 20    1490400.0              6.06          1.44    117550.5    237642.0
# 21          NaN               NaN           NaN         NaN         NaN
# 22         99.0              2.95          0.24        40.0        45.0
# 23          NaN               NaN           NaN         NaN         NaN
# 24          NaN               NaN           NaN         NaN         NaN
# 25          NaN               NaN           NaN         NaN         NaN
# 26          NaN               NaN           NaN         NaN         NaN
# 27          NaN               NaN           NaN         NaN         NaN
# 28          NaN               NaN           NaN         NaN         NaN
# 29          NaN               NaN           NaN         NaN         NaN
#
#     summary_na_count summary_nunique
# 0                0.0            <NA>
# 1                0.0            <NA>
# 2                0.0            <NA>
# 3                0.0              16
# 4                0.0            <NA>
# 5                0.0            <NA>
# 6                0.0               2
# 7                0.0            <NA>
# 8                0.0               2
# 9                0.0               7
# 10               0.0              42
# 11               0.0              15
# 12               0.0               5
# 13               0.0               6
# 14               0.0               9
# 15               0.0            <NA>
# 16               0.0            <NA>
# 17               0.0            <NA>
# 18               0.0              16
# 19               0.0            <NA>
# 20               0.0            <NA>
# 21               0.0               2
# 22               0.0            <NA>
# 23               0.0               2
# 24               0.0               7
# 25               0.0              42
# 26               0.0              15
# 27               0.0               5
# 28               0.0               6
# 29               0.0               9
