# %% [markdown]
# # User Story
#
# This demo is checklist for "User Stories" of PETsARD Spec. Also it can help users to set their own config file. Enjoy : )
#
# 本示例為【資料生成演算法分析與評估系統 Spec】當中【用戶故事 User Stories】的檢查清單。它還可以幫助用戶設置自己的配置文件。祝您使用愉快 : )

# %% [markdown]
# ## Stocktaking
#
# Type 1: Generation
#
# 1. User Story 1: Describing - **Completed**
#
# 2. User Story 2: Synthesizing - **Completed**
#
# 3. User Story 3: Default Synthesizing - **Completed**
#
# 4. User Story 4: Evaluating - **Completed**
#
# 5. User Story 5: Customized Evaluating - **Completed**
#
# Type 2: Evaluating data
#
# 1. User Story 6: Given data evaluating - **Incompleted**
#    - 缺 Reporter method = 'save_report'
#
# 2. User Story 7: Given data customized evaluating - **Incompleted**
#    - 缺 Reporter method = 'save_report'
#
# Type 3: Evaluating algorithm
#
# 1. User Story 8: Synthesizing on default data - **Completed**
#
# 2. User Story 9: Synthesizing on multiple data - **Completed**
#
# 3.  User Story 8: Synthesizing and Evaluating on default data - **Incompleted**
#    - 缺 Reporter method = 'save_report'

# %% [markdown]
# ## Environment

# %%
import os
import sys

path_petsard = os.path.dirname(os.getcwd())
print(path_petsard)
sys.path.append(path_petsard)


###### ###### ###### ###### ###### ######

import pprint

import yaml

from PETsARD import Executor


def DevTest_UserStory(config_file: str):
    print(f"YAML file {config_file} is ...")
    print(f"")
    pp = pprint.PrettyPrinter(depth=3)
    with open(config_file, 'r') as yaml_file:
        yaml_raw: dict = yaml.safe_load(yaml_file)
    pp.pprint(yaml_raw)

    print(f"")
    print(f"")
    print(f"Here's the result...")
    print(f"")
    exec = Executor(config=config_file)
    exec.run()

    print(f"")
    print(f"")
    print(f"Here's the result...")
    print(f"")
    pp.pprint(exec.get_result())
# Out:
# d:\Dropbox\89_other_application\GitHub\PETsARD

# %% [markdown]
# # Type 1: Generation
#
# > Type 1: Generate a privacy enhanced dataset along with reports
# >
# > 類型一：生成一個隱私強化資料集、與提供相關報告

# %% [markdown]
# ## User Story 1: Describing
#
# > Given a dataset as an input, the pipeline can go through the "describe" module to get a summary of the dataset.
# >
# > 給定一個資料集做輸入，該流程可以藉由調用 "describe" 模組而得到該資料集的摘要

# %%
config_file = 'UserStory_01.yaml'

DevTest_UserStory(config_file = config_file)
# Out:
# YAML file UserStory_01.yaml is ...
#
# {'Describer': {'demo': {'method': 'default'}},
#  'Loader': {'adult': {'filepath': 'benchmark://adult', 'na_values': {...}}},
#  'Reporter': {'save_report_columnwise': {'eval': 'demo',
#                                          'granularity': 'columnwise',
#                                          'method': 'save_report',
#                                          'output': 'UserStory_01'},
#               'save_report_global': {'eval': 'demo',
#                                      'granularity': 'global',
#                                      'method': 'save_report',
#                                      'output': 'UserStory_01'},
#               'save_report_pairwise': {'eval': 'demo',
#                                        'granularity': 'pairwise',
#                                        'method': 'save_report',
#                                        'output': 'UserStory_01'}}}
#
#
# Here's the result...
#
# Now is Loader with adult...
# Loader - Benchmarker: file benchmark\adult.csv already exist and match SHA-256.
#                       PETsARD will ignore download and use local data directly.
# Now is Describer with demo...
# Now is Reporter with save_report_global...
# Now is UserStory_01[Report]_demo_[global] save to csv...
# Now is Reporter with save_report_columnwise...
# Now is UserStory_01[Report]_demo_[columnwise] save to csv...
# Now is Reporter with save_report_pairwise...
# Now is UserStory_01[Report]_demo_[pairwise] save to csv...
#
#
# Here's the result...
#
# {'Loader[adult]_Describer[demo]_Reporter[save_report_columnwise]': {'demo_[columnwise]':                                 full_expt_name           column  \
# 0   Loader[adult]_Describer[demo_[columnwise]]              age
# 1   Loader[adult]_Describer[demo_[columnwise]]           fnlwgt
# 2   Loader[adult]_Describer[demo_[columnwise]]  educational-num
# 3   Loader[adult]_Describer[demo_[columnwise]]     capital-gain
# 4   Loader[adult]_Describer[demo_[columnwise]]     capital-loss
# 5   Loader[adult]_Describer[demo_[columnwise]]   hours-per-week
# 6   Loader[adult]_Describer[demo_[columnwise]]        workclass
# 7   Loader[adult]_Describer[demo_[columnwise]]        education
# 8   Loader[adult]_Describer[demo_[columnwise]]   marital-status
# 9   Loader[adult]_Describer[demo_[columnwise]]       occupation
# 10  Loader[adult]_Describer[demo_[columnwise]]     relationship
# 11  Loader[adult]_Describer[demo_[columnwise]]             race
# 12  Loader[adult]_Describer[demo_[columnwise]]           gender
# 13  Loader[adult]_Describer[demo_[columnwise]]   native-country
# 14  Loader[adult]_Describer[demo_[columnwise]]           income
#
#              mean    median            std      min        max    kurtosis  \
# 0       38.643585      37.0      13.710510     17.0       90.0   -0.184269
# 1   189664.134597  178144.5  105604.025423  12285.0  1490400.0    6.057848
# 2       10.078089      10.0       2.570973      1.0       16.0    0.625745
# 3     1079.067626       0.0    7452.019058      0.0    99999.0  152.693096
# 4       87.502314       0.0     403.004552      0.0     4356.0   20.014346
# 5       40.422382      40.0      12.391444      1.0       99.0    2.951059
# 6             NaN       NaN            NaN      NaN        NaN         NaN
# 7             NaN       NaN            NaN      NaN        NaN         NaN
# 8             NaN       NaN            NaN      NaN        NaN         NaN
# 9             NaN       NaN            NaN      NaN        NaN         NaN
# 10            NaN       NaN            NaN      NaN        NaN         NaN
# 11            NaN       NaN            NaN      NaN        NaN         NaN
# 12            NaN       NaN            NaN      NaN        NaN         NaN
# 13            NaN       NaN            NaN      NaN        NaN         NaN
# 14            NaN       NaN            NaN      NaN        NaN         NaN
#
#          skew        q1        q3  na_count  nunique
# 0    0.557580      28.0      48.0         0      NaN
# 1    1.438892  117550.5  237642.0         0      NaN
# 2   -0.316525       9.0      12.0         0      NaN
# 3   11.894659       0.0       0.0         0      NaN
# 4    4.569809       0.0       0.0         0      NaN
# 5    0.238750      40.0      45.0         0      NaN
# 6         NaN       NaN       NaN      2799      8.0
# 7         NaN       NaN       NaN         0     16.0
# 8         NaN       NaN       NaN         0      7.0
# 9         NaN       NaN       NaN      2809     14.0
# 10        NaN       NaN       NaN         0      6.0
# 11        NaN       NaN       NaN         0      5.0
# 12        NaN       NaN       NaN         0      2.0
# 13        NaN       NaN       NaN       857     41.0
# 14        NaN       NaN       NaN         0      2.0  },
#  'Loader[adult]_Describer[demo]_Reporter[save_report_global]': {'demo_[global]':                            full_expt_name  row_count  col_count  na_count
# 0  Loader[adult]_Describer[demo_[global]]      48842         15      3620},
#  'Loader[adult]_Describer[demo]_Reporter[save_report_pairwise]': {'demo_[pairwise]':                               full_expt_name          column1  \
# 0   Loader[adult]_Describer[demo_[pairwise]]              age
# 1   Loader[adult]_Describer[demo_[pairwise]]           fnlwgt
# 2   Loader[adult]_Describer[demo_[pairwise]]  educational-num
# 3   Loader[adult]_Describer[demo_[pairwise]]     capital-gain
# 4   Loader[adult]_Describer[demo_[pairwise]]     capital-loss
# 5   Loader[adult]_Describer[demo_[pairwise]]   hours-per-week
# 6   Loader[adult]_Describer[demo_[pairwise]]           fnlwgt
# 7   Loader[adult]_Describer[demo_[pairwise]]  educational-num
# 8   Loader[adult]_Describer[demo_[pairwise]]     capital-gain
# 9   Loader[adult]_Describer[demo_[pairwise]]     capital-loss
# 10  Loader[adult]_Describer[demo_[pairwise]]   hours-per-week
# 11  Loader[adult]_Describer[demo_[pairwise]]  educational-num
# 12  Loader[adult]_Describer[demo_[pairwise]]     capital-gain
# 13  Loader[adult]_Describer[demo_[pairwise]]     capital-loss
# 14  Loader[adult]_Describer[demo_[pairwise]]   hours-per-week
# 15  Loader[adult]_Describer[demo_[pairwise]]     capital-gain
# 16  Loader[adult]_Describer[demo_[pairwise]]     capital-loss
# 17  Loader[adult]_Describer[demo_[pairwise]]   hours-per-week
# 18  Loader[adult]_Describer[demo_[pairwise]]     capital-loss
# 19  Loader[adult]_Describer[demo_[pairwise]]   hours-per-week
# 20  Loader[adult]_Describer[demo_[pairwise]]   hours-per-week
#
#             column2      corr
# 0               age  1.000000
# 1               age -0.076628
# 2               age  0.030940
# 3               age  0.077229
# 4               age  0.056944
# 5               age  0.071558
# 6            fnlwgt  1.000000
# 7            fnlwgt -0.038761
# 8            fnlwgt -0.003706
# 9            fnlwgt -0.004366
# 10           fnlwgt -0.013519
# 11  educational-num  1.000000
# 12  educational-num  0.125146
# 13  educational-num  0.080972
# 14  educational-num  0.143689
# 15     capital-gain  1.000000
# 16     capital-gain -0.031441
# 17     capital-gain  0.082157
# 18     capital-loss  1.000000
# 19     capital-loss  0.054467
# 20   hours-per-week  1.000000  }}

# %% [markdown]
# ## User Story 2: Synthesizing
#
# > Given an original dataset, specified privacy enhancing data generation algorithms and parameters, the pipeline will generate a privacy enhanced dataset.
# >
# > 給定一個原始資料集，並指定隱私強化技術生成演算法與參數，該流程會依此產生隱私強化資料集。

# %%
config_file = 'UserStory_02.yaml'

DevTest_UserStory(config_file = config_file)
# Out:
# YAML file UserStory_02.yaml is ...
#
# {'Loader': {'adult': {'filepath': 'benchmark://adult', 'na_values': {...}}},
#  'Postprocessor': {'demo': {'method': 'default'}},
#  'Preprocessor': {'demo': {'method': 'default'}},
#  'Reporter': {'save_data': {'method': 'save_data',
#                             'output': 'UserStory_02',
#                             'source': 'Postprocessor'}},
#  'Synthesizer': {'sdv-gaussian': {'method': 'sdv-single_table-gaussiancopula'}}}
#
#
# Here's the result...
#
# Now is Loader with adult...
# Loader - Benchmarker: file benchmark\adult.csv already exist and match SHA-256.
#                       PETsARD will ignore download and use local data directly.
# Now is Preprocessor with demo...
# Now is Synthesizer with sdv-gaussian...
# Synthesizer (SDV - SingleTable): Metafile loading time: 0.0312 sec.
# Synthesizer (SDV - SingleTable): Fitting GaussianCopula.
# Synthesizer (SDV - SingleTable): Fitting  GaussianCopula spent 8.4971 sec.
# Synthesizer (SDV - SingleTable): Sampling GaussianCopula # 26933 rows (same as raw) in 1.8218 sec.
# Now is Postprocessor with demo...
# Now is Reporter with save_data...
# Now is UserStory_02_Loader[adult]_Preprocessor[demo]_Synthesizer[sdv-gaussian]_Postprocessor[demo] save to csv...
#
#
# Here's the result...
#
# {'Loader[adult]_Preprocessor[demo]_Synthesizer[sdv-gaussian]_Postprocessor[demo]_Reporter[save_data]': {'Loader[adult]_Preprocessor[demo]_Synthesizer[sdv-gaussian]_Postprocessor[demo]':              age         workclass         fnlwgt     education  \
# 0      40.453796           Private   67768.752434       Masters
# 1      21.875367           Private   83948.343524       HS-grad
# 2      24.512454           Private   65400.378310     Bachelors
# 3      49.353166           Private  167455.539733  Some-college
# 4      26.651752           Private  355756.280482       Masters
# ...          ...               ...            ...           ...
# 26928  48.637893  Self-emp-not-inc  327364.590718          10th
# 26929  26.062750           Private  248332.879115       HS-grad
# 26930  35.233626       Federal-gov  328182.428831       HS-grad
# 26931  47.329708           Private  287936.525963     Bachelors
# 26932  52.443899           Private  259976.202897  Some-college
#
#        educational-num         marital-status       occupation   relationship  \
# 0             9.584892     Married-civ-spouse   Prof-specialty  Not-in-family
# 1             8.509839     Married-civ-spouse            Sales  Not-in-family
# 2            12.284975               Divorced  Farming-fishing      Own-child
# 3             7.541014     Married-civ-spouse     Adm-clerical  Not-in-family
# 4            13.690224                Widowed   Prof-specialty      Own-child
# ...                ...                    ...              ...            ...
# 26928        11.874972          Never-married   Prof-specialty  Not-in-family
# 26929        11.913427  Married-spouse-absent     Tech-support      Unmarried
# 26930         9.142747     Married-civ-spouse     Tech-support        Husband
# 26931        12.416216               Divorced     Adm-clerical      Own-child
# 26932        14.928048          Never-married            Sales  Not-in-family
#
#         race  gender  capital-gain  capital-loss  hours-per-week  \
# 0      White    Male           0.0           0.0       43.593888
# 1      White  Female           0.0           0.0       39.622939
# 2      White  Female           0.0           0.0       40.886995
# 3      White    Male           0.0           0.0       41.230401
# 4      White    Male           0.0           0.0       42.590476
# ...      ...     ...           ...           ...             ...
# 26928  White    Male           0.0           0.0       46.641519
# 26929  White  Female           0.0           0.0       38.589894
# 26930  White    Male           0.0           0.0       42.582570
# 26931  White  Female           0.0           0.0       40.377125
# 26932  Other    Male           0.0           0.0       38.489412
#
#       native-country income
# 0      United-States  <=50K
# 1      United-States   >50K
# 2      United-States  <=50K
# 3      United-States  <=50K
# 4      United-States  <=50K
# ...              ...    ...
# 26928  United-States  <=50K
# 26929  United-States  <=50K
# 26930  United-States  <=50K
# 26931  United-States   >50K
# 26932  United-States  <=50K
#
# [26933 rows x 15 columns]}}

# %% [markdown]
# ## User Story 3: Default Synthesizing
#
# > Given an original dataset without specified algorithm, the pipeline will generate a list of privacy enhanced datasets using the default algorithms.
# >
# > 給定一個原始資料集、但未指定演算法，該流程會利用預設的演算法生成一組隱私強化資料集。

# %%
config_file = 'UserStory_03.yaml'

DevTest_UserStory(config_file = config_file)
# Out:
# YAML file UserStory_03.yaml is ...
#
# {'Loader': {'adult': {'filepath': 'benchmark://adult', 'na_values': {...}}},
#  'Postprocessor': {'demo': {'method': 'default'}},
#  'Preprocessor': {'demo': {'method': 'default'}},
#  'Reporter': {'save_data': {'method': 'save_data',
#                             'output': 'UserStory_03',
#                             'source': 'Postprocessor'}},
#  'Synthesizer': {'demo': {'method': 'default'}}}
#
#
# Here's the result...
#
# Now is Loader with adult...
# Loader - Benchmarker: file benchmark\adult.csv already exist and match SHA-256.
#                       PETsARD will ignore download and use local data directly.
# Now is Preprocessor with demo...
# Now is Synthesizer with demo...
# Synthesizer (SDV - SingleTable): Metafile loading time: 0.0232 sec.
# Synthesizer (SDV - SingleTable): Fitting GaussianCopula.
# Synthesizer (SDV - SingleTable): Fitting  GaussianCopula spent 8.7779 sec.
# Synthesizer (SDV - SingleTable): Sampling GaussianCopula # 26933 rows (same as raw) in 1.8461 sec.
# Now is Postprocessor with demo...
# Now is Reporter with save_data...
# Now is UserStory_03_Loader[adult]_Preprocessor[demo]_Synthesizer[demo]_Postprocessor[demo] save to csv...
#
#
# Here's the result...
#
# {'Loader[adult]_Preprocessor[demo]_Synthesizer[demo]_Postprocessor[demo]_Reporter[save_data]': {'Loader[adult]_Preprocessor[demo]_Synthesizer[demo]_Postprocessor[demo]':              age         workclass         fnlwgt    education  \
# 0      43.236120           Private  144879.518088  Prof-school
# 1      20.399872  Self-emp-not-inc  137969.207727    Bachelors
# 2      23.591897           Private  164881.520228      HS-grad
# 3      44.184407           Private  168262.551770      HS-grad
# 4      32.016262           Private  274491.771934    Assoc-voc
# ...          ...               ...            ...          ...
# 26928  61.365727           Private  169841.929567      Masters
# 26929  28.436461           Private  294162.370314      HS-grad
# 26930  33.418384           Private  417668.000000      HS-grad
# 26931  26.800397       Federal-gov  250479.124710    Bachelors
# 26932  70.675284         State-gov  109089.786496      HS-grad
#
#        educational-num      marital-status       occupation   relationship  \
# 0             9.220171  Married-civ-spouse   Prof-specialty  Not-in-family
# 1             8.166402       Never-married  Farming-fishing  Not-in-family
# 2            12.735143       Never-married    Other-service      Own-child
# 3             7.825416  Married-civ-spouse  Exec-managerial        Husband
# 4            13.373360             Widowed   Prof-specialty      Own-child
# ...                ...                 ...              ...            ...
# 26928        11.780953  Married-civ-spouse   Prof-specialty  Not-in-family
# 26929        11.929935             Widowed  Farming-fishing      Unmarried
# 26930         9.183462  Married-civ-spouse     Tech-support        Husband
# 26931        13.358345       Never-married     Craft-repair      Own-child
# 26932        13.947726            Divorced    Other-service  Not-in-family
#
#         race  gender  capital-gain  capital-loss  hours-per-week  \
# 0      White    Male           0.0           0.0       47.422975
# 1      White    Male           0.0           0.0       44.367445
# 2      White  Female           0.0           0.0       42.520242
# 3      White    Male           0.0           0.0       39.745352
# 4      White    Male           0.0           0.0       39.398368
# ...      ...     ...           ...           ...             ...
# 26928  White  Female           0.0           0.0       40.391808
# 26929  White  Female           0.0           0.0       37.030461
# 26930  White    Male           0.0           0.0       42.292575
# 26931  White    Male           0.0           0.0       37.604342
# 26932  White    Male           0.0           0.0       42.261807
#
#       native-country income
# 0      United-States  <=50K
# 1      United-States   >50K
# 2      United-States  <=50K
# 3      United-States  <=50K
# 4      United-States  <=50K
# ...              ...    ...
# 26928  United-States  <=50K
# 26929  United-States  <=50K
# 26930  United-States   >50K
# 26931  United-States  <=50K
# 26932  United-States  <=50K
#
# [26933 rows x 15 columns]}}

# %% [markdown]
# ## User Story 4: Evaluating
#
# > Following User Story 2 and 3, if users enable the "evaluate" step ,  the evaluation module will create a report covering default privacy risk and utility metrics.
# >
# > 根據用戶故事 2 跟 3，如果使用者啟用了 "evaluate"  步驟，評估模組會產生涵蓋預設的隱私風險與效用指標的報告。

# %%
config_file = 'UserStory_04.yaml'

DevTest_UserStory(config_file = config_file)
# Out:
# YAML file UserStory_04.yaml is ...
#
# {'Evaluator': {'demo': {'method': 'default'}},
#  'Loader': {'adult': {'filepath': 'benchmark://adult', 'na_values': {...}}},
#  'Postprocessor': {'demo': {'method': 'default'}},
#  'Preprocessor': {'demo': {'method': 'default'}},
#  'Reporter': {'save_data': {'method': 'save_data',
#                             'output': 'UserStory_04',
#                             'source': 'Postprocessor'},
#               'save_report_global': {'eval': 'demo',
#                                      'granularity': 'global',
#                                      'method': 'save_report',
#                                      'output': 'UserStory_04'}},
#  'Synthesizer': {'demo': {'method': 'default'}}}
#
#
# Here's the result...
#
# Now is Loader with adult...
# Loader - Benchmarker: file benchmark\adult.csv already exist and match SHA-256.
#                       PETsARD will ignore download and use local data directly.
# Now is Preprocessor with demo...
# Now is Synthesizer with demo...
# Synthesizer (SDV - SingleTable): Metafile loading time: 0.0333 sec.
# Synthesizer (SDV - SingleTable): Fitting GaussianCopula.
# Synthesizer (SDV - SingleTable): Fitting  GaussianCopula spent 9.1733 sec.
# Synthesizer (SDV - SingleTable): Sampling GaussianCopula # 26933 rows (same as raw) in 1.7919 sec.
# Now is Postprocessor with demo...
# Now is Evaluator with demo...
# Generating report ...
# (1/2) Evaluating Column Shapes: : 100%|██████████| 15/15 [00:00<00:00, 84.21it/s]
# (2/2) Evaluating Column Pair Trends: : 100%|██████████| 105/105 [00:04<00:00, 21.93it/s]
#
# Overall Score: 77.83%
#
# Properties:
# - Column Shapes: 94.05%
# - Column Pair Trends: 61.62%
# Now is Reporter with save_data...
# Now is UserStory_04_Loader[adult]_Preprocessor[demo]_Synthesizer[demo]_Postprocessor[demo] save to csv...
# Now is Reporter with save_report_global...
# Now is UserStory_04[Report]_demo_[global] save to csv...
#
#
# Here's the result...
#
# {'Loader[adult]_Preprocessor[demo]_Synthesizer[demo]_Postprocessor[demo]_Evaluator[demo]_Reporter[save_data]': {'Loader[adult]_Preprocessor[demo]_Synthesizer[demo]_Postprocessor[demo]':              age     workclass         fnlwgt     education  educational-num  \
# 0      47.372495       Private   89630.970937          10th         8.866666
# 1      28.673074     Local-gov   98302.456691  Some-college         7.929647
# 2      40.005262       Private   55744.411273       HS-grad        11.848163
# 3      36.496919       Private  174435.709093       HS-grad         7.892895
# 4      50.008158     State-gov  262282.645492     Assoc-voc        12.579503
# ...          ...           ...            ...           ...              ...
# 26928  40.145119       Private  290137.078375          10th        12.358970
# 26929  32.984544       Private  237846.460551       HS-grad        11.911512
# 26930  53.933652  Self-emp-inc  356022.443505       HS-grad         8.923783
# 26931  29.486454   Federal-gov  238958.519977     Bachelors        13.283509
# 26932  31.107734       Private  358296.743069     Bachelors        15.983656
#
#            marital-status         occupation   relationship   race  gender  \
# 0      Married-civ-spouse     Prof-specialty        Husband  White  Female
# 1      Married-civ-spouse       Tech-support      Unmarried  White    Male
# 2                Divorced  Machine-op-inspct      Own-child  Black  Female
# 3      Married-civ-spouse       Craft-repair        Husband  White    Male
# 4                Divorced       Craft-repair      Unmarried  Black    Male
# ...                   ...                ...            ...    ...     ...
# 26928  Married-civ-spouse     Prof-specialty        Husband  Black    Male
# 26929             Widowed    Farming-fishing           Wife  White  Female
# 26930  Married-civ-spouse       Tech-support        Husband  White    Male
# 26931       Never-married       Craft-repair      Own-child  White    Male
# 26932            Divorced       Adm-clerical  Not-in-family  White    Male
#
#        capital-gain  capital-loss  hours-per-week native-country income
# 0               0.0           0.0       47.817481  United-States  <=50K
# 1               0.0           0.0       45.527413  United-States   >50K
# 2               0.0           0.0       40.819354  United-States  <=50K
# 3               0.0           0.0       40.306237  United-States  <=50K
# 4               0.0           0.0       36.613108  United-States  <=50K
# ...             ...           ...             ...            ...    ...
# 26928           0.0           0.0       38.757974  United-States  <=50K
# 26929           0.0           0.0       36.372757  United-States  <=50K
# 26930           0.0           0.0       41.283506  United-States   >50K
# 26931           0.0           0.0       37.759135  United-States  <=50K
# 26932           0.0           0.0       45.278795  United-States  <=50K
#
# [26933 rows x 15 columns]},
#  'Loader[adult]_Preprocessor[demo]_Synthesizer[demo]_Postprocessor[demo]_Evaluator[demo]_Reporter[save_report_global]': {'demo_[global]':                                            full_expt_name     Score  \
# result  Loader[adult]_Preprocessor[demo]_Synthesizer[d...  0.778327
#
#         Column Shapes  Column Pair Trends
# result       0.940459            0.616196  }}

# %% [markdown]
# ## User Story 5: Customized Evaluating
#
# > Following User Story 4, if specific types of metrics are set or a customized evaluation script is provided, the module will create a customized evaluation report.
# >
# > 根據用戶故事 4，如果指定特定的指標、或是提供用戶自定義的評估腳本，模組會產生客製化的評估報告。

# %%
config_file = 'UserStory_05.yaml'

DevTest_UserStory(config_file = config_file)
# Out:
# YAML file UserStory_05.yaml is ...
#
# {'Evaluator': {'custom': {'custom_method': {...}, 'method': 'custom_method'}},
#  'Loader': {'adult': {'filepath': 'benchmark://adult', 'na_values': {...}}},
#  'Postprocessor': {'demo': {'method': 'default'}},
#  'Preprocessor': {'demo': {'method': 'default'}},
#  'Reporter': {'save_report_columnwise': {'eval': 'custom',
#                                          'granularity': 'columnwise',
#                                          'method': 'save_report',
#                                          'output': 'UserStory_05'},
#               'save_report_global': {'eval': 'custom',
#                                      'granularity': 'global',
#                                      'method': 'save_report',
#                                      'output': 'UserStory_05'},
#               'save_report_pairwise': {'eval': 'custom',
#                                        'granularity': 'pairwise',
#                                        'method': 'save_report',
#                                        'output': 'UserStory_05'}},
#  'Synthesizer': {'demo': {'method': 'default'}}}
#
#
# Here's the result...
#
# Now is Loader with adult...
# Loader - Benchmarker: file benchmark\adult.csv already exist and match SHA-256.
#                       PETsARD will ignore download and use local data directly.
# Now is Preprocessor with demo...
# Now is Synthesizer with demo...
# Synthesizer (SDV - SingleTable): Metafile loading time: 0.0331 sec.
# Synthesizer (SDV - SingleTable): Fitting GaussianCopula.
# Synthesizer (SDV - SingleTable): Fitting  GaussianCopula spent 8.6405 sec.
# Synthesizer (SDV - SingleTable): Sampling GaussianCopula # 26933 rows (same as raw) in 1.7748 sec.
# Now is Postprocessor with demo...
# Now is Evaluator with custom...
# Now is Reporter with save_report_global...
# Now is UserStory_05[Report]_custom_[global] save to csv...
# Now is Reporter with save_report_columnwise...
# Now is UserStory_05[Report]_custom_[columnwise] save to csv...
# Now is Reporter with save_report_pairwise...
# Now is UserStory_05[Report]_custom_[pairwise] save to csv...
#
#
# Here's the result...
#
# {'Loader[adult]_Preprocessor[demo]_Synthesizer[demo]_Postprocessor[demo]_Evaluator[custom]_Reporter[save_report_columnwise]': {'custom_[columnwise]':                                        full_expt_name           column  score
# 0   Loader[adult]_Preprocessor[demo]_Synthesizer[d...              age    100
# 1   Loader[adult]_Preprocessor[demo]_Synthesizer[d...        workclass    100
# 2   Loader[adult]_Preprocessor[demo]_Synthesizer[d...           fnlwgt    100
# 3   Loader[adult]_Preprocessor[demo]_Synthesizer[d...        education    100
# 4   Loader[adult]_Preprocessor[demo]_Synthesizer[d...  educational-num    100
# 5   Loader[adult]_Preprocessor[demo]_Synthesizer[d...   marital-status    100
# 6   Loader[adult]_Preprocessor[demo]_Synthesizer[d...       occupation    100
# 7   Loader[adult]_Preprocessor[demo]_Synthesizer[d...     relationship    100
# 8   Loader[adult]_Preprocessor[demo]_Synthesizer[d...             race    100
# 9   Loader[adult]_Preprocessor[demo]_Synthesizer[d...           gender    100
# 10  Loader[adult]_Preprocessor[demo]_Synthesizer[d...     capital-gain    100
# 11  Loader[adult]_Preprocessor[demo]_Synthesizer[d...     capital-loss    100
# 12  Loader[adult]_Preprocessor[demo]_Synthesizer[d...   hours-per-week    100
# 13  Loader[adult]_Preprocessor[demo]_Synthesizer[d...   native-country    100
# 14  Loader[adult]_Preprocessor[demo]_Synthesizer[d...           income    100},
#  'Loader[adult]_Preprocessor[demo]_Synthesizer[demo]_Postprocessor[demo]_Evaluator[custom]_Reporter[save_report_global]': {'custom_[global]':                                            full_expt_name  score
# result  Loader[adult]_Preprocessor[demo]_Synthesizer[d...    100},
#  'Loader[adult]_Preprocessor[demo]_Synthesizer[demo]_Postprocessor[demo]_Evaluator[custom]_Reporter[save_report_pairwise]': {'custom_[pairwise]':                                         full_expt_name    column1  \
# 0    Loader[adult]_Preprocessor[demo]_Synthesizer[d...        age
# 1    Loader[adult]_Preprocessor[demo]_Synthesizer[d...  workclass
# 2    Loader[adult]_Preprocessor[demo]_Synthesizer[d...  workclass
# 3    Loader[adult]_Preprocessor[demo]_Synthesizer[d...     fnlwgt
# 4    Loader[adult]_Preprocessor[demo]_Synthesizer[d...     fnlwgt
# ..                                                 ...        ...
# 115  Loader[adult]_Preprocessor[demo]_Synthesizer[d...     income
# 116  Loader[adult]_Preprocessor[demo]_Synthesizer[d...     income
# 117  Loader[adult]_Preprocessor[demo]_Synthesizer[d...     income
# 118  Loader[adult]_Preprocessor[demo]_Synthesizer[d...     income
# 119  Loader[adult]_Preprocessor[demo]_Synthesizer[d...     income
#
#             column2  score
# 0               age    100
# 1               age    100
# 2         workclass    100
# 3               age    100
# 4         workclass    100
# ..              ...    ...
# 115    capital-gain    100
# 116    capital-loss    100
# 117  hours-per-week    100
# 118  native-country    100
# 119          income    100
#
# [120 rows x 4 columns]}}

# %% [markdown]
# # Type 2: Evaluating data
#
# > Type 2: Evaluate privacy enhanced dataset
# >
# > 類型二：評估隱私強化資料集

# %% [markdown]
# ## User Story 6: Given data evaluating
#
# > Given an original dataset and a privacy enhanced dataset to the evaluation module, the pipeline will create a report covering default/general metrics of privacy risk and utility.
# >
# > 給定原始資料集與對應的隱私強化資料集到評估模組中，該流程會產生一份涵蓋預設/一般指標的隱私風險與效用的報告。

# %%
config_file = 'UserStory_06-1.yaml'

DevTest_UserStory(config_file = config_file)
# Out:
# YAML file UserStory_06-1.yaml is ...
#
# {'Evaluator': {'demo': {'method': 'default'}},
#  'Loader': {'custom': {'filepath': 'ori.csv'}},
#  'Reporter': {'save_report_global': {'eval': 'demo',
#                                      'granularity': 'global',
#                                      'method': 'save_report',
#                                      'output': 'UserStory_06-1'}},
#  'Synthesizer': {'custom': {'filepath': 'syn.csv', 'method': 'custom_data'}}}
#
#
# Here's the result...
#
# Now is Loader with custom...
# Now is Synthesizer with custom...
# Now is Evaluator with demo...
# Generating report ...
# (1/2) Evaluating Column Shapes: : 100%|██████████| 15/15 [00:00<00:00, 69.87it/s]
# (2/2) Evaluating Column Pair Trends: : 100%|██████████| 105/105 [00:04<00:00, 25.64it/s]
#
# Overall Score: 78.22%
#
# Properties:
# - Column Shapes: 95.42%
# - Column Pair Trends: 61.03%
# Now is Reporter with save_report_global...
# Now is UserStory_06-1[Report]_demo_[global] save to csv...
#
#
# Here's the result...
#
# {'Loader[custom]_Synthesizer[custom]_Evaluator[demo]_Reporter[save_report_global]': {'demo_[global]':                                            full_expt_name     Score  \
# result  Loader[custom]_Synthesizer[custom]_Evaluator[d...  0.782221
#
#         Column Shapes  Column Pair Trends
# result       0.954186            0.610256  }}

# %%
config_file = 'UserStory_06-2.yaml'

DevTest_UserStory(config_file = config_file)
# Out:
# YAML file UserStory_06-2.yaml is ...
#
# {'Evaluator': {'anony-singling': {'method': 'anonymeter-singlingout_univariate',
#                                   'n_attack': 2},
#                'demo': {'method': 'default'}},
#  'Reporter': {'save_report_global_anony': {'eval': 'anony-singling',
#                                            'granularity': 'global',
#                                            'method': 'save_report',
#                                            'output': 'UserStory_06-2'},
#               'save_report_global_demo': {'eval': 'demo',
#                                           'granularity': 'global',
#                                           'method': 'save_report',
#                                           'output': 'UserStory_06-2'}},
#  'Splitter': {'custom': {'filepath': {...}, 'method': 'custom_data'}},
#  'Synthesizer': {'custom': {'filepath': 'syn.csv', 'method': 'custom_data'}}}
#
#
# Here's the result...
#
# Now is Splitter with custom_[1-1]...
# Now is Synthesizer with custom...
# Now is Evaluator with demo...
# Generating report ...
# (1/2) Evaluating Column Shapes: : 100%|██████████| 15/15 [00:00<00:00, 86.70it/s]
# (2/2) Evaluating Column Pair Trends: : 100%|██████████| 105/105 [00:04<00:00, 25.82it/s]
#
# Overall Score: 78.22%
#
# Properties:
# - Column Shapes: 95.42%
# - Column Pair Trends: 61.03%
# Now is Reporter with save_report_global_demo...
# Now is UserStory_06-2[Report]_demo_[global] save to csv...
# Now is Reporter with save_report_global_anony...
# Now is Evaluator with anony-singling...
# Now is Reporter with save_report_global_demo...
# Now is Reporter with save_report_global_anony...
# Now is UserStory_06-2[Report]_anony-singling_[global] save to csv...
#
#
# Here's the result...
#
# {'Splitter[custom_[1-1]]_Synthesizer[custom]_Evaluator[anony-singling]_Reporter[save_report_global_anony]': {'anony-singling_[global]':                                            full_expt_name  risk  risk_CI_btm  \
# result  Splitter[custom_[1-1]]_Synthesizer[custom]_Eva...   0.0          0.0
#
#         risk_CI_top  attack_rate  attack_rate_err  baseline_rate  \
# result     0.011937     0.043377         0.008876       0.001458
#
#         baseline_rate_err  control_rate  control_rate_err
# result           0.001369       0.04462          0.008998  },
#  'Splitter[custom_[1-1]]_Synthesizer[custom]_Evaluator[anony-singling]_Reporter[save_report_global_demo]': {},
#  'Splitter[custom_[1-1]]_Synthesizer[custom]_Evaluator[demo]_Reporter[save_report_global_anony]': {},
#  'Splitter[custom_[1-1]]_Synthesizer[custom]_Evaluator[demo]_Reporter[save_report_global_demo]': {'demo_[global]':                                            full_expt_name     Score  \
# result  Splitter[custom_[1-1]]_Synthesizer[custom]_Eva...  0.782221
#
#         Column Shapes  Column Pair Trends
# result       0.954186            0.610256  }}

# %% [markdown]
# ## User Story 7: Given data customized evaluating
#
# > Following User Story 6, if specific types of metrics are set or a customized evaluation script is provided, the module will create a customized evaluation report.
# >
# > 根據用戶故事 6，如果指定特定的指標、或是提供用戶自定義的評估腳本，模組會產生客製化的評估報告。

# %%
config_file = 'UserStory_07.yaml'

DevTest_UserStory(config_file = config_file)
# Out:
# YAML file UserStory_07.yaml is ...
#
# {'Evaluator': {'custom': {'custom_method': {...}, 'method': 'custom_method'},
#                'demo': {'method': 'default'}},
#  'Loader': {'adult_ori': {'filepath': 'ori.csv'}},
#  'Reporter': {'save_report_custom': {'eval': 'custom',
#                                      'granularity': 'global',
#                                      'method': 'save_report',
#                                      'output': 'UserStory_07'},
#               'save_report_demo': {'eval': 'demo',
#                                    'granularity': 'global',
#                                    'method': 'save_report',
#                                    'output': 'UserStory_07'},
#               'save_report_sd-qlt': {'eval': 'sd-qlt',
#                                      'granularity': 'global',
#                                      'method': 'save_report',
#                                      'output': 'UserStory_07'}},
#  'Synthesizer': {'custom': {'filepath': 'syn.csv', 'method': 'custom_data'}}}
#
#
# Here's the result...
#
# Now is Loader with adult_ori...
# Now is Synthesizer with custom...
# Now is Evaluator with demo...
# Generating report ...
# (1/2) Evaluating Column Shapes: : 100%|██████████| 15/15 [00:00<00:00, 76.35it/s]
# (2/2) Evaluating Column Pair Trends: : 100%|██████████| 105/105 [00:06<00:00, 16.40it/s]
#
# Overall Score: 78.22%
#
# Properties:
# - Column Shapes: 95.42%
# - Column Pair Trends: 61.03%
# Now is Reporter with save_report_demo...
# Now is UserStory_07[Report]_demo_[global] save to csv...
# Now is Reporter with save_report_sd-qlt...
# Now is Reporter with save_report_custom...
# Now is Evaluator with custom...
# Now is Reporter with save_report_demo...
# Now is Reporter with save_report_sd-qlt...
# Now is Reporter with save_report_custom...
# Now is UserStory_07[Report]_custom_[global] save to csv...
#
#
# Here's the result...
#
# {'Loader[adult_ori]_Synthesizer[custom]_Evaluator[custom]_Reporter[save_report_custom]': {'custom_[global]':                                            full_expt_name  score
# result  Loader[adult_ori]_Synthesizer[custom]_Evaluato...    100},
#  'Loader[adult_ori]_Synthesizer[custom]_Evaluator[custom]_Reporter[save_report_demo]': {},
#  'Loader[adult_ori]_Synthesizer[custom]_Evaluator[custom]_Reporter[save_report_sd-qlt]': {},
#  'Loader[adult_ori]_Synthesizer[custom]_Evaluator[demo]_Reporter[save_report_custom]': {},
#  'Loader[adult_ori]_Synthesizer[custom]_Evaluator[demo]_Reporter[save_report_demo]': {'demo_[global]':                                            full_expt_name     Score  \
# result  Loader[adult_ori]_Synthesizer[custom]_Evaluato...  0.782221
#
#         Column Shapes  Column Pair Trends
# result       0.954186            0.610256  },
#  'Loader[adult_ori]_Synthesizer[custom]_Evaluator[demo]_Reporter[save_report_sd-qlt]': {}}

# %% [markdown]
# # Type 3: Evaluating algorithm
#
# > Type 3: Evaluate a data generation algorithm (incl. data processing)
# >
# > 類型三：評估資料生成演算法（與資料處理流程）

# %% [markdown]
# ## User Story 8: Synthesizing on default data
#
# > With a specified data generation algorithm, a default benchmark dataset collection will serve as inputs, and the pipeline will generate the corresponding privacy enhanced datasets as output, using the selected algorithm.
# >
# > 指定資料生成演算法後，預設的經典資料集會用作輸入，並且該流程將使用該演算法輸出對應的隱私強化資料集。

# %%
config_file = 'UserStory_08.yaml'

DevTest_UserStory(config_file = config_file)
# Out:
# YAML file UserStory_08.yaml is ...
#
# {'Loader': {'demo': {'method': 'default'}},
#  'Postprocessor': {'demo': {'method': 'default'}},
#  'Preprocessor': {'demo': {'method': 'default'}},
#  'Reporter': {'save_data': {'method': 'save_data',
#                             'output': 'UserStory_08',
#                             'source': 'Postprocessor'}},
#  'Synthesizer': {'sdv-gaussian': {'method': 'sdv-single_table-gaussiancopula'}}}
#
#
# Here's the result...
#
# Now is Loader with demo...
# Loader - Benchmarker: file benchmark\adult.csv already exist and match SHA-256.
#                       PETsARD will ignore download and use local data directly.
# Now is Preprocessor with demo...
# Now is Synthesizer with sdv-gaussian...
# Synthesizer (SDV - SingleTable): Metafile loading time: 0.02 sec.
# Synthesizer (SDV - SingleTable): Fitting GaussianCopula.
# Synthesizer (SDV - SingleTable): Fitting  GaussianCopula spent 9.8336 sec.
# Synthesizer (SDV - SingleTable): Sampling GaussianCopula # 28558 rows (same as raw) in 2.3192 sec.
# Now is Postprocessor with demo...
# Now is Reporter with save_data...
# Now is UserStory_08_Loader[demo]_Preprocessor[demo]_Synthesizer[sdv-gaussian]_Postprocessor[demo] save to csv...
#
#
# Here's the result...
#
# {'Loader[demo]_Preprocessor[demo]_Synthesizer[sdv-gaussian]_Postprocessor[demo]_Reporter[save_data]': {'Loader[demo]_Preprocessor[demo]_Synthesizer[sdv-gaussian]_Postprocessor[demo]':              age         workclass         fnlwgt     education  \
# 0      31.374638      Self-emp-inc  166422.056395       Masters
# 1      42.593069           Private  202172.650697  Some-college
# 2      46.431801                 ?  188070.559890     Bachelors
# 3      30.038527           Private  186453.751792  Some-college
# 4      52.637047           Private   72130.215031     Bachelors
# ...          ...               ...            ...           ...
# 28553  37.194149           Private  117875.651216  Some-college
# 28554  18.540566  Self-emp-not-inc   46648.819308     Bachelors
# 28555  38.034662           Private  200309.203249     Bachelors
# 28556  52.233852           Private  328403.934324    Assoc-acdm
# 28557  53.002253         State-gov  162465.543029  Some-college
#
#        educational-num      marital-status         occupation   relationship  \
# 0             9.549007  Married-civ-spouse     Prof-specialty        Husband
# 1             7.834106  Married-civ-spouse       Craft-repair  Not-in-family
# 2            11.172208            Divorced       Tech-support      Own-child
# 3             7.959503  Married-civ-spouse      Other-service        Husband
# 4            12.723360  Married-civ-spouse       Craft-repair      Unmarried
# ...                ...                 ...                ...            ...
# 28553        15.301618  Married-civ-spouse              Sales      Unmarried
# 28554        12.091247  Married-civ-spouse       Craft-repair        Husband
# 28555        10.586316            Divorced     Prof-specialty      Unmarried
# 28556         9.189097  Married-civ-spouse  Handlers-cleaners        Husband
# 28557        11.183429  Married-civ-spouse       Craft-repair  Not-in-family
#
#         race  gender  capital-gain  capital-loss  hours-per-week  \
# 0      White    Male           0.0           0.0       44.377463
# 1      Black    Male           0.0           0.0       42.806884
# 2      White    Male           0.0           0.0       34.204399
# 3      White    Male           0.0           0.0       43.901734
# 4      Black  Female           0.0           0.0       37.199721
# ...      ...     ...           ...           ...             ...
# 28553  White    Male           0.0           0.0       34.781130
# 28554  White    Male           0.0           0.0       35.362086
# 28555  Black    Male           0.0           0.0       45.347516
# 28556  White    Male           0.0           0.0       34.956171
# 28557  White    Male           0.0           0.0       51.728869
#
#       native-country income
# 0      United-States   >50K
# 1      United-States  <=50K
# 2      United-States  <=50K
# 3      United-States   >50K
# 4              India  <=50K
# ...              ...    ...
# 28553  United-States  <=50K
# 28554  United-States   >50K
# 28555       Columbia  <=50K
# 28556  United-States  <=50K
# 28557  United-States  <=50K
#
# [28558 rows x 15 columns]}}

# %% [markdown]
# ## User Story 9: Synthesizing on multiple data
#
# >Following User Story 8, the user can specify a list of datasets instead.
# >
# > 根據用戶故事 8，使用者可以改為指定一個資料集列表。

# %%
config_file = 'UserStory_09.yaml'

DevTest_UserStory(config_file = config_file)
# Out:
# YAML file UserStory_09.yaml is ...
#
# {'Loader': {'adult_local': {'filepath': 'benchmark://adult',
#                             'na_values': {...}},
#             'demo': {'method': 'default'}},
#  'Postprocessor': {'demo': {'method': 'default'}},
#  'Preprocessor': {'demo': {'method': 'default'}},
#  'Reporter': {'save_data': {'method': 'save_data',
#                             'output': 'UserStory_09',
#                             'source': 'Postprocessor'}},
#  'Synthesizer': {'sdv-gaussian': {'method': 'sdv-single_table-gaussiancopula'}}}
#
#
# Here's the result...
#
# Now is Loader with demo...
# Loader - Benchmarker: file benchmark\adult.csv already exist and match SHA-256.
#                       PETsARD will ignore download and use local data directly.
# Now is Preprocessor with demo...
# Now is Synthesizer with sdv-gaussian...
# Synthesizer (SDV - SingleTable): Metafile loading time: 0.0313 sec.
# Synthesizer (SDV - SingleTable): Fitting GaussianCopula.
# Synthesizer (SDV - SingleTable): Fitting  GaussianCopula spent 14.673 sec.
# Synthesizer (SDV - SingleTable): Sampling GaussianCopula # 28558 rows (same as raw) in 2.6087 sec.
# Now is Postprocessor with demo...
# Now is Reporter with save_data...
# Now is UserStory_09_Loader[demo]_Preprocessor[demo]_Synthesizer[sdv-gaussian]_Postprocessor[demo] save to csv...
# Now is Loader with adult_local...
# Loader - Benchmarker: file benchmark\adult.csv already exist and match SHA-256.
#                       PETsARD will ignore download and use local data directly.
# Now is Preprocessor with demo...
# Now is Synthesizer with sdv-gaussian...
# Synthesizer (SDV - SingleTable): Metafile loading time: 0.0304 sec.
# Synthesizer (SDV - SingleTable): Fitting GaussianCopula.
# Synthesizer (SDV - SingleTable): Fitting  GaussianCopula spent 11.198 sec.
# Synthesizer (SDV - SingleTable): Sampling GaussianCopula # 26933 rows (same as raw) in 2.5488 sec.
# Now is Postprocessor with demo...
# Now is Reporter with save_data...
# Now is UserStory_09_Loader[adult_local]_Preprocessor[demo]_Synthesizer[sdv-gaussian]_Postprocessor[demo] save to csv...
#
#
# Here's the result...
#
# {'Loader[adult_local]_Preprocessor[demo]_Synthesizer[sdv-gaussian]_Postprocessor[demo]_Reporter[save_data]': {'Loader[adult_local]_Preprocessor[demo]_Synthesizer[sdv-gaussian]_Postprocessor[demo]':              age         workclass         fnlwgt     education  \
# 0      44.643325  Self-emp-not-inc  203810.423005       HS-grad
# 1      50.672999           Private  198436.660152       HS-grad
# 2      49.222980         State-gov  238524.594945     Bachelors
# 3      31.685424           Private  184346.146201       HS-grad
# 4      42.113370         Local-gov   69594.692733     Assoc-voc
# ...          ...               ...            ...           ...
# 26928  24.487484         Local-gov  159628.855538          11th
# 26929  25.760114           Private  104420.804132     Bachelors
# 26930  40.779796           Private   15976.542307  Some-college
# 26931  44.688990           Private   57021.099553   Prof-school
# 26932  17.576224           Private  251041.232913          10th
#
#        educational-num      marital-status         occupation    relationship  \
# 0            15.278920       Never-married       Adm-clerical         Husband
# 1            10.058436  Married-civ-spouse       Adm-clerical         Husband
# 2             6.386738            Divorced      Other-service       Unmarried
# 3            10.312494  Married-civ-spouse  Handlers-cleaners         Husband
# 4            12.228158  Married-civ-spouse       Craft-repair       Unmarried
# ...                ...                 ...                ...             ...
# 26928        13.796146       Never-married    Exec-managerial   Not-in-family
# 26929         5.717732           Separated    Exec-managerial  Other-relative
# 26930         7.420911  Married-civ-spouse      Other-service         Husband
# 26931        12.084404       Never-married     Prof-specialty   Not-in-family
# 26932         9.439290  Married-civ-spouse     Prof-specialty       Own-child
#
#         race  gender  capital-gain  capital-loss  hours-per-week  \
# 0      White    Male           0.0           0.0       42.420354
# 1      Black    Male           0.0           0.0       38.666900
# 2      White  Female           0.0           0.0       42.169913
# 3      White    Male           0.0           0.0       41.043959
# 4      Black  Female           0.0           0.0       40.157514
# ...      ...     ...           ...           ...             ...
# 26928  White    Male           0.0           0.0       42.075279
# 26929  White  Female           0.0           0.0       40.599293
# 26930  White    Male           0.0           0.0       50.684109
# 26931  White  Female           0.0           0.0       38.012514
# 26932  White  Female           0.0           0.0       45.541173
#
#       native-country income
# 0      United-States   >50K
# 1      United-States  <=50K
# 2      United-States  <=50K
# 3      United-States  <=50K
# 4              China  <=50K
# ...              ...    ...
# 26928          Italy  <=50K
# 26929  United-States  <=50K
# 26930  United-States  <=50K
# 26931  United-States  <=50K
# 26932  United-States   >50K
#
# [26933 rows x 15 columns]},
#  'Loader[demo]_Preprocessor[demo]_Synthesizer[sdv-gaussian]_Postprocessor[demo]_Reporter[save_data]': {'Loader[demo]_Preprocessor[demo]_Synthesizer[sdv-gaussian]_Postprocessor[demo]':              age workclass         fnlwgt     education  educational-num  \
# 0      50.993115   Private  229746.038465       HS-grad        15.149104
# 1      28.929958   Private  195897.560637       HS-grad        10.828506
# 2      35.326572   Private  292443.209409  Some-college         7.005100
# 3      44.307631   Private  167062.412347       HS-grad         9.792793
# 4      22.695904   Private  140933.547869    Assoc-acdm        13.234278
# ...          ...       ...            ...           ...              ...
# 28553  40.353256   Private  124757.634540          10th         8.808571
# 28554  52.969522   Private  150839.122368       HS-grad        11.503851
# 28555  22.148512   Private  114868.208470     Bachelors        14.337733
# 28556  43.565032   Private  392959.041509     Bachelors         8.930096
# 28557  34.572442   Private  139447.305862  Some-college        14.353188
#
#            marital-status        occupation relationship   race  gender  \
# 0           Never-married   Exec-managerial      Husband  White    Male
# 1      Married-civ-spouse   Farming-fishing    Own-child  White    Male
# 2                Divorced      Adm-clerical    Unmarried  White  Female
# 3      Married-civ-spouse     Other-service      Husband  White    Male
# 4      Married-civ-spouse    Prof-specialty    Unmarried  White  Female
# ...                   ...               ...          ...    ...     ...
# 28553       Never-married    Prof-specialty         Wife  White    Male
# 28554            Divorced    Prof-specialty      Husband  White    Male
# 28555       Never-married      Adm-clerical         Wife  Black    Male
# 28556  Married-civ-spouse  Transport-moving      Husband  White    Male
# 28557  Married-civ-spouse    Prof-specialty      Husband  White    Male
#
#        capital-gain  capital-loss  hours-per-week native-country income
# 0               0.0           0.0       40.890217  United-States  <=50K
# 1               0.0           0.0       36.583342  United-States   >50K
# 2               0.0           0.0       42.448730  United-States  <=50K
# 3               0.0           0.0       39.373316  United-States  <=50K
# 4               0.0           0.0       48.763574  United-States  <=50K
# ...             ...           ...             ...            ...    ...
# 28553           0.0           0.0       49.728497  United-States  <=50K
# 28554           0.0           0.0       51.301059  United-States  <=50K
# 28555           0.0           0.0       35.916060    Puerto-Rico   >50K
# 28556           0.0           0.0       49.158639  United-States   >50K
# 28557           0.0           0.0       34.509579  United-States   >50K
#
# [28558 rows x 15 columns]}}

# %% [markdown]
# ## User Story 10: Synthesizing and Evaluating on default data
#
# > Following User Story 8, if users enable the evaluation step,  the evaluation module will create a report covering default privacy risk and utility metrics for all datasets.
# >
# > 根據用戶故事 8，如果使用者啟用評估步驟，評估模組將會產生一份涵蓋所有資料集的隱私風險與效用指標報告。

# %%
config_file = 'UserStory_10.yaml'

DevTest_UserStory(config_file = config_file)
# Out:
# YAML file UserStory_10.yaml is ...
#
# {'Loader': {'demo': {'method': 'default'}},
#  'Postprocessor': {'demo': {'method': 'default'}},
#  'Preprocessor': {'demo': {'method': 'default'}},
#  'Reporter': {'save_data': {'method': 'save_data',
#                             'output': 'UserStory_10',
#                             'source': 'Postprocessor'}},
#  'Synthesizer': {'sdv-gaussian': {'method': 'sdv-single_table-gaussiancopula'}}}
#
#
# Here's the result...
#
# Now is Loader with demo...
# Loader - Benchmarker: file benchmark\adult.csv already exist and match SHA-256.
#                       PETsARD will ignore download and use local data directly.
# Now is Preprocessor with demo...
# Now is Synthesizer with sdv-gaussian...
# Synthesizer (SDV - SingleTable): Metafile loading time: 0.0391 sec.
# Synthesizer (SDV - SingleTable): Fitting GaussianCopula.
# Synthesizer (SDV - SingleTable): Fitting  GaussianCopula spent 10.8861 sec.
# Synthesizer (SDV - SingleTable): Sampling GaussianCopula # 28558 rows (same as raw) in 2.0028 sec.
# Now is Postprocessor with demo...
# Now is Reporter with save_data...
# Now is UserStory_10_Loader[demo]_Preprocessor[demo]_Synthesizer[sdv-gaussian]_Postprocessor[demo] save to csv...
#
#
# Here's the result...
#
# {'Loader[demo]_Preprocessor[demo]_Synthesizer[sdv-gaussian]_Postprocessor[demo]_Reporter[save_data]': {'Loader[demo]_Preprocessor[demo]_Synthesizer[sdv-gaussian]_Postprocessor[demo]':              age    workclass         fnlwgt     education  educational-num  \
# 0      44.704825      Private   95142.237680  Some-college        15.353567
# 1      55.573177      Private  144496.497940     Bachelors         9.701703
# 2      45.972619      Private   52452.246801       HS-grad         6.913293
# 3      27.118801      Private  181417.199103       HS-grad        10.599032
# 4      50.587678  Federal-gov  183221.186940          11th        11.524541
# ...          ...          ...            ...           ...              ...
# 28553  26.136479            ?  247799.919037     Assoc-voc         9.596884
# 28554  34.729164      Private  257024.341775  Some-college        11.982793
# 28555  51.129693      Private  361013.946365           9th        12.329816
# 28556  49.334319      Private   65895.678458  Some-college         8.903669
# 28557  66.089241      Private  189116.416340     Bachelors        12.497377
#
#            marital-status         occupation   relationship   race  gender  \
# 0           Never-married              Sales        Husband  White    Male
# 1           Never-married  Handlers-cleaners  Not-in-family  Black    Male
# 2           Never-married     Prof-specialty      Own-child  White  Female
# 3           Never-married      Other-service        Husband  White    Male
# 4                Divorced    Exec-managerial           Wife  White    Male
# ...                   ...                ...            ...    ...     ...
# 28553  Married-civ-spouse     Prof-specialty           Wife  White    Male
# 28554  Married-civ-spouse    Exec-managerial        Husband  White  Female
# 28555       Never-married   Transport-moving      Own-child  White  Female
# 28556  Married-civ-spouse       Craft-repair        Husband  White    Male
# 28557  Married-civ-spouse      Other-service  Not-in-family  White    Male
#
#        capital-gain  capital-loss  hours-per-week native-country income
# 0               0.0           0.0       42.746949  United-States   >50K
# 1               0.0           0.0       42.933029  United-States  <=50K
# 2               0.0           0.0       36.686966  United-States  <=50K
# 3               0.0           0.0       42.804454  United-States  <=50K
# 4               0.0           0.0       35.015157  United-States  <=50K
# ...             ...           ...             ...            ...    ...
# 28553           0.0           0.0       35.799218  United-States  <=50K
# 28554           0.0           0.0       33.204623  United-States   >50K
# 28555           0.0           0.0       40.442882              ?  <=50K
# 28556           0.0           0.0       37.188562         Canada  <=50K
# 28557           0.0           0.0       51.041106  United-States   >50K
#
# [28558 rows x 15 columns]}}
