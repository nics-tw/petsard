# %% [markdown]
# # User Story C
# **Privacy Enhancing Data Evaluation**
#
#
# This demo will show how to evaluate privacy-enhanced data using `PETsARD`.
#
# In this demonstration, you, as the user, already have a data file on your local machine, as well as its corresponding synthetic data results, which are likely from your existing privacy protection service. `PETsARD` will assist you in reading these files and evaluating the results, helping you compare your current solution with other technologies.
#
# 本示範將展示如何使用 `PETsARD` 生成與評測隱私強化資料。
#
# 在這個示範中，您作為使用者，在本機上已經擁有一份資料檔案、以及其對應的合成資料結果，這很可能是來自於您現有的隱私保護服務，而 `PETsARD` 將幫助您讀取這些檔案、評測結果，幫助您針對現有的解決方案跟其他技術做比較。

# %% [markdown]
# ---
#
# ## Environment

# %%
import os
import pprint
import sys

import yaml


# Setting up the path to the PETsARD package
path_petsard = os.path.dirname(os.getcwd())
print(path_petsard)
sys.path.append(path_petsard)


from PETsARD import Executor
# Out:
# d:\Dropbox\89_other_application\GitHub\PETsARD

# %% [markdown]
# > `Demo_UserStory` is a function created for demonstrating details and can be ignored.
# >
# > `Demo_UserStory` 是為了展現示範細節而建立的函式，可忽略。

# %%
def Demo_UserStory(config_file: str):
    print(f"YAML file {config_file} is ...")
    print(f"")
    pp = pprint.PrettyPrinter(depth=3, sort_dicts=False)
    with open(config_file, 'r') as yaml_file:
        yaml_raw: dict = yaml.safe_load(yaml_file)
    pp.pprint(yaml_raw)

    print(f"")
    print(f"")
    print(f"Here's the execution...")
    print(f"")
    exec = Executor(config=config_file)
    exec.run()

    print(f"")
    print(f"")
    print(f"Here's the result...")
    print(f"")
    pp.pprint(exec.get_result())

# %% [markdown]
# ---
#
# ## User Story C-1
# **Default Describing**
#
# Given a dataset as an input, the pipeline can go through the "describe" module to get a summary of the dataset.
#
# 給定一個資料集做輸入，該流程可以藉由調用 "describe" 模組而得到該資料集的摘要

# %%
config_file = '../yaml/User Story C-1.yaml'

Demo_UserStory(config_file = config_file)
# Out:
# YAML file user_story/User Story C-1.yaml is ...
#
# {'Loader': {'adult': {'filepath': 'benchmark/adult-income.csv',
#                       'na_values': {...}}},
#  'Describer': {'demo': {'method': 'default'}},
#  'Reporter': {'save_report_global': {'method': 'save_report',
#                                      'output': 'User Story C-1',
#                                      'eval': 'demo',
#                                      'granularity': 'global'},
#               'save_report_columnwise': {'method': 'save_report',
#                                          'output': 'User Story C-1',
#                                          'eval': 'demo',
#                                          'granularity': 'columnwise'},
#               'save_report_pairwise': {'method': 'save_report',
#                                        'output': 'User Story C-1',
#                                        'eval': 'demo',
#                                        'granularity': 'pairwise'}}}
#
#
# Here's the execution...
#
# Now is Loader with adult...
# Now is Describer with demo...
# Now is Reporter with save_report_global...
# Now is User Story C-1[Report]_demo_[global] save to csv...
# Now is Reporter with save_report_columnwise...
# Now is User Story C-1[Report]_demo_[columnwise] save to csv...
# Now is Reporter with save_report_pairwise...
# Now is User Story C-1[Report]_demo_[pairwise] save to csv...
#
#
# Here's the result...
#
# {'Loader[adult]_Describer[demo]_Reporter[save_report_global]': {'demo_[global]':                            full_expt_name  row_count  col_count  na_count
# 0  Loader[adult]_Describer[demo_[global]]      48842         15      3620},
#  'Loader[adult]_Describer[demo]_Reporter[save_report_columnwise]': {'demo_[columnwise]':                                 full_expt_name           column  \
# 0   Loader[adult]_Describer[demo_[columnwise]]              age
# 1   Loader[adult]_Describer[demo_[columnwise]]           fnlwgt
# 2   Loader[adult]_Describer[demo_[columnwise]]  educational-num
# 3   Loader[adult]_Describer[demo_[columnwise]]     capital-gain
# 4   Loader[adult]_Describer[demo_[columnwise]]     capital-loss
# 5   Loader[adult]_Describer[demo_[columnwise]]   hours-per-week
# 6   Loader[adult]_Describer[demo_[columnwise]]        workclass
# 7   Loader[adult]_Describer[demo_[columnwise]]        education
# 8   Loader[adult]_Describer[demo_[columnwise]]   marital-status
# 9   Loader[adult]_Describer[demo_[columnwise]]       occupation
# 10  Loader[adult]_Describer[demo_[columnwise]]     relationship
# 11  Loader[adult]_Describer[demo_[columnwise]]             race
# 12  Loader[adult]_Describer[demo_[columnwise]]           gender
# 13  Loader[adult]_Describer[demo_[columnwise]]   native-country
# 14  Loader[adult]_Describer[demo_[columnwise]]           income
#
#              mean    median            std      min        max    kurtosis  \
# 0       38.643585      37.0      13.710510     17.0       90.0   -0.184269
# 1   189664.134597  178144.5  105604.025423  12285.0  1490400.0    6.057848
# 2       10.078089      10.0       2.570973      1.0       16.0    0.625745
# 3     1079.067626       0.0    7452.019058      0.0    99999.0  152.693096
# 4       87.502314       0.0     403.004552      0.0     4356.0   20.014346
# 5       40.422382      40.0      12.391444      1.0       99.0    2.951059
# 6             NaN       NaN            NaN      NaN        NaN         NaN
# 7             NaN       NaN            NaN      NaN        NaN         NaN
# 8             NaN       NaN            NaN      NaN        NaN         NaN
# 9             NaN       NaN            NaN      NaN        NaN         NaN
# 10            NaN       NaN            NaN      NaN        NaN         NaN
# 11            NaN       NaN            NaN      NaN        NaN         NaN
# 12            NaN       NaN            NaN      NaN        NaN         NaN
# 13            NaN       NaN            NaN      NaN        NaN         NaN
# 14            NaN       NaN            NaN      NaN        NaN         NaN
#
#          skew        q1        q3  na_count  nunique
# 0    0.557580      28.0      48.0         0      NaN
# 1    1.438892  117550.5  237642.0         0      NaN
# 2   -0.316525       9.0      12.0         0      NaN
# 3   11.894659       0.0       0.0         0      NaN
# 4    4.569809       0.0       0.0         0      NaN
# 5    0.238750      40.0      45.0         0      NaN
# 6         NaN       NaN       NaN      2799      8.0
# 7         NaN       NaN       NaN         0     16.0
# 8         NaN       NaN       NaN         0      7.0
# 9         NaN       NaN       NaN      2809     14.0
# 10        NaN       NaN       NaN         0      6.0
# 11        NaN       NaN       NaN         0      5.0
# 12        NaN       NaN       NaN         0      2.0
# 13        NaN       NaN       NaN       857     41.0
# 14        NaN       NaN       NaN         0      2.0  },
#  'Loader[adult]_Describer[demo]_Reporter[save_report_pairwise]': {'demo_[pairwise]':                               full_expt_name          column1  \
# 0   Loader[adult]_Describer[demo_[pairwise]]              age
# 1   Loader[adult]_Describer[demo_[pairwise]]           fnlwgt
# 2   Loader[adult]_Describer[demo_[pairwise]]  educational-num
# 3   Loader[adult]_Describer[demo_[pairwise]]     capital-gain
# 4   Loader[adult]_Describer[demo_[pairwise]]     capital-loss
# 5   Loader[adult]_Describer[demo_[pairwise]]   hours-per-week
# 6   Loader[adult]_Describer[demo_[pairwise]]           fnlwgt
# 7   Loader[adult]_Describer[demo_[pairwise]]  educational-num
# 8   Loader[adult]_Describer[demo_[pairwise]]     capital-gain
# 9   Loader[adult]_Describer[demo_[pairwise]]     capital-loss
# 10  Loader[adult]_Describer[demo_[pairwise]]   hours-per-week
# 11  Loader[adult]_Describer[demo_[pairwise]]  educational-num
# 12  Loader[adult]_Describer[demo_[pairwise]]     capital-gain
# 13  Loader[adult]_Describer[demo_[pairwise]]     capital-loss
# 14  Loader[adult]_Describer[demo_[pairwise]]   hours-per-week
# 15  Loader[adult]_Describer[demo_[pairwise]]     capital-gain
# 16  Loader[adult]_Describer[demo_[pairwise]]     capital-loss
# 17  Loader[adult]_Describer[demo_[pairwise]]   hours-per-week
# 18  Loader[adult]_Describer[demo_[pairwise]]     capital-loss
# 19  Loader[adult]_Describer[demo_[pairwise]]   hours-per-week
# 20  Loader[adult]_Describer[demo_[pairwise]]   hours-per-week
#
#             column2      corr
# 0               age  1.000000
# 1               age -0.076628
# 2               age  0.030940
# 3               age  0.077229
# 4               age  0.056944
# 5               age  0.071558
# 6            fnlwgt  1.000000
# 7            fnlwgt -0.038761
# 8            fnlwgt -0.003706
# 9            fnlwgt -0.004366
# 10           fnlwgt -0.013519
# 11  educational-num  1.000000
# 12  educational-num  0.125146
# 13  educational-num  0.080972
# 14  educational-num  0.143689
# 15     capital-gain  1.000000
# 16     capital-gain -0.031441
# 17     capital-gain  0.082157
# 18     capital-loss  1.000000
# 19     capital-loss  0.054467
# 20   hours-per-week  1.000000  }}

# %% [markdown]
# ---
#
# ## User Story C-2
# **Given data evaluating**
#
# Given an original dataset and a privacy enhanced dataset to the evaluation module, the pipeline will create a report covering default/general metrics of privacy risk and utility.
#
# 給定原始資料集與對應的隱私強化資料集到評估模組中，該流程會產生一份涵蓋預設/一般指標的隱私風險與效用的報告。

# %% [markdown]
# ### User Story C-2a
#
# C-2a demonstrates the evaluation approach of the Evaluator as comparing "original data" with "synthetic data," for instance, using`method = 'default'` or tools starting with `'sdmetrics-'` from SDMetrics.
#
# C-2a 展示的是 Evaluator 的評測方式是「原始資料」對照「合成資料」，例如 `method = 'default'` 或 `'sdmetrics-'` 開頭的 SDMetrics 評測工具。

# %%
config_file = '../yaml/User Story C-2a.yaml'

Demo_UserStory(config_file = config_file)
# Out:
# YAML file user_story/User Story C-2a.yaml is ...
#
# {'Loader': {'adult_ori': {'filepath': 'benchmark/adult-income_ori.csv'}},
#  'Synthesizer': {'custom': {'method': 'custom_data',
#                             'filepath': 'benchmark/adult-income_syn.csv'}},
#  'Evaluator': {'demo': {'method': 'default'}},
#  'Reporter': {'save_report_global': {'method': 'save_report',
#                                      'output': 'User Story C-2a',
#                                      'eval': 'demo',
#                                      'granularity': 'global'}}}
#
#
# Here's the execution...
#
# Now is Loader with adult_ori...
# Now is Synthesizer with custom...
# Now is Evaluator with demo...
# Generating report ...
# (1/2) Evaluating Column Shapes: : 100%|██████████| 15/15 [00:00<00:00, 60.45it/s]
# (2/2) Evaluating Column Pair Trends: : 100%|██████████| 105/105 [00:06<00:00, 17.11it/s]
#
# Overall Score: 78.22%
#
# Properties:
# - Column Shapes: 95.42%
# - Column Pair Trends: 61.03%
# Now is Reporter with save_report_global...
# Now is User Story C-2a[Report]_demo_[global] save to csv...
#
#
# Here's the result...
#
# {'Loader[adult_ori]_Synthesizer[custom]_Evaluator[demo]_Reporter[save_report_global]': {'demo_[global]':                                            full_expt_name     Score  \
# result  Loader[adult_ori]_Synthesizer[custom]_Evaluato...  0.782221
#
#         Column Shapes  Column Pair Trends
# result       0.954186            0.610256  }}

# %% [markdown]
# ### User Story C-2b
#
#
# C-2b demonstrates the evaluation method of the Evaluator as involving "original data used in synthesis" (abbreviated as ori), "original data not used in synthesis" (abbreviated as control), and "synthesized data" (abbreviated as syn), for example, using tools starting with `method ='anonymeter-'` from Anonymeter.
#
# C-2b 展示的是 Evaluator 的評測方式是「參與合成的原始資料」(original data, 縮寫為 ori)、「不參與合成的原始資料」(control data, 縮寫為 control)、與「合成資料」(synthesized data, 縮寫為 syn)，例如 `method ='anonymeter-'` 開頭的 Anonymeter 評測工具。

# %%
config_file = '../yaml/User Story C-2b.yaml'

Demo_UserStory(config_file = config_file)
# Out:
# YAML file user_story/User Story C-2b.yaml is ...
# {'Splitter': {'custom': {'method': 'custom_data', 'filepath': {...}}},
#  'Synthesizer': {'custom': {'method': 'custom_data',
#                             'filepath': 'benchmark/adult-income_syn.csv'}},
#  'Evaluator': {'demo': {'method': 'default'},
#                'anony-singling': {'method': 'anonymeter-singlingout_univariate'}},
#  'Reporter': {'save_report_global_demo': {'method': 'save_report',
#                                           'output': 'User Story C-2b',
#                                           'eval': 'demo',
#                                           'granularity': 'global'},
#               'save_report_global_anony': {'method': 'save_report',
#                                            'output': 'User Story C-2b',
#                                            'eval': 'anony-singling',
#                                            'granularity': 'global'}}}
#
#
# Here's the execution...
#
# Now is Splitter with custom_[1-1]...
# Now is Synthesizer with custom...
# Now is Evaluator with demo...
# Generating report ...
# (1/2) Evaluating Column Shapes: : 100%|██████████| 15/15 [00:00<00:00, 84.98it/s]
# (2/2) Evaluating Column Pair Trends: : 100%|██████████| 105/105 [00:05<00:00, 17.67it/s]
#
# Overall Score: 78.22%
#
# Properties:
# - Column Shapes: 95.42%
# - Column Pair Trends: 61.03%
# Now is Reporter with save_report_global_demo...
# Now is User Story C-2b[Report]_demo_[global] save to csv...
# Now is Reporter with save_report_global_anony...
# Now is Evaluator with anony-singling...
# Now is Reporter with save_report_global_demo...
# Now is Reporter with save_report_global_anony...
# Now is User Story C-2b[Report]_anony-singling_[global] save to csv...
#
#
# Here's the result...
#
# {'Splitter[custom_[1-1]]_Synthesizer[custom]_Evaluator[demo]_Reporter[save_report_global_demo]': {'demo_[global]':                                            full_expt_name     Score  \
# result  Splitter[custom_[1-1]]_Synthesizer[custom]_Eva...  0.782221
#
#         Column Shapes  Column Pair Trends
# result       0.954186            0.610256  },
#  'Splitter[custom_[1-1]]_Synthesizer[custom]_Evaluator[demo]_Reporter[save_report_global_anony]': {},
#  'Splitter[custom_[1-1]]_Synthesizer[custom]_Evaluator[anony-singling]_Reporter[save_report_global_demo]': {},
#  'Splitter[custom_[1-1]]_Synthesizer[custom]_Evaluator[anony-singling]_Reporter[save_report_global_anony]': {'anony-singling_[global]':                                            full_expt_name  risk  risk_CI_btm  \
# result  Splitter[custom_[1-1]]_Synthesizer[custom]_Eva...   0.0          0.0
#
#         risk_CI_top  attack_rate  attack_rate_err  baseline_rate  \
# result     0.010353     0.043876         0.008925       0.001957
#
#         baseline_rate_err  control_rate  control_rate_err
# result           0.001682      0.046856          0.009212  }}

# %% [markdown]
# ---
#
# ## User Story C-3 - Given data customized evaluating
#
# > Following User Story C-2, if specific types of metrics are set or a customized evaluation script is provided, the module will create a customized evaluation report.
# >
# >
# > 根據用戶故事 C-2，如果指定特定的指標、或是提供用戶自定義的評估腳本，模組會產生客製化的評估報告。
#
# > Aligning with User Story 7 of the Spec
# >
# >
# > 對標規格說明 (Spec) 的 User Story 7

# %%
config_file = '../yaml/User Story C-3.yaml'

Demo_UserStory(config_file = config_file)
# Out:
# YAML file user_story/User Story C-3.yaml is ...
#
# {'Loader': {'adult_ori': {'filepath': 'benchmark/adult-income_ori.csv'}},
#  'Synthesizer': {'custom': {'method': 'custom_data',
#                             'filepath': 'benchmark/adult-income_syn.csv'}},
#  'Evaluator': {'custom': {'method': 'custom_method', 'custom_method': {...}}},
#  'Reporter': {'save_report_global': {'method': 'save_report',
#                                      'output': 'User Story C-3',
#                                      'eval': 'custom',
#                                      'granularity': 'global'},
#               'save_report_columnwise': {'method': 'save_report',
#                                          'output': 'User Story C-3',
#                                          'eval': 'custom',
#                                          'granularity': 'columnwise'},
#               'save_report_pairwise': {'method': 'save_report',
#                                        'output': 'User Story C-3',
#                                        'eval': 'custom',
#                                        'granularity': 'pairwise'}}}
#
#
# Here's the execution...
#
# Now is Loader with adult_ori...
# Now is Synthesizer with custom...
# Now is Evaluator with custom...
# Now is Reporter with save_report_global...
# Now is User Story C-3[Report]_custom_[global] save to csv...
# Now is Reporter with save_report_columnwise...
# Now is User Story C-3[Report]_custom_[columnwise] save to csv...
# Now is Reporter with save_report_pairwise...
# Now is User Story C-3[Report]_custom_[pairwise] save to csv...
#
#
# Here's the result...
#
# {'Loader[adult_ori]_Synthesizer[custom]_Evaluator[custom]_Reporter[save_report_global]': {'custom_[global]':                                            full_expt_name  score
# result  Loader[adult_ori]_Synthesizer[custom]_Evaluato...    100},
#  'Loader[adult_ori]_Synthesizer[custom]_Evaluator[custom]_Reporter[save_report_columnwise]': {'custom_[columnwise]':                                        full_expt_name           column  score
# 0   Loader[adult_ori]_Synthesizer[custom]_Evaluato...              age    100
# 1   Loader[adult_ori]_Synthesizer[custom]_Evaluato...        workclass    100
# 2   Loader[adult_ori]_Synthesizer[custom]_Evaluato...           fnlwgt    100
# 3   Loader[adult_ori]_Synthesizer[custom]_Evaluato...        education    100
# 4   Loader[adult_ori]_Synthesizer[custom]_Evaluato...  educational-num    100
# 5   Loader[adult_ori]_Synthesizer[custom]_Evaluato...   marital-status    100
# 6   Loader[adult_ori]_Synthesizer[custom]_Evaluato...       occupation    100
# 7   Loader[adult_ori]_Synthesizer[custom]_Evaluato...     relationship    100
# 8   Loader[adult_ori]_Synthesizer[custom]_Evaluato...             race    100
# 9   Loader[adult_ori]_Synthesizer[custom]_Evaluato...           gender    100
# 10  Loader[adult_ori]_Synthesizer[custom]_Evaluato...     capital-gain    100
# 11  Loader[adult_ori]_Synthesizer[custom]_Evaluato...     capital-loss    100
# 12  Loader[adult_ori]_Synthesizer[custom]_Evaluato...   hours-per-week    100
# 13  Loader[adult_ori]_Synthesizer[custom]_Evaluato...   native-country    100
# 14  Loader[adult_ori]_Synthesizer[custom]_Evaluato...           income    100},
#  'Loader[adult_ori]_Synthesizer[custom]_Evaluator[custom]_Reporter[save_report_pairwise]': {'custom_[pairwise]':                                         full_expt_name    column1  \
# 0    Loader[adult_ori]_Synthesizer[custom]_Evaluato...        age
# 1    Loader[adult_ori]_Synthesizer[custom]_Evaluato...  workclass
# 2    Loader[adult_ori]_Synthesizer[custom]_Evaluato...  workclass
# 3    Loader[adult_ori]_Synthesizer[custom]_Evaluato...     fnlwgt
# 4    Loader[adult_ori]_Synthesizer[custom]_Evaluato...     fnlwgt
# ..                                                 ...        ...
# 115  Loader[adult_ori]_Synthesizer[custom]_Evaluato...     income
# 116  Loader[adult_ori]_Synthesizer[custom]_Evaluato...     income
# 117  Loader[adult_ori]_Synthesizer[custom]_Evaluato...     income
# 118  Loader[adult_ori]_Synthesizer[custom]_Evaluato...     income
# 119  Loader[adult_ori]_Synthesizer[custom]_Evaluato...     income
#
#             column2  score
# 0               age    100
# 1               age    100
# 2         workclass    100
# 3               age    100
# 4         workclass    100
# ..              ...    ...
# 115    capital-gain    100
# 116    capital-loss    100
# 117  hours-per-week    100
# 118  native-country    100
# 119          income    100
#
# [120 rows x 4 columns]}}
