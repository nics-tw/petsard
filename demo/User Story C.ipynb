# %% [markdown]
# # User Story C
# **Privacy Enhancing Data Evaluation**
#
#
# This demo will show how to evaluate privacy-enhanced data using `PETsARD`.
#
# In this demonstration, you, as the user, already have a data file on your local machine, as well as its corresponding synthetic data results, which are likely from your existing privacy protection service. `PETsARD` will assist you in reading these files and evaluating the results, helping you compare your current solution with other technologies.
#
# 本示範將展示如何使用 `PETsARD` 生成與評測隱私強化資料。
#
# 在這個示範中，您作為使用者，在本機上已經擁有一份資料檔案、以及其對應的合成資料結果，這很可能是來自於您現有的隱私保護服務，而 `PETsARD` 將幫助您讀取這些檔案、評測結果，幫助您針對現有的解決方案跟其他技術做比較。

# %% [markdown]
# ---
#
# ## Environment

# %%
import os
import pprint
import sys

import yaml


# Setting up the path to the PETsARD package
path_petsard = os.path.dirname(os.getcwd())
sys.path.append(path_petsard)
# setting for pretty priny YAML
pp = pprint.PrettyPrinter(depth=3, sort_dicts=False)


from petsard import Executor # noqa: E402

# %% [markdown]
# ---
#
# ## User Story C-1
# **Default Describing**
#
# Given a dataset as an input, the pipeline can go through the "describe" module to get a summary of the dataset.
#
# 給定一個資料集做輸入，該流程可以藉由調用 "describe" 模組而得到該資料集的摘要

# %%
config_file = '../yaml/User Story C-1.yaml'

with open(config_file, 'r') as yaml_file:
    yaml_raw: dict = yaml.safe_load(yaml_file)
pp.pprint(yaml_raw)
# Out:
# {'Loader': {'adult': {'filepath': '../benchmark/adult-income.csv',
#                       'na_values': {...}}},
#  'Describer': {'demo': {'method': 'default'}},
#  'Reporter': {'save_report_global': {'method': 'save_report',
#                                      'output': 'User Story C-1',
#                                      'eval': 'demo',
#                                      'granularity': 'global'},
#               'save_report_columnwise': {'method': 'save_report',
#                                          'output': 'User Story C-1',
#                                          'eval': 'demo',
#                                          'granularity': 'columnwise'},
#               'save_report_pairwise': {'method': 'save_report',
#                                        'output': 'User Story C-1',
#                                        'eval': 'demo',
#                                        'granularity': 'pairwise'}}}

# %%
exec = Executor(config=config_file)
exec.run()
# Out:
# Now is User Story C-1[Report]_demo_[global] save to csv...
# Now is User Story C-1[Report]_demo_[columnwise] save to csv...
# Now is User Story C-1[Report]_demo_[pairwise] save to csv...

# %%
pp.pprint(exec.get_result())
# Out:
# {'Loader[adult]_Describer[demo]_Reporter[save_report_global]': {'demo_[global]':                          full_expt_name Loader      Describer  demo_row_count  \
# 0  Loader[adult]_Describerdemo_[global]  adult  demo_[global]           48842
#
#    demo_col_count  demo_na_count
# 0              15           3620  },
#  'Loader[adult]_Describer[demo]_Reporter[save_report_columnwise]': {'demo_[columnwise]':                               full_expt_name Loader          Describer  \
# 0   Loader[adult]_Describerdemo_[columnwise]  adult  demo_[columnwise]
# 1   Loader[adult]_Describerdemo_[columnwise]  adult  demo_[columnwise]
# 2   Loader[adult]_Describerdemo_[columnwise]  adult  demo_[columnwise]
# 3   Loader[adult]_Describerdemo_[columnwise]  adult  demo_[columnwise]
# 4   Loader[adult]_Describerdemo_[columnwise]  adult  demo_[columnwise]
# 5   Loader[adult]_Describerdemo_[columnwise]  adult  demo_[columnwise]
# 6   Loader[adult]_Describerdemo_[columnwise]  adult  demo_[columnwise]
# 7   Loader[adult]_Describerdemo_[columnwise]  adult  demo_[columnwise]
# 8   Loader[adult]_Describerdemo_[columnwise]  adult  demo_[columnwise]
# 9   Loader[adult]_Describerdemo_[columnwise]  adult  demo_[columnwise]
# 10  Loader[adult]_Describerdemo_[columnwise]  adult  demo_[columnwise]
# 11  Loader[adult]_Describerdemo_[columnwise]  adult  demo_[columnwise]
# 12  Loader[adult]_Describerdemo_[columnwise]  adult  demo_[columnwise]
# 13  Loader[adult]_Describerdemo_[columnwise]  adult  demo_[columnwise]
# 14  Loader[adult]_Describerdemo_[columnwise]  adult  demo_[columnwise]
#
#              column      demo_mean  demo_median       demo_std  demo_min  \
# 0               age      38.643585         37.0      13.710510      17.0
# 1            fnlwgt  189664.134597     178144.5  105604.025423   12285.0
# 2   educational-num      10.078089         10.0       2.570973       1.0
# 3      capital-gain    1079.067626          0.0    7452.019058       0.0
# 4      capital-loss      87.502314          0.0     403.004552       0.0
# 5    hours-per-week      40.422382         40.0      12.391444       1.0
# 6         workclass            NaN          NaN            NaN       NaN
# 7         education            NaN          NaN            NaN       NaN
# 8    marital-status            NaN          NaN            NaN       NaN
# 9        occupation            NaN          NaN            NaN       NaN
# 10     relationship            NaN          NaN            NaN       NaN
# 11             race            NaN          NaN            NaN       NaN
# 12           gender            NaN          NaN            NaN       NaN
# 13   native-country            NaN          NaN            NaN       NaN
# 14           income            NaN          NaN            NaN       NaN
#
#      demo_max  demo_kurtosis  demo_skew   demo_q1   demo_q3  demo_na_count  \
# 0        90.0      -0.184269   0.557580      28.0      48.0              0
# 1   1490400.0       6.057848   1.438892  117550.5  237642.0              0
# 2        16.0       0.625745  -0.316525       9.0      12.0              0
# 3     99999.0     152.693096  11.894659       0.0       0.0              0
# 4      4356.0      20.014346   4.569809       0.0       0.0              0
# 5        99.0       2.951059   0.238750      40.0      45.0              0
# 6         NaN            NaN        NaN       NaN       NaN           2799
# 7         NaN            NaN        NaN       NaN       NaN              0
# 8         NaN            NaN        NaN       NaN       NaN              0
# 9         NaN            NaN        NaN       NaN       NaN           2809
# 10        NaN            NaN        NaN       NaN       NaN              0
# 11        NaN            NaN        NaN       NaN       NaN              0
# 12        NaN            NaN        NaN       NaN       NaN              0
# 13        NaN            NaN        NaN       NaN       NaN            857
# 14        NaN            NaN        NaN       NaN       NaN              0
#
#    demo_nunique
# 0          <NA>
# 1          <NA>
# 2          <NA>
# 3          <NA>
# 4          <NA>
# 5          <NA>
# 6             8
# 7            16
# 8             7
# 9            14
# 10            6
# 11            5
# 12            2
# 13           41
# 14            2  },
#  'Loader[adult]_Describer[demo]_Reporter[save_report_pairwise]': {'demo_[pairwise]':                             full_expt_name Loader        Describer  \
# 0   Loader[adult]_Describerdemo_[pairwise]  adult  demo_[pairwise]
# 1   Loader[adult]_Describerdemo_[pairwise]  adult  demo_[pairwise]
# 2   Loader[adult]_Describerdemo_[pairwise]  adult  demo_[pairwise]
# 3   Loader[adult]_Describerdemo_[pairwise]  adult  demo_[pairwise]
# 4   Loader[adult]_Describerdemo_[pairwise]  adult  demo_[pairwise]
# 5   Loader[adult]_Describerdemo_[pairwise]  adult  demo_[pairwise]
# 6   Loader[adult]_Describerdemo_[pairwise]  adult  demo_[pairwise]
# 7   Loader[adult]_Describerdemo_[pairwise]  adult  demo_[pairwise]
# 8   Loader[adult]_Describerdemo_[pairwise]  adult  demo_[pairwise]
# 9   Loader[adult]_Describerdemo_[pairwise]  adult  demo_[pairwise]
# 10  Loader[adult]_Describerdemo_[pairwise]  adult  demo_[pairwise]
# 11  Loader[adult]_Describerdemo_[pairwise]  adult  demo_[pairwise]
# 12  Loader[adult]_Describerdemo_[pairwise]  adult  demo_[pairwise]
# 13  Loader[adult]_Describerdemo_[pairwise]  adult  demo_[pairwise]
# 14  Loader[adult]_Describerdemo_[pairwise]  adult  demo_[pairwise]
# 15  Loader[adult]_Describerdemo_[pairwise]  adult  demo_[pairwise]
# 16  Loader[adult]_Describerdemo_[pairwise]  adult  demo_[pairwise]
# 17  Loader[adult]_Describerdemo_[pairwise]  adult  demo_[pairwise]
# 18  Loader[adult]_Describerdemo_[pairwise]  adult  demo_[pairwise]
# 19  Loader[adult]_Describerdemo_[pairwise]  adult  demo_[pairwise]
# 20  Loader[adult]_Describerdemo_[pairwise]  adult  demo_[pairwise]
#
#             column1          column2  demo_corr
# 0               age              age   1.000000
# 1            fnlwgt              age  -0.076628
# 2   educational-num              age   0.030940
# 3      capital-gain              age   0.077229
# 4      capital-loss              age   0.056944
# 5    hours-per-week              age   0.071558
# 6            fnlwgt           fnlwgt   1.000000
# 7   educational-num           fnlwgt  -0.038761
# 8      capital-gain           fnlwgt  -0.003706
# 9      capital-loss           fnlwgt  -0.004366
# 10   hours-per-week           fnlwgt  -0.013519
# 11  educational-num  educational-num   1.000000
# 12     capital-gain  educational-num   0.125146
# 13     capital-loss  educational-num   0.080972
# 14   hours-per-week  educational-num   0.143689
# 15     capital-gain     capital-gain   1.000000
# 16     capital-loss     capital-gain  -0.031441
# 17   hours-per-week     capital-gain   0.082157
# 18     capital-loss     capital-loss   1.000000
# 19   hours-per-week     capital-loss   0.054467
# 20   hours-per-week   hours-per-week   1.000000  }}

# %% [markdown]
# ---
#
# ## User Story C-2
# **Given data evaluating**
#
# Given an original dataset and a privacy enhanced dataset to the evaluation module, the pipeline will create a report covering default/general metrics of privacy risk and utility.
#
# 給定原始資料集與對應的隱私強化資料集到評估模組中，該流程會產生一份涵蓋預設/一般指標的隱私風險與效用的報告。

# %% [markdown]
# ### User Story C-2a
#
# C-2a demonstrates the evaluation approach of the Evaluator as comparing "original data" with "synthetic data," for instance, using`method = 'default'` or tools starting with `'sdmetrics-'` from SDMetrics.
#
# C-2a 展示的是 Evaluator 的評測方式是「原始資料」對照「合成資料」，例如 `method = 'default'` 或 `'sdmetrics-'` 開頭的 SDMetrics 評測工具。

# %%
config_file = '../yaml/User Story C-2a.yaml'

with open(config_file, 'r') as yaml_file:
    yaml_raw: dict = yaml.safe_load(yaml_file)
pp.pprint(yaml_raw)
# Out:
# {'Loader': {'adult_ori': {'filepath': '../benchmark/adult-income_ori.csv'}},
#  'Synthesizer': {'custom': {'method': 'custom_data',
#                             'filepath': '../benchmark/adult-income_syn.csv'}},
#  'Evaluator': {'demo': {'method': 'default'}},
#  'Reporter': {'save_report_global': {'method': 'save_report',
#                                      'output': 'User Story C-2a',
#                                      'eval': 'demo',
#                                      'granularity': 'global'}}}

# %%
exec = Executor(config=config_file)
exec.run()
# Out:
# INFO:root:workclass changes data dtype from category[object] to category[object] for metadata alignment.
# INFO:root:education changes data dtype from category[object] to category[object] for metadata alignment.
# INFO:root:marital-status changes data dtype from category[object] to category[object] for metadata alignment.
# INFO:root:occupation changes data dtype from category[object] to category[object] for metadata alignment.
# INFO:root:relationship changes data dtype from category[object] to category[object] for metadata alignment.
# INFO:root:race changes data dtype from category[object] to category[object] for metadata alignment.
# INFO:root:gender changes data dtype from category[object] to category[object] for metadata alignment.
# INFO:root:capital-gain changes data dtype from int8 to int32 for metadata alignment.
# INFO:root:capital-loss changes data dtype from int8 to int16 for metadata alignment.
# INFO:root:native-country changes data dtype from category[object] to category[object] for metadata alignment.
# INFO:root:income changes data dtype from category[object] to category[object] for metadata alignment.
# INFO:sdv.metadata.single_table:Detected metadata:
# INFO:sdv.metadata.single_table:{
#     "columns": {
#         "age": {
#             "sdtype": "numerical"
#         },
#         "workclass": {
#             "sdtype": "categorical"
#         },
#         "fnlwgt": {
#             "sdtype": "numerical"
#         },
#         "education": {
#             "sdtype": "categorical"
#         },
#         "educational-num": {
#             "sdtype": "numerical"
#         },
#         "marital-status": {
#             "sdtype": "categorical"
#         },
#         "occupation": {
#             "sdtype": "categorical"
#         },
#         "relationship": {
#             "sdtype": "categorical"
#         },
#         "race": {
#             "sdtype": "categorical"
#         },
#         "gender": {
#             "sdtype": "categorical"
#         },
#         "capital-gain": {
#             "sdtype": "numerical"
#         },
#         "capital-loss": {
#             "sdtype": "numerical"
#         },
#         "hours-per-week": {
#             "sdtype": "numerical"
#         },
#         "native-country": {
#             "sdtype": "categorical"
#         },
#         "income": {
#             "sdtype": "categorical"
#         }
#     },
#     "METADATA_SPEC_VERSION": "SINGLE_TABLE_V1"
# }
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 15/15 [00:00<00:00, 88.57it/s]|
# Column Shapes Score: 94.32%
#
# (2/2) Evaluating Column Pair Trends: |          | 0/105 [00:00<?, ?it/s]|
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# (2/2) Evaluating Column Pair Trends: |████▉     | 52/105 [00:00<00:00, 255.09it/s]|
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# ...
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# INFO:PETsARD.Evaluator:Completed Evaluator execution (elapsed: 0:00:01)
# INFO:PETsARD.Executor:Executing Reporter with save_report_global
# INFO:PETsARD.Reporter:Starting Reporter execution
# INFO:PETsARD.Reporter:Completed Reporter execution (elapsed: 0:00:00)
# INFO:PETsARD.Executor:Completed PETsARD execution workflow (elapsed: 0:00:01)
# Overall Score (Average): 77.37%
#
# Now is User Story C-2a[Report]_demo_[global] save to csv...

# %%
pp.pprint(exec.get_result())
# Out:
# {'Loader[adult_ori]_Synthesizer[custom]_Evaluator[demo]_Reporter[save_report_global]': {'demo_[global]':                                            full_expt_name     Loader  \
# result  Loader[adult_ori]_Synthesizer[custom]_Evaluato...  adult_ori
#
#        Synthesizer      Evaluator  demo_Score  demo_Column Shapes  \
# result      custom  demo_[global]    0.773713            0.943236
#
#         demo_Column Pair Trends
# result                 0.604191  }}

# %% [markdown]
# ### User Story C-2b
#
#
# C-2b demonstrates the evaluation method of the Evaluator as involving "original data used in synthesis" (abbreviated as ori), "original data not used in synthesis" (abbreviated as control), and "synthesized data" (abbreviated as syn), for example, using tools starting with `method ='anonymeter-'` from Anonymeter.
#
# C-2b 展示的是 Evaluator 的評測方式是「參與合成的原始資料」(original data, 縮寫為 ori)、「不參與合成的原始資料」(control data, 縮寫為 control)、與「合成資料」(synthesized data, 縮寫為 syn)，例如 `method ='anonymeter-'` 開頭的 Anonymeter 評測工具。

# %%
config_file = '../yaml/User Story C-2b.yaml'

with open(config_file, 'r') as yaml_file:
    yaml_raw: dict = yaml.safe_load(yaml_file)
pp.pprint(yaml_raw)
# Out:
# {'Splitter': {'custom': {'method': 'custom_data', 'filepath': {...}}},
#  'Synthesizer': {'custom': {'method': 'custom_data',
#                             'filepath': '../benchmark/adult-income_syn.csv'}},
#  'Evaluator': {'demo': {'method': 'default'},
#                'anony-singling': {'method': 'anonymeter-singlingout'}},
#  'Reporter': {'save_report_global_demo': {'method': 'save_report',
#                                           'output': 'User Story C-2b',
#                                           'eval': 'demo',
#                                           'granularity': 'global'},
#               'save_report_global_anony': {'method': 'save_report',
#                                            'output': 'User Story C-2b',
#                                            'eval': 'anony-singling',
#                                            'granularity': 'global'}}}

# %%
exec = Executor(config=config_file)
exec.run()
# Out:
# INFO:root:workclass changes data dtype from category[object] to category[object] for metadata alignment.
# INFO:root:education changes data dtype from category[object] to category[object] for metadata alignment.
# INFO:root:marital-status changes data dtype from category[object] to category[object] for metadata alignment.
# INFO:root:occupation changes data dtype from category[object] to category[object] for metadata alignment.
# INFO:root:relationship changes data dtype from category[object] to category[object] for metadata alignment.
# INFO:root:race changes data dtype from category[object] to category[object] for metadata alignment.
# INFO:root:gender changes data dtype from category[object] to category[object] for metadata alignment.
# INFO:root:capital-gain changes data dtype from int8 to int32 for metadata alignment.
# INFO:root:capital-loss changes data dtype from int8 to int16 for metadata alignment.
# INFO:root:native-country changes data dtype from category[object] to category[object] for metadata alignment.
# INFO:root:income changes data dtype from category[object] to category[object] for metadata alignment.
# INFO:root:workclass changes data dtype from category[object] to category[object] for metadata alignment.
# INFO:root:education changes data dtype from category[object] to category[object] for metadata alignment.
# INFO:root:marital-status changes data dtype from category[object] to category[object] for metadata alignment.
# INFO:root:occupation changes data dtype from category[object] to category[object] for metadata alignment.
# INFO:root:relationship changes data dtype from category[object] to category[object] for metadata alignment.
# INFO:root:race changes data dtype from category[object] to category[object] for metadata alignment.
# INFO:root:gender changes data dtype from category[object] to category[object] for metadata alignment.
# INFO:root:native-country changes data dtype from category[object] to category[object] for metadata alignment.
# INFO:root:income changes data dtype from category[object] to category[object] for metadata alignment.
# INFO:sdv.metadata.single_table:Detected metadata:
# INFO:sdv.metadata.single_table:{
#     "columns": {
#         "age": {
#             "sdtype": "numerical"
#         },
#         "workclass": {
#             "sdtype": "categorical"
#         },
#         "fnlwgt": {
#             "sdtype": "numerical"
#         },
#         "education": {
#             "sdtype": "categorical"
#         },
#         "educational-num": {
#             "sdtype": "numerical"
#         },
#         "marital-status": {
#             "sdtype": "categorical"
#         },
#         "occupation": {
#             "sdtype": "categorical"
#         },
#         "relationship": {
#             "sdtype": "categorical"
#         },
#         "race": {
#             "sdtype": "categorical"
#         },
#         "gender": {
#             "sdtype": "categorical"
#         },
#         "capital-gain": {
#             "sdtype": "numerical"
#         },
#         "capital-loss": {
#             "sdtype": "numerical"
#         },
#         "hours-per-week": {
#             "sdtype": "numerical"
#         },
#         "native-country": {
#             "sdtype": "categorical"
#         },
#         "income": {
#             "sdtype": "categorical"
#         }
#     },
#     "METADATA_SPEC_VERSION": "SINGLE_TABLE_V1"
# }
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 15/15 [00:00<00:00, 92.05it/s]|
# Column Shapes Score: 94.32%
#
# (2/2) Evaluating Column Pair Trends: |          | 0/105 [00:00<?, ?it/s]|
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# (2/2) Evaluating Column Pair Trends: |█████     | 53/105 [00:00<00:00, 264.76it/s]|
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# ...
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_real = real.groupby(list(columns), dropna=False).size() / len(real)
# /Users/justyn.chen/Dropbox/310_Career_工作/20231016_NICS_資安院/41_PETsARD/petsard/.venv/lib/python3.10/site-packages/sdmetrics/column_pairs/statistical/contingency_similarity.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contingency_synthetic = synthetic.groupby(list(columns), dropna=False).size() / len(
# INFO:PETsARD.Evaluator:Completed Evaluator execution (elapsed: 0:00:01)
# INFO:PETsARD.Executor:Executing Reporter with save_report_global_demo
# INFO:PETsARD.Reporter:Starting Reporter execution
# INFO:PETsARD.Reporter:Completed Reporter execution (elapsed: 0:00:00)
# INFO:PETsARD.Executor:Executing Reporter with save_report_global_anony
# INFO:PETsARD.Reporter:Starting Reporter execution
# INFO:PETsARD.Reporter:Completed Reporter execution (elapsed: 0:00:00)
# INFO:PETsARD.Executor:Executing Evaluator with anony-singling
# INFO:PETsARD.Evaluator:Starting Evaluator execution
# INFO:root:workclass changes data dtype from category[object] to category[object] for metadata alignment.
# INFO:root:education changes data dtype from category[object] to category[object] for metadata alignment.
# INFO:root:marital-status changes data dtype from category[object] to category[object] for metadata alignment.
# INFO:root:occupation changes data dtype from category[object] to category[object] for metadata alignment.
# INFO:root:relationship changes data dtype from category[object] to category[object] for metadata alignment.
# Overall Score (Average): 77.37%
#
# Now is User Story C-2b[Report]_demo_[global] save to csv...
# Reporter: No CSV file will be saved. This warning can be ignored if running with different granularity config.
# INFO:root:race changes data dtype from category[object] to category[object] for metadata alignment.
# INFO:root:gender changes data dtype from category[object] to category[object] for metadata alignment.
# INFO:root:capital-gain changes data dtype from int8 to int32 for metadata alignment.
# INFO:root:capital-loss changes data dtype from int8 to int16 for metadata alignment.
# INFO:root:native-country changes data dtype from category[object] to category[object] for metadata alignment.
# INFO:root:income changes data dtype from category[object] to category[object] for metadata alignment.
# INFO:root:workclass changes data dtype from category[object] to category[object] for metadata alignment.
# INFO:root:education changes data dtype from category[object] to category[object] for metadata alignment.
# INFO:root:marital-status changes data dtype from category[object] to category[object] for metadata alignment.
# INFO:root:occupation changes data dtype from category[object] to category[object] for metadata alignment.
# INFO:root:relationship changes data dtype from category[object] to category[object] for metadata alignment.
# INFO:root:race changes data dtype from category[object] to category[object] for metadata alignment.
# INFO:root:gender changes data dtype from category[object] to category[object] for metadata alignment.
# INFO:root:native-country changes data dtype from category[object] to category[object] for metadata alignment.
# INFO:root:income changes data dtype from category[object] to category[object] for metadata alignment.
# WARNING:anonymeter.evaluators.singling_out_evaluator:Found 1654 failed queries out of 2000. Check DEBUG messages for more details.
# WARNING:anonymeter.evaluators.singling_out_evaluator:Reached maximum number of attempts 500000 when generating singling out queries. Returning 110 instead of the requested 2000.To avoid this, increase the number of attempts or set it to ``None`` to disable The limitation entirely.
# WARNING:anonymeter.evaluators.singling_out_evaluator:Attack `multivariate` could generate only 110 singling out queries out of the requested 2000. This can probably lead to an underestimate of the singling out risk.
# INFO:PETsARD.Evaluator:Completed Evaluator execution (elapsed: 0:12:15)
# INFO:PETsARD.Executor:Executing Reporter with save_report_global_demo
# INFO:PETsARD.Reporter:Starting Reporter execution
# INFO:PETsARD.Reporter:Completed Reporter execution (elapsed: 0:00:00)
# INFO:PETsARD.Executor:Executing Reporter with save_report_global_anony
# INFO:PETsARD.Reporter:Starting Reporter execution
# INFO:PETsARD.Reporter:Completed Reporter execution (elapsed: 0:00:00)
# INFO:PETsARD.Executor:Completed PETsARD execution workflow (elapsed: 0:12:16)
# Reporter: No CSV file will be saved. This warning can be ignored if running with different granularity config.
# Now is User Story C-2b[Report]_anony-singling_[global] save to csv...

# %%
pp.pprint(exec.get_result())
# Out:
# {'Splitter[custom_[1-1]]_Synthesizer[custom]_Evaluator[demo]_Reporter[save_report_global_demo]': {'demo_[global]':                                            full_expt_name      Splitter  \
# result  Splitter[custom_[1-1]]_Synthesizer[custom]_Eva...  custom_[1-1]
#
#        Synthesizer      Evaluator  demo_Score  demo_Column Shapes  \
# result      custom  demo_[global]    0.773713            0.943236
#
#         demo_Column Pair Trends
# result                 0.604191  },
#  'Splitter[custom_[1-1]]_Synthesizer[custom]_Evaluator[demo]_Reporter[save_report_global_anony]': {},
#  'Splitter[custom_[1-1]]_Synthesizer[custom]_Evaluator[anony-singling]_Reporter[save_report_global_demo]': {},
#  'Splitter[custom_[1-1]]_Synthesizer[custom]_Evaluator[anony-singling]_Reporter[save_report_global_anony]': {'anony-singling_[global]':                                            full_expt_name      Splitter  \
# result  Splitter[custom_[1-1]]_Synthesizer[custom]_Eva...  custom_[1-1]
#
#        Synthesizer                Evaluator  anony-singling_risk  \
# result      custom  anony-singling_[global]                  0.0
#
#         anony-singling_risk_CI_btm  anony-singling_risk_CI_top  \
# result                         0.0                    0.006058
#
#         anony-singling_attack_rate  anony-singling_attack_rate_err  \
# result                    0.009941                        0.004241
#
#         anony-singling_baseline_rate  anony-singling_baseline_rate_err  \
# result                      0.003454                          0.002385
#
#         anony-singling_control_rate  anony-singling_control_rate_err
# result                     0.009941                         0.004241  }}

# %% [markdown]
# ---
#
# ## User Story C-3 - Given data customized evaluating
#
# > Following User Story C-2, if specific types of metrics are set or a customized evaluation script is provided, the module will create a customized evaluation report.
# >
# >
# > 根據用戶故事 C-2，如果指定特定的指標、或是提供用戶自定義的評估腳本，模組會產生客製化的評估報告。
#
# > Aligning with User Story 7 of the Spec
# >
# >
# > 對標規格說明 (Spec) 的 User Story 7

# %%
config_file = '../yaml/User Story C-3.yaml'

with open(config_file, 'r') as yaml_file:
    yaml_raw: dict = yaml.safe_load(yaml_file)
pp.pprint(yaml_raw)
# Out:
# {'Loader': {'adult_ori': {'filepath': '../benchmark/adult-income_ori.csv'}},
#  'Synthesizer': {'custom': {'method': 'custom_data',
#                             'filepath': '../benchmark/adult-income_syn.csv'}},
#  'Evaluator': {'custom': {'method': 'custom_method', 'custom_method': {...}}},
#  'Reporter': {'save_report_global': {'method': 'save_report',
#                                      'output': 'User Story C-3',
#                                      'eval': 'custom',
#                                      'granularity': 'global'},
#               'save_report_columnwise': {'method': 'save_report',
#                                          'output': 'User Story C-3',
#                                          'eval': 'custom',
#                                          'granularity': 'columnwise'},
#               'save_report_pairwise': {'method': 'save_report',
#                                        'output': 'User Story C-3',
#                                        'eval': 'custom',
#                                        'granularity': 'pairwise'}}}

# %%
exec = Executor(config=config_file)
exec.run()
# Out:
# INFO:root:workclass changes data dtype from category[object] to category[object] for metadata alignment.
# INFO:root:education changes data dtype from category[object] to category[object] for metadata alignment.
# INFO:root:marital-status changes data dtype from category[object] to category[object] for metadata alignment.
# INFO:root:occupation changes data dtype from category[object] to category[object] for metadata alignment.
# INFO:root:relationship changes data dtype from category[object] to category[object] for metadata alignment.
# INFO:root:race changes data dtype from category[object] to category[object] for metadata alignment.
# INFO:root:gender changes data dtype from category[object] to category[object] for metadata alignment.
# INFO:root:capital-gain changes data dtype from int8 to int32 for metadata alignment.
# INFO:root:capital-loss changes data dtype from int8 to int16 for metadata alignment.
# INFO:root:native-country changes data dtype from category[object] to category[object] for metadata alignment.
# INFO:root:income changes data dtype from category[object] to category[object] for metadata alignment.
# INFO:PETsARD.Evaluator:Completed Evaluator execution (elapsed: 0:00:00)
# INFO:PETsARD.Executor:Executing Reporter with save_report_global
# INFO:PETsARD.Reporter:Starting Reporter execution
# INFO:PETsARD.Reporter:Completed Reporter execution (elapsed: 0:00:00)
# INFO:PETsARD.Executor:Executing Reporter with save_report_columnwise
# INFO:PETsARD.Reporter:Starting Reporter execution
# INFO:PETsARD.Reporter:Completed Reporter execution (elapsed: 0:00:00)
# INFO:PETsARD.Executor:Executing Reporter with save_report_pairwise
# INFO:PETsARD.Reporter:Starting Reporter execution
# INFO:PETsARD.Reporter:Completed Reporter execution (elapsed: 0:00:00)
# INFO:PETsARD.Executor:Completed PETsARD execution workflow (elapsed: 0:00:00)
# Now is User Story C-3[Report]_custom_[global] save to csv...
# Now is User Story C-3[Report]_custom_[columnwise] save to csv...
# Now is User Story C-3[Report]_custom_[pairwise] save to csv...

# %%
pp.pprint(exec.get_result())
# Out:
# {'Loader[adult_ori]_Synthesizer[custom]_Evaluator[custom]_Reporter[save_report_global]': {'custom_[global]':                                            full_expt_name     Loader  \
# result  Loader[adult_ori]_Synthesizer[custom]_Evaluato...  adult_ori
#
#        Synthesizer        Evaluator  custom_score
# result      custom  custom_[global]           100  },
#  'Loader[adult_ori]_Synthesizer[custom]_Evaluator[custom]_Reporter[save_report_columnwise]': {'custom_[columnwise]':                                        full_expt_name     Loader Synthesizer  \
# 0   Loader[adult_ori]_Synthesizer[custom]_Evaluato...  adult_ori      custom
# 1   Loader[adult_ori]_Synthesizer[custom]_Evaluato...  adult_ori      custom
# 2   Loader[adult_ori]_Synthesizer[custom]_Evaluato...  adult_ori      custom
# 3   Loader[adult_ori]_Synthesizer[custom]_Evaluato...  adult_ori      custom
# 4   Loader[adult_ori]_Synthesizer[custom]_Evaluato...  adult_ori      custom
# 5   Loader[adult_ori]_Synthesizer[custom]_Evaluato...  adult_ori      custom
# 6   Loader[adult_ori]_Synthesizer[custom]_Evaluato...  adult_ori      custom
# 7   Loader[adult_ori]_Synthesizer[custom]_Evaluato...  adult_ori      custom
# 8   Loader[adult_ori]_Synthesizer[custom]_Evaluato...  adult_ori      custom
# 9   Loader[adult_ori]_Synthesizer[custom]_Evaluato...  adult_ori      custom
# 10  Loader[adult_ori]_Synthesizer[custom]_Evaluato...  adult_ori      custom
# 11  Loader[adult_ori]_Synthesizer[custom]_Evaluato...  adult_ori      custom
# 12  Loader[adult_ori]_Synthesizer[custom]_Evaluato...  adult_ori      custom
# 13  Loader[adult_ori]_Synthesizer[custom]_Evaluato...  adult_ori      custom
# 14  Loader[adult_ori]_Synthesizer[custom]_Evaluato...  adult_ori      custom
#
#               Evaluator           column  custom_score
# 0   custom_[columnwise]              age           100
# 1   custom_[columnwise]        workclass           100
# 2   custom_[columnwise]           fnlwgt           100
# 3   custom_[columnwise]        education           100
# 4   custom_[columnwise]  educational-num           100
# 5   custom_[columnwise]   marital-status           100
# 6   custom_[columnwise]       occupation           100
# 7   custom_[columnwise]     relationship           100
# 8   custom_[columnwise]             race           100
# 9   custom_[columnwise]           gender           100
# 10  custom_[columnwise]     capital-gain           100
# 11  custom_[columnwise]     capital-loss           100
# 12  custom_[columnwise]   hours-per-week           100
# 13  custom_[columnwise]   native-country           100
# 14  custom_[columnwise]           income           100  },
#  'Loader[adult_ori]_Synthesizer[custom]_Evaluator[custom]_Reporter[save_report_pairwise]': {'custom_[pairwise]':                                         full_expt_name     Loader Synthesizer  \
# 0    Loader[adult_ori]_Synthesizer[custom]_Evaluato...  adult_ori      custom
# 1    Loader[adult_ori]_Synthesizer[custom]_Evaluato...  adult_ori      custom
# 2    Loader[adult_ori]_Synthesizer[custom]_Evaluato...  adult_ori      custom
# 3    Loader[adult_ori]_Synthesizer[custom]_Evaluato...  adult_ori      custom
# 4    Loader[adult_ori]_Synthesizer[custom]_Evaluato...  adult_ori      custom
# ..                                                 ...        ...         ...
# 115  Loader[adult_ori]_Synthesizer[custom]_Evaluato...  adult_ori      custom
# 116  Loader[adult_ori]_Synthesizer[custom]_Evaluato...  adult_ori      custom
# 117  Loader[adult_ori]_Synthesizer[custom]_Evaluato...  adult_ori      custom
# 118  Loader[adult_ori]_Synthesizer[custom]_Evaluato...  adult_ori      custom
# 119  Loader[adult_ori]_Synthesizer[custom]_Evaluato...  adult_ori      custom
#
#              Evaluator    column1         column2  custom_score
# 0    custom_[pairwise]        age             age           100
# 1    custom_[pairwise]  workclass             age           100
# 2    custom_[pairwise]  workclass       workclass           100
# 3    custom_[pairwise]     fnlwgt             age           100
# 4    custom_[pairwise]     fnlwgt       workclass           100
# ..                 ...        ...             ...           ...
# 115  custom_[pairwise]     income    capital-gain           100
# 116  custom_[pairwise]     income    capital-loss           100
# 117  custom_[pairwise]     income  hours-per-week           100
# 118  custom_[pairwise]     income  native-country           100
# 119  custom_[pairwise]     income          income           100
#
# [120 rows x 7 columns]}}
