# %% [markdown]
# # Environment setting
# 環境設定

# %%
import os
import requests
from pathlib import Path


# determine branch, default is main
branch = "main"

# Check if running in Google Colab
is_colab = "COLAB_GPU" in os.environ

if is_colab:
    # Download the utils.py file from GitHub
    utils_url = (
        f"https://raw.githubusercontent.com/nics-tw/petsard/{branch}/demo/utils.py"
    )
    response = requests.get(utils_url)

    if response.status_code == 200:
        # Save the utils.py file
        with open("utils.py", "w") as f:
            f.write(response.text)

        # Create an empty __init__.py
        Path("__init__.py").touch()
    else:
        raise RuntimeError(
            f"Failed to download utils.py. Status code: {response.status_code}"
        )

# %%
# Now import and run the setup
from utils import (
    get_yaml_path,
    setup_environment,
)


setup_environment(
    is_colab,
    branch,
    benchmark_data=[
        "adult-income",
    ],
)

# %%
from petsard import Executor

# %% [markdown]
# # YAML Configuration for PETsARD
# PETsARD 的 YAML 設定

# %% [markdown]
# ## Default Synthesis and Default Evaluation
# 預設合成與預設評測

# %%
yaml_file_case: str = "logging-configuration.yaml"

yaml_path_case: str = get_yaml_path(
    is_colab=is_colab,
    yaml_file=yaml_file_case,
    branch=branch,
)
# Out:
# Configuration content:
# ---
# Executor:
#   log_output_type: both
#   log_level: DEBUG
#   log_dir: demo_logs
#   log_filename: PETsARD_demo_{timestamp}.log
# Loader:
#   log-data:
#     filepath: 'benchmark/adult-income.csv'
# Splitter:
#   demo:
#     num_samples: 1
#     train_split_ratio: 0.8
# Preprocessor:
#   demo:
#     method: 'default'
# Synthesizer:
#   demo:
#     method: 'default'
# Postprocessor:
#   demo:
#     method: 'default'
# Evaluator:
#   demo-diagnostic:
#     method: 'sdmetrics-diagnosticreport'
#   demo-quality:
#     method: 'sdmetrics-qualityreport'
# Reporter:
#   output:
#     method: 'save_data'
#     source: 'Synthesizer'
#   save_report_global:
#     method: 'save_report'
#     granularity: 'global'
# ...

# %% [markdown]
# ### Execution and Result
# 執行與結果

# %%
exec_case = Executor(config=yaml_path_case)
exec_case.run()
# Out:
# 2025-06-09 16:01:32,334 - PETsARD.Executor      - _get_config       - INFO     - Logger reconfigured with settings from YAML
# 2025-06-09 16:01:32,335 - PETsARD.Loader        - __init__          - INFO     - Initializing Loader
# 2025-06-09 16:01:32,335 - PETsARD.Loader        - __init__          - DEBUG    - Loader parameters - filepath: benchmark/adult-income.csv, method: None, column_types: None
# 2025-06-09 16:01:32,336 - PETsARD.LoaderConfig  - __post_init__     - DEBUG    - Initializing LoaderConfig
# 2025-06-09 16:01:32,337 - PETsARD.LoaderConfig  - __post_init__     - DEBUG    - File path information - dir: benchmark, name: adult-income, ext: .csv, ext code: 1
# 2025-06-09 16:01:32,337 - PETsARD.Loader        - __init__          - DEBUG    - LoaderConfig successfully initialized
# 2025-06-09 16:01:32,338 - PETsARD.Synthesizer   - __init__          - INFO     - Initializing Synthesizer with method: default, sample_num_rows: None
# 2025-06-09 16:01:32,339 - PETsARD.SynthesizerConfig - __post_init__     - DEBUG    - Initializing SynthesizerConfig
# 2025-06-09 16:01:32,339 - PETsARD.SynthesizerConfig - __post_init__     - DEBUG    - Mapped synthesizing method 'default' to code 1
# 2025-06-09 16:01:32,340 - PETsARD.SynthesizerConfig - __post_init__     - INFO     - SynthesizerConfig initialized with method: default, syn_method: sdv-single_table-gaussiancopula
# 2025-06-09 16:01:32,340 - PETsARD.Synthesizer   - __init__          - DEBUG    - SynthesizerConfig successfully initialized
# 2025-06-09 16:01:32,340 - PETsARD.Synthesizer   - __init__          - DEBUG    - No additional parameters provided
# 2025-06-09 16:01:32,341 - PETsARD.Synthesizer   - __init__          - INFO     - Synthesizer initialization completed
# 2025-06-09 16:01:32,341 - PETsARD.Evaluator     - __init__          - INFO     - Initializing Evaluator with method: sdmetrics-diagnosticreport
# 2025-06-09 16:01:32,342 - PETsARD.EvaluatorConfig - __post_init__     - DEBUG    - Initializing EvaluatorConfig
# 2025-06-09 16:01:32,342 - PETsARD.EvaluatorConfig - _init_eval_method - DEBUG    - Mapped evaluating method 'sdmetrics-diagnosticreport' to code EvaluatorMap.SDMETRICS
# 2025-06-09 16:01:32,343 - PETsARD.EvaluatorConfig - _init_eval_method - INFO     - EvaluatorConfig initialized with method: sdmetrics-diagnosticreport, eval_method: sdmetrics-diagnosticreport
# 2025-06-09 16:01:32,344 - PETsARD.Evaluator     - _configure_implementation - DEBUG    - EvaluatorConfig successfully initialized
# 2025-06-09 16:01:32,344 - PETsARD.Evaluator     - _configure_implementation - DEBUG    - No additional parameters provided
# 2025-06-09 16:01:32,344 - PETsARD.Evaluator     - __init__          - INFO     - ≈ initialization completed
# 2025-06-09 16:01:32,345 - PETsARD.Evaluator     - __init__          - INFO     - Initializing Evaluator with method: sdmetrics-qualityreport
# 2025-06-09 16:01:32,345 - PETsARD.EvaluatorConfig - __post_init__     - DEBUG    - Initializing EvaluatorConfig
# 2025-06-09 16:01:32,346 - PETsARD.EvaluatorConfig - _init_eval_method - DEBUG    - Mapped evaluating method 'sdmetrics-qualityreport' to code EvaluatorMap.SDMETRICS
# 2025-06-09 16:01:32,346 - PETsARD.EvaluatorConfig - _init_eval_method - INFO     - EvaluatorConfig initialized with method: sdmetrics-qualityreport, eval_method: sdmetrics-qualityreport
# 2025-06-09 16:01:32,346 - PETsARD.Evaluator     - _configure_implementation - DEBUG    - EvaluatorConfig successfully initialized
# 2025-06-09 16:01:32,346 - PETsARD.Evaluator     - _configure_implementation - DEBUG    - No additional parameters provided
# 2025-06-09 16:01:32,347 - PETsARD.Evaluator     - __init__          - INFO     - ≈ initialization completed
# 2025-06-09 16:01:32,347 - PETsARD.Executor      - run               - INFO     - Starting PETsARD execution workflow
# 2025-06-09 16:01:32,348 - PETsARD.Executor      - run               - INFO     - Executing Loader with log-data
# 2025-06-09 16:01:32,348 - PETsARD.LoaderOp      - run               - INFO     - Starting LoaderOp execution
# 2025-06-09 16:01:32,348 - PETsARD.LoaderOp      - _run              - DEBUG    - Starting data loading process
# 2025-06-09 16:01:32,349 - PETsARD.Loader        - load              - INFO     - Loading data from benchmark/adult-income.csv
# 2025-06-09 16:01:32,349 - PETsARD.Loader        - load              - INFO     - Loading data using file extension: .csv
# 2025-06-09 16:01:32,350 - PETsARD.Loader        - load              - DEBUG    - Using inferred headers
# 2025-06-09 16:01:32,423 - PETsARD.Loader        - load              - INFO     - Successfully loaded data with shape: (48842, 15)
# 2025-06-09 16:01:32,424 - PETsARD.Loader        - load              - INFO     - Building schema configuration
# 2025-06-09 16:01:32,424 - PETsARD.Loader        - load              - INFO     - Building schema metadata from dataframe
# 2025-06-09 16:01:32,425 - PETsARD.SchemaOperations - build_schema_from_dataframe - INFO     - Building schema metadata for DataFrame with shape (48842, 15)
# 2025-06-09 16:01:32,425 - PETsARD.FieldOperations - build_field_from_series - DEBUG    - Building field metadata for 'age' with length 48842
# 2025-06-09 16:01:32,429 - PETsARD.FieldOperations - build_field_from_series - DEBUG    - Building field metadata for 'workclass' with length 48842
# 2025-06-09 16:01:32,438 - PETsARD.FieldOperations - build_field_from_series - DEBUG    - Building field metadata for 'fnlwgt' with length 48842
# 2025-06-09 16:01:32,441 - PETsARD.FieldOperations - build_field_from_series - DEBUG    - Building field metadata for 'education' with length 48842
# 2025-06-09 16:01:32,449 - PETsARD.FieldOperations - build_field_from_series - DEBUG    - Building field metadata for 'educational-num' with length 48842
# 2025-06-09 16:01:32,452 - PETsARD.FieldOperations - build_field_from_series - DEBUG    - Building field metadata for 'marital-status' with length 48842
# 2025-06-09 16:01:32,460 - PETsARD.FieldOperations - build_field_from_series - DEBUG    - Building field metadata for 'occupation' with length 48842
# 2025-06-09 16:01:32,468 - PETsARD.FieldOperations - build_field_from_series - DEBUG    - Building field metadata for 'relationship' with length 48842
# 2025-06-09 16:01:32,496 - PETsARD.FieldOperations - build_field_from_series - DEBUG    - Building field metadata for 'race' with length 48842
# 2025-06-09 16:01:32,541 - PETsARD.FieldOperations - build_field_from_series - DEBUG    - Building field metadata for 'gender' with length 48842
# 2025-06-09 16:01:32,591 - PETsARD.FieldOperations - build_field_from_series - DEBUG    - Building field metadata for 'capital-gain' with length 48842
# 2025-06-09 16:01:32,598 - PETsARD.FieldOperations - build_field_from_series - DEBUG    - Building field metadata for 'capital-loss' with length 48842
# 2025-06-09 16:01:32,616 - PETsARD.FieldOperations - build_field_from_series - DEBUG    - Building field metadata for 'hours-per-week' with length 48842
# 2025-06-09 16:01:32,622 - PETsARD.FieldOperations - build_field_from_series - DEBUG    - Building field metadata for 'native-country' with length 48842
# 2025-06-09 16:01:32,638 - PETsARD.FieldOperations - build_field_from_series - DEBUG    - Building field metadata for 'income' with length 48842
# 2025-06-09 16:01:32,647 - PETsARD.SchemaOperations - build_schema_from_dataframe - INFO     - Successfully built metadata for 15 fields
# 2025-06-09 16:01:32,647 - PETsARD.Loader        - load              - DEBUG    - Built schema with 15 fields
# 2025-06-09 16:01:32,648 - PETsARD.Loader        - load              - INFO     - Applying field configurations to optimize data
# 2025-06-09 16:01:32,648 - PETsARD.SchemaOperations - apply_field_config - INFO     - Applying field configurations to DataFrame with shape (48842, 15)
# 2025-06-09 16:01:32,691 - PETsARD.SchemaOperations - apply_field_config - INFO     - Transformation complete: 15 successful, 0 failed, 0 skipped
# 2025-06-09 16:01:32,702 - PETsARD.Loader        - load              - DEBUG    - Field configurations applied successfully
# 2025-06-09 16:01:32,704 - PETsARD.Loader        - load              - INFO     - Data loading completed successfully
# 2025-06-09 16:01:32,705 - PETsARD.LoaderOp      - _run              - DEBUG    - Converting SchemaMetadata to legacy Metadata format
# 2025-06-09 16:01:32,709 - PETsARD.LoaderOp      - _run              - DEBUG    - Data loading completed
# 2025-06-09 16:01:32,710 - PETsARD.LoaderOp      - run               - INFO     - Completed LoaderOp execution (elapsed: 0:00:00)
# 2025-06-09 16:01:32,711 - PETsARD.Executor      - run               - INFO     - Executing Splitter with demo_[1-1]
# 2025-06-09 16:01:32,711 - PETsARD.SplitterOp    - run               - INFO     - Starting SplitterOp execution
# 2025-06-09 16:01:32,712 - PETsARD.SplitterOp    - _run              - DEBUG    - Starting data splitting process
# 2025-06-09 16:01:32,750 - PETsARD.SplitterOp    - _run              - DEBUG    - Data splitting completed
# 2025-06-09 16:01:32,753 - PETsARD.SplitterOp    - run               - INFO     - Completed SplitterOp execution (elapsed: 0:00:00)
# 2025-06-09 16:01:32,754 - PETsARD.Executor      - run               - INFO     - Executing Preprocessor with demo
# 2025-06-09 16:01:32,755 - PETsARD.PreprocessorOp - run               - INFO     - Starting PreprocessorOp execution
# 2025-06-09 16:01:32,756 - PETsARD.PreprocessorOp - _run              - DEBUG    - Initializing processor
# 2025-06-09 16:01:32,756 - PETsARD.Processor     - __init__          - DEBUG    - Initializing Processor
# 2025-06-09 16:01:32,756 - PETsARD.Processor     - __init__          - DEBUG    - Loaded metadata contains 15 columns, with 48842 rows
# 2025-06-09 16:01:32,757 - PETsARD.Processor     - __init__          - DEBUG    - config is provided:
# 2025-06-09 16:01:32,757 - PETsARD.Processor     - __init__          - DEBUG    - config is provided: {}
# 2025-06-09 16:01:32,757 - PETsARD.Processor     - __init__          - DEBUG    - Metadata loaded.
# 2025-06-09 16:01:32,758 - PETsARD.Processor     - _generate_config  - DEBUG    - Starting config generation
# 2025-06-09 16:01:32,758 - PETsARD.Processor     - _generate_config  - DEBUG    - Processing column 'age': inferred type numerical
# 2025-06-09 16:01:32,758 - PETsARD.Processor     - _generate_config  - DEBUG    -   > Setting missing processor: MissingMean
# 2025-06-09 16:01:32,758 - PETsARD.Processor     - _generate_config  - DEBUG    -   > Setting outlier processor: OutlierIQR
# 2025-06-09 16:01:32,759 - PETsARD.Processor     - _generate_config  - DEBUG    -   > Setting encoder processor: <lambda>
# 2025-06-09 16:01:32,759 - PETsARD.Processor     - _generate_config  - DEBUG    -   > Setting scaler processor: ScalerStandard
# 2025-06-09 16:01:32,759 - PETsARD.Processor     - _generate_config  - DEBUG    -   > Setting discretizing processor: DiscretizingKBins
# 2025-06-09 16:01:32,759 - PETsARD.Processor     - _generate_config  - DEBUG    - Processing column 'workclass': inferred type categorical
# 2025-06-09 16:01:32,760 - PETsARD.Processor     - _generate_config  - DEBUG    -   > Setting missing processor: MissingDrop
# 2025-06-09 16:01:32,760 - PETsARD.Processor     - _generate_config  - DEBUG    -   > Setting outlier processor: <lambda>
# 2025-06-09 16:01:32,760 - PETsARD.Processor     - _generate_config  - DEBUG    -   > Setting encoder processor: EncoderUniform
# 2025-06-09 16:01:32,761 - PETsARD.Processor     - _generate_config  - DEBUG    -   > Setting scaler processor: <lambda>
# 2025-06-09 16:01:32,761 - PETsARD.Processor     - _generate_config  - DEBUG    -   > Setting discretizing processor: EncoderLabel
# 2025-06-09 16:01:32,761 - PETsARD.Processor     - _generate_config  - DEBUG    - Processing column 'fnlwgt': inferred type numerical
# 2025-06-09 16:01:32,761 - PETsARD.Processor     - _generate_config  - DEBUG    -   > Setting missing processor: MissingMean
# 2025-06-09 16:01:32,762 - PETsARD.Processor     - _generate_config  - DEBUG    -   > Setting outlier processor: OutlierIQR
# 2025-06-09 16:01:32,762 - PETsARD.Processor     - _generate_config  - DEBUG    -   > Setting encoder processor: <lambda>
# 2025-06-09 16:01:32,762 - PETsARD.Processor     - _generate_config  - DEBUG    -   > Setting scaler processor: ScalerStandard
# 2025-06-09 16:01:32,763 - PETsARD.Processor     - _generate_config  - DEBUG    -   > Setting discretizing processor: DiscretizingKBins
# 2025-06-09 16:01:32,763 - PETsARD.Processor     - _generate_config  - DEBUG    - Processing column 'education': inferred type categorical
# 2025-06-09 16:01:32,763 - PETsARD.Processor     - _generate_config  - DEBUG    -   > Setting missing processor: MissingDrop
# 2025-06-09 16:01:32,764 - PETsARD.Processor     - _generate_config  - DEBUG    -   > Setting outlier processor: <lambda>
# 2025-06-09 16:01:32,764 - PETsARD.Processor     - _generate_config  - DEBUG    -   > Setting encoder processor: EncoderUniform
# 2025-06-09 16:01:32,764 - PETsARD.Processor     - _generate_config  - DEBUG    -   > Setting scaler processor: <lambda>
# 2025-06-09 16:01:32,765 - PETsARD.Processor     - _generate_config  - DEBUG    -   > Setting discretizing processor: EncoderLabel
# 2025-06-09 16:01:32,765 - PETsARD.Processor     - _generate_config  - DEBUG    - Processing column 'educational-num': inferred type numerical
# 2025-06-09 16:01:32,765 - PETsARD.Processor     - _generate_config  - DEBUG    -   > Setting missing processor: MissingMean
# 2025-06-09 16:01:32,766 - PETsARD.Processor     - _generate_config  - DEBUG    -   > Setting outlier processor: OutlierIQR
# 2025-06-09 16:01:32,766 - PETsARD.Processor     - _generate_config  - DEBUG    -   > Setting encoder processor: <lambda>
# 2025-06-09 16:01:32,766 - PETsARD.Processor     - _generate_config  - DEBUG    -   > Setting scaler processor: ScalerStandard
# 2025-06-09 16:01:32,767 - PETsARD.Processor     - _generate_config  - DEBUG    -   > Setting discretizing processor: DiscretizingKBins
# 2025-06-09 16:01:32,767 - PETsARD.Processor     - _generate_config  - DEBUG    - Processing column 'marital-status': inferred type categorical
# 2025-06-09 16:01:32,768 - PETsARD.Processor     - _generate_config  - DEBUG    -   > Setting missing processor: MissingDrop
# 2025-06-09 16:01:32,768 - PETsARD.Processor     - _generate_config  - DEBUG    -   > Setting outlier processor: <lambda>
# 2025-06-09 16:01:32,768 - PETsARD.Processor     - _generate_config  - DEBUG    -   > Setting encoder processor: EncoderUniform
# 2025-06-09 16:01:32,769 - PETsARD.Processor     - _generate_config  - DEBUG    -   > Setting scaler processor: <lambda>
# 2025-06-09 16:01:32,769 - PETsARD.Processor     - _generate_config  - DEBUG    -   > Setting discretizing processor: EncoderLabel
# 2025-06-09 16:01:32,770 - PETsARD.Processor     - _generate_config  - DEBUG    - Processing column 'occupation': inferred type categorical
# 2025-06-09 16:01:32,770 - PETsARD.Processor     - _generate_config  - DEBUG    -   > Setting missing processor: MissingDrop
# 2025-06-09 16:01:32,770 - PETsARD.Processor     - _generate_config  - DEBUG    -   > Setting outlier processor: <lambda>
# 2025-06-09 16:01:32,770 - PETsARD.Processor     - _generate_config  - DEBUG    -   > Setting encoder processor: EncoderUniform
# 2025-06-09 16:01:32,771 - PETsARD.Processor     - _generate_config  - DEBUG    -   > Setting scaler processor: <lambda>
# 2025-06-09 16:01:32,771 - PETsARD.Processor     - _generate_config  - DEBUG    -   > Setting discretizing processor: EncoderLabel
# 2025-06-09 16:01:32,771 - PETsARD.Processor     - _generate_config  - DEBUG    - Processing column 'relationship': inferred type categorical
# 2025-06-09 16:01:32,771 - PETsARD.Processor     - _generate_config  - DEBUG    -   > Setting missing processor: MissingDrop
# 2025-06-09 16:01:32,772 - PETsARD.Processor     - _generate_config  - DEBUG    -   > Setting outlier processor: <lambda>
# 2025-06-09 16:01:32,772 - PETsARD.Processor     - _generate_config  - DEBUG    -   > Setting encoder processor: EncoderUniform
# 2025-06-09 16:01:32,772 - PETsARD.Processor     - _generate_config  - DEBUG    -   > Setting scaler processor: <lambda>
# 2025-06-09 16:01:32,772 - PETsARD.Processor     - _generate_config  - DEBUG    -   > Setting discretizing processor: EncoderLabel
# 2025-06-09 16:01:32,773 - PETsARD.Processor     - _generate_config  - DEBUG    - Processing column 'race': inferred type categorical
# 2025-06-09 16:01:32,773 - PETsARD.Processor     - _generate_config  - DEBUG    -   > Setting missing processor: MissingDrop
# 2025-06-09 16:01:32,773 - PETsARD.Processor     - _generate_config  - DEBUG    -   > Setting outlier processor: <lambda>
# 2025-06-09 16:01:32,774 - PETsARD.Processor     - _generate_config  - DEBUG    -   > Setting encoder processor: EncoderUniform
# 2025-06-09 16:01:32,774 - PETsARD.Processor     - _generate_config  - DEBUG    -   > Setting scaler processor: <lambda>
# 2025-06-09 16:01:32,775 - PETsARD.Processor     - _generate_config  - DEBUG    -   > Setting discretizing processor: EncoderLabel
# 2025-06-09 16:01:32,775 - PETsARD.Processor     - _generate_config  - DEBUG    - Processing column 'gender': inferred type categorical
# 2025-06-09 16:01:32,775 - PETsARD.Processor     - _generate_config  - DEBUG    -   > Setting missing processor: MissingDrop
# 2025-06-09 16:01:32,776 - PETsARD.Processor     - _generate_config  - DEBUG    -   > Setting outlier processor: <lambda>
# 2025-06-09 16:01:32,776 - PETsARD.Processor     - _generate_config  - DEBUG    -   > Setting encoder processor: EncoderUniform
# 2025-06-09 16:01:32,776 - PETsARD.Processor     - _generate_config  - DEBUG    -   > Setting scaler processor: <lambda>
# 2025-06-09 16:01:32,777 - PETsARD.Processor     - _generate_config  - DEBUG    -   > Setting discretizing processor: EncoderLabel
# 2025-06-09 16:01:32,777 - PETsARD.Processor     - _generate_config  - DEBUG    - Processing column 'capital-gain': inferred type numerical
# 2025-06-09 16:01:32,777 - PETsARD.Processor     - _generate_config  - DEBUG    -   > Setting missing processor: MissingMean
# 2025-06-09 16:01:32,778 - PETsARD.Processor     - _generate_config  - DEBUG    -   > Setting outlier processor: OutlierIQR
# 2025-06-09 16:01:32,778 - PETsARD.Processor     - _generate_config  - DEBUG    -   > Setting encoder processor: <lambda>
# 2025-06-09 16:01:32,779 - PETsARD.Processor     - _generate_config  - DEBUG    -   > Setting scaler processor: ScalerStandard
# 2025-06-09 16:01:32,779 - PETsARD.Processor     - _generate_config  - DEBUG    -   > Setting discretizing processor: DiscretizingKBins
# 2025-06-09 16:01:32,779 - PETsARD.Processor     - _generate_config  - DEBUG    - Processing column 'capital-loss': inferred type numerical
# 2025-06-09 16:01:32,780 - PETsARD.Processor     - _generate_config  - DEBUG    -   > Setting missing processor: MissingMean
# 2025-06-09 16:01:32,780 - PETsARD.Processor     - _generate_config  - DEBUG    -   > Setting outlier processor: OutlierIQR
# 2025-06-09 16:01:32,780 - PETsARD.Processor     - _generate_config  - DEBUG    -   > Setting encoder processor: <lambda>
# 2025-06-09 16:01:32,781 - PETsARD.Processor     - _generate_config  - DEBUG    -   > Setting scaler processor: ScalerStandard
# 2025-06-09 16:01:32,781 - PETsARD.Processor     - _generate_config  - DEBUG    -   > Setting discretizing processor: DiscretizingKBins
# 2025-06-09 16:01:32,781 - PETsARD.Processor     - _generate_config  - DEBUG    - Processing column 'hours-per-week': inferred type numerical
# 2025-06-09 16:01:32,781 - PETsARD.Processor     - _generate_config  - DEBUG    -   > Setting missing processor: MissingMean
# 2025-06-09 16:01:32,782 - PETsARD.Processor     - _generate_config  - DEBUG    -   > Setting outlier processor: OutlierIQR
# 2025-06-09 16:01:32,782 - PETsARD.Processor     - _generate_config  - DEBUG    -   > Setting encoder processor: <lambda>
# 2025-06-09 16:01:32,782 - PETsARD.Processor     - _generate_config  - DEBUG    -   > Setting scaler processor: ScalerStandard
# 2025-06-09 16:01:32,783 - PETsARD.Processor     - _generate_config  - DEBUG    -   > Setting discretizing processor: DiscretizingKBins
# 2025-06-09 16:01:32,783 - PETsARD.Processor     - _generate_config  - DEBUG    - Processing column 'native-country': inferred type categorical
# 2025-06-09 16:01:32,783 - PETsARD.Processor     - _generate_config  - DEBUG    -   > Setting missing processor: MissingDrop
# 2025-06-09 16:01:32,783 - PETsARD.Processor     - _generate_config  - DEBUG    -   > Setting outlier processor: <lambda>
# 2025-06-09 16:01:32,784 - PETsARD.Processor     - _generate_config  - DEBUG    -   > Setting encoder processor: EncoderUniform
# 2025-06-09 16:01:32,784 - PETsARD.Processor     - _generate_config  - DEBUG    -   > Setting scaler processor: <lambda>
# 2025-06-09 16:01:32,784 - PETsARD.Processor     - _generate_config  - DEBUG    -   > Setting discretizing processor: EncoderLabel
# 2025-06-09 16:01:32,785 - PETsARD.Processor     - _generate_config  - DEBUG    - Processing column 'income': inferred type categorical
# 2025-06-09 16:01:32,785 - PETsARD.Processor     - _generate_config  - DEBUG    -   > Setting missing processor: MissingDrop
# 2025-06-09 16:01:32,786 - PETsARD.Processor     - _generate_config  - DEBUG    -   > Setting outlier processor: <lambda>
# 2025-06-09 16:01:32,786 - PETsARD.Processor     - _generate_config  - DEBUG    -   > Setting encoder processor: EncoderUniform
# 2025-06-09 16:01:32,786 - PETsARD.Processor     - _generate_config  - DEBUG    -   > Setting scaler processor: <lambda>
# 2025-06-09 16:01:32,787 - PETsARD.Processor     - _generate_config  - DEBUG    -   > Setting discretizing processor: EncoderLabel
# 2025-06-09 16:01:32,787 - PETsARD.Processor     - _generate_config  - DEBUG    - Config generation completed
# 2025-06-09 16:01:32,787 - PETsARD.Processor     - __init__          - DEBUG    - Config loaded.
# 2025-06-09 16:01:32,787 - PETsARD.PreprocessorOp - _run              - DEBUG    - Using default processing sequence
# 2025-06-09 16:01:32,787 - PETsARD.Processor     - fit               - INFO     - MediatorMissing is created.
# 2025-06-09 16:01:32,788 - PETsARD.Processor     - fit               - INFO     - MediatorOutlier is created.
# 2025-06-09 16:01:32,788 - PETsARD.Processor     - fit               - INFO     - MediatorEncoder is created.
# 2025-06-09 16:01:32,788 - PETsARD.Processor     - fit               - INFO     - MediatorScaler is created.
# 2025-06-09 16:01:32,788 - PETsARD.Processor     - fit               - DEBUG    - Fitting sequence generation completed.
# 2025-06-09 16:01:32,789 - PETsARD.Processor     - fit               - DEBUG    - missing: MissingMean from age start processing.
# 2025-06-09 16:01:32,790 - PETsARD.Processor     - fit               - DEBUG    - missing: MissingDrop from workclass start processing.
# 2025-06-09 16:01:32,790 - PETsARD.Processor     - fit               - DEBUG    - missing: MissingMean from fnlwgt start processing.
# 2025-06-09 16:01:32,791 - PETsARD.Processor     - fit               - DEBUG    - missing: MissingDrop from education start processing.
# 2025-06-09 16:01:32,791 - PETsARD.Processor     - fit               - DEBUG    - missing: MissingMean from educational-num start processing.
# 2025-06-09 16:01:32,792 - PETsARD.Processor     - fit               - DEBUG    - missing: MissingDrop from marital-status start processing.
# 2025-06-09 16:01:32,792 - PETsARD.Processor     - fit               - DEBUG    - missing: MissingDrop from occupation start processing.
# 2025-06-09 16:01:32,792 - PETsARD.Processor     - fit               - DEBUG    - missing: MissingDrop from relationship start processing.
# 2025-06-09 16:01:32,793 - PETsARD.Processor     - fit               - DEBUG    - missing: MissingDrop from race start processing.
# 2025-06-09 16:01:32,793 - PETsARD.Processor     - fit               - DEBUG    - missing: MissingDrop from gender start processing.
# 2025-06-09 16:01:32,793 - PETsARD.Processor     - fit               - DEBUG    - missing: MissingMean from capital-gain start processing.
# 2025-06-09 16:01:32,794 - PETsARD.Processor     - fit               - DEBUG    - missing: MissingMean from capital-loss start processing.
# 2025-06-09 16:01:32,794 - PETsARD.Processor     - fit               - DEBUG    - missing: MissingMean from hours-per-week start processing.
# 2025-06-09 16:01:32,795 - PETsARD.Processor     - fit               - DEBUG    - missing: MissingDrop from native-country start processing.
# 2025-06-09 16:01:32,795 - PETsARD.Processor     - fit               - DEBUG    - missing: MissingDrop from income start processing.
# 2025-06-09 16:01:32,795 - PETsARD.Processor     - fit               - INFO     - missing fitting done.
# 2025-06-09 16:01:32,796 - PETsARD.Processor     - fit               - DEBUG    - mediator: MissingDrop start processing.
# 2025-06-09 16:01:32,796 - PETsARD.Processor     - fit               - INFO     - MissingDrop fitting done.
# 2025-06-09 16:01:32,796 - PETsARD.Processor     - fit               - DEBUG    - outlier: OutlierIQR from age start processing.
# 2025-06-09 16:01:32,798 - PETsARD.Processor     - fit               - DEBUG    - outlier: NoneType from workclass start processing.
# 2025-06-09 16:01:32,798 - PETsARD.Processor     - fit               - DEBUG    - outlier: OutlierIQR from fnlwgt start processing.
# 2025-06-09 16:01:32,799 - PETsARD.Processor     - fit               - DEBUG    - outlier: NoneType from education start processing.
# 2025-06-09 16:01:32,800 - PETsARD.Processor     - fit               - DEBUG    - outlier: OutlierIQR from educational-num start processing.
# 2025-06-09 16:01:32,801 - PETsARD.Processor     - fit               - DEBUG    - outlier: NoneType from marital-status start processing.
# 2025-06-09 16:01:32,801 - PETsARD.Processor     - fit               - DEBUG    - outlier: NoneType from occupation start processing.
# 2025-06-09 16:01:32,802 - PETsARD.Processor     - fit               - DEBUG    - outlier: NoneType from relationship start processing.
# 2025-06-09 16:01:32,802 - PETsARD.Processor     - fit               - DEBUG    - outlier: NoneType from race start processing.
# 2025-06-09 16:01:32,802 - PETsARD.Processor     - fit               - DEBUG    - outlier: NoneType from gender start processing.
# 2025-06-09 16:01:32,803 - PETsARD.Processor     - fit               - DEBUG    - outlier: OutlierIQR from capital-gain start processing.
# 2025-06-09 16:01:32,803 - PETsARD.Processor     - fit               - DEBUG    - outlier: OutlierIQR from capital-loss start processing.
# 2025-06-09 16:01:32,804 - PETsARD.Processor     - fit               - DEBUG    - outlier: OutlierIQR from hours-per-week start processing.
# 2025-06-09 16:01:32,805 - PETsARD.Processor     - fit               - DEBUG    - outlier: NoneType from native-country start processing.
# 2025-06-09 16:01:32,806 - PETsARD.Processor     - fit               - DEBUG    - outlier: NoneType from income start processing.
# 2025-06-09 16:01:32,806 - PETsARD.Processor     - fit               - INFO     - outlier fitting done.
# 2025-06-09 16:01:32,806 - PETsARD.Processor     - fit               - DEBUG    - mediator: NoneType start processing.
# 2025-06-09 16:01:32,806 - PETsARD.Processor     - fit               - INFO     - NoneType fitting done.
# 2025-06-09 16:01:32,807 - PETsARD.Processor     - fit               - DEBUG    - encoder: NoneType from age start processing.
# 2025-06-09 16:01:32,807 - PETsARD.Processor     - fit               - DEBUG    - encoder: EncoderUniform from workclass start processing.
# 2025-06-09 16:01:32,808 - PETsARD.Processor     - fit               - DEBUG    - encoder: NoneType from fnlwgt start processing.
# 2025-06-09 16:01:32,808 - PETsARD.Processor     - fit               - DEBUG    - encoder: EncoderUniform from education start processing.
# 2025-06-09 16:01:32,809 - PETsARD.Processor     - fit               - DEBUG    - encoder: NoneType from educational-num start processing.
# 2025-06-09 16:01:32,810 - PETsARD.Processor     - fit               - DEBUG    - encoder: EncoderUniform from marital-status start processing.
# 2025-06-09 16:01:32,811 - PETsARD.Processor     - fit               - DEBUG    - encoder: EncoderUniform from occupation start processing.
# 2025-06-09 16:01:32,812 - PETsARD.Processor     - fit               - DEBUG    - encoder: EncoderUniform from relationship start processing.
# 2025-06-09 16:01:32,812 - PETsARD.Processor     - fit               - DEBUG    - encoder: EncoderUniform from race start processing.
# 2025-06-09 16:01:32,814 - PETsARD.Processor     - fit               - DEBUG    - encoder: EncoderUniform from gender start processing.
# 2025-06-09 16:01:32,815 - PETsARD.Processor     - fit               - DEBUG    - encoder: NoneType from capital-gain start processing.
# 2025-06-09 16:01:32,815 - PETsARD.Processor     - fit               - DEBUG    - encoder: NoneType from capital-loss start processing.
# 2025-06-09 16:01:32,815 - PETsARD.Processor     - fit               - DEBUG    - encoder: NoneType from hours-per-week start processing.
# 2025-06-09 16:01:32,816 - PETsARD.Processor     - fit               - DEBUG    - encoder: EncoderUniform from native-country start processing.
# 2025-06-09 16:01:32,817 - PETsARD.Processor     - fit               - DEBUG    - encoder: EncoderUniform from income start processing.
# 2025-06-09 16:01:32,818 - PETsARD.Processor     - fit               - INFO     - encoder fitting done.
# 2025-06-09 16:01:32,818 - PETsARD.Processor     - fit               - DEBUG    - mediator: EncoderUniform start processing.
# 2025-06-09 16:01:32,819 - PETsARD.Processor     - fit               - INFO     - EncoderUniform fitting done.
# 2025-06-09 16:01:32,819 - PETsARD.Processor     - fit               - DEBUG    - scaler: ScalerStandard from age start processing.
# 2025-06-09 16:01:32,820 - PETsARD.Processor     - fit               - DEBUG    - scaler: NoneType from workclass start processing.
# 2025-06-09 16:01:32,820 - PETsARD.Processor     - fit               - DEBUG    - scaler: ScalerStandard from fnlwgt start processing.
# 2025-06-09 16:01:32,821 - PETsARD.Processor     - fit               - DEBUG    - scaler: NoneType from education start processing.
# 2025-06-09 16:01:32,822 - PETsARD.Processor     - fit               - DEBUG    - scaler: ScalerStandard from educational-num start processing.
# 2025-06-09 16:01:32,823 - PETsARD.Processor     - fit               - DEBUG    - scaler: NoneType from marital-status start processing.
# 2025-06-09 16:01:32,823 - PETsARD.Processor     - fit               - DEBUG    - scaler: NoneType from occupation start processing.
# 2025-06-09 16:01:32,824 - PETsARD.Processor     - fit               - DEBUG    - scaler: NoneType from relationship start processing.
# 2025-06-09 16:01:32,824 - PETsARD.Processor     - fit               - DEBUG    - scaler: NoneType from race start processing.
# 2025-06-09 16:01:32,824 - PETsARD.Processor     - fit               - DEBUG    - scaler: NoneType from gender start processing.
# 2025-06-09 16:01:32,825 - PETsARD.Processor     - fit               - DEBUG    - scaler: ScalerStandard from capital-gain start processing.
# 2025-06-09 16:01:32,826 - PETsARD.Processor     - fit               - DEBUG    - scaler: ScalerStandard from capital-loss start processing.
# 2025-06-09 16:01:32,827 - PETsARD.Processor     - fit               - DEBUG    - scaler: ScalerStandard from hours-per-week start processing.
# 2025-06-09 16:01:32,828 - PETsARD.Processor     - fit               - DEBUG    - scaler: NoneType from native-country start processing.
# 2025-06-09 16:01:32,828 - PETsARD.Processor     - fit               - DEBUG    - scaler: NoneType from income start processing.
# 2025-06-09 16:01:32,828 - PETsARD.Processor     - fit               - INFO     - scaler fitting done.
# 2025-06-09 16:01:32,829 - PETsARD.PreprocessorOp - _run              - DEBUG    - Transforming data
# 2025-06-09 16:01:32,829 - PETsARD.Processor     - transform         - DEBUG    - Starting data transformation, input shape: (39073, 15)
# 2025-06-09 16:01:32,830 - PETsARD.Processor     - transform         - DEBUG    - Executing missing processing
# 2025-06-09 16:01:32,830 - PETsARD.Processor     - transform         - DEBUG    - missing: MissingMean from age start transforming.
# 2025-06-09 16:01:32,831 - PETsARD.Processor     - transform         - DEBUG    -   > Pre-transform stats: mean=38.6667, std=13.7021, na_cnt=0
# 2025-06-09 16:01:32,832 - PETsARD.Processor     - transform         - DEBUG    -   > Post-transform stats: mean=38.6667, std=13.7021, na_cnt=0
# 2025-06-09 16:01:32,833 - PETsARD.Processor     - transform         - DEBUG    - missing: MissingDrop from workclass start transforming.
# 2025-06-09 16:01:32,834 - PETsARD.Processor     - transform         - DEBUG    -   > Post-transform stats: mean=0.0000, std=0.0000, na_cnt=0
# 2025-06-09 16:01:32,834 - PETsARD.Processor     - transform         - DEBUG    - missing: MissingMean from fnlwgt start transforming.
# 2025-06-09 16:01:32,836 - PETsARD.Processor     - transform         - DEBUG    -   > Pre-transform stats: mean=189792.5631, std=105684.6515, na_cnt=0
# 2025-06-09 16:01:32,837 - PETsARD.Processor     - transform         - DEBUG    -   > Post-transform stats: mean=189792.5631, std=105684.6515, na_cnt=0
# 2025-06-09 16:01:32,837 - PETsARD.Processor     - transform         - DEBUG    - missing: MissingDrop from education start transforming.
# 2025-06-09 16:01:32,838 - PETsARD.Processor     - transform         - DEBUG    -   > Post-transform stats: mean=0.0000, std=0.0000, na_cnt=0
# 2025-06-09 16:01:32,838 - PETsARD.Processor     - transform         - DEBUG    - missing: MissingMean from educational-num start transforming.
# 2025-06-09 16:01:32,839 - PETsARD.Processor     - transform         - DEBUG    -   > Pre-transform stats: mean=10.0762, std=2.5641, na_cnt=0
# 2025-06-09 16:01:32,841 - PETsARD.Processor     - transform         - DEBUG    -   > Post-transform stats: mean=10.0762, std=2.5641, na_cnt=0
# 2025-06-09 16:01:32,841 - PETsARD.Processor     - transform         - DEBUG    - missing: MissingDrop from marital-status start transforming.
# 2025-06-09 16:01:32,842 - PETsARD.Processor     - transform         - DEBUG    -   > Post-transform stats: mean=0.0000, std=0.0000, na_cnt=0
# 2025-06-09 16:01:32,842 - PETsARD.Processor     - transform         - DEBUG    - missing: MissingDrop from occupation start transforming.
# 2025-06-09 16:01:32,843 - PETsARD.Processor     - transform         - DEBUG    -   > Post-transform stats: mean=0.0000, std=0.0000, na_cnt=0
# 2025-06-09 16:01:32,843 - PETsARD.Processor     - transform         - DEBUG    - missing: MissingDrop from relationship start transforming.
# 2025-06-09 16:01:32,845 - PETsARD.Processor     - transform         - DEBUG    -   > Post-transform stats: mean=0.0000, std=0.0000, na_cnt=0
# 2025-06-09 16:01:32,845 - PETsARD.Processor     - transform         - DEBUG    - missing: MissingDrop from race start transforming.
# 2025-06-09 16:01:32,846 - PETsARD.Processor     - transform         - DEBUG    -   > Post-transform stats: mean=0.0000, std=0.0000, na_cnt=0
# 2025-06-09 16:01:32,847 - PETsARD.Processor     - transform         - DEBUG    - missing: MissingDrop from gender start transforming.
# 2025-06-09 16:01:32,848 - PETsARD.Processor     - transform         - DEBUG    -   > Post-transform stats: mean=0.0000, std=0.0000, na_cnt=0
# 2025-06-09 16:01:32,849 - PETsARD.Processor     - transform         - DEBUG    - missing: MissingMean from capital-gain start transforming.
# 2025-06-09 16:01:32,850 - PETsARD.Processor     - transform         - DEBUG    -   > Pre-transform stats: mean=1073.7255, std=7432.1323, na_cnt=0
# 2025-06-09 16:01:32,851 - PETsARD.Processor     - transform         - DEBUG    -   > Post-transform stats: mean=1073.7255, std=7432.1323, na_cnt=0
# 2025-06-09 16:01:32,851 - PETsARD.Processor     - transform         - DEBUG    - missing: MissingMean from capital-loss start transforming.
# 2025-06-09 16:01:32,853 - PETsARD.Processor     - transform         - DEBUG    -   > Pre-transform stats: mean=89.2604, std=407.3442, na_cnt=0
# 2025-06-09 16:01:32,854 - PETsARD.Processor     - transform         - DEBUG    -   > Post-transform stats: mean=89.2604, std=407.3442, na_cnt=0
# 2025-06-09 16:01:32,854 - PETsARD.Processor     - transform         - DEBUG    - missing: MissingMean from hours-per-week start transforming.
# 2025-06-09 16:01:32,856 - PETsARD.Processor     - transform         - DEBUG    -   > Pre-transform stats: mean=40.4706, std=12.3993, na_cnt=0
# 2025-06-09 16:01:32,858 - PETsARD.Processor     - transform         - DEBUG    -   > Post-transform stats: mean=40.4706, std=12.3993, na_cnt=0
# 2025-06-09 16:01:32,858 - PETsARD.Processor     - transform         - DEBUG    - missing: MissingDrop from native-country start transforming.
# 2025-06-09 16:01:32,860 - PETsARD.Processor     - transform         - DEBUG    -   > Post-transform stats: mean=0.0000, std=0.0000, na_cnt=0
# 2025-06-09 16:01:32,860 - PETsARD.Processor     - transform         - DEBUG    - missing: MissingDrop from income start transforming.
# 2025-06-09 16:01:32,861 - PETsARD.Processor     - transform         - DEBUG    -   > Post-transform stats: mean=0.0000, std=0.0000, na_cnt=0
# 2025-06-09 16:01:32,861 - PETsARD.Processor     - transform         - INFO     - missing transformation done.
# 2025-06-09 16:01:32,862 - PETsARD.Processor     - transform         - DEBUG    - mediator: MediatorMissing start transforming.
# 2025-06-09 16:01:32,862 - PETsARD.Processor     - transform         - DEBUG    - before transformation: data shape: (39073, 15)
# 2025-06-09 16:01:32,873 - PETsARD.Processor     - transform         - DEBUG    - after transformation: data shape: (39073, 15)
# 2025-06-09 16:01:32,874 - PETsARD.Processor     - transform         - INFO     - MediatorMissing transformation done.
# 2025-06-09 16:01:32,874 - PETsARD.Processor     - transform         - DEBUG    - Executing outlier processing
# 2025-06-09 16:01:32,875 - PETsARD.Processor     - transform         - DEBUG    - outlier: OutlierIQR from age start transforming.
# 2025-06-09 16:01:32,876 - PETsARD.Processor     - transform         - DEBUG    -   > Pre-transform stats: mean=38.6667, std=13.7021, na_cnt=0
# 2025-06-09 16:01:32,878 - PETsARD.Processor     - transform         - DEBUG    -   > Post-transform stats: mean=0.0044, std=0.0658, na_cnt=0
# 2025-06-09 16:01:32,878 - PETsARD.Processor     - transform         - DEBUG    - outlier: NoneType from workclass start transforming.
# 2025-06-09 16:01:32,878 - PETsARD.Processor     - transform         - DEBUG    -   > Skipping column 'workclass': no processing needed
# 2025-06-09 16:01:32,878 - PETsARD.Processor     - transform         - DEBUG    - outlier: OutlierIQR from fnlwgt start transforming.
# 2025-06-09 16:01:32,879 - PETsARD.Processor     - transform         - DEBUG    -   > Pre-transform stats: mean=189792.5631, std=105684.6515, na_cnt=0
# 2025-06-09 16:01:32,881 - PETsARD.Processor     - transform         - DEBUG    -   > Post-transform stats: mean=0.0298, std=0.1701, na_cnt=0
# 2025-06-09 16:01:32,881 - PETsARD.Processor     - transform         - DEBUG    - outlier: NoneType from education start transforming.
# 2025-06-09 16:01:32,881 - PETsARD.Processor     - transform         - DEBUG    -   > Skipping column 'education': no processing needed
# 2025-06-09 16:01:32,882 - PETsARD.Processor     - transform         - DEBUG    - outlier: OutlierIQR from educational-num start transforming.
# 2025-06-09 16:01:32,883 - PETsARD.Processor     - transform         - DEBUG    -   > Pre-transform stats: mean=10.0762, std=2.5641, na_cnt=0
# 2025-06-09 16:01:32,885 - PETsARD.Processor     - transform         - DEBUG    -   > Post-transform stats: mean=0.0360, std=0.1863, na_cnt=0
# 2025-06-09 16:01:32,886 - PETsARD.Processor     - transform         - DEBUG    - outlier: NoneType from marital-status start transforming.
# 2025-06-09 16:01:32,887 - PETsARD.Processor     - transform         - DEBUG    -   > Skipping column 'marital-status': no processing needed
# 2025-06-09 16:01:32,887 - PETsARD.Processor     - transform         - DEBUG    - outlier: NoneType from occupation start transforming.
# 2025-06-09 16:01:32,887 - PETsARD.Processor     - transform         - DEBUG    -   > Skipping column 'occupation': no processing needed
# 2025-06-09 16:01:32,888 - PETsARD.Processor     - transform         - DEBUG    - outlier: NoneType from relationship start transforming.
# 2025-06-09 16:01:32,888 - PETsARD.Processor     - transform         - DEBUG    -   > Skipping column 'relationship': no processing needed
# 2025-06-09 16:01:32,889 - PETsARD.Processor     - transform         - DEBUG    - outlier: NoneType from race start transforming.
# 2025-06-09 16:01:32,889 - PETsARD.Processor     - transform         - DEBUG    -   > Skipping column 'race': no processing needed
# 2025-06-09 16:01:32,890 - PETsARD.Processor     - transform         - DEBUG    - outlier: NoneType from gender start transforming.
# 2025-06-09 16:01:32,891 - PETsARD.Processor     - transform         - DEBUG    -   > Skipping column 'gender': no processing needed
# 2025-06-09 16:01:32,891 - PETsARD.Processor     - transform         - DEBUG    - outlier: OutlierIQR from capital-gain start transforming.
# 2025-06-09 16:01:32,892 - PETsARD.Processor     - transform         - DEBUG    -   > Pre-transform stats: mean=1073.7255, std=7432.1323, na_cnt=0
# 2025-06-09 16:01:32,894 - PETsARD.Processor     - transform         - DEBUG    -   > Post-transform stats: mean=0.0825, std=0.2751, na_cnt=0
# 2025-06-09 16:01:32,894 - PETsARD.Processor     - transform         - DEBUG    - outlier: OutlierIQR from capital-loss start transforming.
# 2025-06-09 16:01:32,895 - PETsARD.Processor     - transform         - DEBUG    -   > Pre-transform stats: mean=89.2604, std=407.3442, na_cnt=0
# 2025-06-09 16:01:32,898 - PETsARD.Processor     - transform         - DEBUG    -   > Post-transform stats: mean=0.0476, std=0.2130, na_cnt=0
# 2025-06-09 16:01:32,898 - PETsARD.Processor     - transform         - DEBUG    - outlier: OutlierIQR from hours-per-week start transforming.
# 2025-06-09 16:01:32,899 - PETsARD.Processor     - transform         - DEBUG    -   > Pre-transform stats: mean=40.4706, std=12.3993, na_cnt=0
# 2025-06-09 16:01:32,900 - PETsARD.Processor     - transform         - DEBUG    -   > Post-transform stats: mean=0.2750, std=0.4465, na_cnt=0
# 2025-06-09 16:01:32,900 - PETsARD.Processor     - transform         - DEBUG    - outlier: NoneType from native-country start transforming.
# 2025-06-09 16:01:32,900 - PETsARD.Processor     - transform         - DEBUG    -   > Skipping column 'native-country': no processing needed
# 2025-06-09 16:01:32,901 - PETsARD.Processor     - transform         - DEBUG    - outlier: NoneType from income start transforming.
# 2025-06-09 16:01:32,901 - PETsARD.Processor     - transform         - DEBUG    -   > Skipping column 'income': no processing needed
# 2025-06-09 16:01:32,901 - PETsARD.Processor     - transform         - INFO     - outlier transformation done.
# 2025-06-09 16:01:32,902 - PETsARD.Processor     - transform         - DEBUG    - mediator: MediatorOutlier start transforming.
# 2025-06-09 16:01:32,902 - PETsARD.Processor     - transform         - DEBUG    - before transformation: data shape: (39073, 15)
# 2025-06-09 16:01:32,910 - PETsARD.Processor     - transform         - DEBUG    - after transformation: data shape: (22869, 15)
# 2025-06-09 16:01:32,910 - PETsARD.Processor     - transform         - INFO     - MediatorOutlier transformation done.
# 2025-06-09 16:01:32,910 - PETsARD.Processor     - transform         - DEBUG    - Executing encoder processing
# 2025-06-09 16:01:32,911 - PETsARD.Processor     - transform         - DEBUG    - encoder: NoneType from age start transforming.
# 2025-06-09 16:01:32,911 - PETsARD.Processor     - transform         - DEBUG    -   > Skipping column 'age': no processing needed
# 2025-06-09 16:01:32,911 - PETsARD.Processor     - transform         - DEBUG    - encoder: EncoderUniform from workclass start transforming.
# 2025-06-09 16:01:32,999 - PETsARD.Processor     - transform         - DEBUG    -   > Post-transform stats: mean=0.4870, std=0.2863, na_cnt=0
# 2025-06-09 16:01:33,000 - PETsARD.Processor     - transform         - DEBUG    - encoder: NoneType from fnlwgt start transforming.
# 2025-06-09 16:01:33,000 - PETsARD.Processor     - transform         - DEBUG    -   > Skipping column 'fnlwgt': no processing needed
# 2025-06-09 16:01:33,001 - PETsARD.Processor     - transform         - DEBUG    - encoder: EncoderUniform from education start transforming.
# 2025-06-09 16:01:33,087 - PETsARD.Processor     - transform         - DEBUG    -   > Post-transform stats: mean=0.4660, std=0.2795, na_cnt=0
# 2025-06-09 16:01:33,087 - PETsARD.Processor     - transform         - DEBUG    - encoder: NoneType from educational-num start transforming.
# 2025-06-09 16:01:33,088 - PETsARD.Processor     - transform         - DEBUG    -   > Skipping column 'educational-num': no processing needed
# 2025-06-09 16:01:33,088 - PETsARD.Processor     - transform         - DEBUG    - encoder: EncoderUniform from marital-status start transforming.
# 2025-06-09 16:01:33,162 - PETsARD.Processor     - transform         - DEBUG    -   > Post-transform stats: mean=0.5069, std=0.2886, na_cnt=0
# 2025-06-09 16:01:33,163 - PETsARD.Processor     - transform         - DEBUG    - encoder: EncoderUniform from occupation start transforming.
# 2025-06-09 16:01:33,247 - PETsARD.Processor     - transform         - DEBUG    -   > Post-transform stats: mean=0.4862, std=0.2880, na_cnt=0
# 2025-06-09 16:01:33,249 - PETsARD.Processor     - transform         - DEBUG    - encoder: EncoderUniform from relationship start transforming.
# 2025-06-09 16:01:33,305 - PETsARD.Processor     - transform         - DEBUG    -   > Post-transform stats: mean=0.4992, std=0.2883, na_cnt=0
# 2025-06-09 16:01:33,306 - PETsARD.Processor     - transform         - DEBUG    - encoder: EncoderUniform from race start transforming.
# 2025-06-09 16:01:33,356 - PETsARD.Processor     - transform         - DEBUG    -   > Post-transform stats: mean=0.5049, std=0.2908, na_cnt=0
# 2025-06-09 16:01:33,356 - PETsARD.Processor     - transform         - DEBUG    - encoder: EncoderUniform from gender start transforming.
# 2025-06-09 16:01:33,413 - PETsARD.Processor     - transform         - DEBUG    -   > Post-transform stats: mean=0.5001, std=0.2881, na_cnt=0
# 2025-06-09 16:01:33,413 - PETsARD.Processor     - transform         - DEBUG    - encoder: NoneType from capital-gain start transforming.
# 2025-06-09 16:01:33,414 - PETsARD.Processor     - transform         - DEBUG    -   > Skipping column 'capital-gain': no processing needed
# 2025-06-09 16:01:33,415 - PETsARD.Processor     - transform         - DEBUG    - encoder: NoneType from capital-loss start transforming.
# 2025-06-09 16:01:33,415 - PETsARD.Processor     - transform         - DEBUG    -   > Skipping column 'capital-loss': no processing needed
# 2025-06-09 16:01:33,416 - PETsARD.Processor     - transform         - DEBUG    - encoder: NoneType from hours-per-week start transforming.
# 2025-06-09 16:01:33,416 - PETsARD.Processor     - transform         - DEBUG    -   > Skipping column 'hours-per-week': no processing needed
# 2025-06-09 16:01:33,416 - PETsARD.Processor     - transform         - DEBUG    - encoder: EncoderUniform from native-country start transforming.
# 2025-06-09 16:01:33,477 - PETsARD.Processor     - transform         - DEBUG    -   > Post-transform stats: mean=0.4976, std=0.2868, na_cnt=0
# 2025-06-09 16:01:33,477 - PETsARD.Processor     - transform         - DEBUG    - encoder: EncoderUniform from income start transforming.
# 2025-06-09 16:01:33,535 - PETsARD.Processor     - transform         - DEBUG    -   > Post-transform stats: mean=0.4859, std=0.2831, na_cnt=0
# 2025-06-09 16:01:33,535 - PETsARD.Processor     - transform         - INFO     - encoder transformation done.
# 2025-06-09 16:01:33,536 - PETsARD.Processor     - transform         - DEBUG    - mediator: MediatorEncoder start transforming.
# 2025-06-09 16:01:33,536 - PETsARD.Processor     - transform         - DEBUG    - before transformation: data shape: (22869, 15)
# ...
# 2025-06-09 16:01:37,782 - PETsARD.SDMetricsSingleTable - _eval             - DEBUG    - Warning during _eval: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# 2025-06-09 16:01:37,782 - PETsARD.SDMetricsSingleTable - _eval             - DEBUG    - Warning during _eval: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# 2025-06-09 16:01:37,782 - PETsARD.SDMetricsSingleTable - _eval             - DEBUG    - Warning during _eval: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# 2025-06-09 16:01:37,782 - PETsARD.SDMetricsSingleTable - _eval             - DEBUG    - Warning during _eval: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# 2025-06-09 16:01:37,783 - PETsARD.SDMetricsSingleTable - _eval             - DEBUG    - Warning during _eval: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# 2025-06-09 16:01:37,783 - PETsARD.SDMetricsSingleTable - _eval             - DEBUG    - Warning during _eval: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# 2025-06-09 16:01:37,783 - PETsARD.SDMetricsSingleTable - _eval             - DEBUG    - Warning during _eval: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# 2025-06-09 16:01:37,783 - PETsARD.SDMetricsSingleTable - _eval             - DEBUG    - Warning during _eval: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# 2025-06-09 16:01:37,783 - PETsARD.SDMetricsSingleTable - _eval             - DEBUG    - Warning during _eval: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# 2025-06-09 16:01:37,784 - PETsARD.SDMetricsSingleTable - _eval             - DEBUG    - Warning during _eval: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# 2025-06-09 16:01:37,784 - PETsARD.SDMetricsSingleTable - _eval             - DEBUG    - Warning during _eval: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# 2025-06-09 16:01:37,784 - PETsARD.SDMetricsSingleTable - _eval             - DEBUG    - Warning during _eval: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# Overall Score (Average): 78.3%
# 2025-06-09 16:01:37,784 - PETsARD.SDMetricsSingleTable - _eval             - INFO     - Successfully evaluating from data
# 2025-06-09 16:01:37,785 - PETsARD.SDMetricsSingleTable - _extract_scores   - DEBUG    - Extract scores level from SDMetrics
# 2025-06-09 16:01:37,785 - PETsARD.SDMetricsSingleTable - _extract_scores   - DEBUG    - Extracting properties level from SDMetrics
# 2025-06-09 16:01:37,786 - PETsARD.SDMetricsSingleTable - _extract_scores   - DEBUG    - Extracting details level from SDMetrics
# 2025-06-09 16:01:37,786 - PETsARD.SDMetricsSingleTable - _eval             - DEBUG    - Extracted scores: ['score', 'properties', 'details']
# 2025-06-09 16:01:37,786 - PETsARD.SDMetricsSingleTable - _eval             - DEBUG    - Extracting global level as PETsARD format
# 2025-06-09 16:01:37,787 - PETsARD.SDMetricsSingleTable - _eval             - DEBUG    - Extracting columnwise level as PETsARD format
# 2025-06-09 16:01:37,788 - PETsARD.SDMetricsSingleTable - _eval             - DEBUG    - Extracting pairwise level as PETsARD format
# 2025-06-09 16:01:37,789 - PETsARD.SDMetricsSingleTable - _eval             - INFO     - Successfully extracting scores
# 2025-06-09 16:01:37,790 - PETsARD.SDMetricsSingleTable - eval              - INFO     - Successfully evaluating SDMetricsSingleTable
# 2025-06-09 16:01:37,790 - PETsARD.Evaluator     - eval              - INFO     - Evaluation completed successfully in 0.741 seconds
# 2025-06-09 16:01:37,794 - PETsARD.Evaluator     - eval              - DEBUG    - Evaluation report summary: Data keys: ['ori', 'syn', 'control'], Column count by type per dataframe: {'ori': {dtype('int8'): 3, dtype('int32'): 2, CategoricalDtype(categories=['?', 'Federal-gov', 'Local-gov', 'Never-worked', 'Private',
#                   'Self-emp-inc', 'Self-emp-not-inc', 'State-gov',
#                   'Without-pay'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['10th', '11th', '12th', '1st-4th', '5th-6th', '7th-8th',
#                   '9th', 'Assoc-acdm', 'Assoc-voc', 'Bachelors', 'Doctorate',
#                   'HS-grad', 'Masters', 'Preschool', 'Prof-school',
#                   'Some-college'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['Divorced', 'Married-AF-spouse', 'Married-civ-spouse',
#                   'Married-spouse-absent', 'Never-married', 'Separated',
#                   'Widowed'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['?', 'Adm-clerical', 'Armed-Forces', 'Craft-repair',
#                   'Exec-managerial', 'Farming-fishing', 'Handlers-cleaners',
#                   'Machine-op-inspct', 'Other-service', 'Priv-house-serv',
#                   'Prof-specialty', 'Protective-serv', 'Sales', 'Tech-support',
#                   'Transport-moving'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['Husband', 'Not-in-family', 'Other-relative', 'Own-child',
#                   'Unmarried', 'Wife'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['Amer-Indian-Eskimo', 'Asian-Pac-Islander', 'Black', 'Other',
#                   'White'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['Female', 'Male'], ordered=False, categories_dtype=object): 1, dtype('int16'): 1, CategoricalDtype(categories=['?', 'Cambodia', 'Canada', 'China', 'Columbia', 'Cuba',
#                   'Dominican-Republic', 'Ecuador', 'El-Salvador', 'England',
#                   'France', 'Germany', 'Greece', 'Guatemala', 'Haiti',
#                   'Holand-Netherlands', 'Honduras', 'Hong', 'Hungary', 'India',
#                   'Iran', 'Ireland', 'Italy', 'Jamaica', 'Japan', 'Laos',
#                   'Mexico', 'Nicaragua', 'Outlying-US(Guam-USVI-etc)', 'Peru',
#                   'Philippines', 'Poland', 'Portugal', 'Puerto-Rico',
#                   'Scotland', 'South', 'Taiwan', 'Thailand', 'Trinadad&Tobago',
#                   'United-States', 'Vietnam', 'Yugoslavia'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['<=50K', '>50K'], ordered=False, categories_dtype=object): 1}, 'syn': {dtype('int8'): 3, dtype('int32'): 2, CategoricalDtype(categories=['?', 'Federal-gov', 'Local-gov', 'Never-worked', 'Private',
#                   'Self-emp-inc', 'Self-emp-not-inc', 'State-gov',
#                   'Without-pay'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['10th', '11th', '12th', '7th-8th', '9th', 'Assoc-acdm',
#                   'Assoc-voc', 'Bachelors', 'Doctorate', 'HS-grad', 'Masters',
#                   'Prof-school', 'Some-college'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['Divorced', 'Married-AF-spouse', 'Married-civ-spouse',
#                   'Married-spouse-absent', 'Never-married', 'Separated',
#                   'Widowed'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['?', 'Adm-clerical', 'Armed-Forces', 'Craft-repair',
#                   'Exec-managerial', 'Farming-fishing', 'Handlers-cleaners',
#                   'Machine-op-inspct', 'Other-service', 'Priv-house-serv',
#                   'Prof-specialty', 'Protective-serv', 'Sales', 'Tech-support',
#                   'Transport-moving'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['Husband', 'Not-in-family', 'Other-relative', 'Own-child',
#                   'Unmarried', 'Wife'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['Amer-Indian-Eskimo', 'Asian-Pac-Islander', 'Black', 'Other',
#                   'White'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['Female', 'Male'], ordered=False, categories_dtype=object): 1, dtype('int16'): 1, CategoricalDtype(categories=['?', 'Cambodia', 'Canada', 'China', 'Columbia', 'Cuba',
#                   'Dominican-Republic', 'Ecuador', 'El-Salvador', 'England',
#                   'France', 'Germany', 'Greece', 'Guatemala', 'Haiti',
#                   'Honduras', 'Hong', 'Hungary', 'India', 'Iran', 'Ireland',
#                   'Italy', 'Jamaica', 'Japan', 'Laos', 'Mexico', 'Nicaragua',
#                   'Outlying-US(Guam-USVI-etc)', 'Peru', 'Philippines',
#                   'Poland', 'Portugal', 'Puerto-Rico', 'Scotland', 'South',
#                   'Taiwan', 'Thailand', 'Trinadad&Tobago', 'United-States',
#                   'Vietnam', 'Yugoslavia'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['<=50K', '>50K'], ordered=False, categories_dtype=object): 1}, 'control': {dtype('int8'): 3, dtype('int32'): 2, CategoricalDtype(categories=['?', 'Federal-gov', 'Local-gov', 'Never-worked', 'Private',
#                   'Self-emp-inc', 'Self-emp-not-inc', 'State-gov',
#                   'Without-pay'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['10th', '11th', '12th', '1st-4th', '5th-6th', '7th-8th',
#                   '9th', 'Assoc-acdm', 'Assoc-voc', 'Bachelors', 'Doctorate',
#                   'HS-grad', 'Masters', 'Preschool', 'Prof-school',
#                   'Some-college'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['Divorced', 'Married-AF-spouse', 'Married-civ-spouse',
#                   'Married-spouse-absent', 'Never-married', 'Separated',
#                   'Widowed'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['?', 'Adm-clerical', 'Armed-Forces', 'Craft-repair',
#                   'Exec-managerial', 'Farming-fishing', 'Handlers-cleaners',
#                   'Machine-op-inspct', 'Other-service', 'Priv-house-serv',
#                   'Prof-specialty', 'Protective-serv', 'Sales', 'Tech-support',
#                   'Transport-moving'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['Husband', 'Not-in-family', 'Other-relative', 'Own-child',
#                   'Unmarried', 'Wife'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['Amer-Indian-Eskimo', 'Asian-Pac-Islander', 'Black', 'Other',
#                   'White'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['Female', 'Male'], ordered=False, categories_dtype=object): 1, dtype('int16'): 1, CategoricalDtype(categories=['?', 'Cambodia', 'Canada', 'China', 'Columbia', 'Cuba',
#                   'Dominican-Republic', 'Ecuador', 'El-Salvador', 'England',
#                   'France', 'Germany', 'Greece', 'Guatemala', 'Haiti',
#                   'Holand-Netherlands', 'Honduras', 'Hong', 'Hungary', 'India',
#                   'Iran', 'Ireland', 'Italy', 'Jamaica', 'Japan', 'Laos',
#                   'Mexico', 'Nicaragua', 'Outlying-US(Guam-USVI-etc)', 'Peru',
#                   'Philippines', 'Poland', 'Portugal', 'Puerto-Rico',
#                   'Scotland', 'South', 'Taiwan', 'Thailand', 'Trinadad&Tobago',
#                   'United-States', 'Vietnam', 'Yugoslavia'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['<=50K', '>50K'], ordered=False, categories_dtype=object): 1}}, Columns by key: {'ori': ['age', 'workclass', 'fnlwgt', 'education', 'educational-num', 'marital-status', 'occupation', 'relationship', 'race', 'gender', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country', 'income'], 'syn': ['age', 'workclass', 'fnlwgt', 'education', 'educational-num', 'marital-status', 'occupation', 'relationship', 'race', 'gender', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country', 'income'], 'control': ['age', 'workclass', 'fnlwgt', 'education', 'educational-num', 'marital-status', 'occupation', 'relationship', 'race', 'gender', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country', 'income']}
# 2025-06-09 16:01:37,795 - PETsARD.EvaluatorOp   - _run              - DEBUG    - Data evaluating completed
# 2025-06-09 16:01:37,795 - PETsARD.EvaluatorOp   - run               - INFO     - Completed EvaluatorOp execution (elapsed: 0:00:01)
# 2025-06-09 16:01:37,796 - PETsARD.Executor      - run               - INFO     - Executing Reporter with output
# 2025-06-09 16:01:37,806 - PETsARD.ReporterOp    - run               - INFO     - Starting ReporterOp execution
# 2025-06-09 16:01:37,806 - PETsARD.ReporterOp    - _run              - DEBUG    - Starting data reporting process
# 2025-06-09 16:01:37,806 - PETsARD.ReporterOp    - _run              - DEBUG    - Reporting configuration initialization completed
# Now is petsard_Loader[log-data]_Splitter[demo_[1-1]]_Preprocessor[demo]_Synthesizer[demo] save to csv...
# 2025-06-09 16:01:38,111 - PETsARD.ReporterOp    - _run              - DEBUG    - Data reporting completed
# 2025-06-09 16:01:38,111 - PETsARD.ReporterOp    - run               - INFO     - Completed ReporterOp execution (elapsed: 0:00:00)
# 2025-06-09 16:01:38,112 - PETsARD.Executor      - _set_result       - DEBUG    - Collecting final results for Reporter
# 2025-06-09 16:01:38,113 - PETsARD.Executor      - run               - INFO     - Executing Reporter with save_report_global
# 2025-06-09 16:01:38,121 - PETsARD.ReporterOp    - run               - INFO     - Starting ReporterOp execution
# 2025-06-09 16:01:38,121 - PETsARD.ReporterOp    - _run              - DEBUG    - Starting data reporting process
# 2025-06-09 16:01:38,125 - PETsARD.ReporterOp    - _run              - DEBUG    - Reporting configuration initialization completed
# 2025-06-09 16:01:38,127 - PETsARD.ReporterOp    - _run              - DEBUG    - Data reporting completed
# 2025-06-09 16:01:38,127 - PETsARD.ReporterOp    - run               - INFO     - Completed ReporterOp execution (elapsed: 0:00:00)
# 2025-06-09 16:01:38,128 - PETsARD.Executor      - _set_result       - DEBUG    - Collecting final results for Reporter
# 2025-06-09 16:01:38,129 - PETsARD.Executor      - run               - INFO     - Completed PETsARD execution workflow (elapsed: 0:00:06)
# Now is petsard[Report]_[global] save to csv...

# %%
exec_case.get_result()[
    "Loader[log-data]_Splitter[demo_[1-1]]_Preprocessor[demo]_Synthesizer[demo]_Postprocessor[demo]_Evaluator[demo-quality]_Reporter[save_report_global]"
]["[global]"]
# Out:
#                                       full_expt_name    Loader    Splitter  \
# 0  Loader[log-data]_Splitter[demo_[1-1]]_Preproce...  log-data  demo_[1-1]
#
#   Preprocessor Synthesizer Postprocessor Evaluator    Score  Data Validity  \
# 0         demo        demo          demo  [global]  0.78296            1.0
#
#    Data Structure  Column Shapes  Column Pair Trends
# 0             1.0       0.951258            0.614662
