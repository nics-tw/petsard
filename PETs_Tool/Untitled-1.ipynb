# %%
import os
os.chdir('C:\\Users\\justyn.chen\\Desktop\\PETs-Experiment')
# os.chdir('D:\\Dropbox\\89_其他應用\\GitHub\\PETs-Experiment')

# reload during dev
from importlib import reload
import PETs_Tool
PETs_Tool = reload(PETs_Tool)


Loader = PETs_Tool.PETs_Loader('data/[Adt Income] adult.csv'
                              ,{'read_params': {'downcast'       : 'N'}
                               }
                              )
Describer = PETs_Tool.PETs_Describer(Loader ,{'test':'test'})
test = PETs_Tool.PETs_Desc_Reporter(Describer
                            ,{'report': 'Y'})
# Out:
# Filepath: data/[Adt Income] adult.csv
#
# Execute time: 2023-11-15 09:26:38.430864+08:00
#
# Columns: 15
# dtypes dict as below:
# {'age': 'int64',
#  'capital-gain': 'int64',
#  'capital-loss': 'int64',
#  'education': 'object',
#  'educational-num': 'int64',
#  'fnlwgt': 'int64',
#  'gender': 'object',
#  'hours-per-week': 'int64',
#  'income': 'object',
#  'marital-status': 'object',
#  'native-country': 'object',
#  'occupation': 'object',
#  'race': 'object',
#  'relationship': 'object',
#  'workclass': 'object'}
#
#
#
# Rows: 48842
#
# # Continue variable: 15
#
#                                       age     workclass        fnlwgt  \
# nobs                         48842.000000  48842.000000  4.884200e+04
# mean                            38.643585           NaN  1.896641e+05
# std                             13.710370           NaN  1.056029e+05
# min                             17.000000           NaN  1.228500e+04
# 25%                             28.000000           NaN  1.175505e+05
# 50%                             37.000000           NaN  1.781445e+05
# 75%                             48.000000           NaN  2.376420e+05
# max                             90.000000           NaN  1.490400e+06
# range                           73.000000           NaN  1.478115e+06
# mode_36_cnt                   1348.000000           NaN           NaN
# mode_36_per                      0.027599           NaN           NaN
# skew                             0.557563           NaN  1.438848e+00
# kurtosis                        -0.184373           NaN  6.057105e+00
# normal_p                         0.000000           NaN  0.000000e+00
# unique                                NaN      9.000000           NaN
# top_Private_freq                      NaN  33906.000000           NaN
# top_Private_per                       NaN      0.694198           NaN
# mode_203488_cnt                       NaN           NaN  2.100000e+01
# mode_203488_per                       NaN           NaN  4.299578e-04
# top_HS-grad_freq                      NaN           NaN           NaN
# top_HS-grad_per                       NaN           NaN           NaN
# mode_9_cnt                            NaN           NaN           NaN
# mode_9_per                            NaN           NaN           NaN
# top_Married-civ-spouse_freq           NaN           NaN           NaN
# top_Married-civ-spouse_per            NaN           NaN           NaN
# top_Prof-specialty_freq               NaN           NaN           NaN
# top_Prof-specialty_per                NaN           NaN           NaN
# top_Husband_freq                      NaN           NaN           NaN
# top_Husband_per                       NaN           NaN           NaN
# top_White_freq                        NaN           NaN           NaN
# top_White_per                         NaN           NaN           NaN
# top_Male_freq                         NaN           NaN           NaN
# top_Male_per                          NaN           NaN           NaN
# mode_0_cnt                            NaN           NaN           NaN
# mode_0_per                            NaN           NaN           NaN
# mode_40_cnt                           NaN           NaN           NaN
# mode_40_per                           NaN           NaN           NaN
# top_United-States_freq                NaN           NaN           NaN
# top_United-States_per                 NaN           NaN           NaN
# top_<=50K_freq                        NaN           NaN           NaN
# top_<=50K_per                         NaN           NaN           NaN
#
#                                 education  educational-num  marital-status  \
# nobs                         48842.000000     4.884200e+04    48842.000000
# mean                                  NaN     1.007809e+01             NaN
# std                                   NaN     2.570946e+00             NaN
# min                                   NaN     1.000000e+00             NaN
# 25%                                   NaN     9.000000e+00             NaN
# 50%                                   NaN     1.000000e+01             NaN
# 75%                                   NaN     1.200000e+01             NaN
# max                                   NaN     1.600000e+01             NaN
# range                                 NaN     1.500000e+01             NaN
# mode_36_cnt                           NaN              NaN             NaN
# mode_36_per                           NaN              NaN             NaN
# skew                                  NaN    -3.165151e-01             NaN
# kurtosis                              NaN     6.255584e-01             NaN
# normal_p                              NaN    2.770043e-272             NaN
# unique                          16.000000              NaN        7.000000
# top_Private_freq                      NaN              NaN             NaN
# top_Private_per                       NaN              NaN             NaN
# mode_203488_cnt                       NaN              NaN             NaN
# mode_203488_per                       NaN              NaN             NaN
# top_HS-grad_freq             15784.000000              NaN             NaN
# top_HS-grad_per                  0.323164              NaN             NaN
# mode_9_cnt                            NaN     1.578400e+04             NaN
# mode_9_per                            NaN     3.231645e-01             NaN
# top_Married-civ-spouse_freq           NaN              NaN    22379.000000
# top_Married-civ-spouse_per            NaN              NaN        0.458192
# top_Prof-specialty_freq               NaN              NaN             NaN
# top_Prof-specialty_per                NaN              NaN             NaN
# top_Husband_freq                      NaN              NaN             NaN
# top_Husband_per                       NaN              NaN             NaN
# top_White_freq                        NaN              NaN             NaN
# top_White_per                         NaN              NaN             NaN
# top_Male_freq                         NaN              NaN             NaN
# top_Male_per                          NaN              NaN             NaN
# mode_0_cnt                            NaN              NaN             NaN
# mode_0_per                            NaN              NaN             NaN
# mode_40_cnt                           NaN              NaN             NaN
# mode_40_per                           NaN              NaN             NaN
# top_United-States_freq                NaN              NaN             NaN
# top_United-States_per                 NaN              NaN             NaN
# top_<=50K_freq                        NaN              NaN             NaN
# top_<=50K_per                         NaN              NaN             NaN
#
#                                occupation  relationship          race  \
# nobs                         48842.000000  48842.000000  48842.000000
# mean                                  NaN           NaN           NaN
# std                                   NaN           NaN           NaN
# min                                   NaN           NaN           NaN
# 25%                                   NaN           NaN           NaN
# 50%                                   NaN           NaN           NaN
# 75%                                   NaN           NaN           NaN
# max                                   NaN           NaN           NaN
# range                                 NaN           NaN           NaN
# mode_36_cnt                           NaN           NaN           NaN
# mode_36_per                           NaN           NaN           NaN
# skew                                  NaN           NaN           NaN
# kurtosis                              NaN           NaN           NaN
# normal_p                              NaN           NaN           NaN
# unique                          15.000000      6.000000      5.000000
# top_Private_freq                      NaN           NaN           NaN
# top_Private_per                       NaN           NaN           NaN
# mode_203488_cnt                       NaN           NaN           NaN
# mode_203488_per                       NaN           NaN           NaN
# top_HS-grad_freq                      NaN           NaN           NaN
# top_HS-grad_per                       NaN           NaN           NaN
# mode_9_cnt                            NaN           NaN           NaN
# mode_9_per                            NaN           NaN           NaN
# top_Married-civ-spouse_freq           NaN           NaN           NaN
# top_Married-civ-spouse_per            NaN           NaN           NaN
# top_Prof-specialty_freq       6172.000000           NaN           NaN
# top_Prof-specialty_per           0.126367           NaN           NaN
# top_Husband_freq                      NaN  19716.000000           NaN
# top_Husband_per                       NaN      0.403669           NaN
# top_White_freq                        NaN           NaN  41762.000000
# top_White_per                         NaN           NaN      0.855043
# top_Male_freq                         NaN           NaN           NaN
# top_Male_per                          NaN           NaN           NaN
# mode_0_cnt                            NaN           NaN           NaN
# mode_0_per                            NaN           NaN           NaN
# mode_40_cnt                           NaN           NaN           NaN
# mode_40_per                           NaN           NaN           NaN
# top_United-States_freq                NaN           NaN           NaN
# top_United-States_per                 NaN           NaN           NaN
# top_<=50K_freq                        NaN           NaN           NaN
# top_<=50K_per                         NaN           NaN           NaN
#
#                                    gender  capital-gain  capital-loss  \
# nobs                         48842.000000  48842.000000  48842.000000
# mean                                  NaN   1079.067626     87.502314
# std                                   NaN   7451.942770    403.000427
# min                                   NaN      0.000000      0.000000
# 25%                                   NaN      0.000000      0.000000
# 50%                                   NaN      0.000000      0.000000
# 75%                                   NaN      0.000000      0.000000
# max                                   NaN  99999.000000   4356.000000
# range                                 NaN  99999.000000   4356.000000
# mode_36_cnt                           NaN           NaN           NaN
# mode_36_per                           NaN           NaN           NaN
# skew                                  NaN     11.894294      4.569669
# kurtosis                              NaN    152.677343     20.012174
# normal_p                              NaN      0.000000      0.000000
# unique                           2.000000           NaN           NaN
# top_Private_freq                      NaN           NaN           NaN
# top_Private_per                       NaN           NaN           NaN
# mode_203488_cnt                       NaN           NaN           NaN
# mode_203488_per                       NaN           NaN           NaN
# top_HS-grad_freq                      NaN           NaN           NaN
# top_HS-grad_per                       NaN           NaN           NaN
# mode_9_cnt                            NaN           NaN           NaN
# mode_9_per                            NaN           NaN           NaN
# top_Married-civ-spouse_freq           NaN           NaN           NaN
# top_Married-civ-spouse_per            NaN           NaN           NaN
# top_Prof-specialty_freq               NaN           NaN           NaN
# top_Prof-specialty_per                NaN           NaN           NaN
# top_Husband_freq                      NaN           NaN           NaN
# top_Husband_per                       NaN           NaN           NaN
# top_White_freq                        NaN           NaN           NaN
# top_White_per                         NaN           NaN           NaN
# top_Male_freq                32650.000000           NaN           NaN
# top_Male_per                     0.668482           NaN           NaN
# mode_0_cnt                            NaN  44807.000000  46560.000000
# mode_0_per                            NaN      0.917387      0.953278
# mode_40_cnt                           NaN           NaN           NaN
# mode_40_per                           NaN           NaN           NaN
# top_United-States_freq                NaN           NaN           NaN
# top_United-States_per                 NaN           NaN           NaN
# top_<=50K_freq                        NaN           NaN           NaN
# top_<=50K_per                         NaN           NaN           NaN
#
#                              hours-per-week  native-country        income
# nobs                           48842.000000    48842.000000  48842.000000
# mean                              40.422382             NaN           NaN
# std                               12.391317             NaN           NaN
# min                                1.000000             NaN           NaN
# 25%                               40.000000             NaN           NaN
# 50%                               40.000000             NaN           NaN
# 75%                               45.000000             NaN           NaN
# max                               99.000000             NaN           NaN
# range                             98.000000             NaN           NaN
# mode_36_cnt                             NaN             NaN           NaN
# mode_36_per                             NaN             NaN           NaN
# skew                               0.238742             NaN           NaN
# kurtosis                           2.950634             NaN           NaN
# normal_p                           0.000000             NaN           NaN
# unique                                  NaN       42.000000      2.000000
# top_Private_freq                        NaN             NaN           NaN
# top_Private_per                         NaN             NaN           NaN
# mode_203488_cnt                         NaN             NaN           NaN
# mode_203488_per                         NaN             NaN           NaN
# top_HS-grad_freq                        NaN             NaN           NaN
# top_HS-grad_per                         NaN             NaN           NaN
# mode_9_cnt                              NaN             NaN           NaN
# mode_9_per                              NaN             NaN           NaN
# top_Married-civ-spouse_freq             NaN             NaN           NaN
# top_Married-civ-spouse_per              NaN             NaN           NaN
# top_Prof-specialty_freq                 NaN             NaN           NaN
# top_Prof-specialty_per                  NaN             NaN           NaN
# top_Husband_freq                        NaN             NaN           NaN
# top_Husband_per                         NaN             NaN           NaN
# top_White_freq                          NaN             NaN           NaN
# top_White_per                           NaN             NaN           NaN
# top_Male_freq                           NaN             NaN           NaN
# top_Male_per                            NaN             NaN           NaN
# mode_0_cnt                              NaN             NaN           NaN
# mode_0_per                              NaN             NaN           NaN
# mode_40_cnt                    22803.000000             NaN           NaN
# mode_40_per                        0.466873             NaN           NaN
# top_United-States_freq                  NaN    43832.000000           NaN
# top_United-States_per                   NaN        0.897424           NaN
# top_<=50K_freq                          NaN             NaN  37155.000000
# top_<=50K_per                           NaN             NaN      0.760718
#
#
#
# There's no missing in Continue variable.
