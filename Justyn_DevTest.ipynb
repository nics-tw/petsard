# %% [markdown]
# 1. 測試 PETs_Loader > Describer > Desc_Reporter

# %%
import os
# os.chdir('C:\\Users\\justyn.chen\\Desktop\\PETs-Experiment')
os.chdir('D:\\Dropbox\\89_其他應用\\GitHub\\PETs-Experiment')

# reload during dev
from importlib import reload
import PETs_Tool
PETs_Tool = reload(PETs_Tool)

Loader = PETs_Tool.PETs_Loader('data/[Adt Income] adult.csv'
                              ,{'filename'   : '[Adt Income]'
                               ,'read_params': {'downcast' : 'Y'}
                               }
                              )
Describer     = PETs_Tool.PETs_Describer(Loader
                                        ,{'describe_params' : {'dist_fitting' : 'Y'
                                                              ,'correlation'  : 'Y'
                                                              ,'collinearity' : 'Y'
                                                              ,'missing_level': {'data': {'?'}}
                                                              }
                                         }
                                        )
Desc_Reporter = PETs_Tool.PETs_Desc_Reporter(Describer
                                            ,{'report': 'Y'
                                             ,'report_params' : {'print_report'  : 'Y'
                                                                ,'save_report'   : 'Y'
                                                                ,'save_filename' : '[Adt Income]'
                                                                }
                                             }
                                            )
# Out:
# Filepath: data/[Adt Income] adult.csv
#
# Execute time: 2023-11-15 16:53:15.583451+08:00
#
# Columns: 15
# dtypes dict as below:
# {'age': 'int8',
#  'capital-gain': 'int32',
#  'capital-loss': 'int16',
#  'education': 'category',
#  'educational-num': 'int8',
#  'fnlwgt': 'int32',
#  'gender': 'category',
#  'hours-per-week': 'int8',
#  'income': 'category',
#  'marital-status': 'category',
#  'native-country': 'category',
#  'occupation': 'category',
#  'race': 'category',
#  'relationship': 'category',
#  'workclass': 'category'}
#
#
#
# Rows: 48842
#
# # Continue variable: 6
#
#                                                 age                   fnlwgt  \
# nobs                                          48842                    48842
# mean                                      38.643585            189664.134597
# std                                        13.71037             105602.94434
# min                                              17                    12285
# ...

# %% [markdown]
# 2. 測試 SDV：

# %%
import os
# os.chdir('C:\\Users\\justyn.chen\\Desktop\\PETs-Experiment')
os.chdir('D:\\Dropbox\\89_其他應用\\GitHub\\PETs-Experiment')

# reload during dev
from importlib import reload
import PETs_Tool
PETs_Tool = reload(PETs_Tool)


Loader = PETs_Tool.PETs_Loader('data/[Adt Income] adult.csv'
                              ,{'filename'   : '[Adt Income]'
                               ,'read_params': {'downcast' : 'Y'}
                               }
                              )
SDer = PETs_Tool.PETs_SD_SDV(Loader
                            ,{'sample' : 'Y'})
SDer = PETs_Tool.PETs_SD_SDV(SDer
                            ,{'sample' : 'Y'
                             ,'sample_params' : {'sample_rows': 101}
                             })
# Out:
# Metafile loading time: 0.038 sec.
# We are execute SingleTable - GaussianCoupula.
# Model training time: 22.3549 sec.
# Sample # 100 rows data by GaussianCoupula in 0.1321 秒
# Sample # 101 rows data by GaussianCoupula in 0.069 秒

# %% [markdown]
# 3. 測試 df_bootstrap

# %%
import os
# os.chdir('C:\\Users\\justyn.chen\\Desktop\\PETs-Experiment')
os.chdir('D:\\Dropbox\\89_其他應用\\GitHub\\PETs-Experiment')

# reload during dev
from importlib import reload
import PETs_Tool
PETs_Tool = reload(PETs_Tool)

folder_raw = '.\\data'
filename_raw = '[Adt Income] adult.csv'
data = PETs_Tool.PETs_Loader(os.path.join(folder_raw ,filename_raw)).data

PETs_Tool.PETs_util.df_bootstrap(data ,{'bootstrap_params' : {'bootstrap_time' : 30
                                                             ,'sample_ratio'   : 0.8
                                                             ,'random_state'   : None
                                                             }
                                        ,'index_params' : {'index_save'      : 'Y'
                                                          ,'index_save_data' : 'Y'
                                                          }
                                        }
                                )
# Out:
# Bootstrap df: 30 times is done.
# Bootstrap df: indexes with data save in Boostrap_20231116_143243_Asia_Taipei.pkl.
# ({'data':        age     workclass  fnlwgt     education  educational-num  \
#   0       25       Private  226802          11th                7
#   1       38       Private   89814       HS-grad                9
#   2       28     Local-gov  336951    Assoc-acdm               12
#   3       44       Private  160323  Some-college               10
#   4       18             ?  103497  Some-college               10
#   ...    ...           ...     ...           ...              ...
#   48837   27       Private  257302    Assoc-acdm               12
#   48838   40       Private  154374       HS-grad                9
#   48839   58       Private  151910       HS-grad                9
#   48840   22       Private  201490       HS-grad                9
#   48841   52  Self-emp-inc  287927       HS-grad                9
#
# ...

# %%
dict_PETs_setting = {'adult' : {'filename'    : '[Adult]'
                               ,'read_params' : {'downcast' : 'Y'}
                               ,'describe_params' : {'data': {'?'}}
                               }
                    }
dict_filename = {'adult': {'raw' : '[Adt Income] adult.csv'
                          }
                }
dict_filename = {key: {**value, 'params': dict_PETs_setting.get(key, {})} 
                 for key, value in dict_filename.items()}
# print(dict_filename)



# update default in SDV
list_adult_SD_SDV_train = ['CoupulaGAN'
                          ,'CTGAN'
                          ,'GaussianCoupula'
                          ,'TVAE'
                          ]
dict_adult_SD_SDV_train = {k: {'sd_params': {'model': k}} for k in list_adult_SD_SDV_train}
dict_filename = {key: PETs_Tool.PETs_util.update_append_nested(value
                                                              ,{'SD_train': dict_adult_SD_SDV_train}
                                                              ) 
                 for key, value in dict_filename.items()}
dict_adult_SD_SDV_train_default = {'sd_params': {'save_model': 'N'}
                                  ,'sample'   : 'N'
                                  ,'sample_params' : {'sample_rows_as_raw' : 'Y'}
                                  }
dict_adult_SD_train = {'SDV' : PETs_Tool.PETs_util.update_append_nested(dict_adult_SD_SDV_train_default
                                                                       ,dict_adult_SD_SDV_train.get(key ,{})
                                                                       )
                       for key in dict_adult_SD_SDV_train
                      }
dict_filename = {k1: {k2: dict_adult_SD_train if k2 == 'SD_train' else v2
                      for k2 ,v2 in dict_filename[k1].items()
                     } 
                 for k1 in dict_filename
                }
print(dict_filename)


# import json
# print(json.dumps(dict_adult_SD_SDV_train ,indent=4))
# Out:
# {'adult': {'raw': '[Adt Income] adult.csv', 'params': {'filename': '[Adult]', 'read_params': {'downcast': 'Y'}, 'describe_params': {'data': {'?'}}}, 'SD_train': {'SDV': {'sd_params': {'save_model': 'N', 'model': 'TVAE'}, 'sample': 'N', 'sample_params': {'sample_rows_as_raw': 'Y'}}}}}
